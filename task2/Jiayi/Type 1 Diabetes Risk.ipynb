# %% [markdown]
# # 1. Basic setup

# %%
import os
import sys

sys.path.append('..')
from utils import *

USER = "Jiayi"
DATA_ROOT = '/Users/legion/Desktop/Courses/IS389/data'   
OUTPUT_ROOT = '/Users/legion/Desktop/Courses/IS389/output2'
TRAIT = 'Type 1 Diabetes Risk'

OUTPUT_DIR = os.path.join(OUTPUT_ROOT, USER, '-'.join(TRAIT.split()))
JSON_PATH = os.path.join(OUTPUT_DIR, "cohort_info.json")
if not os.path.exists(OUTPUT_DIR):
    os.makedirs(OUTPUT_DIR, exist_ok=True)
# Out:
# utils.py has been loaded

# %% [markdown]
# ## The GEO dataset

# %%
dataset = 'GEO'
trait_subdir = "Type-1-Diabetes-Risk"

trait_path = os.path.join(DATA_ROOT, dataset, trait_subdir)
os.listdir(trait_path)
# Out:
# ['GSE30208',
#  'GSE30209',
#  'GSE30210',
#  'GSE43488',
#  'GSE51058',
#  'GSE52724',
#  'GSE75062']

# %% [markdown]
# Repeat the below steps for all the accession numbers

# %%
# Finished
cohort = accession_num = "GSE30208"
cohort_dir = os.path.join(trait_path, accession_num)
soft_file, matrix_file = geo_get_relevant_filepaths(cohort_dir)
soft_file, matrix_file
# Out:
# ('/Users/legion/Desktop/Courses/IS389/data\\GEO\\Type-1-Diabetes-Risk\\GSE30208\\GSE30208_family.soft.gz',
#  '/Users/legion/Desktop/Courses/IS389/data\\GEO\\Type-1-Diabetes-Risk\\GSE30208\\GSE30208_series_matrix.txt.gz')

# %%
# Finished
cohort = accession_num = "GSE30209"
cohort_dir = os.path.join(trait_path, accession_num)
soft_file, matrix_file = geo_get_relevant_filepaths(cohort_dir)
soft_file, matrix_file
# Out:
# ('/Users/legion/Desktop/Courses/IS389/data\\GEO\\Type-1-Diabetes-Risk\\GSE30209\\GSE30209_family.soft.gz',
#  '/Users/legion/Desktop/Courses/IS389/data\\GEO\\Type-1-Diabetes-Risk\\GSE30209\\GSE30209_series_matrix.txt.gz')

# %%
# Finished
cohort = accession_num = "GSE30210"
cohort_dir = os.path.join(trait_path, accession_num)
soft_file, matrix_file = geo_get_relevant_filepaths(cohort_dir)
soft_file, matrix_file
# Out:
# ('/Users/legion/Desktop/Courses/IS389/data\\GEO\\Type-1-Diabetes-Risk\\GSE30210\\GSE30210_family.soft.gz',
#  '/Users/legion/Desktop/Courses/IS389/data\\GEO\\Type-1-Diabetes-Risk\\GSE30210\\GSE30210_series_matrix.txt.gz')

# %%
# Finished
cohort = accession_num = "GSE43488"
cohort_dir = os.path.join(trait_path, accession_num)
soft_file, matrix_file = geo_get_relevant_filepaths(cohort_dir)
soft_file, matrix_file
# Out:
# ('/Users/legion/Desktop/Courses/IS389/data\\GEO\\Type-1-Diabetes-Risk\\GSE43488\\GSE43488_family.soft.gz',
#  '/Users/legion/Desktop/Courses/IS389/data\\GEO\\Type-1-Diabetes-Risk\\GSE43488\\GSE43488_series_matrix.txt.gz')

# %%
# Finished
cohort = accession_num = "GSE51058"
cohort_dir = os.path.join(trait_path, accession_num)
soft_file, matrix_file = geo_get_relevant_filepaths(cohort_dir)
soft_file, matrix_file
# Out:
# ('/Users/legion/Desktop/Courses/IS389/data\\GEO\\Type-1-Diabetes-Risk\\GSE51058\\GSE51058_family.soft.gz',
#  '/Users/legion/Desktop/Courses/IS389/data\\GEO\\Type-1-Diabetes-Risk\\GSE51058\\GSE51058_series_matrix.txt.gz')

# %%
# No obvious trait
cohort = accession_num = "GSE52724"
cohort_dir = os.path.join(trait_path, accession_num)
soft_file, matrix_file = geo_get_relevant_filepaths(cohort_dir)
soft_file, matrix_file
# Out:
# ('/Users/legion/Desktop/Courses/IS389/data\\GEO\\Type-1-Diabetes-Risk\\GSE52724\\GSE52724_family.soft.gz',
#  '/Users/legion/Desktop/Courses/IS389/data\\GEO\\Type-1-Diabetes-Risk\\GSE52724\\GSE52724_series_matrix.txt.gz')

# %%
# Finished
cohort = accession_num = "GSE75062"
cohort_dir = os.path.join(trait_path, accession_num)
soft_file, matrix_file = geo_get_relevant_filepaths(cohort_dir)
soft_file, matrix_file
# Out:
# ('/Users/legion/Desktop/Courses/IS389/data\\GEO\\Type-1-Diabetes-Risk\\GSE75062\\GSE75062_family.soft.gz',
#  '/Users/legion/Desktop/Courses/IS389/data\\GEO\\Type-1-Diabetes-Risk\\GSE75062\\GSE75062_series_matrix.txt.gz')

# %% [markdown]
# ### Initial filtering and clinical data preprocessing

# %%
from utils import *
background_prefixes = ['!Series_title', '!Series_summary', '!Series_overall_design']
clinical_prefixes = ['!Sample_geo_accession', '!Sample_characteristics_ch1']    

background_info, clinical_data = get_background_and_clinical_data(matrix_file, background_prefixes, clinical_prefixes)
print(background_info)
# Out:
# !Series_title	"Discovery and validation of a gene expression profile for human islet integrity and transplant functionality"
# !Series_summary	"There is growing evidence that transplantation of cadaveric human islets is an effective therapy for type 1 diabetes. However, gauging the suitability of islet samples for clinical use remains a challenge. We hypothesized that islet quality is reflected in the expression of specific genes. Therefore, gene expression in 59 human islet preparations was analyzed and correlated with diabetes reversal after transplantation in diabetic mice. Analysis yielded 262 differentially expressed probesets, which together predict islet quality with 83% accuracy. Pathway analysis revealed that failing islet preparations activated inflammatory pathways, while functional islets showed increased regeneration pathway gene expression. Gene expression associated with apoptosis and oxygen consumption showed little overlap with each other or with the 262 probeset classifier, indicating that the three tests are measuring different aspects of islet cell biology. A subset of 36 probesets surpassed the predictive accuracy of the entire set for reversal of diabetes, and was further reduced by logistic regression to sets of 14 and 5 without losing accuracy. These genes were further validated with an independent cohort of 16 samples. We believe this limited number of gene classifiers in combination with other tests may provide complementary verification of islet quality prior to their clinical use."
# !Series_overall_design	"Microarray profiles of 59 human islet preparations were compared between three data sets using class comparisons, network and biological function analyses. Specific genes were validated by quantitative PCR and immunopathology. Clinical findings were also compared."

# %%
clinical_data.head()
# Out:
#          !Sample_geo_accession                     GSM1941673  \
# 0  !Sample_characteristics_ch1  diabetes reversal status: Yes
# 1  !Sample_characteristics_ch1               tissue: pancreas
# 2  !Sample_characteristics_ch1         cell type: islet cells
#
#                      GSM1941674                     GSM1941675  \
# 0  diabetes reversal status: No  diabetes reversal status: Yes
# 1              tissue: pancreas               tissue: pancreas
# 2        cell type: islet cells         cell type: islet cells
#
#                      GSM1941676                    GSM1941677  \
# 0  diabetes reversal status: No  diabetes reversal status: No
# 1              tissue: pancreas              tissue: pancreas
# 2        cell type: islet cells        cell type: islet cells
#
#                      GSM1941678                    GSM1941679  \
# 0  diabetes reversal status: No  diabetes reversal status: No
# 1              tissue: pancreas              tissue: pancreas
# 2        cell type: islet cells        cell type: islet cells
#
#                       GSM1941680                     GSM1941681  ...  \
# 0  diabetes reversal status: Yes  diabetes reversal status: Yes  ...
# 1               tissue: pancreas               tissue: pancreas  ...
# 2         cell type: islet cells         cell type: islet cells  ...
#
#                       GSM1941722                    GSM1941723  \
# 0  diabetes reversal status: Yes  diabetes reversal status: No
# 1               tissue: pancreas              tissue: pancreas
# 2         cell type: islet cells        cell type: islet cells
#
#                       GSM1941724                     GSM1941725  \
# 0  diabetes reversal status: Yes  diabetes reversal status: Yes
# 1               tissue: pancreas               tissue: pancreas
# 2         cell type: islet cells         cell type: islet cells
#
#                       GSM1941726                    GSM1941727  \
# 0  diabetes reversal status: Yes  diabetes reversal status: No
# 1               tissue: pancreas              tissue: pancreas
# 2         cell type: islet cells        cell type: islet cells
#
#                      GSM1941728                     GSM1941729  \
# 0  diabetes reversal status: No  diabetes reversal status: Yes
# 1              tissue: pancreas               tissue: pancreas
# 2        cell type: islet cells         cell type: islet cells
#
#                       GSM1941730                     GSM1941731
# 0  diabetes reversal status: Yes  diabetes reversal status: Yes
# 1               tissue: pancreas               tissue: pancreas
# 2         cell type: islet cells         cell type: islet cells
#
# [3 rows x 60 columns]

# %% [markdown]
# Analyze the trait row:

# %%
tumor_stage_row = clinical_data.iloc[0]
tumor_stage_row.unique()
# Out:
# array(['!Sample_characteristics_ch1', 'diabetes reversal status: Yes',
#        'diabetes reversal status: No'], dtype=object)

# %% [markdown]
# Determine the trait row, age row, and gender row. Then implement the conversion functions:

# %%
trait_row = 0
age_row = None
gender_row = None

def convert_trait(trait):
    # Check if the trait indicates a normal disease status
    if (trait == 'diabetes reversal status: Yes'):
        return 0
    else:
        return 1


def convert_age(age_string):
    if age_string.lower() == 'n.a.':
        return None
    try:
        age = int(age_string.split(':')[1])/12
        age = round(age, 0)
        return age
    except (ValueError, IndexError):
        return None

def convert_gender(gender_string):
    if (gender_string.lower() == 'sex: female' or gender_string.lower() == 'sex: f' or gender_string.lower() == 'gender: female' or gender_string.lower() == 'gender: f'):
        return 1
    elif (gender_string.lower() == 'sex: male' or gender_string.lower() == 'sex: m' or gender_string.lower() == 'gender: male' or gender_string.lower() == 'gender: m') :  # changeed 
        return 0
    else:
        return None

# %% [markdown]
# Check the processed clinical data:

# %%
selected_clinical_data = geo_select_clinical_features(clinical_data, TRAIT, trait_row, convert_trait, age_row=age_row,
                                                      convert_age=convert_age, gender_row=gender_row,
                                                      convert_gender=convert_gender)
selected_clinical_data.head()
# Out:
# c:\Users\legion\Desktop\TAIS_2024SP\TAIS_2024SP\task2\Jiayi\utils.py:218: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   clinical_df = clinical_df.applymap(convert_fn)
#                       GSM1941673  GSM1941674  GSM1941675  GSM1941676  \
# Type 1 Diabetes Risk           0           1           0           1
#
#                       GSM1941677  GSM1941678  GSM1941679  GSM1941680  \
# Type 1 Diabetes Risk           1           1           1           0
#
#                       GSM1941681  GSM1941682  ...  GSM1941722  GSM1941723  \
# Type 1 Diabetes Risk           0           0  ...           0           1
#
#                       GSM1941724  GSM1941725  GSM1941726  GSM1941727  \
# Type 1 Diabetes Risk           0           0           0           1
#
#                       GSM1941728  GSM1941729  GSM1941730  GSM1941731
# Type 1 Diabetes Risk           1           0           0           0
#
# [1 rows x 59 columns]

# %% [markdown]
# ### Genetic data preprocessing and final filtering

# %% [markdown]
# Check the genetic data:

# %%
genetic_data = get_genetic_data(matrix_file)
genetic_data.head()
# Out:
#            GSM1941673  GSM1941674  GSM1941675  GSM1941676  GSM1941677  \
# ID
# 1007_s_at      10.659      10.776      10.588      10.507      10.563
# 1053_at         7.033       7.015       6.266       6.870       6.923
# 117_at          8.983       8.647      11.663      11.283      11.860
# 121_at          8.858       8.916       8.856       9.008       9.007
# 1255_g_at       2.859       2.941       2.638       2.549       2.882
#
#            GSM1941678  GSM1941679  GSM1941680  GSM1941681  GSM1941682  ...  \
# ID                                                                     ...
# 1007_s_at      10.495      10.597      10.385      10.214      10.747  ...
# 1053_at         6.708       6.910       6.334       7.019       6.874  ...
# 117_at         12.592       7.502       9.174      10.405      10.761  ...
# 121_at          8.926       8.822       9.233       9.190       8.894  ...
# 1255_g_at       2.937       2.769       2.881       2.889       2.788  ...
#
#            GSM1941722  GSM1941723  GSM1941724  GSM1941725  GSM1941726  \
# ID
# 1007_s_at      10.725      10.828      10.923      11.239      11.081
# 1053_at         6.822       6.886       6.925       6.660       6.713
# 117_at          7.666       8.209       6.542       7.107       7.658
# 121_at          8.802       8.793       8.775       8.246       8.703
# 1255_g_at       2.780       2.735       2.651       2.766       2.788
#
#            GSM1941727  GSM1941728  GSM1941729  GSM1941730  GSM1941731
# ID
# 1007_s_at      11.075      10.337      10.707      10.639      10.823
# 1053_at         6.993       6.994       6.933       6.847       6.909
# 117_at          8.295       7.060       7.349       9.351       7.000
# 121_at          8.569       8.987       8.598       8.680       8.405
# 1255_g_at       2.720       2.791       2.674       2.628       2.513
#
# [5 rows x 59 columns]

# %% [markdown]
# Check if the gene dataset requires mapping to get the gene symbols corresponding to each data row.

# %%
requires_gene_mapping = True

if requires_gene_mapping:
    gene_annotation = get_gene_annotation(soft_file)
    gene_annotation_summary = preview_df(gene_annotation)
    print(gene_annotation_summary)

gene_annotation.columns
# Out:
# {'ID': ['1007_s_at', '1053_at', '117_at', '121_at', '1255_g_at'], 'GB_ACC': ['U48705', 'M87338', 'X51757', 'X69699', 'L36861'], 'SPOT_ID': [nan, nan, nan, nan, nan], 'Species Scientific Name': ['Homo sapiens', 'Homo sapiens', 'Homo sapiens', 'Homo sapiens', 'Homo sapiens'], 'Annotation Date': ['Oct 6, 2014', 'Oct 6, 2014', 'Oct 6, 2014', 'Oct 6, 2014', 'Oct 6, 2014'], 'Sequence Type': ['Exemplar sequence', 'Exemplar sequence', 'Exemplar sequence', 'Exemplar sequence', 'Exemplar sequence'], 'Sequence Source': ['Affymetrix Proprietary Database', 'GenBank', 'Affymetrix Proprietary Database', 'GenBank', 'Affymetrix Proprietary Database'], 'Target Description': ['U48705 /FEATURE=mRNA /DEFINITION=HSU48705 Human receptor tyrosine kinase DDR gene, complete cds', 'M87338 /FEATURE= /DEFINITION=HUMA1SBU Human replication factor C, 40-kDa subunit (A1) mRNA, complete cds', "X51757 /FEATURE=cds /DEFINITION=HSP70B Human heat-shock protein HSP70B' gene", 'X69699 /FEATURE= /DEFINITION=HSPAX8A H.sapiens Pax8 mRNA', 'L36861 /FEATURE=expanded_cds /DEFINITION=HUMGCAPB Homo sapiens guanylate cyclase activating protein (GCAP) gene exons 1-4, complete cds'], 'Representative Public ID': ['U48705', 'M87338', 'X51757', 'X69699', 'L36861'], 'Gene Title': ['discoidin domain receptor tyrosine kinase 1 /// microRNA 4640', 'replication factor C (activator 1) 2, 40kDa', "heat shock 70kDa protein 6 (HSP70B')", 'paired box 8', 'guanylate cyclase activator 1A (retina)'], 'Gene Symbol': ['DDR1 /// MIR4640', 'RFC2', 'HSPA6', 'PAX8', 'GUCA1A'], 'ENTREZ_GENE_ID': ['780 /// 100616237', '5982', '3310', '7849', '2978'], 'RefSeq Transcript ID': ['NM_001202521 /// NM_001202522 /// NM_001202523 /// NM_001954 /// NM_013993 /// NM_013994 /// NR_039783 /// XM_005249385 /// XM_005249386 /// XM_005249387 /// XM_005249389 /// XM_005272873 /// XM_005272874 /// XM_005272875 /// XM_005272877 /// XM_005275027 /// XM_005275028 /// XM_005275030 /// XM_005275031 /// XM_005275162 /// XM_005275163 /// XM_005275164 /// XM_005275166 /// XM_005275457 /// XM_005275458 /// XM_005275459 /// XM_005275461 /// XM_006715185 /// XM_006715186 /// XM_006715187 /// XM_006715188 /// XM_006715189 /// XM_006715190 /// XM_006725501 /// XM_006725502 /// XM_006725503 /// XM_006725504 /// XM_006725505 /// XM_006725506 /// XM_006725714 /// XM_006725715 /// XM_006725716 /// XM_006725717 /// XM_006725718 /// XM_006725719 /// XM_006725720 /// XM_006725721 /// XM_006725722 /// XM_006725827 /// XM_006725828 /// XM_006725829 /// XM_006725830 /// XM_006725831 /// XM_006725832 /// XM_006726017 /// XM_006726018 /// XM_006726019 /// XM_006726020 /// XM_006726021 /// XM_006726022 /// XR_427836 /// XR_430858 /// XR_430938 /// XR_430974 /// XR_431015', 'NM_001278791 /// NM_001278792 /// NM_001278793 /// NM_002914 /// NM_181471 /// XM_006716080', 'NM_002155', 'NM_003466 /// NM_013951 /// NM_013952 /// NM_013953 /// NM_013992', 'NM_000409 /// XM_006715073'], 'Gene Ontology Biological Process': ['0001558 // regulation of cell growth // inferred from electronic annotation /// 0001952 // regulation of cell-matrix adhesion // inferred from electronic annotation /// 0006468 // protein phosphorylation // inferred from electronic annotation /// 0007155 // cell adhesion // traceable author statement /// 0007169 // transmembrane receptor protein tyrosine kinase signaling pathway // inferred from electronic annotation /// 0007565 // female pregnancy // inferred from electronic annotation /// 0007566 // embryo implantation // inferred from electronic annotation /// 0007595 // lactation // inferred from electronic annotation /// 0008285 // negative regulation of cell proliferation // inferred from electronic annotation /// 0010715 // regulation of extracellular matrix disassembly // inferred from mutant phenotype /// 0014909 // smooth muscle cell migration // inferred from mutant phenotype /// 0016310 // phosphorylation // inferred from electronic annotation /// 0018108 // peptidyl-tyrosine phosphorylation // inferred from electronic  ...
# Index(['ID', 'GB_ACC', 'SPOT_ID', 'Species Scientific Name', 'Annotation Date',
#        'Sequence Type', 'Sequence Source', 'Target Description',
#        'Representative Public ID', 'Gene Title', 'Gene Symbol',
#        'ENTREZ_GENE_ID', 'RefSeq Transcript ID',
#        'Gene Ontology Biological Process', 'Gene Ontology Cellular Component',
#        'Gene Ontology Molecular Function'],
#       dtype='object')

# %%
if requires_gene_mapping:
    identifier_key = 'ID'
    gene_symbol_key = 'Gene Symbol'
    gene_mapping = get_gene_mapping(gene_annotation, identifier_key, gene_symbol_key)
    genetic_data = apply_gene_mapping(genetic_data, gene_mapping)

# %%
genetic_data = normalize_gene_symbols_in_index(genetic_data)
genetic_data
# Out:
#           GSM1941673  GSM1941674  GSM1941675  GSM1941676  GSM1941677  \
# A1BG        7.201000    7.528000    6.962000    6.682000    6.961000
# A1BG-AS1    6.269000    5.975000    5.972000    5.924000    5.752000
# A1CF        7.430000    7.149000    7.426000    7.448000    7.631000
# A2M         7.085000    7.499000    7.868000    7.738500    7.507000
# A2M-AS1     5.328000    5.207000    5.470000    4.705000    5.111000
# ...              ...         ...         ...         ...         ...
# ZYG11A      5.453000    5.181000    5.453000    5.137000    5.238000
# ZYG11B      8.542000    8.052667    8.202667    7.655333    7.581000
# ZYX         7.078500    7.672500    6.933000    7.397500    7.695500
# GSM1941703  6.885333   5.316  8.142000  7.0020  6.260667  8.8225
# GSM1941704  6.769833   5.009  8.069667  6.7740  6.258667  8.8620
# GSM1941705  6.920000   5.474  8.103667  6.7375  6.530000  8.8950
# GSM1941706  6.837333   5.378  8.306333  6.2580  6.483667  9.0790
# GSM1941707  6.644333   5.468  7.837333  7.1305  6.723000  8.7490
# GSM1941708  6.799000   5.216  8.071000  6.5230  6.413000  8.6695
# GSM1941709  6.948500   5.566  7.891000  7.3150  6.402333  8.3550
# GSM1941710  7.093667   5.563  8.015000  6.9110  6.721667  8.6195
# GSM1941711  7.086667   5.647  8.177333  6.6255  6.389333  9.3735
# GSM1941712  7.100167   5.422  8.456000  6.4865  6.780000  9.8705
# GSM1941713  6.713333   5.355  7.811333  6.5210  6.349333  8.8465
# GSM1941714  6.997000   5.295  8.518667  6.5440  6.623333  9.4495
# GSM1941715  6.971833   5.323  8.440000  6.5910  6.498667  9.1330
# GSM1941716  6.743000   5.172  7.931667  6.5690  6.312667  8.2795
# GSM1941717  6.789833   5.245  8.013000  6.8595  6.130333  8.4545
# GSM1941718  6.721500   5.045  7.969333  6.8540  6.292333  8.3720
# GSM1941719  6.598500   5.032  7.980333  7.3350  6.298333  8.2975
# GSM1941720  6.700667   5.280  8.008667  6.6185  6.325000  8.4695
# GSM1941721  6.834333   5.470  8.140333  6.6025  6.565333  8.8495
# GSM1941722  6.691333   5.125  8.290667  6.6475  6.301667  8.6535
# GSM1941723  6.725333   5.090  8.227333  6.5710  6.241000  8.6780
# GSM1941724  6.987167   5.284  8.304333  6.5885  6.406000  9.5120
# GSM1941725  6.843000   5.366  7.989000  6.5720  6.406667  8.7395
# GSM1941726  6.644167   5.369  8.087000  6.2750  6.169333  8.5920
# GSM1941727  6.704667   5.056  7.951000  6.6430  6.437667  8.7950
# GSM1941728  6.673833   5.064  7.847333  6.8025  6.290000  8.4955
# GSM1941729  6.870833   5.519  8.131000  6.4415  6.633667  9.2700
# GSM1941730  6.962500   5.440  8.042000  6.7890  6.619333  9.2140
# GSM1941731  6.896167   5.253  8.066000  7.2155  6.931333  9.3145
#
# [59 rows x 17858 columns]

# %% [markdown]
# Check if the merged data biased or not:

# %%
trait_type = 'binary'
print(f"The merged dataset contains {len(merged_data)} samples.")
is_trait_biased, merged_data = judge_and_remove_biased_features(merged_data, TRAIT, trait_type=trait_type)
is_trait_biased
# Out:
# The merged dataset contains 59 samples.
# For the feature 'Type 1 Diabetes Risk', the least common label is '1.0' with 24 occurrences. This represents 40.68% of the dataset.
# The distribution of the feature 'Type 1 Diabetes Risk' in this dataset is fine.
# False

# %% [markdown]
# Save the data as a csv file:

# %%
if is_available:
    save_cohort_info(cohort, JSON_PATH, is_available, is_trait_biased, merged_data, note='')
else:
    save_cohort_info(cohort, JSON_PATH, is_available)
merged_data.head()
if not is_trait_biased:
    merged_data.to_csv(os.path.join(OUTPUT_DIR, cohort + '.csv'), index=False)
