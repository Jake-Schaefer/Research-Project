# %% [markdown]
# # 1. Basic setup

# %%
import os
import sys

sys.path.append('..')
from utils import *

USER = "Jiayi"
DATA_ROOT = '/Users/legion/Desktop/Courses/IS389/data'   
OUTPUT_ROOT = '/Users/legion/Desktop/Courses/IS389/output2'
TRAIT = 'Uterine Carcinosarcoma'

OUTPUT_DIR = os.path.join(OUTPUT_ROOT, USER, '-'.join(TRAIT.split()))
JSON_PATH = os.path.join(OUTPUT_DIR, "cohort_info.json")
if not os.path.exists(OUTPUT_DIR):
    os.makedirs(OUTPUT_DIR, exist_ok=True)
# Out:
# utils.py has been loaded

# %% [markdown]
# # 2. Data preprocessing and selection

# %% [markdown]
# ## 2.1. The TCGA Xena dataset

# %% [markdown]
# In TCGA Xena, there is either zero or one cohort related to the trait. We search the names of subdirectories to see if any matches the trait. If a match is found, we directly obtain the file paths.

# %%
dataset = 'TCGA'
dataset_dir = os.path.join(DATA_ROOT, dataset)
os.listdir(dataset_dir)[:10]
# Out:
# ['TCGA_Adrenocortical_Cancer_(ACC)',
#  'TCGA_Breast_Cancer_(BRCA)',
#  'TCGA_Cervical_Cancer_(CESC)',
#  'TCGA_Kidney_Chromophobe_(KICH)',
#  'TCGA_Kidney_Papillary_Cell_Carcinoma_(KIRP)',
#  'TCGA_Lower_Grade_Glioma_(LGG)',
#  'TCGA_Melanoma_(SKCM)',
#  'TCGA_Mesothelioma_(MESO)',
#  'TCGA_Testicular_Cancer_(TGCT)',
#  'TCGA_Uterine_Carcinosarcoma_(UCS)']

# %%
trait_subdir = "TCGA_Uterine_Carcinosarcoma_(UCS)"
cohort = 'Xena'
trait_type = 'binary'
is_available = True

cohort_dir = os.path.join(DATA_ROOT, dataset, trait_subdir)
clinical_data_file, genetic_data_file = xena_get_relevant_filepaths(cohort_dir)
clinical_data_file, genetic_data_file
# Out:
# ('/Users/legion/Desktop/Courses/IS389/data\\TCGA\\TCGA_Uterine_Carcinosarcoma_(UCS)\\TCGA.UCS.sampleMap_UCS_clinicalMatrix',
#  '/Users/legion/Desktop/Courses/IS389/data\\TCGA\\TCGA_Uterine_Carcinosarcoma_(UCS)\\TCGA.UCS.sampleMap_HiSeqV2_PANCAN.gz')

# %%
import pandas as pd

clinical_data = pd.read_csv(clinical_data_file, sep='\t', index_col=0)
genetic_data = pd.read_csv(genetic_data_file, compression='gzip', sep='\t', index_col=0)
age_col = gender_col = None

# %%
_, clinical_data_cols = check_rows_and_columns(clinical_data)
clinical_data_cols[:10]
# Out:
# ['CDE_ID_3226963',
#  '_INTEGRATION',
#  '_PATIENT',
#  '_cohort',
#  '_primary_disease',
#  '_primary_site',
#  'additional_pharmaceutical_therapy',
#  'additional_radiation_therapy',
#  'age_at_initial_pathologic_diagnosis',
#  'aln_pos_ihc']

# %% [markdown]
# Read all the column names in the clinical dataset, to find the columns that record information about age or gender.
# Reference prompt:

# %%
f'''
Below is a list of column names from a biomedical dataset. Please examine it and identify the columns that are likely to contain information about patients' age. Additionally, please do the same for columns that may hold data on patients' gender. Please provide your answer by strictly following this format, without redundant words:
candidate_age_cols = [col_name1, col_name2, ...]
candidate_gender_cols = [col_name1, col_name2, ...]
If no columns match a criterion, please provide an empty list.

Column names:
{clinical_data_cols}
'''
# Out:
# "\nBelow is a list of column names from a biomedical dataset. Please examine it and identify the columns that are likely to contain information about patients' age. Additionally, please do the same for columns that may hold data on patients' gender. Please provide your answer by strictly following this format, without redundant words:\ncandidate_age_cols = [col_name1, col_name2, ...]\ncandidate_gender_cols = [col_name1, col_name2, ...]\nIf no columns match a criterion, please provide an empty list.\n\nColumn names:\n['CDE_ID_3226963', '_INTEGRATION', '_PATIENT', '_cohort', '_primary_disease', '_primary_site', 'additional_pharmaceutical_therapy', 'additional_radiation_therapy', 'age_at_initial_pathologic_diagnosis', 'aln_pos_ihc', 'aln_pos_light_micro', 'anatomic_neoplasm_subdivision', 'bcr_followup_barcode', 'bcr_patient_barcode', 'bcr_sample_barcode', 'birth_control_pill_history_usage_category', 'clinical_stage', 'colorectal_cancer', 'days_to_birth', 'days_to_collection', 'days_to_death', 'days_to_initial_pathologic_diagnosis', 'days_to_last_followup', 'days_to_new_tumor_event_additional_surgery_procedure', 'days_to_new_tumor_event_after_initial_treatment', 'diabetes', 'form_completion_date', 'gender', 'height', 'histological_type', 'history_of_neoadjuvant_treatment', 'horm_ther', 'hypertension', 'icd_10', 'icd_o_3_histology', 'icd_o_3_site', 'informed_consent_verified', 'initial_pathologic_diagnosis_method', 'initial_weight', 'is_ffpe', 'lost_follow_up', 'menopause_status', 'new_neoplasm_event_occurrence_anatomic_site', 'new_neoplasm_event_type', 'new_neoplasm_occurrence_anatomic_site_text', 'new_tumor_event_additional_surgery_procedure', 'new_tumor_event_after_initial_treatment', 'oct_embedded', 'other_dx', 'pathology_report_file_name', 'patient_id', 'pct_tumor_invasion', 'peritoneal_wash', 'person_neoplasm_cancer_status', 'pln_pos_ihc', 'pln_pos_light_micro', 'postoperative_rx_tx', 'pregnancies', 'primary_therapy_outcome_success', 'prior_tamoxifen_administered_usage_category', 'radiation_therapy', 'recurrence_second_surgery_neoplasm_surgical_procedure_name', 'residual_tumor', 'sample_type', 'sample_type_id', 'surgical_approach', 'system_version', 'tissue_prospective_collection_indicator', 'tissue_retrospective_collection_indicator', 'tissue_source_site', 'total_aor_lnp', 'total_aor_lnr', 'total_pelv_lnp', 'total_pelv_lnr', 'tumor_tissue_site', 'vial_number', 'vital_status', 'weight', 'year_of_initial_pathologic_diagnosis', '_GENOMIC_ID_TCGA_UCS_miRNA_HiSeq', '_GENOMIC_ID_TCGA_UCS_RPPA', '_GENOMIC_ID_data/public/TCGA/UCS/miRNA_HiSeq_gene', '_GENOMIC_ID_TCGA_UCS_exp_HiSeqV2_exon', '_GENOMIC_ID_TCGA_UCS_exp_HiSeqV2', '_GENOMIC_ID_TCGA_UCS_mutation_bcm_gene', '_GENOMIC_ID_TCGA_UCS_exp_HiSeqV2_percentile', '_GENOMIC_ID_TCGA_UCS_mutation_curated_broad_gene', '_GENOMIC_ID_TCGA_UCS_gistic2thd', '_GENOMIC_ID_TCGA_UCS_exp_HiSeqV2_PANCAN', '_GENOMIC_ID_TCGA_UCS_mutation_broad_gene', '_GENOMIC_ID_TCGA_UCS_PDMRNAseqCNV', '_GENOMIC_ID_TCGA_UCS_gistic2', '_GENOMIC_ID_TCGA_UCS_mutation_bcgsc_gene', '_GENOMIC_ID_TCGA_UCS_hMethyl450', '_GENOMIC_ID_TCGA_UCS_PDMRNAseq']\n"

# %%
candidate_age_cols = ['age_at_initial_pathologic_diagnosis']
candidate_gender_cols = ['gender']

# %% [markdown]
# Choose a single column from the candidate columns that record age and gender information respectively.
# If no column meets the requirement, keep 'age_col' or 'gender_col' to None

# %%
age_col = 'age_at_initial_pathologic_diagnosis'
gender_col = 'gender'
selected_clinical_data = xena_select_clinical_features(clinical_data, TRAIT, age_col=age_col, gender_col=gender_col)

# %%
genetic_data = normalize_gene_symbols_in_index(genetic_data)

# %%
genetic_data
# Out:
#            TCGA-N7-A4Y5-01  TCGA-N5-A4RM-01  TCGA-N9-A4Q8-01  TCGA-N9-A4Q7-01  \
# ARHGEF10L         0.159808        -0.342892        -2.561692         0.814708
# HIF3A             8.116374         3.251374         3.964374         2.101974
# RNF17            -0.531035        -0.531035        -0.531035        -0.531035
# RNF10             0.491128         0.449828        -0.213572         0.247028
# RNF11             0.221222        -0.508578        -0.239378        -1.285978
# ...                    ...              ...              ...              ...
# GNGT1             2.162310         2.528110        -1.281390         2.062210
# TULP3             1.156223         0.980423         0.125923        -0.115377
# BCL6B            -1.218927        -0.407627        -1.056927        -1.821127
# GSTK1            -1.559495        -0.638195        -0.807795         1.332405
# SELP             -2.305133        -0.953433        -3.142633        -1.671733
#
#            TCGA-N6-A4VD-01  TCGA-N5-A4RT-01  TCGA-N9-A4Q1-01  TCGA-N5-A4RD-01  \
# ARHGEF10L        -0.747992        -1.216492        -1.183192        -1.075592
# HIF3A             1.745474         4.559774         6.436574         5.400374
# RNF17            -0.531035        -0.531035         0.023165         0.337765
# RNF10             0.142628        -0.295572        -0.819172        -0.327472
# RNF11            -0.141278         0.112322         0.777922        -0.623978
# ...                    ...              ...              ...              ...
# GNGT1            -0.500290         1.902010         2.914810         3.925510
# TULP3             0.394023         0.373923         1.008823         0.600623
# BCL6B            -1.103927        -0.457927        -0.592327        -0.892127
# GSTK1            -0.030595        -1.583695        -1.032395        -0.581895
# SELP             -2.314333        -2.458333        -0.407733        -3.565233
#
#            TCGA-N8-A4PL-01  TCGA-ND-A4WC-01  ...  TCGA-ND-A4WA-01  \
# ARHGEF10L        -0.139592        -0.308092  ...        -0.399792
# HIF3A             5.781974         2.870174  ...         5.370274
# RNF17            -0.531035         0.006465  ...        -0.531035
# RNF10             0.092528         0.082328  ...        -0.056772
# RNF11            -1.300578        -0.339078  ...        -0.258378
# ...                    ...              ...  ...              ...
# GNGT1             1.604410         1.498710  ...         3.084910
# TULP3             1.977023         0.193523  ...        -0.100777
# BCL6B            -3.291227        -0.344127  ...        -0.937927
# GSTK1            -0.764895         0.187505  ...         0.145405
# SELP             -4.636333        -0.402033  ...         0.632667
#
#            TCGA-N8-A56S-01  TCGA-ND-A4WF-01  TCGA-N5-A4RJ-01  TCGA-NA-A4QX-01  \
# ARHGEF10L         0.710908        -0.276192         0.275708        -0.697392
# HIF3A             7.416774         5.491974         5.896174         5.058874
# RNF17            -0.531035        -0.531035         0.372565        -0.531035
# RNF10             0.087828         0.532928        -0.087372         0.173328
# RNF11            -0.149078        -0.143578        -0.719378         0.129022
# ...                    ...              ...              ...              ...
# GNGT1             2.572910         3.055810         1.251910         3.911510
# TULP3             0.737523         0.622323         0.508223         1.000123
# BCL6B             0.270373         0.005173         0.983573        -0.433727
# GSTK1            -0.545095        -0.330595         0.058705        -1.419095
# SELP             -0.679133        -4.959633         0.255367        -1.856033
#
#            TCGA-N5-A4RS-01  TCGA-N5-A4RO-01  TCGA-NF-A5CP-01  TCGA-N6-A4VC-01  \
# ARHGEF10L        -0.258992        -1.682292        -0.213692        -1.378792
# HIF3A             4.639074         5.189674         0.857074         1.616374
# RNF17            -0.531035        -0.531035        -0.531035        -0.531035
# RNF10            -1.143872        -0.096972        -0.306672         0.606228
# RNF11            -0.635478        -1.139278        -0.246478         0.172722
# ...                    ...              ...              ...              ...
# GNGT1             4.970610         3.990210         1.539910         2.313210
# TULP3             1.038223         0.882223         0.320623         1.178323
# BCL6B            -1.194427        -2.458227         0.992073        -1.211927
# GSTK1            -0.349695        -1.139895        -0.443995        -0.818895
# SELP             -1.530333        -4.626233         0.696067        -3.610933
#
#            TCGA-N5-A4RU-01
# ARHGEF10L        -1.113392
# HIF3A             4.505174
# RNF17            -0.531035
# RNF10             0.110928
# RNF11            -0.160778
# ...                    ...
# GNGT1             0.151610
# TULP3            -0.238477
# BCL6B             0.821373
# GSTK1            -1.583695
# SELP             -3.881633
#
# [17339 rows x 57 columns]

# %%
merged_data = selected_clinical_data.join(genetic_data.T).dropna()
merged_data.head()
# Out:
#                  Uterine Carcinosarcoma  Age  Gender  ARHGEF10L     HIF3A  \
# sampleID
# TCGA-N5-A4R8-01                       1   65       0  -0.957792  6.814974
# TCGA-N5-A4RA-01                       1   63       0  -0.436292  6.814374
# TCGA-N5-A4RD-01                       1   69       0  -1.075592  5.400374
# TCGA-N5-A4RF-01                       1   68       0  -0.616892  4.298374
# TCGA-N5-A4RJ-01                       1   61       0   0.275708  5.896174
#
#                     RNF17     RNF10     RNF11    RNF13   GTF2IP1  ...  \
# sampleID                                                          ...
# TCGA-N5-A4R8-01 -0.531035 -0.200472 -0.535378 -1.42261 -0.539194  ...
# TCGA-N5-A4RA-01 -0.531035  0.387528 -0.035178 -1.14681 -0.246094  ...
# TCGA-N5-A4RD-01  0.337765 -0.327472 -0.623978 -0.76911  0.301706  ...
# TCGA-N5-A4RF-01 -0.531035  0.068628 -0.272078 -1.90441 -0.123494  ...
# TCGA-N5-A4RJ-01  0.372565 -0.087372 -0.719378 -1.19391 -0.032194  ...
#
#                   SLC7A10   PLA2G2C     TULP2     NPY5R     GNGT2    GNGT1  \
# sampleID
# TCGA-N5-A4R8-01  5.055914 -0.086682  0.017922  3.273883 -0.262233  1.95401
# TCGA-N5-A4RA-01  6.600414 -0.086682  0.234322 -1.013317 -1.696233  0.02041
# TCGA-N5-A4RD-01  6.132114  0.412218 -0.748878  1.260083  0.190467  3.92551
# TCGA-N5-A4RF-01  5.434814  1.727818 -0.748878 -1.587117  2.072467  3.56111
# TCGA-N5-A4RJ-01  5.051014 -0.086682 -0.748878  0.710983  0.398067  1.25191
#
#                     TULP3     BCL6B     GSTK1      SELP
# sampleID
# TCGA-N5-A4R8-01  1.290723 -0.852727 -2.000395 -5.091733
# TCGA-N5-A4RA-01  0.931723 -2.614627 -0.800295 -5.525533
# TCGA-N5-A4RD-01  0.600623 -0.892127 -0.581895 -3.565233
# TCGA-N5-A4RF-01  0.549123  0.040173 -0.607895 -3.091133
# TCGA-N5-A4RJ-01  0.508223  0.983573  0.058705  0.255367
#
# [5 rows x 17342 columns]

# %%
print(f"The merged dataset contains {len(merged_data)} samples.")
is_trait_biased, merge_data = judge_and_remove_biased_features(merged_data, TRAIT, trait_type=trait_type)
is_trait_biased
# Out:
# The merged dataset contains 57 samples.
# For the feature 'Uterine Carcinosarcoma', the least common label is '1' with 57 occurrences. This represents 100.00% of the dataset.
# The distribution of the feature 'Uterine Carcinosarcoma' in this dataset is severely biased.
#
# Quartiles for 'Age':
#   25%: 62.0
#   50% (Median): 68.0
#   75%: 76.0
# Min: 51
# Max: 90
# The distribution of the feature 'Age' in this dataset is fine.
#
# For the feature 'Gender', the least common label is '0' with 57 occurrences. This represents 100.00% of the dataset.
# The distribution of the feature 'Gender' in this dataset is severely biased.
# True

# %%
merged_data.head()
if not is_trait_biased:
    merge_data.to_csv(os.path.join(OUTPUT_DIR, cohort + '.csv'), index=False)

# %%
save_cohort_info(cohort, JSON_PATH, is_available, is_trait_biased, merged_data)
# Out:
# A new JSON file was created at: /Users/legion/Desktop/Courses/IS389/output2\Jiayi\Uterine-Carcinosarcoma\cohort_info.json

# %% [markdown]
# ## 2.2. The GEO dataset

# %%
dataset = 'GEO'
trait_subdir = "Uterine-Carcinosarcoma"

trait_path = os.path.join(DATA_ROOT, dataset, trait_subdir)
os.listdir(trait_path)
# Out:
# ['GSE16680', 'GSE32507', 'GSE36133', 'GSE36138', 'GSE36139', 'GSE68950']

# %% [markdown]
# Repeat the below steps for all the accession numbers

# %%
# Biased
cohort = accession_num = "GSE16680"
cohort_dir = os.path.join(trait_path, accession_num)
soft_file, matrix_file = geo_get_relevant_filepaths(cohort_dir)
soft_file, matrix_file
# Out:
# ('/Users/legion/Desktop/Courses/IS389/data\\GEO\\Uterine-Carcinosarcoma\\GSE16680\\GSE16680_family.soft.gz',
#  '/Users/legion/Desktop/Courses/IS389/data\\GEO\\Uterine-Carcinosarcoma\\GSE16680\\GSE16680_series_matrix.txt.gz')

# %%
# Finished
cohort = accession_num = "GSE32507"
cohort_dir = os.path.join(trait_path, accession_num)
soft_file, matrix_file = geo_get_relevant_filepaths(cohort_dir)
soft_file, matrix_file
# Out:
# ('/Users/legion/Desktop/Courses/IS389/data\\GEO\\Uterine-Carcinosarcoma\\GSE32507\\GSE32507_family.soft.gz',
#  '/Users/legion/Desktop/Courses/IS389/data\\GEO\\Uterine-Carcinosarcoma\\GSE32507\\GSE32507_series_matrix.txt.gz')

# %%
# No gene mapping
cohort = accession_num = "GSE36133"
cohort_dir = os.path.join(trait_path, accession_num)
soft_file, matrix_file = geo_get_relevant_filepaths(cohort_dir)
soft_file, matrix_file
# Out:
# ('/Users/legion/Desktop/Courses/IS389/data\\GEO\\Uterine-Carcinosarcoma\\GSE36133\\GSE36133_family.soft.gz',
#  '/Users/legion/Desktop/Courses/IS389/data\\GEO\\Uterine-Carcinosarcoma\\GSE36133\\GSE36133_series_matrix.txt.gz')

# %%
# MemoryError
cohort = accession_num = "GSE36138"
cohort_dir = os.path.join(trait_path, accession_num)
soft_file, matrix_file = geo_get_relevant_filepaths(cohort_dir)
soft_file, matrix_file
# Out:
# ('/Users/legion/Desktop/Courses/IS389/data\\GEO\\Uterine-Carcinosarcoma\\GSE36138\\GSE36138_family.soft.gz',
#  '/Users/legion/Desktop/Courses/IS389/data\\GEO\\Uterine-Carcinosarcoma\\GSE36138\\GSE36138_series_matrix.txt.gz')

# %%
# No gene mapping
cohort = accession_num = "GSE36139"
cohort_dir = os.path.join(trait_path, accession_num)
soft_file, matrix_file = geo_get_relevant_filepaths(cohort_dir)
soft_file, matrix_file
# Out:
# ('/Users/legion/Desktop/Courses/IS389/data\\GEO\\Uterine-Carcinosarcoma\\GSE36139\\GSE36139_family.soft.gz',
#  '/Users/legion/Desktop/Courses/IS389/data\\GEO\\Uterine-Carcinosarcoma\\GSE36139\\GSE36139-GPL15308_series_matrix.txt.gz')

# %%
# No obvious trait
cohort = accession_num = "GSE68950"
cohort_dir = os.path.join(trait_path, accession_num)
soft_file, matrix_file = geo_get_relevant_filepaths(cohort_dir)
soft_file, matrix_file
# Out:
# ('/Users/legion/Desktop/Courses/IS389/data\\GEO\\Uterine-Carcinosarcoma\\GSE68950\\GSE68950_family.soft.gz',
#  '/Users/legion/Desktop/Courses/IS389/data\\GEO\\Uterine-Carcinosarcoma\\GSE68950\\GSE68950_series_matrix.txt.gz')

# %% [markdown]
# ### Initial filtering and clinical data preprocessing

# %%
from utils import *
background_prefixes = ['!Series_title', '!Series_summary', '!Series_overall_design']
clinical_prefixes = ['!Sample_geo_accession', '!Sample_characteristics_ch1']    

background_info, clinical_data = get_background_and_clinical_data(matrix_file, background_prefixes, clinical_prefixes)
print(background_info)
# Out:
# !Series_title	"caArray_golub-00327: Sanger cell line Affymetrix gene expression project"
# !Series_summary	"The microarray gene expression pattern was studied using 798 different cancer cell lines. The cancer cell lines are obtained from different centers. Annotation information were provided in the supplementary file."
# !Series_overall_design	"golub-00327"
# !Series_overall_design	"Assay Type: Gene Expression"
# !Series_overall_design	"Provider: Affymetrix"
# !Series_overall_design	"Array Designs: HT_HG-U133A"
# !Series_overall_design	"Organism: Homo sapiens (ncbitax)"
# !Series_overall_design	"Tissue Sites: leukemia, Urinary tract, Lung, BiliaryTract, Autonomic Ganglion, Thyroid gland, Stomach, Breast, Pancreas, Head and Neck, Lymphoma, Colorectal, Placenta, Liver, Brain, Bone, pleura, Skin, endometrium, Ovary, cervix, Oesophagus, Connective and Soft Tissue, Muscle, Kidney, Prostate, Adrenal Gland, Eye, Testis, Smooth Muscle Tissue, Vulva, Unknow"
# !Series_overall_design	"Material Types: cell, synthetic_RNA, whole_organism, total_RNA, BVG"
# !Series_overall_design	"Disease States: M3 acute myeloid leukemia, hairy cell leukemia, transitional cell carcinoma, Adenocarcinoma, B cell lymphoma unspecified, Acute Lymphoblastic Leukemia, blast phase chronic myeloid leukemia, Carcinoma, M6 acute myeloid leukemia, Neuroblastoma, follicular carcinoma, ductal carcinoma, Burkitt Lymphoma, Squamous Cell Carcinoma, M5 acute myeloid leukemia, Mycosis Fungoides and Sezary Syndrome, Acute T-Cell Lymphoblastic Leukemia, Adult T-Cell Leukemia/Lymphoma, M2 Therapy-Related Myeloid Neoplasm, Choriocarcinoma, Plasma Cell Myeloma, Hepatocellular Carcinoma, anaplastic large cell lymphoma, primitive neuroectodermal tumor-medulloblastoma, M4 acute myeloid leukemia, B Acute Lymphoblastic Leukemia, Acute Leukemia of Ambiguous Lineage, Osteosarcoma, Hodgkin Lymphoma, Mesothelioma, chondrosarcoma, Glioblastoma Multiforme, Malignant Melanoma, carcinosarcoma-malignant mesodermal mixed tumor, bronchioloalveolar adenocarcinoma, chronic lymphocytic leukemia-small lymphocytic lymphoma, micropapillary carcinoma, diffuse large B cell lymphoma, myelodysplastic syndrome, giant cell carcinoma, teratoma, multipotential sarcoma, Small Cell Carcinoma, ASTROCYTOMA, Fibrosarcoma, mucoepidermoid carcinoma, Rhabdomyosarcoma, L1 Acute T-Cell Lymphoblastic Leukemia, Glioma, Anaplastic Astrocytoma, Non-small cell carcinoma, Large Cell Carcinoma, mucinous carcinoma, Acute Myeloid Leukemia, malignant fibrous histiocytoma-pleomorphic sarcoma, clear cell carcinoma, B cell lymphoma unspecified, Anaplastic Carcinoma, Ewings sarcoma-peripheral primitive neuroectodermal tumor, undifferentiated carcinoma, Sarcoma, Embryonal Rhabdomyosarcoma, epithelioid sarcoma, renal cell carcinoma, carcinoid-endocrine tumor, Synovial Sarcoma, lymphoid neoplasm, rhabdoid tumor, Refractory Anemia with Excess Blasts, Liposarcoma, biphasic mesothelioma, adrenal cortical carcinoma, adenosquamous carcinoma, L2 Acute T-Cell Lymphoblastic Leukemia, chronic myeloid leukemia, Micropapillary Serous Carcinoma, desmoplastic, acute leukemia, Retinoblastoma, teratocarcinoma, clear cell renal cell carcinoma, Follicular Lymphoma, Wilms Tumor, M7 acute myeloid leukemia, gliosarcoma, embryonal carcinoma, Leiomyosarcoma, medullary carcinoma, granulosa cell tumor, papillary carcinoma, NS Acute Lymphoblastic Leukemia, papillary transitional cell carcinoma, small cell adenocarcinoma, epithelial dysplasia, hyperplasia, tubular adenocarcinoma, metaplasia, papillary ductal carcinoma, chronic eosinophilic leukemia-hypereosinophilic syndrome, #N/A, malignant trichilemmal cyst, Medullary Breast Carcinoma, L2 Acute Lymphoblastic Leukemia, Osteoblastic Osteosarcoma"

# %%
clinical_data
# Out:
#          !Sample_geo_accession  \
# 0  !Sample_characteristics_ch1
# 1  !Sample_characteristics_ch1
# 2  !Sample_characteristics_ch1
# 3  !Sample_characteristics_ch1
# 4  !Sample_characteristics_ch1
# 5  !Sample_characteristics_ch1
# 6  !Sample_characteristics_ch1
# 7  !Sample_characteristics_ch1
# 8  !Sample_characteristics_ch1
#
#                                           GSM1687570  \
# 0                                  cosmic id: 924101
# 1     disease state: L2 Acute Lymphoblastic Leukemia
# 2  disease location: Hematopoietic and Lymphoid T...
# 3                            organism part: Leukemia
# 4                                        sample: 736
# 5                                cell line code: 749
# 6                                     supplier: DSMZ
# 7                                      affy_batch: 1
# 8                                      crna plate: 8
#
#                                           GSM1687571  \
# 0                                  cosmic id: 906800
# 1     disease state: NS Acute Lymphoblastic Leukemia
# 2  disease location: Hematopoietic and Lymphoid T...
# 3                            organism part: Leukemia
# 4                                        sample: 494
# 5                                cell line code: 493
# 6                                     supplier: DSMZ
# 7                                      affy_batch: 1
# 8                                      crna plate: 6
#
#                      GSM1687572                     GSM1687573  \
# 0             cosmic id: 687452              cosmic id: 924100
# 1      disease state: carcinoma  disease state: adenocarcinoma
# 2     disease location: bladder     disease location: prostate
# 3  organism part: Urinary tract        organism part: Prostate
# 4                     sample: 7                    sample: 746
# 5           cell line code: 505            cell line code: 760
# 6                supplier: ATCC                 supplier: DSMZ
# 7                 affy_batch: 2                  affy_batch: 1
# 8                crna plate: 11                  crna plate: 8
#
#                       GSM1687574                                  GSM1687575  \
# 0              cosmic id: 910924                           cosmic id: 906798
# 1  disease state: adenocarcinoma  disease state: transitional cell carcinoma
# 2      disease location: stomach                    disease location: ureter
# 3         organism part: Stomach                organism part: Urinary tract
# 4                    sample: 439                                 sample: 168
# 5            cell line code: 437                         cell line code: 151
# 6                 supplier: DSMZ                              supplier: DSMZ
# 7                  affy_batch: 1                               affy_batch: 1
# 8                  crna plate: 5                               crna plate: 2
#
#                                    GSM1687576  \
# 0                           cosmic id: 906797
# 1  disease state: transitional cell carcinoma
# 2                   disease location: bladder
# 3                organism part: Urinary tract
# 4                                 sample: 152
# 5                         cell line code: 134
# 6                              supplier: DSMZ
# 7                               affy_batch: 1
# 8                               crna plate: 2
#
#                                    GSM1687577  \
# 0                           cosmic id: 906797
# 1  disease state: transitional cell carcinoma
# 2                   disease location: bladder
# 3                organism part: Urinary tract
# 4                                  sample: 37
# 5                         cell line code: 134
# 6                              supplier: DSMZ
# 7                               affy_batch: 2
# 8                              crna plate: 12
#
#                                        GSM1687578  ...  \
# 0                               cosmic id: 910922  ...
# 1  disease state: clear cell renal cell carcinoma  ...
# 2                        disease location: kidney  ...
# 3                           organism part: Kidney  ...
# 4                                     sample: 450  ...
# 5                             cell line code: 449  ...
# 6                           supplier: Unspecified  ...
# 7                                   affy_batch: 1  ...
# 8                                   crna plate: 5  ...
#
#                             GSM1688358                     GSM1688359  \
# 0                    cosmic id: 909781              cosmic id: 909782
# 1  disease state: renal cell carcinoma  disease state: retinoblastoma
# 2             disease location: kidney       disease location: retina
# 3                organism part: Kidney             organism part: Eye
# 4                          sample: 470                    sample: 246
# 5                  cell line code: 469            cell line code: 231
# 6                      supplier: HSRRB                 supplier: ATCC
# 7                        affy_batch: 1                  affy_batch: 1
# 8                        crna plate: 5                  crna plate: 3
#
#                       GSM1688360                         GSM1688361  \
# 0              cosmic id: 909782                  cosmic id: 909784
# 1  disease state: retinoblastoma  disease state: malignant melanoma
# 2       disease location: retina             disease location: skin
# 3             organism part: Eye                organism part: Skin
# 4                    sample: 246                        sample: 714
# 5            cell line code: 231                cell line code: 727
# 6                 supplier: ATCC                     supplier: ATCC
# 7                  affy_batch: 2                      affy_batch: 1
# 8                 crna plate: 12                      crna plate: 8
#
#                            GSM1688362                          GSM1688363  \
# 0                   cosmic id: 909785                   cosmic id: 909785
# 1  disease state: follicular lymphoma  disease state: follicular lymphoma
# 2        disease location: lymph node        disease location: lymph node
# 3             organism part: Lymphoma             organism part: Lymphoma
# 4                         sample: 482                          sample: 49
# 5                 cell line code: 481                 cell line code: 481
# 6                      supplier: DSMZ                      supplier: DSMZ
# 7                       affy_batch: 1                       affy_batch: 2
# 8                       crna plate: 5                      crna plate: 12
#
#                    GSM1688364                              GSM1688365  \
# 0           cosmic id: 909904                       cosmic id: 909905
# 1    disease state: carcinoma  disease state: glioblastoma multiforme
# 2  disease location: pancreas                 disease location: brain
# 3     organism part: Pancreas                    organism part: Brain
# 4                 sample: 234                              sample: 41
# 5         cell line code: 219                     cell line code: 401
# 6              supplier: DSMZ                         supplier: HSRRB
# 7               affy_batch: 1                           affy_batch: 2
# 8               crna plate: 3                          crna plate: 12
#
#                                GSM1688366                       GSM1688367
# 0                       cosmic id: 687592                cosmic id: 909907
# 1  disease state: glioblastoma multiforme  disease state: ductal carcinoma
# 2         disease location: temporal lobe         disease location: breast
# 3                    organism part: Brain            organism part: Breast
# 4                             sample: 397                      sample: 726
# 5                     cell line code: 390              cell line code: 738
# 6                         supplier: HSRRB                   supplier: ATCC
# 7                           affy_batch: 1                    affy_batch: 1
# 8                           crna plate: 4                    crna plate: 8
#
# [9 rows x 799 columns]

# %% [markdown]
# Analyze the trait row:

# %%
tumor_stage_row = clinical_data.iloc[1]
tumor_stage_row.unique()
# Out:
# array(['!Sample_characteristics_ch1',
#        'disease state: L2 Acute Lymphoblastic Leukemia',
#        'disease state: NS Acute Lymphoblastic Leukemia',
#        'disease state: carcinoma', 'disease state: adenocarcinoma',
#        'disease state: transitional cell carcinoma',
#        'disease state: clear cell renal cell carcinoma',
#        'disease state: anaplastic carcinoma',
#        'disease state: glioblastoma multiforme',
#        'disease state: malignant melanoma',
#        'disease state: rhabdomyosarcoma',
#        'disease state: mucoepidermoid carcinoma',
#        'disease state: squamous cell carcinoma',
#        'disease state: renal cell carcinoma',
#        'disease state: neuroblastoma',
#        'disease state: Acute Lymphoblastic Leukemia',
#        'disease state: M5 acute myeloid leukemia',
#        'disease state: plasma cell myeloma',
#        'disease state: L1 Acute T-Cell Lymphoblastic Leukemia',
#        'disease state: astrocytoma',
#        'disease state: B Acute Lymphoblastic Leukemia',
#        'disease state: B cell lymphoma unspecified',
#        'disease state: papillary carcinoma',
#        'disease state: papillary transitional cell carcinoma',
#        'disease state: Burkitt lymphoma',
#        'disease state: hairy cell leukemia', 'disease state: hyperplasia',
#        'disease state: papillary ductal carcinoma',
#        'disease state: blast phase chronic myeloid leukemia',
#        'disease state: hepatocellular carcinoma',
#        'disease state: Adult T-Cell Leukemia/Lymphoma',
#        'disease state: Non-Small Cell Carcinoma',
#        'disease state: ductal carcinoma',
#        'disease state: Osteoblastic Osteosarcoma',
#        'disease state: M4 acute myeloid leukemia',
#        'disease state: follicular carcinoma',
#        'disease state: M7 acute myeloid leukemia',
#        'disease state: small cell carcinoma',
#        'disease state: large cell carcinoma',
#        'disease state: acute myeloid leukemia',
#        'disease state: primitive neuroectodermal tumor-medulloblastoma',
#        'disease state: glioma', 'disease state: desmoplastic',
#        'disease state: diffuse large B cell lymphoma',
#        'disease state: lymphoid neoplasm',
#        'disease state: malignant trichilemmal cyst',
#        'disease state: epithelial dysplasia',
#        'disease state: small cell adenocarcinoma',
#        'disease state: Micropapillary Serous Carcinoma',
#        'disease state: mucinous carcinoma',
#        'disease state: chronic lymphocytic leukemia-small lymphocytic lymphoma',
#        'disease state: chronic eosinophilic leukemia-hypereosinophilic syndrome',
#        'disease state: Ewings sarcoma-peripheral primitive neuroectodermal tumor',
#        'disease state: carcinosarcoma-malignant mesodermal mixed tumor',
#        'disease state: rhabdoid tumor',
#        'disease state: malignant fibrous histiocytoma-pleomorphic sarcoma',
#        'disease state: gliosarcoma',
#        'disease state: Mycosis Fungoides and Sezary Syndrome',
#        'disease state: Hodgkin lymphoma',
#        'disease state: M6 acute myeloid leukemia',
#        'disease state: chondrosarcoma',
#        'disease state: M3 acute myeloid leukemia',
#        'disease state: osteosarcoma', 'disease state: fibrosarcoma',
#        'disease state: mesothelioma',
#        'disease state: embryonal carcinoma',
#        'disease state: choriocarcinoma',
#        'disease state: Acute T-Cell Lymphoblastic Leukemia',
#        'disease state: anaplastic large cell lymphoma',
#        'disease state: M2 Therapy-Related Myeloid Neoplasm',
#        'disease state: granulosa cell tumor',
#        'disease state: Anaplastic Astrocytoma',
#        'disease state: undifferentiated carcinoma',
#        'disease state: Acute Leukemia of Ambiguous Lineage',
#        'disease state: giant cell carcinoma',
#        'disease state: Medullary Breast Carcinoma',
#        'disease state: sarcoma', 'disease state: tubular adenocarcinoma',
#        'disease state: L2 Acute T-Cell Lymphoblastic Leukemia',
#        'disease state: biphasic mesothelioma',
#        'disease state: Refractory Anemia with Excess Blasts',
#        'disease state: teratocarcinoma',
#        'disease state: bronchioloalveolar adenocarcinoma',
#        'disease state: adenosquamous carcinoma',
#        'disease state: adrenal cortical carcinoma',
#        'disease state: carcinoid-endocrine tumor',
#        'disease state: micropapillary carcinoma',
#        'disease state: metaplasia', 'disease state: teratoma',
#        'disease state: #N/A', 'disease state: Embryonal Rhabdomyosarcoma',
#        'disease state: clear cell carcinoma',
#        'disease state: chronic myeloid leukemia',
#        'disease state: acute leukemia',
#        'disease state: multipotential sarcoma',
#        'disease state: myelodysplastic syndrome',
#        'disease state: Wilms tumor', 'disease state: leiomyosarcoma',
#        'disease state: liposarcoma', 'disease state: synovial sarcoma',
#        'disease state: medullary carcinoma',
#        'disease state: epithelioid sarcoma',
#        'disease state: retinoblastoma',
#        'disease state: follicular lymphoma'], dtype=object)

# %% [markdown]
# Determine the trait row, age row, and gender row. Then implement the conversion functions:

# %%
trait_row = 0
age_row = None
gender_row = None

def convert_trait(trait):
    if (trait == 'primary site: endometrium'):
        return 1  
    else:
        return 0  

def convert_age(age_string):
    if age_string == 'n.a.':
        return None
    try:
        age = int(age_string.split(': ')[1])
        return age
    except (ValueError, IndexError):
        return None

def convert_gender(gender_string):
    if (gender_string.lower() == 'sex: female' or gender_string.lower() == 'sex: f' or gender_string.lower() == 'gender: female' or gender_string.lower() == 'gender: f'):
        return 1
    elif (gender_string.lower() == 'sex: male' or gender_string.lower() == 'sex: m' or gender_string.lower() == 'gender: male' or gender_string.lower() == 'gender: m') :  # changeed 
        return 0
    else:
        return None

# %% [markdown]
# Check the processed clinical data:

# %%
selected_clinical_data = geo_select_clinical_features(clinical_data, TRAIT, trait_row, convert_trait, age_row=age_row,
                                                      convert_age=convert_age, gender_row=gender_row,
                                                      convert_gender=convert_gender)
selected_clinical_data.head()
# Out:
# c:\Users\legion\Desktop\TAIS_2024SP\TAIS_2024SP\task2\Jiayi\utils.py:218: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   clinical_df = clinical_df.applymap(convert_fn)
#                         GSM886835  GSM886836  GSM886837  GSM886838  GSM886839  \
# Uterine Carcinosarcoma          0          0          0          0          0
#
#                         GSM886840  GSM886841  GSM886842  GSM886843  GSM886844  \
# Uterine Carcinosarcoma          0          0          0          0          0
#
#                         ...  GSM887742  GSM887743  GSM887744  GSM887745  \
# Uterine Carcinosarcoma  ...          0          0          0          0
#
#                         GSM887746  GSM887747  GSM887748  GSM887749  GSM887750  \
# Uterine Carcinosarcoma          0          0          0          0          0
#
#                         GSM887751
# Uterine Carcinosarcoma          0
#
# [1 rows x 917 columns]

# %% [markdown]
# ### Genetic data preprocessing and final filtering

# %% [markdown]
# Check the genetic data:

# %%
genetic_data = get_genetic_data(matrix_file)
genetic_data.head()
# Out:
#               GSM886835  GSM886836  GSM886837  GSM886838  GSM886839  \
# ID
# 100009676_at     6.1161     6.2052     6.1249     6.6154     5.4236
# 10000_at         8.1556     6.6152     4.5676     4.3519     6.6723
# 10001_at         9.7864     9.9699     8.8720     9.1376    10.0290
# 10002_at         3.7977     4.0304     3.8455     3.7085     3.6431
# 10003_at         3.5458     3.8504     4.0458     3.9508     4.1589
#
#               GSM886840  GSM886841  GSM886842  GSM886843  GSM886844  ...  \
# ID                                                                   ...
# 100009676_at     6.0204     6.3859     6.0518     5.5014     5.4835  ...
# 10000_at         6.6316     6.1898     7.5308     6.0786     7.6018  ...
# 10001_at         9.6573     9.4910     9.3053     9.5423     8.7085  ...
# 10002_at         4.0679     3.8344     3.7223     3.9649     4.2291  ...
# 10003_at         4.1798     3.7039     3.6759     3.6180     3.6748  ...
#
#               GSM887742  GSM887743  GSM887744  GSM887745  GSM887746  \
# ID
# 100009676_at     5.7775     5.5271     6.5087     5.2957     5.0551
# 10000_at         4.4568     5.3949     6.7777     6.4488     6.5771
# 10001_at         8.6107     9.1372     9.5185     9.0581     9.8340
# 10002_at         3.7260     4.3524     4.0484     4.2962     4.0643
# 10003_at         3.5464     3.7550     3.8436     3.8422     3.7768
#
#               GSM887747  GSM887748  GSM887749  GSM887750  GSM887751
# ID
# 100009676_at     5.6623     5.4516     5.7055     5.2289     5.2136
# 10000_at         6.9336     7.0296     4.6383     5.8960     4.4004
# 10001_at         9.1133     8.3857     8.5755     9.3064     9.0476
# 10002_at         4.1060     3.5973     3.9060     4.7090     4.0903
# 10003_at         3.8934     3.8004     4.0094     3.6699     3.8667
#
# [5 rows x 917 columns]

# %% [markdown]
# Check if the gene dataset requires mapping to get the gene symbols corresponding to each data row.

# %%
requires_gene_mapping = True

if requires_gene_mapping:
    gene_annotation = get_gene_annotation(soft_file)
    gene_annotation_summary = preview_df(gene_annotation)
    print(gene_annotation_summary)

gene_annotation.columns
# Out:
# {'ID': ['1_at', '10_at', '100_at', '1000_at', '10000_at'], 'ORF': ['1', '10', '100', '1000', '10000'], 'Description': ['alpha-1-B glycoprotein', 'N-acetyltransferase 2 (arylamine N-acetyltransferase)', 'adenosine deaminase', 'cadherin 2, type 1, N-cadherin (neuronal)', 'v-akt murine thymoma viral oncogene homolog 3 (protein kinase B, gamma)']}
# Index(['ID', 'ORF', 'Description'], dtype='object')

# %%
if requires_gene_mapping:
    identifier_key = 'ID'
    gene_symbol_key = 'ORF'
    gene_mapping = get_gene_mapping(gene_annotation, identifier_key, gene_symbol_key)
    genetic_data = apply_gene_mapping(genetic_data, gene_mapping)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[56], line 5
#       3 gene_symbol_key = 'ORF'
#       4 gene_mapping = get_gene_mapping(gene_annotation, identifier_key, gene_symbol_key)
# ----> 5 genetic_data = apply_gene_mapping(genetic_data, gene_mapping)
#
# File c:\Users\legion\Desktop\TAIS_2024SP\TAIS_2024SP\task2\Jiayi\utils.py:177, in apply_gene_mapping(expression_df, mapping_df)
#     174 mapping_df.set_index('ID', inplace=True)
#     176 # Merge 'mapping_df' with 'expression_df' by their indices
# --> 177 merged_df = mapping_df.join(expression_df)
#     179 # Group by 'Gene' and calculate the mean expression values
#     180 gene_expression_df = merged_df.groupby('Gene').mean().dropna()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:10744, in DataFrame.join(self, other, on, how, lsuffix, rsuffix, sort, validate)
#   10734     if how == "cross":
#   10735         return merge(
#   10736             self,
#   10737             other,
#    (...)
#   10742             validate=validate,
#   10743         )
# > 10744     return merge(
#   10745         self,
#   10746         other,
#   10747         left_on=on,
#   10748         how=how,
#   10749         left_index=on is None,
#   10750         right_index=True,
#   10751         suffixes=(lsuffix, rsuffix),
#   10752         sort=sort,
#   10753         validate=validate,
#   10754     )
#   10755 else:
#   10756     if on is not None:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\reshape\merge.py:184, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     169 else:
#     170     op = _MergeOperation(
#     171         left_df,
#     172         right_df,
#    (...)
#     182         validate=validate,
#     183     )
# --> 184     return op.get_result(copy=copy)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\reshape\merge.py:888, in _MergeOperation.get_result(self, copy)
#     884     self.left, self.right = self._indicator_pre_merge(self.left, self.right)
#     886 join_index, left_indexer, right_indexer = self._get_join_info()
# --> 888 result = self._reindex_and_concat(
#     889     join_index, left_indexer, right_indexer, copy=copy
#     890 )
#     891 result = result.__finalize__(self, method=self._merge_type)
#     893 if self.indicator:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\reshape\merge.py:863, in _MergeOperation._reindex_and_concat(self, join_index, left_indexer, right_indexer, copy)
#     858 left.index = join_index
#     860 if right_indexer is not None and not is_range_indexer(
#     861     right_indexer, len(right)
#     862 ):
# --> 863     rmgr = right._mgr.reindex_indexer(
#     864         join_index,
#     865         right_indexer,
#     866         axis=1,
#     867         copy=False,
#     868         only_slice=True,
#     869         allow_dups=True,
#     870         use_na_proxy=True,
#     871     )
#     872     right = right._constructor_from_mgr(rmgr, axes=rmgr.axes)
#     873 right.index = join_index
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\internals\managers.py:687, in BaseBlockManager.reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, only_slice, use_na_proxy)
#     680     new_blocks = self._slice_take_blocks_ax0(
#     681         indexer,
#     682         fill_value=fill_value,
#     683         only_slice=only_slice,
#     684         use_na_proxy=use_na_proxy,
#     685     )
#     686 else:
# --> 687     new_blocks = [
#     688         blk.take_nd(
#     689             indexer,
#     690             axis=1,
#     691             fill_value=(
#     692                 fill_value if fill_value is not None else blk.fill_value
#     693             ),
#     694         )
#     695         for blk in self.blocks
#     696     ]
#     698 new_axes = list(self.axes)
#     699 new_axes[axis] = new_axis
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\internals\managers.py:688, in <listcomp>(.0)
#     680     new_blocks = self._slice_take_blocks_ax0(
#     681         indexer,
#     682         fill_value=fill_value,
#     683         only_slice=only_slice,
#     684         use_na_proxy=use_na_proxy,
#     685     )
#     686 else:
#     687     new_blocks = [
# --> 688         blk.take_nd(
#     689             indexer,
#     690             axis=1,
#     691             fill_value=(
#     692                 fill_value if fill_value is not None else blk.fill_value
#     693             ),
#     694         )
#     695         for blk in self.blocks
#     696     ]
#     698 new_axes = list(self.axes)
#     699 new_axes[axis] = new_axis
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\internals\blocks.py:1307, in Block.take_nd(self, indexer, axis, new_mgr_locs, fill_value)
#    1304     allow_fill = True
#    1306 # Note: algos.take_nd has upcast logic similar to coerce_to_target_dtype
# -> 1307 new_values = algos.take_nd(
#    1308     values, indexer, axis=axis, allow_fill=allow_fill, fill_value=fill_value
#    1309 )
#    1311 # Called from three places in managers, all of which satisfy
#    1312 #  these assertions
#    1313 if isinstance(self, ExtensionBlock):
#    1314     # NB: in this case, the 'axis' kwarg will be ignored in the
#    1315     #  algos.take_nd call above.
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\array_algos\take.py:117, in take_nd(arr, indexer, axis, fill_value, allow_fill)
#     114     return arr.take(indexer, fill_value=fill_value, allow_fill=allow_fill)
#     116 arr = np.asarray(arr)
# --> 117 return _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\array_algos\take.py:157, in _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#     155     out = np.empty(out_shape, dtype=dtype, order="F")
#     156 else:
# --> 157     out = np.empty(out_shape, dtype=dtype)
#     159 func = _get_take_nd_function(
#     160     arr.ndim, arr.dtype, out.dtype, axis=axis, mask_info=mask_info
#     161 )
#     162 func(arr, indexer, out, fill_value)
#
# MemoryError: Unable to allocate 162. MiB for an array with shape (21254341, 1) and data type float64

# %%
genetic_data = normalize_gene_symbols_in_index(genetic_data)
genetic_data
# Out:
#           GSM804806  GSM804807  GSM804808  GSM804809  GSM804810  GSM804811  \
# A1BG      -0.428374  -1.185519   0.905210   2.229184  -0.807230  -1.049002
# A1BG-AS1   0.112597  -2.545402   0.345880   2.294041  -1.484570  -2.047867
# A1CF      -0.414572   1.155139   0.204161   1.504030  -0.382042  -0.231401
# A2M       -1.598132   1.704536  -1.966787   2.845671  -0.677535  -1.352631
# A2ML1     -0.518708  -0.038120   0.456291   0.202503   0.341105   0.115908
# ...             ...        ...        ...        ...        ...        ...
# ZYG11A     1.133136  -0.275506   1.333713  -1.295064  -2.577468   2.349671
# ZYG11B     0.220626   0.242326   0.234571   0.625795  -0.150644  -0.156697
# ZYX       -0.634988   0.121760  -0.194830   1.395852  -1.072702  -0.492642
# ZZEF1      0.394825   0.374459   0.132402   0.041250   0.402375   0.242625
# ZZZ3       0.058989  -0.414844  -0.250578   0.587149  -0.111271   0.006584
#
#           GSM804812  GSM804813  GSM804814  GSM804815  ...  GSM804842  \
# A1BG      -0.788316   0.264672  -0.209491  -0.711295  ...  -0.267915
# A1BG-AS1  -1.833521   0.289472  -0.083492  -0.891364  ...   0.349333
# A1CF      -0.411998   0.456773   0.943821   1.132380  ...   0.474575
# A2M        0.799846   2.531783  -1.624713   0.691356  ...   0.239463
# A2ML1     -0.303251   0.185458   1.257013   0.833159  ...   0.330738
# ...             ...        ...        ...        ...  ...        ...
# ZYG11A    -1.714859  -3.270926  -2.733860  -1.295885  ...  -3.277940
# ZYG11B    -0.340128   0.306694  -0.270027  -0.403181  ...  -1.379437
# ZYX       -0.378221   1.186319  -0.190907  -0.269548  ...  -1.017909
# ZZEF1      0.056147  -0.190490   0.399305   0.309058  ...  -0.113832
# ZZZ3       0.233355  -0.006584  -0.086750  -0.108851  ...  -0.669802
#
#           GSM804843  GSM804844  GSM804845  GSM804846  GSM804847  GSM804848  \
# A1BG       3.873424   2.243029   1.406519  -1.114534  -0.738209   2.528905
# A1BG-AS1   1.197180   2.109467   1.263221  -1.091778  -0.798120   2.082527
# A1CF       0.438384   3.451386  -0.047563  -1.147372  -0.428677  -2.186289
# A2M        0.176425   0.871290   0.008356  -0.008356   0.070050   2.499900
# A2ML1      0.591233   3.242414   0.461115  -0.455732  -0.314194  -1.701203
# ...             ...        ...        ...        ...        ...        ...
# ZYG11A     0.084062   0.138241   1.957550  -0.441590   0.420463  -4.701589
# ZYG11B    -0.171540  -1.479160   0.156511   0.443674  -0.593189   0.641436
# ZYX        0.279231   0.103642  -0.334219  -0.389594   0.005596   2.668182
# ZZEF1     -0.182934   0.602217  -0.232841  -0.079149  -0.002652  -1.439755
# ZZZ3      -0.270942  -2.356920  -0.634593   0.783653  -0.394218   0.223815
#
#           GSM804849  GSM804850  GSM804851
# A1BG       3.867601  -0.190160   2.753432
# A1BG-AS1   0.933188   0.148014   2.245506
# A1CF      -1.243680  -0.042116  -2.034372
# A2M       -0.278881   1.293716   1.761829
# A2ML1     -2.183079  -0.342340  -2.171190
# ...             ...        ...        ...
# ZYG11A     1.435610  -1.461164  -4.537579
# ZYG11B     0.494374  -0.555147  -0.049674
# ZYX        2.161142   1.830761   3.209167
# ZZEF1     -0.456133  -0.135392   0.026198
# ZZZ3       0.786784   0.245289   2.194536
#
# [16561 rows x 46 columns]

# %% [markdown]
# Use selected clinical data and genetic data to generate the merged data:

# %%
merged_data = geo_merge_clinical_genetic_data(selected_clinical_data, genetic_data)
is_available = True

merged_data
# Out:
#            Uterine Carcinosarcoma      A1BG  A1BG-AS1      A1CF       A2M  \
# GSM804806                     1.0 -0.428374  0.112597 -0.414572 -1.598132
# GSM804807                     1.0 -1.185519 -2.545402  1.155139  1.704536
# GSM804808                     1.0  0.905210  0.345880  0.204161 -1.966787
# GSM804809                     1.0  2.229184  2.294041  1.504030  2.845671
# GSM804810                     0.0 -0.807230 -1.484570 -0.382042 -0.677535
# GSM804811                     0.0 -1.049002 -2.047867 -0.231401 -1.352631
# GSM804812                     0.0 -0.788316 -1.833521 -0.411998  0.799846
# GSM804813                     0.0  0.264672  0.289472  0.456773  2.531783
# GSM804814                     0.0 -0.209491 -0.083492  0.943821 -1.624713
# GSM804815                     0.0 -0.711295 -0.891364  1.132380  0.691356
# GSM804816                     0.0  1.390606  1.282936  3.383030 -2.642929
# GSM804817                     0.0 -0.710139 -1.324518  0.761841 -0.306831
# GSM804818                     0.0 -0.695229 -1.173119 -0.244067  0.907819
# GSM804819                     0.0 -0.678943 -0.156337 -0.638632 -0.573290
# GSM804820                     0.0 -0.496459 -0.800597  0.595749 -1.445540
# GSM804821                     0.0 -1.151215 -1.664488 -0.477416  0.273552
# GSM804822                     0.0  0.144806  0.083492  0.424055  0.915587
# GSM804823                     0.0 -0.086049 -2.993872  1.464892 -0.538263
# GSM804824                     0.0 -0.239160 -2.717205  1.586744 -0.896581
# GSM804825                     0.0  1.592178  0.975936  0.030208 -0.601298
# GSM804826                     0.0 -1.440316 -2.891729 -0.143917 -0.869317
# GSM804827                     0.0 -0.391704 -2.920563  1.217825 -0.287837
# GSM804828                     0.0 -0.947486 -1.966007  0.496773 -0.536419
# GSM804829                     1.0  1.486913  0.520850 -0.165696  0.379681
# GSM804830                     1.0  2.494610  0.341135  0.327582 -0.464571
# GSM804831                     0.0  3.154453  2.098560 -0.626915 -0.012141
# GSM804832                     0.0  3.310801  2.515681  0.619570  0.439519
# GSM804833                     1.0  1.433587  0.418731 -1.142217 -0.584583
# GSM804834                     1.0  2.133157  0.831940 -0.521483  0.502314
# GSM804835                     1.0  1.108337 -0.210808 -1.145994  0.537817
# GSM804836                     1.0  1.058905  0.151941  0.871079  0.198332
# GSM804837                     0.0  1.254195 -0.098369 -0.616145  2.734587
# GSM804838                     0.0  0.925874  0.535786 -0.087363  2.092790
# GSM804839                     1.0 -0.491566 -0.877648 -2.027935 -0.567667
# GSM804840                     0.0 -0.960238 -2.012282  0.020990 -1.272291
# GSM804841                     0.0 -0.744778 -0.684135 -0.363746 -0.179080
# GSM804842                     0.0 -0.267915  0.349333  0.474575  0.239463
# GSM804843                     1.0  3.873424  1.197180  0.438384  0.176425
# GSM804844                     1.0  2.243029  2.109467  3.451386  0.871290
# GSM804845                     1.0  1.406519  1.263221 -0.047563  0.008356
# GSM804846                     0.0 -1.114534 -1.091778 -1.147372 -0.008356
# GSM804847                     0.0 -0.738209 -0.798120 -0.428677  0.070050
# GSM804848                     0.0  2.528905  2.082527 -2.186289  2.499900
# GSM804849                     0.0  3.867601  0.933188 -1.243680 -0.278881
# GSM804850                     0.0 -0.190160  0.148014 -0.042116  1.293716
# GSM804851                     0.0  2.753432  2.245506 -2.034372  1.761829
#
#               A2ML1    A4GALT     A4GNT      AAAS      AACS  ...      ZW10  \
# GSM804806 -0.518708 -0.535701 -0.002069 -0.439697  1.063816  ...  0.450995
# GSM804807 -0.038120 -0.203013  0.038813  0.094731 -0.858164  ... -0.860528
# GSM804808  0.456291  0.118227 -0.125198 -0.117670  0.191601  ... -0.252260
# GSM804809  0.202503 -0.192439  2.072114  0.065774 -0.172029  ... -0.855826
# GSM804810  0.341105  0.708834 -0.136926  0.438900  1.311179  ... -0.385150
# GSM804811  0.115908  0.958485  0.205130  0.523745  0.961093  ...  0.236782
# GSM804812 -0.303251  1.216622 -0.644191  0.039782  0.429529  ...  0.062859
# GSM804813  0.185458  0.313938  0.135998 -0.491464 -0.250708  ... -0.560690
# GSM804814  1.257013  0.435924  0.782212  0.704644 -0.677270  ... -0.489612
# GSM804815  0.833159 -0.674847  0.002069  0.539719  1.217782  ... -0.388823
# GSM804816  2.648696  4.266148  1.873615  0.936284 -1.025969  ... -1.319454
# GSM804817  1.003293  0.240304  1.680693  0.199918 -0.237229  ... -0.120971
# GSM804818 -0.471869  1.219427  1.364358 -0.458223 -0.305900  ...  0.343450
# GSM804819 -0.507522  0.114590 -0.662183 -0.352016  0.663802  ...  0.613100
# GSM804820  0.019770 -0.467467  0.403535  0.742528 -0.130062  ... -0.448057
# GSM804821 -0.989811 -0.482698 -0.426089 -0.677159 -0.541754  ...  0.322448
# GSM804822  0.358494  1.765673  0.297714  0.008301  0.469327  ... -0.126956
# GSM804823  1.489029 -0.829083  2.208626 -0.216270  0.090918  ... -0.048181
# GSM804824  1.286853  0.476571  0.878753  0.091504 -0.903709  ... -1.653787
# GSM804825  0.479584 -2.225916  0.155777 -0.491296  0.043430  ...  0.551731
# GSM804826  0.566475 -3.802507 -0.507620 -0.276853  0.458997  ...  0.056492
# GSM804827  1.529358  2.151565  0.318772  0.176628  0.690347  ... -1.138734
# GSM804828  0.476637  0.564874 -0.289421  0.037816  0.927539  ...  0.542744
# GSM804829  0.132478 -2.097306  0.972855 -0.331540 -0.404445  ...  0.682768
# GSM804830 -0.430228 -1.888709 -0.302574 -0.596609 -0.271755  ...  0.682431
# GSM804831 -0.353055 -1.451781  0.155805 -0.173156 -0.467281  ...  0.964643
# GSM804832 -0.019770 -0.048056  0.700765 -0.608933 -0.211051  ... -0.074140
# GSM804833 -0.389882 -2.938521 -0.049035 -0.626174 -0.895535  ...  0.619037
# GSM804834 -0.303972 -0.777917 -0.462536 -0.276447 -0.250623  ... -0.331474
# GSM804835 -0.511210  0.048056  0.484864 -0.368123 -0.007846  ...  0.282319
# GSM804836 -0.362843 -0.943148 -1.236628 -1.013508 -0.735527  ...  0.995773
# GSM804837 -0.427429 -2.364447 -1.174838 -1.350340  0.359030  ...  0.291943
# GSM804838 -0.821037 -1.609256 -0.250885 -1.535690 -0.050420  ...  0.156243
# GSM804839 -1.068218 -0.322649 -1.344134 -0.586410  0.115810  ...  1.477607
# GSM804840  0.270757  1.582611  0.138080  0.695660  0.909899  ... -0.429920
# GSM804841 -0.492266  0.681176 -0.392032  0.032570  0.136582  ...  0.048181
# GSM804842  0.330738  1.709726  0.190537  0.310947 -0.112710  ... -1.166853
# GSM804843  0.591233 -0.346614  0.128811  0.266102  0.007846  ...  0.108862
# GSM804844  3.242414  4.464290  2.267247  1.119255 -0.920048  ... -0.788216
# GSM804845  0.461115 -0.877938 -0.132084 -0.338088  0.263310  ... -0.063442
# GSM804846 -0.455732 -0.516802 -0.332936 -0.008301  0.426692  ...  0.130259
# GSM804847 -0.314194  0.932867 -0.122364  0.035001  0.065712  ... -0.301434
# GSM804848 -1.701203  0.342192 -1.133815 -0.068205 -0.221498  ... -0.357454
# GSM804849 -2.183079 -0.369607 -1.055983  1.106097 -0.019953  ...  0.688094
# GSM804850 -0.342340  0.524866 -0.202258  0.368563  0.146014  ...  0.256675
# GSM804851 -2.171190  0.456490 -1.012704  0.708047  0.286111  ... -1.068768
#
#              ZWILCH     ZWINT      ZXDA      ZXDC    ZYG11A    ZYG11B  \
# GSM804806  0.924672  1.158071 -1.622256 -0.265457  1.133136  0.220626
# GSM804807  0.738762 -0.051341 -0.870751  0.449170 -0.275506  0.242326
# GSM804808  0.440445 -0.285612  0.301058  0.333735  1.333713  0.234571
# GSM804809 -0.030349  0.471311  0.735769  1.174360 -1.295064  0.625795
# GSM804810 -0.205619 -2.443651 -0.599441  0.757772 -2.577468 -0.150644
# GSM804811  0.991536  1.121354 -0.499197  0.220960  2.349671 -0.156697
# GSM804812 -0.174568  0.051341  0.378341  0.242360 -1.714859 -0.340128
# GSM804813 -0.882830 -3.383250  1.279682  0.072676 -3.270926  0.306694
# GSM804814  0.285653 -0.199854 -0.677793  0.177832 -2.733860 -0.270027
# GSM804815  0.550212  0.093551 -0.364940  0.475117 -1.295885 -0.403181
# GSM804816  0.997735 -1.657218 -1.653960  0.125274 -0.280738 -2.429900
# GSM804817  0.029628  1.032496  0.148143 -0.032924  3.125128 -0.353407
# GSM804818 -0.198261 -0.475754  0.400482 -0.164801  0.010023 -0.507770
# GSM804819  0.249747  1.181405 -1.371973 -0.345682  1.273870 -0.508618
# GSM804820 -0.125666 -0.155693 -0.131671  0.757868  2.822178 -0.290649
# GSM804821  0.121805  0.814852  0.250706 -0.070842  2.958247 -0.228590
# GSM804822 -0.439043 -0.344149  0.242552 -0.211427 -0.888919 -0.609752
# GSM804823 -0.440257  0.357764  0.955712  0.488899  1.583009 -0.157970
# GSM804824  0.011096 -1.474104  0.448934  1.218168  0.502213 -0.327501
# GSM804825 -0.439228  1.111326 -0.125265 -0.581414  4.980460  0.636777
# GSM804826  0.121764 -1.221214  0.083440  0.440602 -0.620730  0.046389
# GSM804827 -0.535348 -2.978836  0.901714  0.873914 -1.257772 -0.590603
# GSM804828 -0.313499  0.515259  0.401607 -0.035947 -0.162818  0.333844
# GSM804829  0.324120  0.598722 -0.107376 -0.220175 -0.824041  0.276640
# GSM804830  0.502359  0.499929 -0.319925  0.218914  0.905663  0.226767
# GSM804831  0.499443  0.252018 -0.110771 -0.903009  1.663458  0.161380
# GSM804832  0.406045 -0.486830  1.134279 -0.098571 -2.784843  0.640802
# GSM804833 -0.810250 -0.213049  0.285294  0.408258  0.434050  0.613999
# GSM804834  0.260128  0.321089  0.248201 -0.067904 -0.010023 -0.038355
# GSM804835 -0.924900 -0.670668  0.104423 -0.072448  1.567791  0.435961
# GSM804836 -0.669605  1.253273  0.187346 -0.185491  2.251003  0.168862
# GSM804837  0.762170  0.425143  1.466680 -0.740152 -0.730564  1.696093
# GSM804838 -0.011096 -0.141149  1.801681 -0.436141 -3.541426  1.605734
# GSM804839 -0.037054  0.475747 -0.105539 -0.691089  0.999619  0.057841
# GSM804840 -0.694727 -1.110717 -0.491345  0.220623  0.016479 -0.508697
# GSM804841  0.379861  0.351188  0.017402  0.558123 -4.197624 -0.393444
# GSM804842 -0.559028 -0.825490 -0.656588  0.027825 -3.277940 -1.379437
# GSM804843  1.134451 -0.336857 -0.096910  0.089705  0.084062 -0.171540
# GSM804844  0.770539 -1.887722  0.371753 -0.458492  0.138241 -1.479160
# GSM804845  0.870010  0.890022 -2.463706 -0.328319  1.957550  0.156511
# GSM804846  0.538910  1.107416 -0.942750  0.491962 -0.441590  0.443674
# GSM804847 -0.194717 -0.358971 -1.337905  0.113667  0.420463 -0.593189
# GSM804848 -0.814285  1.257436  0.740486 -1.181619 -4.701589  0.641436
# GSM804849 -0.476535  0.422736  0.789530 -1.075626  1.435610  0.494374
# GSM804850 -1.695494 -1.434581 -0.916578 -0.647612 -1.461164 -0.555147
# GSM804851 -1.728762 -1.183928  0.344576 -1.654749 -4.537579 -0.049674
#
#                 ZYX     ZZEF1      ZZZ3
# GSM804806 -0.634988  0.394825  0.058989
# GSM804807  0.121760  0.374459 -0.414844
# GSM804808 -0.194830  0.132402 -0.250578
# GSM804809  1.395852  0.041250  0.587149
# GSM804810 -1.072702  0.402375 -0.111271
# GSM804811 -0.492642  0.242625  0.006584
# GSM804812 -0.378221  0.056147  0.233355
# GSM804813  1.186319 -0.190490 -0.006584
# GSM804814 -0.190907  0.399305 -0.086750
# GSM804815 -0.269548  0.309058 -0.108851
# GSM804816  0.240540  1.137678 -1.233861
# GSM804817 -0.600680 -0.010966 -0.096380
# GSM804818  0.225622 -0.089319 -0.076195
# GSM804819 -1.324914 -0.624030  0.212984
# GSM804820 -0.685346 -0.246397  0.382994
# GSM804821  0.426789 -0.132319  0.722928
# GSM804822 -0.300030 -0.483364  0.236458
# GSM804823 -0.226357  0.381257  0.344757
# GSM804824 -0.322909  0.699587 -0.489933
# GSM804825 -0.336617  0.615980  0.250000
# GSM804826 -0.806211  0.261524 -0.142458
# GSM804827 -0.901914  0.235393  0.017938
# GSM804828 -0.065670  0.027490 -0.164481
# GSM804829  0.099597 -0.259003 -0.171322
# GSM804830  0.405154 -0.673711  0.662017
# GSM804831  1.399043 -0.069165  0.477886
# GSM804832  0.650824 -0.704572 -0.370144
# GSM804833  0.308989 -0.286188 -0.051157
# GSM804834  1.155498 -0.983259 -0.541571
# GSM804835  0.804173 -0.302328  0.172665
# GSM804836 -0.005596  0.202087 -0.177840
# GSM804837  2.994437  0.010174  0.490109
# GSM804838  2.228283 -0.150764  0.442497
# GSM804839  0.374156 -0.558254  0.300191
# GSM804840 -1.506856 -0.170618 -0.480386
# GSM804841 -0.498142  0.319042  0.062288
# GSM804842 -1.017909 -0.113832 -0.669802
# GSM804843  0.279231 -0.182934 -0.270942
# GSM804844  0.103642  0.602217 -2.356920
# GSM804845 -0.334219 -0.232841 -0.634593
# GSM804846 -0.389594 -0.079149  0.783653
# GSM804847  0.005596 -0.002652 -0.394218
# GSM804848  2.668182 -1.439755  0.223815
# GSM804849  2.161142 -0.456133  0.786784
# GSM804850  1.830761 -0.135392  0.245289
# GSM804851  3.209167  0.026198  2.194536
#
# [46 rows x 16562 columns]

# %% [markdown]
# Check if the merged data biased or not:

# %%
trait_type = 'binary'
print(f"The merged dataset contains {len(merged_data)} samples.")
is_trait_biased, merged_data = judge_and_remove_biased_features(merged_data, TRAIT, trait_type=trait_type)
is_trait_biased
# Out:
# The merged dataset contains 46 samples.
# For the feature 'Uterine Carcinosarcoma', the least common label is '1.0' with 14 occurrences. This represents 30.43% of the dataset.
# The distribution of the feature 'Uterine Carcinosarcoma' in this dataset is fine.
# False

# %% [markdown]
# Save the data as a csv file:

# %%
if is_available:
    save_cohort_info(cohort, JSON_PATH, is_available, is_trait_biased, merged_data, note='')
else:
    save_cohort_info(cohort, JSON_PATH, is_available)
merged_data.head()
if not is_trait_biased:
    merged_data.to_csv(os.path.join(OUTPUT_DIR, cohort + '.csv'), index=False)
