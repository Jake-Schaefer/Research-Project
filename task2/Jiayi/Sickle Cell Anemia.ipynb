# %% [markdown]
# # 1. Basic setup

# %%
import os
import sys

sys.path.append('..')
from utils import *

USER = "Jiayi"
DATA_ROOT = '/Users/legion/Desktop/Courses/IS389/data'   
OUTPUT_ROOT = '/Users/legion/Desktop/Courses/IS389/output2'
TRAIT = "Sickle Cell Anemia"

OUTPUT_DIR = os.path.join(OUTPUT_ROOT, USER, '-'.join(TRAIT.split()))
JSON_PATH = os.path.join(OUTPUT_DIR, "cohort_info.json")
if not os.path.exists(OUTPUT_DIR):
    os.makedirs(OUTPUT_DIR, exist_ok=True)

# %% [markdown]
# ## The GEO dataset

# %%
dataset = 'GEO'
trait_subdir = "Sickle-Cell-Anemia"

trait_path = os.path.join(DATA_ROOT, dataset, trait_subdir)
os.listdir(trait_path)
# Out:
# ['GSE11372',
#  'GSE11524',
#  'GSE117613',
#  'GSE16728',
#  'GSE17078',
#  'GSE1849',
#  'GSE35007',
#  'GSE41575',
#  'GSE46471',
#  'GSE53441',
#  'GSE84632',
#  'GSE84633',
#  'GSE84634',
#  'GSE84635',
#  'GSE9877']

# %% [markdown]
# Repeat the below steps for all the accession numbers

# %%
# No obvious trait
cohort = accession_num = "GSE11372"
cohort_dir = os.path.join(trait_path, accession_num)
soft_file, matrix_file = geo_get_relevant_filepaths(cohort_dir)
soft_file, matrix_file
# Out:
# ('/Users/legion/Desktop/Courses/IS389/data\\GEO\\Sickle-Cell-Anemia\\GSE11372\\GSE11372_family.soft.gz',
#  '/Users/legion/Desktop/Courses/IS389/data\\GEO\\Sickle-Cell-Anemia\\GSE11372\\GSE11372-GPL1426_series_matrix.txt.gz')

# %%
# Finished
cohort = accession_num = "GSE11524"
cohort_dir = os.path.join(trait_path, accession_num)
soft_file, matrix_file = geo_get_relevant_filepaths(cohort_dir)
soft_file, matrix_file
# Out:
# ('/Users/legion/Desktop/Courses/IS389/data\\GEO\\Sickle-Cell-Anemia\\GSE11524\\GSE11524_family.soft.gz',
#  '/Users/legion/Desktop/Courses/IS389/data\\GEO\\Sickle-Cell-Anemia\\GSE11524\\GSE11524_series_matrix.txt.gz')

# %%
# Finished
cohort = accession_num = "GSE117613"
cohort_dir = os.path.join(trait_path, accession_num)
soft_file, matrix_file = geo_get_relevant_filepaths(cohort_dir)
soft_file, matrix_file
# Out:
# ('/Users/legion/Desktop/Courses/IS389/data\\GEO\\Sickle-Cell-Anemia\\GSE117613\\GSE117613_family.soft.gz',
#  '/Users/legion/Desktop/Courses/IS389/data\\GEO\\Sickle-Cell-Anemia\\GSE117613\\GSE117613_series_matrix.txt.gz')

# %%
# Finished
cohort = accession_num = "GSE16728"
cohort_dir = os.path.join(trait_path, accession_num)
soft_file, matrix_file = geo_get_relevant_filepaths(cohort_dir)
soft_file, matrix_file
# Out:
# ('/Users/legion/Desktop/Courses/IS389/data\\GEO\\Sickle-Cell-Anemia\\GSE16728\\GSE16728_family.soft.gz',
#  '/Users/legion/Desktop/Courses/IS389/data\\GEO\\Sickle-Cell-Anemia\\GSE16728\\GSE16728_series_matrix.txt.gz')

# %%
# Finished
cohort = accession_num = "GSE17078"
cohort_dir = os.path.join(trait_path, accession_num)
soft_file, matrix_file = geo_get_relevant_filepaths(cohort_dir)
soft_file, matrix_file
# Out:
# ('/Users/legion/Desktop/Courses/IS389/data\\GEO\\Sickle-Cell-Anemia\\GSE17078\\GSE17078_family.soft.gz',
#  '/Users/legion/Desktop/Courses/IS389/data\\GEO\\Sickle-Cell-Anemia\\GSE17078\\GSE17078_series_matrix.txt.gz')

# %%
# 
cohort = accession_num = "GSE1849"
cohort_dir = os.path.join(trait_path, accession_num)
soft_file, matrix_file = geo_get_relevant_filepaths(cohort_dir)
soft_file, matrix_file
# Out:
# ('/Users/legion/Desktop/Courses/IS389/data\\GEO\\Sickle-Cell-Anemia\\GSE1849\\GSE1849_family.soft.gz',
#  '/Users/legion/Desktop/Courses/IS389/data\\GEO\\Sickle-Cell-Anemia\\GSE1849\\GSE1849-GPL96_series_matrix.txt.gz')

# %%
# Empty
cohort = accession_num = "GSE35007"
cohort_dir = os.path.join(trait_path, accession_num)
soft_file, matrix_file = geo_get_relevant_filepaths(cohort_dir)
soft_file, matrix_file

# %%
# No gene mapping
cohort = accession_num = "GSE41575"
cohort_dir = os.path.join(trait_path, accession_num)
soft_file, matrix_file = geo_get_relevant_filepaths(cohort_dir)
soft_file, matrix_file
# Out:
# ('/Users/legion/Desktop/Courses/IS389/data\\GEO\\Sickle-Cell-Anemia\\GSE41575\\GSE41575_family.soft.gz',
#  '/Users/legion/Desktop/Courses/IS389/data\\GEO\\Sickle-Cell-Anemia\\GSE41575\\GSE41575-GPL14550_series_matrix.txt.gz')

# %%
# Finished
cohort = accession_num = "GSE46471"
cohort_dir = os.path.join(trait_path, accession_num)
soft_file, matrix_file = geo_get_relevant_filepaths(cohort_dir)
soft_file, matrix_file
# Out:
# ('/Users/legion/Desktop/Courses/IS389/data\\GEO\\Sickle-Cell-Anemia\\GSE46471\\GSE46471_family.soft.gz',
#  '/Users/legion/Desktop/Courses/IS389/data\\GEO\\Sickle-Cell-Anemia\\GSE46471\\GSE46471_series_matrix.txt.gz')

# %%
# Finished
cohort = accession_num = "GSE53441"
cohort_dir = os.path.join(trait_path, accession_num)
soft_file, matrix_file = geo_get_relevant_filepaths(cohort_dir)
soft_file, matrix_file
# Out:
# ('/Users/legion/Desktop/Courses/IS389/data\\GEO\\Sickle-Cell-Anemia\\GSE53441\\GSE53441_family.soft.gz',
#  '/Users/legion/Desktop/Courses/IS389/data\\GEO\\Sickle-Cell-Anemia\\GSE53441\\GSE53441_series_matrix.txt.gz')

# %%
# Biased
cohort = accession_num = "GSE84632"
cohort_dir = os.path.join(trait_path, accession_num)
soft_file, matrix_file = geo_get_relevant_filepaths(cohort_dir)
soft_file, matrix_file
# Out:
# ('/Users/legion/Desktop/Courses/IS389/data\\GEO\\Sickle-Cell-Anemia\\GSE84632\\GSE84632_family.soft.gz',
#  '/Users/legion/Desktop/Courses/IS389/data\\GEO\\Sickle-Cell-Anemia\\GSE84632\\GSE84632_series_matrix.txt.gz')

# %%
# Biased
cohort = accession_num = "GSE84633"
cohort_dir = os.path.join(trait_path, accession_num)
soft_file, matrix_file = geo_get_relevant_filepaths(cohort_dir)
soft_file, matrix_file
# Out:
# ('/Users/legion/Desktop/Courses/IS389/data\\GEO\\Sickle-Cell-Anemia\\GSE84633\\GSE84633_family.soft.gz',
#  '/Users/legion/Desktop/Courses/IS389/data\\GEO\\Sickle-Cell-Anemia\\GSE84633\\GSE84633_series_matrix.txt.gz')

# %%
# Biased
cohort = accession_num = "GSE84634"
cohort_dir = os.path.join(trait_path, accession_num)
soft_file, matrix_file = geo_get_relevant_filepaths(cohort_dir)
soft_file, matrix_file
# Out:
# ('/Users/legion/Desktop/Courses/IS389/data\\GEO\\Sickle-Cell-Anemia\\GSE84634\\GSE84634_family.soft.gz',
#  '/Users/legion/Desktop/Courses/IS389/data\\GEO\\Sickle-Cell-Anemia\\GSE84634\\GSE84634_series_matrix.txt.gz')

# %%
# Biased
cohort = accession_num = "GSE84635"
cohort_dir = os.path.join(trait_path, accession_num)
soft_file, matrix_file = geo_get_relevant_filepaths(cohort_dir)
soft_file, matrix_file
# Out:
# ('/Users/legion/Desktop/Courses/IS389/data\\GEO\\Sickle-Cell-Anemia\\GSE84635\\GSE84635_family.soft.gz',
#  '/Users/legion/Desktop/Courses/IS389/data\\GEO\\Sickle-Cell-Anemia\\GSE84635\\GSE84635-GPL16686_series_matrix.txt.gz')

# %%
# No obvious trait
cohort = accession_num = "GSE9877"
cohort_dir = os.path.join(trait_path, accession_num)
soft_file, matrix_file = geo_get_relevant_filepaths(cohort_dir)
soft_file, matrix_file
# Out:
# ('/Users/legion/Desktop/Courses/IS389/data\\GEO\\Sickle-Cell-Anemia\\GSE9877\\GSE9877_family.soft.gz',
#  '/Users/legion/Desktop/Courses/IS389/data\\GEO\\Sickle-Cell-Anemia\\GSE9877\\GSE9877_series_matrix.txt.gz')

# %% [markdown]
# ### Initial filtering and clinical data preprocessing

# %%
from utils import *
background_prefixes = ['!Series_title', '!Series_summary', '!Series_overall_design']
clinical_prefixes = ['!Sample_geo_accession', '!Sample_characteristics_ch1']    

background_info, clinical_data = get_background_and_clinical_data(matrix_file, background_prefixes, clinical_prefixes)
print(background_info)
# Out:
# !Series_title	"Genetic Endothelial Systems Biology of Sickle Stroke Risk"
# !Series_summary	"Genetic differences in endothelial biology could underlie development of phenotypic heterogeneity amongst individuals afflicted with vascular diseases. We obtained BOEC (blood outgrowth endothelial cells) from 20 subjects with sickle cell anemia (age 4-19) shown to be either at-risk (n=11) or not-at-risk (n=9) for ischemic stroke due to, respectively, having or not having occlusive disease at the Circle of Willis (CoW)."
# !Series_summary	"Gene expression profiling identified no significant single gene differences between the two groups, as expected. However, analysis of Biological Systems Scores, using gene sets that were pre-determined to survey each of nine biological systems, showed that only changes in inflammation signaling are characteristic of the at-risk subjects, as supported by multiple statistical approaches"
# !Series_summary	"Keywords: disease status analysis"
# !Series_overall_design	"We obtained BOEC (blood outgrowth endothelial cells) from 20 subjects with sickle cell anemia (age 4-19) shown to be either at-risk (n=11) or not-at-risk (n=9) for ischemic stroke due to, respectively, having or not having occlusive disease at the Circle of Willis (CoW). To allow power calculations to be done, we performed microarray analysis on BOEC from 27 normal subjects of diverse ages. Gene expression profilings were obtained by using Affymetrix U133A chips"

# %%
clinical_data.head()
# Out:
#          !Sample_geo_accession                                    GSM249425  \
# 0  !Sample_characteristics_ch1  cell type: blood outgrowth endothelial cell
# 1  !Sample_characteristics_ch1                               status: normal
# 2  !Sample_characteristics_ch1                       race: African American
# 3  !Sample_characteristics_ch1                                      age: 50
# 4  !Sample_characteristics_ch1                                       sex: F
#
#                                      GSM249426  \
# 0  cell type: blood outgrowth endothelial cell
# 1                               status: normal
# 2                       race: African American
# 3                                      age: 60
# 4                                       sex: M
#
#                                      GSM249427  \
# 0  cell type: blood outgrowth endothelial cell
# 1                               status: normal
# 2                       race: African American
# 3                                      age: 53
# 4                                       sex: F
#
#                                      GSM249428  \
# 0  cell type: blood outgrowth endothelial cell
# 1                               status: normal
# 2                       race: African American
# 3                                      age: 40
# 4                                       sex: F
#
#                                      GSM249429  \
# 0  cell type: blood outgrowth endothelial cell
# 1                               status: normal
# 2                       race: African American
# 3                                      age: 41
# 4                                       sex: M
#
#                                      GSM249430  \
# 0  cell type: blood outgrowth endothelial cell
# 1                               status: normal
# 2                       race: African American
# 3                                      age: 33
# 4                                       sex: M
#
#                                      GSM249431  \
# 0  cell type: blood outgrowth endothelial cell
# 1                               status: normal
# 2                       race: African American
# 3                                      age: 23
# 4                                       sex: F
#
#                                      GSM249432  \
# 0  cell type: blood outgrowth endothelial cell
# 1                               status: normal
# 2                              race: Caucasian
# 3                                      age: 46
# 4                                       sex: M
#
#                                      GSM249433  ...   GSM249462   GSM249463  \
# 0  cell type: blood outgrowth endothelial cell  ...  At Risk: +  At Risk: +
# 1                               status: normal  ...     Age: 10      Age: 4
# 2                       race: African American  ...      Sex: F      Sex: F
# 3                                      age: 31  ...         NaN         NaN
# 4                                       sex: F  ...         NaN         NaN
#
#     GSM249464   GSM249465   GSM249466   GSM249467   GSM249468   GSM249469  \
# 0  At Risk: +  At Risk: +  At Risk: +  At Risk: +  At Risk: +  At Risk: +
# 1     Age: 13      Age: 9     Age: 19     Age: 18     Age: 13     Age: 12
# 2      Sex: M      Sex: F      Sex: F      Sex: M      Sex: F      Sex: M
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#     GSM249470   GSM249471
# 0  At Risk: +  At Risk: +
# 1     Age: 16     Age: 18
# 2      Sex: F      Sex: M
# 3         NaN         NaN
# 4         NaN         NaN
#
# [5 rows x 48 columns]

# %% [markdown]
# Analyze the trait row:

# %%
tumor_stage_row = clinical_data.iloc[1]
tumor_stage_row.unique()
# Out:
# array(['!Sample_characteristics_ch1', 'status: normal', 'Age: 11',
#        'Age: 15', 'Age: 8', 'Age: 14', 'Age: 17', 'Age: 12', 'Age: 10',
#        'Age: 4', 'Age: 13', 'Age: 9', 'Age: 19', 'Age: 18', 'Age: 16'],
#       dtype=object)

# %% [markdown]
# Determine the trait row, age row, and gender row. Then implement the conversion functions:

# %%
trait_row = 0
age_row = None
gender_row = None

def convert_trait(trait):
    if (trait == 'diagnosis: normal'):
        return 0
    else:
        return 1


def convert_age(age_string):
    if age_string.lower() == 'n.a.':
        return None
    try:
        age = int(age_string.split(':')[1])
        age = round(age, 0)
        return age
    except (ValueError, IndexError):
        return None

def convert_gender(gender_string):
    if (gender_string.lower() == 'sex: female' or gender_string.lower() == 'sex: f' or gender_string.lower() == 'gender: female' or gender_string.lower() == 'gender: f'):
        return 1
    elif (gender_string.lower() == 'sex: male' or gender_string.lower() == 'sex: m' or gender_string.lower() == 'gender: male' or gender_string.lower() == 'gender: m') :  # changeed 
        return 0
    else:
        return None

# %% [markdown]
# Check the processed clinical data:

# %%
selected_clinical_data = geo_select_clinical_features(clinical_data, TRAIT, trait_row, convert_trait, age_row=age_row,
                                                      convert_age=convert_age, gender_row=gender_row,
                                                      convert_gender=convert_gender)
selected_clinical_data.head()
# Out:
# c:\Users\legion\Desktop\TAIS_2024SP\TAIS_2024SP\task2\Jiayi\utils.py:218: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   clinical_df = clinical_df.applymap(convert_fn)
#                     GSM1293592  GSM1293593  GSM1293594  GSM1293595  \
# Sickle Cell Anemia           1           1           1           1
#
#                     GSM1293596  GSM1293597  GSM1293598  GSM1293599  \
# Sickle Cell Anemia           1           1           1           1
#
#                     GSM1293600  GSM1293601  ...  GSM1293616  GSM1293617  \
# Sickle Cell Anemia           1           1  ...           0           0
#
#                     GSM1293618  GSM1293619  GSM1293620  GSM1293621  \
# Sickle Cell Anemia           0           0           0           0
#
#                     GSM1293622  GSM1293623  GSM1293624  GSM1293625
# Sickle Cell Anemia           0           0           0           0
#
# [1 rows x 34 columns]

# %% [markdown]
# ### Genetic data preprocessing and final filtering

# %% [markdown]
# Check the genetic data:

# %%
genetic_data = get_genetic_data(matrix_file)
genetic_data.head()
# Out:
#            GSM1293592  GSM1293593  GSM1293594  GSM1293595  GSM1293596  \
# ID
# 1007_s_at        6.26        6.62        6.36        6.44        6.67
# 1053_at          7.30        6.70        6.89        7.34        7.26
# 117_at           7.59        8.37        7.97        8.18        7.85
# 121_at           7.50        7.50        7.40        7.38        7.85
# 1255_g_at        2.89        2.90        2.80        2.74        2.88
#
#            GSM1293597  GSM1293598  GSM1293599  GSM1293600  GSM1293601  ...  \
# ID                                                                     ...
# 1007_s_at        6.48        6.36        6.82        6.35        6.44  ...
# 1053_at          7.32        7.22        7.24        7.42        7.34  ...
# 117_at           8.71        8.54        8.19        7.66        7.88  ...
# 121_at           7.43        7.58        7.66        7.33        7.41  ...
# 1255_g_at        2.99        2.77        2.60        2.79        2.76  ...
#
#            GSM1293616  GSM1293617  GSM1293618  GSM1293619  GSM1293620  \
# ID
# 1007_s_at        6.27        6.11        6.47        6.28        6.47
# 1053_at          7.36        7.42        7.24        7.28        7.30
# 117_at           7.63        7.79        7.31        7.68        8.07
# 121_at           7.23        7.29        7.29        7.42        7.49
# 1255_g_at        2.94        2.79        2.75        2.78        2.94
#
#            GSM1293621  GSM1293622  GSM1293623  GSM1293624  GSM1293625
# ID
# 1007_s_at        6.35        6.59        6.35        6.50        5.94
# 1053_at          7.21        7.34        7.28        7.39        7.04
# 117_at           7.74        7.50        8.80        7.57        7.43
# 121_at           7.25        7.34        7.31        7.33        6.83
# 1255_g_at        2.74        2.75        2.85        2.86        3.01
#
# [5 rows x 34 columns]

# %% [markdown]
# Check if the gene dataset requires mapping to get the gene symbols corresponding to each data row.

# %%
requires_gene_mapping = True

if requires_gene_mapping:
    gene_annotation = get_gene_annotation(soft_file)
    gene_annotation_summary = preview_df(gene_annotation)
    print(gene_annotation_summary)

gene_annotation.columns
# Out:
# {'ID': ['1007_s_at', '1053_at', '117_at', '121_at', '1255_g_at'], 'GB_ACC': ['U48705', 'M87338', 'X51757', 'X69699', 'L36861'], 'SPOT_ID': [nan, nan, nan, nan, nan], 'Species Scientific Name': ['Homo sapiens', 'Homo sapiens', 'Homo sapiens', 'Homo sapiens', 'Homo sapiens'], 'Annotation Date': ['Oct 6, 2014', 'Oct 6, 2014', 'Oct 6, 2014', 'Oct 6, 2014', 'Oct 6, 2014'], 'Sequence Type': ['Exemplar sequence', 'Exemplar sequence', 'Exemplar sequence', 'Exemplar sequence', 'Exemplar sequence'], 'Sequence Source': ['Affymetrix Proprietary Database', 'GenBank', 'Affymetrix Proprietary Database', 'GenBank', 'Affymetrix Proprietary Database'], 'Target Description': ['U48705 /FEATURE=mRNA /DEFINITION=HSU48705 Human receptor tyrosine kinase DDR gene, complete cds', 'M87338 /FEATURE= /DEFINITION=HUMA1SBU Human replication factor C, 40-kDa subunit (A1) mRNA, complete cds', "X51757 /FEATURE=cds /DEFINITION=HSP70B Human heat-shock protein HSP70B' gene", 'X69699 /FEATURE= /DEFINITION=HSPAX8A H.sapiens Pax8 mRNA', 'L36861 /FEATURE=expanded_cds /DEFINITION=HUMGCAPB Homo sapiens guanylate cyclase activating protein (GCAP) gene exons 1-4, complete cds'], 'Representative Public ID': ['U48705', 'M87338', 'X51757', 'X69699', 'L36861'], 'Gene Title': ['discoidin domain receptor tyrosine kinase 1 /// microRNA 4640', 'replication factor C (activator 1) 2, 40kDa', "heat shock 70kDa protein 6 (HSP70B')", 'paired box 8', 'guanylate cyclase activator 1A (retina)'], 'Gene Symbol': ['DDR1 /// MIR4640', 'RFC2', 'HSPA6', 'PAX8', 'GUCA1A'], 'ENTREZ_GENE_ID': ['780 /// 100616237', '5982', '3310', '7849', '2978'], 'RefSeq Transcript ID': ['NM_001202521 /// NM_001202522 /// NM_001202523 /// NM_001954 /// NM_013993 /// NM_013994 /// NR_039783 /// XM_005249385 /// XM_005249386 /// XM_005249387 /// XM_005249389 /// XM_005272873 /// XM_005272874 /// XM_005272875 /// XM_005272877 /// XM_005275027 /// XM_005275028 /// XM_005275030 /// XM_005275031 /// XM_005275162 /// XM_005275163 /// XM_005275164 /// XM_005275166 /// XM_005275457 /// XM_005275458 /// XM_005275459 /// XM_005275461 /// XM_006715185 /// XM_006715186 /// XM_006715187 /// XM_006715188 /// XM_006715189 /// XM_006715190 /// XM_006725501 /// XM_006725502 /// XM_006725503 /// XM_006725504 /// XM_006725505 /// XM_006725506 /// XM_006725714 /// XM_006725715 /// XM_006725716 /// XM_006725717 /// XM_006725718 /// XM_006725719 /// XM_006725720 /// XM_006725721 /// XM_006725722 /// XM_006725827 /// XM_006725828 /// XM_006725829 /// XM_006725830 /// XM_006725831 /// XM_006725832 /// XM_006726017 /// XM_006726018 /// XM_006726019 /// XM_006726020 /// XM_006726021 /// XM_006726022 /// XR_427836 /// XR_430858 /// XR_430938 /// XR_430974 /// XR_431015', 'NM_001278791 /// NM_001278792 /// NM_001278793 /// NM_002914 /// NM_181471 /// XM_006716080', 'NM_002155', 'NM_003466 /// NM_013951 /// NM_013952 /// NM_013953 /// NM_013992', 'NM_000409 /// XM_006715073'], 'Gene Ontology Biological Process': ['0001558 // regulation of cell growth // inferred from electronic annotation /// 0001952 // regulation of cell-matrix adhesion // inferred from electronic annotation /// 0006468 // protein phosphorylation // inferred from electronic annotation /// 0007155 // cell adhesion // traceable author statement /// 0007169 // transmembrane receptor protein tyrosine kinase signaling pathway // inferred from electronic annotation /// 0007565 // female pregnancy // inferred from electronic annotation /// 0007566 // embryo implantation // inferred from electronic annotation /// 0007595 // lactation // inferred from electronic annotation /// 0008285 // negative regulation of cell proliferation // inferred from electronic annotation /// 0010715 // regulation of extracellular matrix disassembly // inferred from mutant phenotype /// 0014909 // smooth muscle cell migration // inferred from mutant phenotype /// 0016310 // phosphorylation // inferred from electronic annotation /// 0018108 // peptidyl-tyrosine phosphorylation // inferred from electronic  ...
# Index(['ID', 'GB_ACC', 'SPOT_ID', 'Species Scientific Name', 'Annotation Date',
#        'Sequence Type', 'Sequence Source', 'Target Description',
#        'Representative Public ID', 'Gene Title', 'Gene Symbol',
#        'ENTREZ_GENE_ID', 'RefSeq Transcript ID',
#        'Gene Ontology Biological Process', 'Gene Ontology Cellular Component',
#        'Gene Ontology Molecular Function'],
#       dtype='object')

# %%
if requires_gene_mapping:
    identifier_key = 'ID'
    gene_symbol_key = 'Gene Symbol'
    gene_mapping = get_gene_mapping(gene_annotation, identifier_key, gene_symbol_key)
# GSM1293625   4.96    5.56   4.04  ...   6.895   6.25  5.55  4.960  5.963333
#
#             ZYG11A    ZYG11B    ZYX     ZZEF1   ZZZ3
# GSM1293592    4.32  7.133333  8.890  5.856667  7.495
# GSM1293593    4.37  7.016667  9.260  6.500000  7.055
# GSM1293594    4.23  6.723333  9.435  6.313333  7.050
# GSM1293595    4.19  7.323333  9.610  6.313333  7.485
# GSM1293596    4.28  6.870000  9.210  6.313333  6.985
# GSM1293597    4.27  7.216667  9.730  6.206667  7.305
# GSM1293598    4.31  7.013333  9.175  6.386667  7.110
# GSM1293599    4.23  6.983333  9.150  6.343333  7.205
# GSM1293600    4.27  7.260000  8.775  5.833333  7.585
# GSM1293601    4.17  7.166667  9.240  6.220000  7.320
# GSM1293602    4.27  7.146667  9.355  6.203333  7.450
# GSM1293603    4.12  7.253333  9.470  6.290000  7.170
# GSM1293604    4.21  7.246667  9.725  6.233333  7.205
# GSM1293605    4.24  7.283333  9.585  6.236667  7.370
# GSM1293606    4.36  7.076667  9.730  6.296667  7.160
# GSM1293607    4.11  7.190000  9.610  6.300000  7.515
# GSM1293608    4.32  7.076667  8.925  6.276667  7.430
# GSM1293609    4.63  6.603333  9.180  6.323333  7.090
# GSM1293610    4.23  7.386667  9.795  6.266667  7.085
# GSM1293611    3.95  7.276667  9.390  6.040000  7.370
# GSM1293612    4.02  7.106667  9.570  6.133333  7.460
# GSM1293613    3.94  7.110000  9.985  6.303333  7.270
# GSM1293614    4.41  7.113333  9.470  6.213333  7.260
# GSM1293615    4.52  6.450000  9.110  6.186667  7.310
# GSM1293616    4.04  7.260000  9.355  6.146667  7.315
# GSM1293617    3.99  7.416667  9.370  6.200000  7.410
# GSM1293618    4.16  7.513333  8.935  6.013333  7.640
# GSM1293619    4.41  7.443333  9.160  6.076667  7.595
# GSM1293620    3.99  7.456667  9.370  6.173333  7.515
# GSM1293621    4.18  6.993333  9.335  6.320000  7.225
# GSM1293622    4.15  7.333333  9.875  5.950000  7.160
# GSM1293623    3.83  7.453333  9.465  6.276667  7.365
# GSM1293624    4.23  7.236667  9.825  6.166667  7.315
# GSM1293625    4.31  6.880000  9.600  6.403333  7.230
#
# [34 rows x 17858 columns]

# %% [markdown]
# Check if the merged data biased or not:

# %%
trait_type = 'binary'
print(f"The merged dataset contains {len(merged_data)} samples.")
is_trait_biased, merged_data = judge_and_remove_biased_features(merged_data, TRAIT, trait_type=trait_type)
is_trait_biased
# Out:
# The merged dataset contains 34 samples.
# For the feature 'Sickle Cell Anemia', the least common label is '0.0' with 10 occurrences. This represents 29.41% of the dataset.
# The distribution of the feature 'Sickle Cell Anemia' in this dataset is fine.
# False

# %% [markdown]
# Save the data as a csv file:

# %%
is_available = False

if is_available:
    save_cohort_info(cohort, JSON_PATH, is_available, is_trait_biased, merged_data, note='')
else:
    save_cohort_info(cohort, JSON_PATH, is_available)
merged_data.head()
if not is_trait_biased:
    merged_data.to_csv(os.path.join(OUTPUT_DIR, cohort + '.csv'), index=False)
