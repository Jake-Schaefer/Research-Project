# %% [markdown]
# # 1. Basic setup

# %%
import os
import sys

sys.path.append('..')
from utils import *

USER = "Jiayi"
DATA_ROOT = '/Users/legion/Desktop/Courses/IS389/data'   
OUTPUT_ROOT = '/Users/legion/Desktop/Courses/IS389/output2'
TRAIT = 'Mitochondrial Disorders'

OUTPUT_DIR = os.path.join(OUTPUT_ROOT, USER, '-'.join(TRAIT.split()))
JSON_PATH = os.path.join(OUTPUT_DIR, "cohort_info.json")
if not os.path.exists(OUTPUT_DIR):
    os.makedirs(OUTPUT_DIR, exist_ok=True)

# %% [markdown]
# ## The GEO dataset

# %%
dataset = 'GEO'
trait_subdir = "Mitochondrial-Disorders"

trait_path = os.path.join(DATA_ROOT, dataset, trait_subdir)
os.listdir(trait_path)
# Out:
# ['GSE102008',
#  'GSE11204',
#  'GSE125309',
#  'GSE17078',
#  'GSE18123',
#  'GSE22651',
#  'GSE25925',
#  'GSE30933',
#  'GSE42986',
#  'GSE53096',
#  'GSE65399']

# %% [markdown]
# Repeat the below steps for all the accession numbers

# %%
# No obvious trait
cohort = accession_num = "GSE102008"
cohort_dir = os.path.join(trait_path, accession_num)
soft_file, matrix_file = geo_get_relevant_filepaths(cohort_dir)
soft_file, matrix_file
# Out:
# ('/Users/legion/Desktop/Courses/IS389/data\\GEO\\Mitochondrial-Disorders\\GSE102008\\GSE102008_family.soft.gz',
#  '/Users/legion/Desktop/Courses/IS389/data\\GEO\\Mitochondrial-Disorders\\GSE102008\\GSE102008_series_matrix.txt.gz')

# %%
# No obvious trait
cohort = accession_num = "GSE11204"
cohort_dir = os.path.join(trait_path, accession_num)
soft_file, matrix_file = geo_get_relevant_filepaths(cohort_dir)
soft_file, matrix_file
# Out:
# ('/Users/legion/Desktop/Courses/IS389/data\\GEO\\Mitochondrial-Disorders\\GSE11204\\GSE11204_family.soft.gz',
#  '/Users/legion/Desktop/Courses/IS389/data\\GEO\\Mitochondrial-Disorders\\GSE11204\\GSE11204_series_matrix.txt.gz')

# %%
# Biased
cohort = accession_num = "GSE125309"
cohort_dir = os.path.join(trait_path, accession_num)
soft_file, matrix_file = geo_get_relevant_filepaths(cohort_dir)
soft_file, matrix_file
# Out:
# ('/Users/legion/Desktop/Courses/IS389/data\\GEO\\Mitochondrial-Disorders\\GSE125309\\GSE125309_family.soft.gz',
#  '/Users/legion/Desktop/Courses/IS389/data\\GEO\\Mitochondrial-Disorders\\GSE125309\\GSE125309_series_matrix.txt.gz')

# %%
# Finished
cohort = accession_num = "GSE17078"
cohort_dir = os.path.join(trait_path, accession_num)
soft_file, matrix_file = geo_get_relevant_filepaths(cohort_dir)
soft_file, matrix_file
# Out:
# ('/Users/legion/Desktop/Courses/IS389/data\\GEO\\Mitochondrial-Disorders\\GSE17078\\GSE17078_family.soft.gz',
#  '/Users/legion/Desktop/Courses/IS389/data\\GEO\\Mitochondrial-Disorders\\GSE17078\\GSE17078_series_matrix.txt.gz')

# %%
# Finished
cohort = accession_num = "GSE18123"
cohort_dir = os.path.join(trait_path, accession_num)
soft_file, matrix_file = geo_get_relevant_filepaths(cohort_dir)
soft_file, matrix_file
# Out:
# ('/Users/legion/Desktop/Courses/IS389/data\\GEO\\Mitochondrial-Disorders\\GSE18123\\GSE18123_family.soft.gz',
#  '/Users/legion/Desktop/Courses/IS389/data\\GEO\\Mitochondrial-Disorders\\GSE18123\\GSE18123-GPL570_series_matrix.txt.gz')

# %%
# Finished
cohort = accession_num = "GSE22651"
cohort_dir = os.path.join(trait_path, accession_num)
soft_file, matrix_file = geo_get_relevant_filepaths(cohort_dir)
soft_file, matrix_file
# Out:
# ('/Users/legion/Desktop/Courses/IS389/data\\GEO\\Mitochondrial-Disorders\\GSE22651\\GSE22651_family.soft.gz',
#  '/Users/legion/Desktop/Courses/IS389/data\\GEO\\Mitochondrial-Disorders\\GSE22651\\GSE22651_series_matrix.txt.gz')

# %%
# No obvious trait
cohort = accession_num = "GSE25925"
cohort_dir = os.path.join(trait_path, accession_num)
soft_file, matrix_file = geo_get_relevant_filepaths(cohort_dir)
soft_file, matrix_file

# %%
# Finished
cohort = accession_num = "GSE30933"
cohort_dir = os.path.join(trait_path, accession_num)
soft_file, matrix_file = geo_get_relevant_filepaths(cohort_dir)
soft_file, matrix_file
# Out:
# ('/Users/legion/Desktop/Courses/IS389/data\\GEO\\Mitochondrial-Disorders\\GSE30933\\GSE30933_family.soft.gz',
#  '/Users/legion/Desktop/Courses/IS389/data\\GEO\\Mitochondrial-Disorders\\GSE30933\\GSE30933_series_matrix.txt.gz')

# %%
# Finished
cohort = accession_num = "GSE42986"
cohort_dir = os.path.join(trait_path, accession_num)
soft_file, matrix_file = geo_get_relevant_filepaths(cohort_dir)
soft_file, matrix_file
# Out:
# ('/Users/legion/Desktop/Courses/IS389/data\\GEO\\Mitochondrial-Disorders\\GSE42986\\GSE42986_family.soft.gz',
#  '/Users/legion/Desktop/Courses/IS389/data\\GEO\\Mitochondrial-Disorders\\GSE42986\\GSE42986_series_matrix.txt.gz')

# %%
# No obvious trait
cohort = accession_num = "GSE53096"
cohort_dir = os.path.join(trait_path, accession_num)
soft_file, matrix_file = geo_get_relevant_filepaths(cohort_dir)
soft_file, matrix_file
# Out:
# ('/Users/legion/Desktop/Courses/IS389/data\\GEO\\Mitochondrial-Disorders\\GSE53096\\GSE53096_family.soft.gz',
#  '/Users/legion/Desktop/Courses/IS389/data\\GEO\\Mitochondrial-Disorders\\GSE53096\\GSE53096-GPL13534_series_matrix.txt.gz')

# %%
# No obvious trait
cohort = accession_num = "GSE65399"
cohort_dir = os.path.join(trait_path, accession_num)
soft_file, matrix_file = geo_get_relevant_filepaths(cohort_dir)
soft_file, matrix_file
# Out:
# ('/Users/legion/Desktop/Courses/IS389/data\\GEO\\Mitochondrial-Disorders\\GSE65399\\GSE65399_family.soft.gz',
#  '/Users/legion/Desktop/Courses/IS389/data\\GEO\\Mitochondrial-Disorders\\GSE65399\\GSE65399_series_matrix.txt.gz')

# %% [markdown]
# ### Initial filtering and clinical data preprocessing

# %%
from utils import *
background_prefixes = ['!Series_title', '!Series_summary', '!Series_overall_design']
clinical_prefixes = ['!Sample_geo_accession', '!Sample_characteristics_ch1']    

background_info, clinical_data = get_background_and_clinical_data(matrix_file, background_prefixes, clinical_prefixes)
print(background_info)
# Out:
# !Series_title	"Epigenetic therapy for Friedreich ataxia."
# !Series_summary	"We set out to investigate whether a histone deacetylase inhibitor (HDACi) would be effective in an in vitro model for the neurodegenerative disease Friedreich ataxia (FRDA) and to evaluate safety and surrogate markers of efficacy in a phase I clinical trial in patients. In the neuronal cell model, HDACi 109/RG2833 increases FXN mRNA levels and frataxin protein, with concomitant changes in the epigenetic state of the gene. Chromatin signatures indicate that histone H3 lysine 9 is a key residue for gene silencing through methylation and reactivation through acetylation, mediated by the HDACi. Drug treatment in FRDA patients demonstrated increased FXN mRNA and H3 lysine 9 acetylation in peripheral blood mononuclear cells. No safety issues were encountered."
# !Series_overall_design	"We used a human FRDA neuronal cell model, derived from patient induced pluripotent stem cells, to determine the efficacy of a 2-aminobenzamide HDACi (109) as a modulator of FXN gene expression and chromatin histone modifications. FRDA patients were dosed in 4 cohorts, ranging from 30mg/day to 240mg/day of the formulated drug product of HDACi 109, RG2833. Patients were monitored for adverse effects as well as for increases in FXN mRNA, frataxin protein, and chromatin modification in blood cells. Gene expression profiles were obtained using the Illumina HT12v4 Gene Expression BeadArray."

# %%
clinical_data.head()
# Out:
#          !Sample_geo_accession  \
# 0  !Sample_characteristics_ch1
# 1  !Sample_characteristics_ch1
#
#                                           GSM1595393  \
# 0  differentiation or tissue type: neural progeni...
# 1                                    time point: d24
#
#                                           GSM1595394  \
# 0  differentiation or tissue type: neural progeni...
# 1                                    time point: d24
#
#                                           GSM1595395  \
# 0  differentiation or tissue type: neural progeni...
# 1                                    time point: d24
#
#                                           GSM1595396  \
# 0  differentiation or tissue type: neural progeni...
# 1                                    time point: d24
#
#                                           GSM1595397  \
# 0  differentiation or tissue type: neural progeni...
# 1                                    time point: d24
#
#                                           GSM1595398  \
# 0  differentiation or tissue type: neural progeni...
# 1                                    time point: d24
#
#                                     GSM1595399  \
# 0  differentiation or tissue type: brain fetal
# 1                             time point: 20wk
#
#                                     GSM1595400  \
# 0  differentiation or tissue type: brain fetal
# 1                             time point: 20wk
#
#                                     GSM1595401  ...  \
# 0  differentiation or tissue type: brain fetal  ...
# 1                             time point: 20wk  ...
#
#                                    GSM1595458  \
# 0  differentiation or tissue type: lung fetal
# 1                             time point: 8wk
#
#                                        GSM1595459  \
# 0  differentiation or tissue type: pancreas fetal
# 1                                time point: 18wk
#
#                                        GSM1595460  \
# 0  differentiation or tissue type: pancreas fetal
# 1                                time point: 19wk
#
#                                        GSM1595461  \
# 0  differentiation or tissue type: pancreas fetal
# 1                                time point: 20wk
#
#                                        GSM1595462  \
# 0  differentiation or tissue type: pancreas fetal
# 1                                time point: 21wk
#
#                                           GSM1595463  \
# 0  differentiation or tissue type: small intestin...
# 1                                   time point: 20wk
#
#                                      GSM1595464  \
# 0  differentiation or tissue type: spleen fetal
# 1                              time point: 14wk
#
#                                      GSM1595465  \
# 0  differentiation or tissue type: spleen fetal
# 1                              time point: 18wk
#
#                                      GSM1595466  \
# 0  differentiation or tissue type: spleen fetal
# 1                              time point: 20wk
#
#                                       GSM1595467
# 0  differentiation or tissue type: stomach fetal
# 1                               time point: 15wk
#
# [2 rows x 76 columns]

# %% [markdown]
# Analyze the trait row:

# %%
columns_to_drop = [col for col in clinical_data if 'Excluded' in clinical_data[col].iloc[-1]]
clinical_data.drop(columns=columns_to_drop, inplace=True)

# %%
tumor_stage_row = clinical_data.iloc[0]
tumor_stage_row.unique()
# Out:
# array(['!Sample_characteristics_ch1',
#        'differentiation or tissue type: neural progenitors',
#        'differentiation or tissue type: brain fetal',
#        'differentiation or tissue type: undifferentiated',
#        'differentiation or tissue type: heart fetal',
#        'differentiation or tissue type: kidney fetal',
#        'differentiation or tissue type: liver fetal',
#        'differentiation or tissue type: lung fetal',
#        'differentiation or tissue type: pancreas fetal',
#        'differentiation or tissue type: small intestine fetal',
#        'differentiation or tissue type: stomach fetal',
#        'differentiation or tissue type: thymus fetal',
#        'differentiation or tissue type: adrenal fetal',
#        'differentiation or tissue type: spleen fetal'], dtype=object)

# %%
clinical_data
# Out:
#          !Sample_geo_accession  \
# 0  !Sample_characteristics_ch1
# 1  !Sample_characteristics_ch1
# 2  !Sample_characteristics_ch1
# 3  !Sample_characteristics_ch1
# 4  !Sample_characteristics_ch1
#
#                                           GSM1054461  \
# 0                            tissue: Skeletal muscle
# 1  respiratory chain complex deficiency: No Respi...
# 2                                          gender: F
# 3                                  age (years): 0.76
# 4           informatic analysis group: Control Group
#
#                                           GSM1054462  \
# 0                            tissue: Skeletal muscle
# 1  respiratory chain complex deficiency: Complexe...
# 2                                          gender: M
# 3                                    age (years): 20
# 4      informatic analysis group: Mito Disease Group
#
#                                           GSM1054463  \
# 0                            tissue: Skeletal muscle
# 1  respiratory chain complex deficiency: Complexe...
# 2                                          gender: M
# 3                                    age (years): 20
# 4      informatic analysis group: Mito Disease Group
#
#                                          GSM1054464  \
# 0                           tissue: Skeletal muscle
# 1  respiratory chain complex deficiency: Complex IV
# 2                                         gender: F
# 3                                   age (years): 16
# 4     informatic analysis group: Mito Disease Group
#
#                                           GSM1054465  \
# 0                            tissue: Skeletal muscle
# 1  respiratory chain complex deficiency: Complexe...
# 2                                          gender: F
# 3                                     age (years): 1
# 4      informatic analysis group: Mito Disease Group
#
#                                           GSM1054466  \
# 0                            tissue: Skeletal muscle
# 1  respiratory chain complex deficiency: No Respi...
# 2                                          gender: F
# 3                                  age (years): 0.75
# 4           informatic analysis group: Control Group
#
#                                           GSM1054467  \
# 0                            tissue: Skeletal muscle
# 1  respiratory chain complex deficiency: No Respi...
# 2                                          gender: F
# 3                                  age (years): 0.75
# 4           informatic analysis group: Control Group
#
#                                           GSM1054468  \
# 0                            tissue: Skeletal muscle
# 1  respiratory chain complex deficiency: No Respi...
# 2                                          gender: M
# 3                                     age (years): 3
# 4           informatic analysis group: Control Group
#
#                                           GSM1054469  ...  \
# 0                            tissue: Skeletal muscle  ...
# 1  respiratory chain complex deficiency: No Respi...  ...
# 2                                          gender: M  ...
# 3                                     age (years): 3  ...
# 4           informatic analysis group: Control Group  ...
#
#                                           GSM1054502  \
# 0                       tissue: fibroblast cell line
# 1  respiratory chain complex deficiency in muscle...
# 2                                          gender: F
# 3                                    age (years): 30
# 4      informatic analysis group: Mito Disease Group
#
#                                           GSM1054503  \
# 0                       tissue: fibroblast cell line
# 1  respiratory chain complex deficiency in muscle...
# 2                                          gender: F
# 3                                     age (years): 2
# 4           informatic analysis group: Control Group
#
#                                           GSM1054505  \
# 0                       tissue: fibroblast cell line
# 1  respiratory chain complex deficiency in muscle...
# 2                                          gender: M
# 3                                    age (years): 39
# 4           informatic analysis group: Control Group
#
#                                           GSM1054506  \
# 0                       tissue: fibroblast cell line
# 1  respiratory chain complex deficiency in muscle...
# 2                                          gender: M
# 3                                     age (years): 6
# 4      informatic analysis group: Mito Disease Group
#
#                                           GSM1054507  \
# 0                       tissue: fibroblast cell line
# 1  respiratory chain complex deficiency in muscle...
# 2                                          gender: F
# 3                                    age (years): 10
# 4           informatic analysis group: Control Group
#
#                                           GSM1054508  \
# 0                       tissue: fibroblast cell line
# 1  respiratory chain complex deficiency in muscle...
# 2                                          gender: F
# 3                                     age (years): 4
# 4      informatic analysis group: Mito Disease Group
#
#                                           GSM1054509  \
# 0                       tissue: fibroblast cell line
# 1  respiratory chain complex deficiency in muscle...
# 2                                          gender: F
# 3                                   age (years): 0.3
# 4      informatic analysis group: Mito Disease Group
#
#                                           GSM1054511  \
# 0                       tissue: fibroblast cell line
# 1  respiratory chain complex deficiency in muscle...
# 2                                          gender: M
# 3                                     age (years): 8
# 4      informatic analysis group: Mito Disease Group
#
#                                           GSM1054512  \
# 0                       tissue: fibroblast cell line
# 1  respiratory chain complex deficiency in muscle...
# 2                                          gender: F
# 3                                    age (years): 11
# 4      informatic analysis group: Mito Disease Group
#
#                                           GSM1054513
# 0                       tissue: fibroblast cell line
# 1  respiratory chain complex deficiency in muscle...
# 2                                          gender: F
# 3                                   age (years): 0.7
# 4      informatic analysis group: Mito Disease Group
#
# [5 rows x 44 columns]

# %% [markdown]
# Determine the trait row, age row, and gender row. Then implement the conversion functions:

# %%
trait_row = 4
age_row = None
gender_row = None

def convert_trait(trait):
    # Check if the trait indicates a normal disease status
    if trait == 'informatic analysis group: Control Group':
        return 0
    else:
        return 1


def convert_age(age_string):
    if age_string.lower() == 'n.a.':
        return None
    try:
        age = int(age_string.split(':')[1])/12
        age = round(age, 0)
        return age
    except (ValueError, IndexError):
        return None

def convert_gender(gender_string):
    if (gender_string.lower() == 'sex: female' or gender_string.lower() == 'sex: f' or gender_string.lower() == 'gender: female' or gender_string.lower() == 'gender: f'):
        return 1
    elif (gender_string.lower() == 'sex: male' or gender_string.lower() == 'sex: m' or gender_string.lower() == 'gender: male' or gender_string.lower() == 'gender: m') :  # changeed 
        return 0
    else:
        return None

# %% [markdown]
# Check the processed clinical data:

# %%
selected_clinical_data = geo_select_clinical_features(clinical_data, TRAIT, trait_row, convert_trait, age_row=age_row,
                                                      convert_age=convert_age, gender_row=gender_row,
                                                      convert_gender=convert_gender)
selected_clinical_data.head()
# Out:
# c:\Users\legion\Desktop\TAIS_2024SP\TAIS_2024SP\task2\Jiayi\utils.py:218: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   clinical_df = clinical_df.applymap(convert_fn)
#                          GSM1054461  GSM1054462  GSM1054463  GSM1054464  \
# Mitochondrial Disorders           0           1           1           1
#
#                          GSM1054465  GSM1054466  GSM1054467  GSM1054468  \
# Mitochondrial Disorders           1           0           0           0
#
#                          GSM1054469  GSM1054470  ...  GSM1054502  GSM1054503  \
# Mitochondrial Disorders           0           1  ...           1           0
#
#                          GSM1054505  GSM1054506  GSM1054507  GSM1054508  \
# Mitochondrial Disorders           0           1           0           1
#
#                          GSM1054509  GSM1054511  GSM1054512  GSM1054513
# Mitochondrial Disorders           1           1           1           1
#
# [1 rows x 43 columns]

# %% [markdown]
# ### Genetic data preprocessing and final filtering

# %% [markdown]
# Check the genetic data:

# %%
genetic_data = get_genetic_data(matrix_file)
genetic_data.head()
# Out:
#               GSM1054461  GSM1054462  GSM1054463  GSM1054464  GSM1054465  \
# ID
# 100009676_at      4.6853      4.8687      5.3162      5.4394      5.2875
# 10000_at          5.1290      5.0028      4.4925      4.8062      5.1422
# 10001_at          6.7766      6.7424      6.4730      6.4838      7.0128
# 10002_at          4.2518      4.0146      4.3891      4.3728      4.1062
# 100033416_at      5.8336      7.0097      4.9461      6.8316      5.5447
#
#               GSM1054466  GSM1054467  GSM1054468  GSM1054469  GSM1054470  ...  \
# ID                                                                        ...
# 100009676_at      5.5058      5.3441      5.3682      4.7472      4.7100  ...
# 10000_at          4.8819      4.6265      5.0931      5.3742      5.6132  ...
# 10001_at          6.4838      5.5824      5.9299      6.4970      5.6638  ...
# 10002_at          4.3003      4.8337      4.5815      4.3030      4.1722  ...
# 100033416_at      6.5127      5.8907      5.6356      7.4410      5.9524  ...
#
#               GSM1054504  GSM1054505  GSM1054506  GSM1054507  GSM1054508  \
# ID
# 100009676_at      7.5565      7.6487      7.2986      7.3274      7.0926
# 10000_at          7.5498      8.0214      7.7382      8.1381      7.7948
# 10001_at          7.5874      8.4247      8.2667      8.2139      8.4509
# 10002_at          6.2488      5.2794      5.7797      5.1912      5.5925
# 100033416_at      5.5917      6.6206      7.2089      7.1178      7.7360
#
#               GSM1054509  GSM1054510  GSM1054511  GSM1054512  GSM1054513
# ID
# 100009676_at      7.3758      7.1859      7.2365      7.3564      7.2491
# 10000_at          7.6120      7.6368      7.9979      7.4112      7.5423
# 10001_at          8.4980      8.0564      8.7085      8.7137      8.1848
# 10002_at          5.6754      5.7834      5.5248      5.4855      5.6269
# 100033416_at      7.0332      6.3431      6.0782      8.0996      6.9443
#
# [5 rows x 53 columns]

# %% [markdown]
# Check if the gene dataset requires mapping to get the gene symbols corresponding to each data row.

# %%
requires_gene_mapping = True

if requires_gene_mapping:
    gene_annotation = get_gene_annotation(soft_file)
    gene_annotation_summary = preview_df(gene_annotation)
    print(gene_annotation_summary)

gene_annotation.columns
# Out:
# {'ID': ['1_at', '2_at', '9_at', '10_at', '12_at'], 'Gene_ID': ['1', '2', '9', '10', '12'], 'ORF': ['A1BG', 'A2M', 'NAT1', 'NAT2', 'SERPINA3'], 'Symbol': ['A1BG', 'A2M', 'NAT1', 'NAT2', 'SERPINA3'], 'Chromosome': ['19', '12', '8', '8', '14'], 'RefSeq_ID': ['NM_130786;NP_570602', 'NM_000014;NP_000005', 'NM_000662;NM_001160170;NM_001160171;NM_001160172;NM_001160173;NM_001160174;NM_001160175;NM_001160176;NM_001160179;NP_000653;NP_001153642;NP_001153643;NP_001153644;NP_001153645;NP_001153646;NP_001153647;NP_001153648;NP_001153651', 'NM_000015;NP_000006', 'NM_001085;NP_001076'], 'Num_Probes': [47.0, 167.0, 74.0, 20.0, 56.0], 'Full_Name': ['alpha-1-B glycoprotein', 'alpha-2-macroglobulin', 'N-acetyltransferase 1 (arylamine N-acetyltransferase)', 'N-acetyltransferase 2 (arylamine N-acetyltransferase)', 'serpin peptidase inhibitor, clade A (alpha-1 antiproteinase, antitrypsin), member 3']}
# Index(['ID', 'Gene_ID', 'ORF', 'Symbol', 'Chromosome', 'RefSeq_ID',
#        'Num_Probes', 'Full_Name'],
#       dtype='object')

# %%
if requires_gene_mapping:
    identifier_key = 'ID'
    gene_symbol_key = 'Symbol'
    gene_mapping = get_gene_mapping(gene_annotation, identifier_key, gene_symbol_key)
    genetic_data = apply_gene_mapping(genetic_data, gene_mapping)

# %%
genetic_data = normalize_gene_symbols_in_index(genetic_data)
genetic_data
# Out:
#           GSM1054461  GSM1054462  GSM1054463  GSM1054464  GSM1054465  \
# A1BG          6.1013      5.8975      6.1725      5.9452      5.8125
# A1BG-AS1      4.1155      3.8231      4.4809      3.8832      3.5292
# A1CF          3.0490      2.8329      3.0462      3.0998      2.8448
# A2M           9.5803      8.8574      8.6237      8.7689      9.6166
# A2ML1         3.2303      3.1281      3.3229      3.3928      3.1351
# ...              ...         ...         ...         ...         ...
# ZYG11A        3.2158      3.7873      3.4058      3.3421      3.3949
# ZYG11B        9.0668      9.4642      9.3095      9.4767      8.9353
# ZYX           7.1701      6.9826      6.9313      7.3664      7.2823
# ZZEF1         6.3858      6.5421      6.7484      6.2827      6.6528
# ZZZ3          5.2251      5.3963      4.8275      5.0468      5.0241
#
#           GSM1054466  GSM1054467  GSM1054468  GSM1054469  GSM1054470  ...  \
# A1BG          6.2270      6.6265      6.1640      6.2533      5.9966  ...
# A1BG-AS1      4.0760      4.2817      4.0797      3.7546      3.7637  ...
# A1CF          2.9790      3.1286      3.2239      2.9757      2.8277  ...
# A2M           9.5560      9.5490      8.8824      8.9636      8.7677  ...
# A2ML1         3.3229      3.7033      3.3818      3.2558      3.2793  ...
# ...              ...         ...         ...         ...         ...  ...
# ZYG11A        3.2535      3.6718      3.5500      3.4669      3.2070  ...
# ZYG11B        8.6806      8.8417      8.3534      8.3751      8.3136  ...
# ZYX           6.6743      6.9897      7.2487      7.2203      8.2768  ...
# ZZEF1         6.2846      6.1841      6.1643      6.1597      6.7696  ...
# ZZZ3          5.1010      4.8599      4.9404      5.0926      5.2231  ...
#
#           GSM1054504  GSM1054505  GSM1054506  GSM1054507  GSM1054508  \
# A1BG          8.1697      7.3470      7.3858      7.2936      7.3586
# A1BG-AS1      6.9534      6.8703      6.5639      7.2063      6.9356
# A1CF          3.8526      3.1797      3.2482      3.1539      3.3267
# A2M           8.3536      8.4455      6.4056      5.0722      7.2323
# A2ML1         4.7692      3.7672      3.9695      3.8859      3.8911
# ...              ...         ...         ...         ...         ...
# ZYG11A        4.8983      4.7218      4.8042      4.0250      4.4530
# ZYG11B        9.4790      9.6251      9.4461      9.4394      9.2585
# ZYX          10.7341     10.9998     10.7922     10.5329     10.4911
# ZZEF1         7.7777      8.1910      8.3599      8.4375      8.4334
# ZZZ3          7.3765      7.9798      7.7927      7.9860      7.9013
#
#           GSM1054509  GSM1054510  GSM1054511  GSM1054512  GSM1054513
# A1BG          7.5003      7.7289      7.2938      7.2880      7.3009
# A1BG-AS1      6.7637      7.2619      6.9173      6.9877      6.8485
# A1CF          3.2850      3.4254      3.2007      3.3306      3.1708
# A2M           6.9800      8.2093      5.0774      5.0126     10.3406
# A2ML1         4.0563      4.1931      3.9923      3.7533      4.0087
# ...              ...         ...         ...         ...         ...
# ZYG11A        4.5717      4.6689      4.7296      4.4920      4.3177
# ZYG11B        9.0012      9.2760      9.3080      9.1942      9.4302
# ZYX          10.2403     11.2125     10.5929     10.4838     10.8218
# ZZEF1         8.3261      7.9002      8.3949      8.2926      8.2379
# ZZZ3          7.7559      7.3924      8.0305      7.8095      7.6898
#
# [17544 rows x 53 columns]

# %% [markdown]
# Use selected clinical data and genetic data to generate the merged data:

# %%
merged_data = geo_merge_clinical_genetic_data(selected_clinical_data, genetic_data)
is_available = True

merged_data
# Out:
#             Mitochondrial Disorders    A1BG  A1BG-AS1    A1CF      A2M  \
# GSM1054461                      0.0  6.1013    4.1155  3.0490   9.5803
# GSM1054462                      1.0  5.8975    3.8231  2.8329   8.8574
# GSM1054463                      1.0  6.1725    4.4809  3.0462   8.6237
# GSM1054464                      1.0  5.9452    3.8832  3.0998   8.7689
# GSM1054465                      1.0  5.8125    3.5292  2.8448   9.6166
# GSM1054466                      0.0  6.2270    4.0760  2.9790   9.5560
# GSM1054467                      0.0  6.6265    4.2817  3.1286   9.5490
# GSM1054468                      0.0  6.1640    4.0797  3.2239   8.8824
# GSM1054469                      0.0  6.2533    3.7546  2.9757   8.9636
# GSM1054470                      1.0  5.9966    3.7637  2.8277   8.7677
# GSM1054471                      1.0  5.6345    3.6525  2.8254   9.5466
# GSM1054472                      0.0  5.9679    3.8574  3.0826   9.0008
# GSM1054473                      1.0  5.6092    3.4124  2.7425   9.7295
# GSM1054474                      0.0  5.9416    3.9226  2.8950   9.4086
# GSM1054475                      1.0  5.8829    3.5686  2.9108   8.9915
# GSM1054476                      1.0  6.3154    4.1574  3.1526   8.9952
# GSM1054477                      1.0  6.1071    4.0192  2.9848   8.8596
# GSM1054479                      1.0  5.8205    3.2674  2.7552   8.4401
# GSM1054480                      1.0  5.9297    3.4582  2.8052   7.9580
# GSM1054483                      0.0  6.1294    3.9094  2.9174   8.8233
# GSM1054484                      0.0  6.6635    4.3272  3.2449   8.7281
# GSM1054485                      0.0  5.8798    3.5844  2.8676   8.2077
# GSM1054487                      1.0  5.6396    3.6012  2.7803   8.6148
# GSM1054490                      0.0  7.4385    7.1722  3.2204   5.3201
# GSM1054491                      0.0  7.0004    7.0466  3.1001   6.5771
# GSM1054492                      0.0  7.1297    7.3300  3.2616   4.8996
# GSM1054493                      1.0  7.2450    7.0268  3.2589   5.6858
# GSM1054494                      0.0  7.1468    7.0425  3.1183   6.8993
# GSM1054496                      1.0  7.3677    6.9973  3.2747   7.3920
# GSM1054497                      1.0  7.4013    6.9534  3.3139   6.9890
# GSM1054498                      1.0  7.3875    7.0710  3.4451   5.8473
# GSM1054499                      1.0  7.2522    6.8242  3.1718   6.4205
# GSM1054500                      0.0  7.3063    6.9274  3.1437   6.2682
# GSM1054502                      1.0  7.5244    7.1620  3.4615  10.4299
# GSM1054503                      0.0  7.3643    7.0130  3.2555   5.0785
# GSM1054505                      0.0  7.3470    6.8703  3.1797   8.4455
# GSM1054506                      1.0  7.3858    6.5639  3.2482   6.4056
# GSM1054507                      0.0  7.2936    7.2063  3.1539   5.0722
# GSM1054483  6.0581  7.3145  6.9052  3.5155   9.3226   7.0620  6.8770  4.9623
# GSM1054484  6.5508  7.3763  6.4566  3.9737   7.7429   6.9145  6.2181  4.7005
# GSM1054485  6.0213  7.1321  6.9038  3.2696   9.3012   7.1332  6.7474  5.2812
# GSM1054487  6.4462  7.1664  6.9852  3.1801   9.5348   7.2281  6.7670  5.1422
# GSM1054490  7.2479  8.5252  8.0012  4.5764   9.7288  10.6232  8.3687  8.0760
# GSM1054491  7.3167  8.3906  8.1439  4.3133   9.2621   9.9298  8.2939  8.4370
# GSM1054492  7.0205  8.1047  7.8983  4.1094   9.5219  10.4447  8.7851  8.1577
# GSM1054493  7.4019  8.2968  8.0049  4.5146   8.9699  10.0450  8.2137  7.8236
# GSM1054494  7.0373  8.0565  8.0106  4.4156   9.2271  10.4999  8.3953  8.1731
# GSM1054496  7.4772  8.4933  7.8751  4.2377   9.5495  10.3390  8.0165  8.1466
# GSM1054497  7.4688  8.6030  8.1382  4.4298   9.5942  10.5005  8.1637  8.0366
# GSM1054498  7.6471  8.4840  8.2386  4.5878   9.3331   9.6730  8.1882  7.9059
# GSM1054499  7.2312  8.3601  8.0991  4.0764   9.0859  10.0572  8.3218  8.2084
# GSM1054500  7.3402  8.5191  8.1215  4.6576   9.3023  10.3978  8.3739  8.1474
# GSM1054502  7.4043  8.3254  7.8031  4.6602   9.2111  10.4286  8.5387  7.5695
# GSM1054503  7.0112  8.0315  7.8589  5.7572   9.5072  10.8868  8.5115  8.1701
# GSM1054505  7.0637  8.3682  7.8773  4.7218   9.6251  10.9998  8.1910  7.9798
# GSM1054506  7.2670  8.4671  8.0801  4.8042   9.4461  10.7922  8.3599  7.7927
# GSM1054507  7.1169  8.1924  8.0482  4.0250   9.4394  10.5329  8.4375  7.9860
# GSM1054508  7.2724  8.3439  8.0633  4.4530   9.2585  10.4911  8.4334  7.9013
# GSM1054509  7.4200  8.6939  8.0615  4.5717   9.0012  10.2403  8.3261  7.7559
# GSM1054511  7.1243  8.3166  8.1081  4.7296   9.3080  10.5929  8.3949  8.0305
# GSM1054512  7.0236  8.3423  7.7346  4.4920   9.1942  10.4838  8.2926  7.8095
# GSM1054513  7.3127  8.4597  7.8855  4.3177   9.4302  10.8218  8.2379  7.6898
#
# [43 rows x 17545 columns]

# %% [markdown]
# Check if the merged data biased or not:

# %%
trait_type = 'binary'
print(f"The merged dataset contains {len(merged_data)} samples.")
is_trait_biased, merged_data = judge_and_remove_biased_features(merged_data, TRAIT, trait_type=trait_type)
is_trait_biased
# Out:
# The merged dataset contains 43 samples.
# For the feature 'Mitochondrial Disorders', the least common label is '0.0' with 18 occurrences. This represents 41.86% of the dataset.
# The distribution of the feature 'Mitochondrial Disorders' in this dataset is fine.
# False

# %% [markdown]
# Save the data as a csv file:

# %%
if is_available:
    save_cohort_info(cohort, JSON_PATH, is_available, is_trait_biased, merged_data, note='')
else:
    save_cohort_info(cohort, JSON_PATH, is_available)
merged_data.head()
if not is_trait_biased:
    merged_data.to_csv(os.path.join(OUTPUT_DIR, cohort + '.csv'), index=False)
