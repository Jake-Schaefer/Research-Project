# %% [markdown]
# <a href="https://colab.research.google.com/github/Jake-Schaefer/Research-Project/blob/main/Final_Case_Study_Jake_Schaefer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Clean Leasing Company Google Reviews
#
# Use this starter notebook to load raw data files.

# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_columns', 100)

# %% [markdown]
# ## Load data
#
# Read the Excel files. These are unmodified files from [Outscraper](https://outscraper.com/)'s scraped output. They contain Google reviews for leasing companies, apartment complexes, and student housing for three different campustowns.
#
# - Brigham Young University (Provo, UT)
# - Penn State University (University Park, PA)
# - University of Illinois at Urbana Champaign (Champaign, IL)

# %% [markdown]
# The text cell below was used to read the dataset.

# %%
df_byu_b = pd.read_csv('https://github.com/bdi475/datasets/raw/main/campustowns-leasing-company-reviews/byu-businesses.csv')
df_byu_r = pd.read_csv('https://github.com/bdi475/datasets/raw/main/campustowns-leasing-company-reviews/byu-reviews.csv')
df_psu_b = pd.read_csv('https://github.com/bdi475/datasets/raw/main/campustowns-leasing-company-reviews/psu-businesses.csv')
df_psu_r = pd.read_csv('https://github.com/bdi475/datasets/raw/main/campustowns-leasing-company-reviews/psu-reviews.csv')
df_uiuc_b = pd.read_csv('https://github.com/bdi475/datasets/raw/main/campustowns-leasing-company-reviews/uiuc-businesses.csv')
df_uiuc_r = pd.read_csv('https://github.com/bdi475/datasets/raw/main/campustowns-leasing-company-reviews/uiuc-reviews.csv')

# %% [markdown]
# I displayed the datasets to ensure all critical information had been correctly imported into Google Collab.

# %%
display(df_byu_b.head(1))
display(df_byu_r.head(1))
display(df_psu_b.head(1))
display(df_psu_r.head(1))
display(df_uiuc_b.head(1))
display(df_uiuc_r.head(1))
# Out:
#                          query            name                          site  \
# 0  ChIJqyXyo6GQTYcRXGfgeIpqc_I  Alpine Village  https://myalpinevillage.com/
#
#                      type                                           subtypes  \
# 0  Student housing center  Student housing center, Apartment building, Ap...
#
#                  category            phone  \
# 0  Student housing center  +1 801-623-6093
#
#                                         full_address      borough  \
# 0  1378 Freedom Blvd 200 W, Provo, UT 84604, Unit...  Carterville
#
#                     street   city  postal_code state us_state  \
# 0  1378 Freedom Blvd 200 W  Provo        84604  Utah     Utah
#
#                     country country_code   latitude   longitude  \
# 0  United States of America           US  40.252607 -111.661247
#
#         time_zone    plus_code  area_service  rating  reviews  \
# 0  America/Denver  85GC783Q+2G         False     2.9      481
#
# ...

# %% [markdown]
# I created a new column that stores the campus in the database.

# %%
df_byu_b['campus'] = 'Bringham Young University'
df_psu_b['campus'] = 'Penn State University Park'
df_uiuc_b['campus'] = 'University of Illinois Urbana-Champaign'

# %% [markdown]
# Checked to ensure I properly inserted a new column by displaying the first two rows of the BYU business database.

# %%
df_byu_b.head(2)
# Out:
#                          query                  name  \
# 0  ChIJqyXyo6GQTYcRXGfgeIpqc_I        Alpine Village
# 1  ChIJGbnTbamQTYcRtZfBrL52jhs  Palladium Apartments
#
#                               site                    type  \
# 0     https://myalpinevillage.com/  Student housing center
# 1  https://www.palladiumprovo.com/         Housing complex
#
#                                             subtypes                category  \
# 0  Student housing center, Apartment building, Ap...  Student housing center
# 1                                    Housing complex         Housing complex
#
#              phone                                       full_address  \
# 0  +1 801-623-6093  1378 Freedom Blvd 200 W, Provo, UT 84604, Unit...
# 1  +1 385-200-0510           538 N Freedom Blvd Unit, Provo, UT 84601
#
#        borough                   street   city  postal_code state us_state  \
# 0  Carterville  1378 Freedom Blvd 200 W  Provo        84604  Utah     Utah
# ...

# %% [markdown]
# I used concat to put all of the ‘businesses’ into one dataframe so I could analyze the data with less code later on.

# %%
df_b = pd.concat([df_byu_b, df_psu_b, df_uiuc_b])
df_r = pd.concat([df_byu_r, df_psu_r, df_uiuc_r])

# %% [markdown]
# Checked out a sample of the data so I can double-check that all of the important information has been retained.

# %%
df_b.head(1)
# Out:
#                          query            name                          site  \
# 0  ChIJqyXyo6GQTYcRXGfgeIpqc_I  Alpine Village  https://myalpinevillage.com/
#
#                      type                                           subtypes  \
# 0  Student housing center  Student housing center, Apartment building, Ap...
#
#                  category            phone  \
# 0  Student housing center  +1 801-623-6093
#
#                                         full_address      borough  \
# 0  1378 Freedom Blvd 200 W, Provo, UT 84604, Unit...  Carterville
#
#                     street   city  postal_code state us_state  \
# 0  1378 Freedom Blvd 200 W  Provo        84604  Utah     Utah
#
#                     country country_code   latitude   longitude  \
# 0  United States of America           US  40.252607 -111.661247
#
#         time_zone    plus_code  area_service  rating  reviews  \
# 0  America/Denver  85GC783Q+2G         False     2.9      481
#
# ...

# %% [markdown]
# I Displayed the number of rows and columns after concating the data.

# %%
df_b.shape
# Out:
# (142, 61)

# %%
df_r.shape
# Out:
# (16848, 33)

# %% [markdown]
# Preprocess data further to retain only the most necessary columns and displayed the first row to ensure all of my selected columns are in the database.

# %%
columns_to_select1 = [
    'campus','place_id','name','site','category', 'borough',
    'street','city','postal_code','state','latitude','longitude',
    'verified'
]
df_b = df_b[columns_to_select1].copy()
df_b.head(1)
# Out:
#                       campus                     place_id            name  \
# 0  Bringham Young University  ChIJqyXyo6GQTYcRXGfgeIpqc_I  Alpine Village
#
#                            site                category      borough  \
# 0  https://myalpinevillage.com/  Student housing center  Carterville
#
#                     street   city  postal_code state   latitude   longitude  \
# 0  1378 Freedom Blvd 200 W  Provo        84604  Utah  40.252607 -111.661247
#
#    verified
# 0      True

# %% [markdown]
# Display the number of rows and columns after adjusting the data

# %%
df_b.shape
# Out:
# (142, 13)

# %% [markdown]
# Preprocess data further to retain only the most necessary columns and displayed the first row to ensure all of my selected columns are in the database.

# %%
columns_to_select2 = [
    'place_id',
    'review_id',
    'author_id',
    'author_title',
    'review_text',
    'review_rating',
    'review_img_url',
    'review_datetime_utc',
    'owner_answer',
    'owner_answer_timestamp_datetime_utc',
    'review_likes'
]

df_r = df_r[columns_to_select2].copy()

df_r.head(2)
# Out:
#                       place_id                             review_id  \
# 0  ChIJqyXyo6GQTYcRXGfgeIpqc_I  ChdDSUhNMG9nS0VJQ0FnSUQ1OXRHZnNnRRAB
# 1  ChIJqyXyo6GQTYcRXGfgeIpqc_I   ChZDSUhNMG9nS0VJQ0FnSUNwOUstOVpBEAE
#
#                author_id    author_title  \
# 0  100512067005706825621     Laura Brown
# 1  102936107836751613731  Pete Haraguchi
#
#                                          review_text  review_rating  \
# 0  Service requests take a very long time to be r...              3
# 1  I was thinking about giving two stars but I le...              1
#
#                                       review_img_url  review_datetime_utc  \
# 0                                                NaN  10/24/2023 12:46:43
# 1  https://lh5.googleusercontent.com/p/AF1QipPeIy...  07/29/2023 20:30:26
#
#                                         owner_answer  \
# 0  Dear Laura, \n\n We hear you loud and clear, t...
# 1  Pete,\n\n Thank you for letting us know about ...
#
# ...

# %% [markdown]
# Display the number of rows and columns after adjusting the data

# %%
df_r.shape
# Out:
# (16848, 11)

# %% [markdown]
# Checked the data type of review_datetime_utc and owner_answer_timestamp_datetime_utc columns. They were object-typed (string types). In the next few steps, I will parse them as datetime using pd.to_datetime().

# %%
df_r[['review_datetime_utc', 'owner_answer_timestamp_datetime_utc']].dtypes
# Out:
# review_datetime_utc                    object
# owner_answer_timestamp_datetime_utc    object
# dtype: object

# %%
df_r['review_datetime_utc'] = pd.to_datetime(df_r['review_datetime_utc'], utc=True)
df_r['owner_answer_timestamp_datetime_utc'] = pd.to_datetime(df_r['owner_answer_timestamp_datetime_utc'])

# %% [markdown]
# Verify that the two datetime columns now display datetime64 types and not object-typed (string types).

# %%
df_r[['review_datetime_utc', 'owner_answer_timestamp_datetime_utc']].dtypes
# Out:
# review_datetime_utc                    datetime64[ns, UTC]
# owner_answer_timestamp_datetime_utc         datetime64[ns]
# dtype: object

# %%
df_r[['review_datetime_utc', 'owner_answer_timestamp_datetime_utc']].head()
# Out:
#    review_datetime_utc owner_answer_timestamp_datetime_utc
# 0  10/24/2023 12:46:43                 10/24/2023 14:56:01
# 1  07/29/2023 20:30:26                 07/29/2023 22:46:48
# 2  08/26/2023 03:31:42                 08/26/2023 04:56:04
# 3  08/28/2023 21:54:09                 08/29/2023 00:00:30
# 4  07/17/2023 21:47:22                 07/17/2023 22:59:16

# %%
df_b.to_csv('businesses.csv', index=None)
df_r.to_csv('reviews.csv', index=None)

# %% [markdown]
# Imported Spacy which will be critical for the next few steps.

# %%
import spacy

# %% [markdown]
# Used 'en_core_web_sm' becuase it is an English pipeline.

# %%
nlp = spacy.load('en_core_web_sm')

# %%
from spacy import displacy

# %% [markdown]
# The next cell of code is used to tokenize and lemmatize the reviews. The ‘cols’ code on the top tells Python which columns to keep. The for loop is used to go over each review_id and tokenize and lemmatize the reviews.

# %%
cols = ["review_id", "text", "lemma", "pos", "explain", "is_stop"]
rows = []

for index, row in df_r[df_r['review_text'].notna()].iterrows():
    doc = nlp(row['review_text'])
    for t in doc:
        new_row = [row['review_id'], t.text, t.lemma_, t.pos_, spacy.explain(t.pos_), t.is_stop]
        rows.append(new_row)

df_tokens = pd.DataFrame(rows, columns=cols)
df_tokens
# Out:
#                                     review_id      text    lemma    pos  \
# 0        ChdDSUhNMG9nS0VJQ0FnSUQ1OXRHZnNnRRAB   Service  service   NOUN
# 1        ChdDSUhNMG9nS0VJQ0FnSUQ1OXRHZnNnRRAB  requests  request   NOUN
# 2        ChdDSUhNMG9nS0VJQ0FnSUQ1OXRHZnNnRRAB      take     take   VERB
# 3        ChdDSUhNMG9nS0VJQ0FnSUQ1OXRHZnNnRRAB         a        a    DET
# 4        ChdDSUhNMG9nS0VJQ0FnSUQ1OXRHZnNnRRAB      very     very    ADV
# ...                                       ...       ...      ...    ...
# 1473566   ChZDSUhNMG9nS0VJQ0FnSURBdHNiMWRnEAE      very     very    ADV
# 1473567   ChZDSUhNMG9nS0VJQ0FnSURBdHNiMWRnEAE   patient  patient    ADJ
# 1473568   ChZDSUhNMG9nS0VJQ0FnSURBdHNiMWRnEAE      with     with    ADP
# 1473569   ChZDSUhNMG9nS0VJQ0FnSURBdHNiMWRnEAE        us       we   PRON
# 1473570   ChZDSUhNMG9nS0VJQ0FnSURBdHNiMWRnEAE         .        .  PUNCT
#
#              explain  is_stop
# 0               noun    False
# 1               noun    False
# ...

# %% [markdown]
# Remove stop words from the dataset to filter the data.

# %%
# only filter non stop words
df_tokens_filtered = df_tokens[~df_tokens['is_stop']]

# remove words shorter than 4 characters long
df_tokens_filtered = df_tokens_filtered[df_tokens_filtered['lemma'].str.len() >= 4]

df_tokens_filtered
# Out:
#                                     review_id        text      lemma   pos  \
# 0        ChdDSUhNMG9nS0VJQ0FnSUQ1OXRHZnNnRRAB     Service    service  NOUN
# 1        ChdDSUhNMG9nS0VJQ0FnSUQ1OXRHZnNnRRAB    requests    request  NOUN
# 5        ChdDSUhNMG9nS0VJQ0FnSUQ1OXRHZnNnRRAB        long       long   ADJ
# 6        ChdDSUhNMG9nS0VJQ0FnSUQ1OXRHZnNnRRAB        time       time  NOUN
# 9        ChdDSUhNMG9nS0VJQ0FnSUQ1OXRHZnNnRRAB   responded    respond  VERB
# ...                                       ...         ...        ...   ...
# 1473554   ChZDSUhNMG9nS0VJQ0FnSURBdHNiMWRnEAE     looking       look  VERB
# 1473556   ChZDSUhNMG9nS0VJQ0FnSURBdHNiMWRnEAE  apartments  apartment  NOUN
# 1473559   ChZDSUhNMG9nS0VJQ0FnSURBdHNiMWRnEAE    answered     answer  VERB
# 1473563   ChZDSUhNMG9nS0VJQ0FnSURBdHNiMWRnEAE   questions   question  NOUN
# 1473567   ChZDSUhNMG9nS0VJQ0FnSURBdHNiMWRnEAE     patient    patient   ADJ
#
#            explain  is_stop
# 0             noun    False
# ...

# %% [markdown]
# Sentiment analysis using distilbert

# %%
! pip install transformers

# %% [markdown]
# My apartment is not in the dataset, so I chose one of my friend's apartments (510 S Neil St)

# %%
df_b[df_b['street'] == '510 S Neil St']
# Out:
#                                      campus                     place_id  \
# 26  University of Illinois Urbana-Champaign  ChIJ5yKD5jXXDIgRkGdSK3ffJl8
#
#                    name                            site  \
# 26  Green Street Realty  https://www.greenstrealty.com/
#
#                    category borough         street       city  postal_code  \
# 26  Apartment rental agency     NaN  510 S Neil St  Champaign        61820
#
#        state   latitude  longitude  verified
# 26  Illinois  40.110767 -88.243313      True

# %% [markdown]
# I checked to see if there were any other Green Street Realty apartments in the dataset but the only apartment from that group is the one I chose (510 S Neil St).

# %%
df_b[df_b['name'] == 'Green Street Realty'].head(5)
# Out:
#                                      campus                     place_id  \
# 26  University of Illinois Urbana-Champaign  ChIJ5yKD5jXXDIgRkGdSK3ffJl8
#
#                    name                            site  \
# 26  Green Street Realty  https://www.greenstrealty.com/
#
#                    category borough         street       city  postal_code  \
# 26  Apartment rental agency     NaN  510 S Neil St  Champaign        61820
#
#        state   latitude  longitude  verified
# 26  Illinois  40.110767 -88.243313      True

# %% [markdown]
# Created a name for my chosen apartment.

# %%
my_appartment = df_r[df_r['place_id'] == 'ChIJ5yKD5jXXDIgRkGdSK3ffJl8']

# %% [markdown]
# This is the mean rating for my friends appartment!

# %%
my_appartment['review_rating'].mean()
# Out:
# 2.29

# %% [markdown]
# The next cell of code is used to tokenize and lemmatize reviews for my chosen apartment. The ‘cols’ code on the top tells Python which columns to keep. The for loop is used to go over each review_id and tokenize and lemmatize the reviews.

# %%
for index, row in my_appartment[my_appartment['review_text'].notna()].iterrows():
    doc = nlp(row['review_text'])
    for t in doc:
        new_row = [row['review_id'], t.text, t.lemma_, t.pos_, spacy.explain(t.pos_), t.is_stop]
        rows.append(new_row)

my_appartment_t = pd.DataFrame(rows, columns=cols)

# only filter non stop words
my_appartment_filtered = my_appartment_t[~my_appartment_t['is_stop']]

# remove words shorter than 4 characters long
my_appartment_filtered = my_appartment_t[my_appartment_t['lemma'].str.len() >= 4]

my_appartment_filtered
# Out:
#                                     review_id      text     lemma   pos  \
# 0        ChdDSUhNMG9nS0VJQ0FnSUQ1OXRHZnNnRRAB   Service   service  NOUN
# 1        ChdDSUhNMG9nS0VJQ0FnSUQ1OXRHZnNnRRAB  requests   request  NOUN
# 2        ChdDSUhNMG9nS0VJQ0FnSUQ1OXRHZnNnRRAB      take      take  VERB
# 4        ChdDSUhNMG9nS0VJQ0FnSUQ1OXRHZnNnRRAB      very      very   ADV
# 5        ChdDSUhNMG9nS0VJQ0FnSUQ1OXRHZnNnRRAB      long      long   ADJ
# ...                                       ...       ...       ...   ...
# 1505366  ChdDSUhNMG9nS0VJQ0FnSUNndk1MWmpBRRAB    actual    actual   ADJ
# 1505367  ChdDSUhNMG9nS0VJQ0FnSUNndk1MWmpBRRAB  customer  customer  NOUN
# 1505368  ChdDSUhNMG9nS0VJQ0FnSUNndk1MWmpBRRAB      they      they  PRON
# 1505369  ChdDSUhNMG9nS0VJQ0FnSUNndk1MWmpBRRAB      care      care  VERB
# 1505370  ChdDSUhNMG9nS0VJQ0FnSUNndk1MWmpBRRAB     about     about   ADP
#
#             explain  is_stop
# 0              noun    False
# 1              noun    False
# ...

# %% [markdown]
# Here, I am finding the top 20 'lemma' words used in reviews. Although many of the words are not helpful, we do see 'great' and 'good' both in the top 20 words used with no 'negative' words in the top 20. The lack of 'negative' terminology is surprising considering the apartment has an average rating of 2.29.

# %%
my_appartment_filtered['lemma'].value_counts().head(20)
# Out:
# they          22254
# have          22132
# that          13019
# with          10824
# apartment     10556
# live           9806
# this           7986
# here           6733
# place          6589
# there          6208
# very           5987
# great          5563
# move           5430
# when           5098
# would          4984
# management     4470
# good           4441
# time           4312
# will           4307
# from           4222
# Name: lemma, dtype: int64

# %%
from transformers import pipeline

classifier = pipeline("sentiment-analysis")
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]

# %% [markdown]
# I sampled 30 rows from my apartment

# %%
df_sample = my_appartment[my_appartment['review_rating'] <= 5].sample(30)

# %% [markdown]
# I create two new columns to store sentiment labels and scores.

# %%
df_sample['sentiment'] = np.nan
df_sample['score'] = np.nan

# %% [markdown]
# I ran a sentiment analysis for my apartment.

# %%
num_rows = df_sample.shape[0]

for i in range(num_rows):
  # grab review text to a variable
  review_text = df_sample['review_text'].iloc[i]

  # calculate sentiments for non-missing review texts
  # the model supports up to 512 tokens
  # truncate longer texts
  if pd.notna(review_text):
    result = classifier(
        review_text,
        truncation=True,
        padding=True,
        max_length=512
    )

    df_sample.iloc[i, df_sample.columns.get_loc('sentiment')] = result[0]['label']
    df_sample.iloc[i, df_sample.columns.get_loc('score')] = result[0]['score']

  # display progress
  progress_percentage = round((i + 1) / num_rows * 100, 2)
  print(f'{i + 1}/{num_rows} ({progress_percentage}%)', end=' ')

  if (i + 1) % 10 == 0:
    print('')

print('====================')
print('Complete')
# Out:
# 1/30 (3.33%) 2/30 (6.67%) 3/30 (10.0%) 4/30 (13.33%) 5/30 (16.67%) 6/30 (20.0%) 7/30 (23.33%) 8/30 (26.67%) 9/30 (30.0%) 10/30 (33.33%)
# 11/30 (36.67%) 12/30 (40.0%) 13/30 (43.33%) 14/30 (46.67%) 15/30 (50.0%) 16/30 (53.33%) 17/30 (56.67%) 18/30 (60.0%) 19/30 (63.33%) 20/30 (66.67%)
# 21/30 (70.0%) 22/30 (73.33%) 23/30 (76.67%) 24/30 (80.0%) 25/30 (83.33%) 26/30 (86.67%) 27/30 (90.0%) 28/30 (93.33%) 29/30 (96.67%) 30/30 (100.0%)
# ...
# Complete

# %% [markdown]
# Sample to ensure 'score' and 'sentiment' are in the database

# %%
df_sample.sample(2)
# Out:
#                          place_id                             review_id  \
# 3902  ChIJ5yKD5jXXDIgRkGdSK3ffJl8  ChdDSUhNMG9nS0VJQ0FnSUNBdXZ1OWpnRRAB
# 3960  ChIJ5yKD5jXXDIgRkGdSK3ffJl8  ChdDSUhNMG9nS0VJQ0FnSUNRM2RYcXd3RRAB
#
#                   author_id     author_title  \
# 3902  109285861970058073993  Jessica Luciano
# 3960  116521256120336857957                R
#
#                                             review_text  review_rating  \
# 3902  I got help from Jean @ Green St Realty, and sh...              5
# 3960  Any 5 star rating you see, it is FAKE. Let thi...              1
#
#      review_img_url  review_datetime_utc  \
# 3902            NaN  03/27/2018 18:12:26
# 3960            NaN  09/12/2018 14:33:43
#
#                                            owner_answer  \
# 3902  Thank you so much for taking the time to leave...
# 3960  Hi Bryan A, We are so sorry to see such a nega...
#
#      owner_answer_timestamp_datetime_utc  review_likes sentiment     score
# ...

# %% [markdown]
# Here, I am trying to find out wether the sample of 30 reviews is mostly positive or negative. In this apartment, the sample was overwhelmingly negative.

# %%
sentiment_counts = df_sample['sentiment'].value_counts()
sentiment_counts
# Out:
# NEGATIVE    20
# POSITIVE    10
# Name: sentiment, dtype: int64

# %% [markdown]
# I merged df_b and df_r with pandas. I chose the 'place_id' as the column to match the two datasets because it is present in both datasets. I chose an outer merge so I could keep all the records from both datasets, regardless of whether there was a match or not, to ensure that no data was lost.

# %%
df_merged = pd.merge(df_b,
                     df_r,
                     on='place_id',
                     how='outer')

# %% [markdown]
# I turned my merged database into a CSV file so I can import the merged dataset into Tableau

# %%
df_merged.to_csv('merged.csv', index=None)

# %% [markdown]
# Shape of the merged dataset

# %%
df_merged.shape
# Out:
# (16848, 23)

# %% [markdown]
# Checked out a sample of the data so I can double-check that all of the important information has been retained.

# %%
df_merged.sample(3)
# Out:
#                                         campus                     place_id  \
# 16256  University of Illinois Urbana-Champaign  ChIJq0-EID_XDIgRGl5jbXhvDTY
# 14507  University of Illinois Urbana-Champaign  ChIJAaRo_t7XDIgRHm74yxuRhKo
# 5986                Penn State University Park  ChIJvxXNi82nzokRcvtOHt8pkHE
#
#                          name  \
# 16256     The Dean Campustown
# 14507                 Seven07
# 5986   Tremont Student Living
#
#                                                     site  \
# 16256                https://www.thedean.com/campustown/
# 14507  https://liveseven07.com/?y_source=1_Mjg2NTExOT...
# 5986   https://tremontstudentliving.com/?y_source=1_M...
#
#                       category     borough          street           city  \
# 16256        Apartment complex  Campustown    708 S 6th St      Champaign
# 14507   Student housing center  Campustown    707 S 4th St      Champaign
# 5986   Apartment rental agency         NaN  201 Vairo Blvd  State College
#
# ...

# %% [markdown]
# # Comparing property management companies in the Champaign/Urbana area vs. other universities!

# %% [markdown]
# To compare the average review ratings of UIUC to other universities, I grouped by 'campus' and specified that I wanted the mean 'review rating' for each campus. Surprisingly, UIUC had the highest review rating of 3.74 and BYU had the lowest rating of 3.15 (both values rounded)

# %%
average_review_by_university = df_merged.groupby('campus')['review_rating'].mean().reset_index()
average_review_by_university
# Out:
#                                     campus  review_rating
# 0                Bringham Young University       3.148083
# 1               Penn State University Park       3.609917
# 2  University of Illinois Urbana-Champaign       3.738799

# %% [markdown]
# To compare the median review ratings of UIUC to other universities, I grouped by 'campus' and specified that I wanted the mean 'review rating' for each campus. Shockingly, UIUC and PSU had medians of 5  and BYU had a median of 4. The median and mean suggest that UIUC's apartments are very good and only a select few apartments had issues.

# %%
median_review_by_university = df_merged.groupby('campus')['review_rating'].median().reset_index()
median_review_by_university
# Out:
#                                     campus  review_rating
# 0                Bringham Young University            4.0
# 1               Penn State University Park            5.0
# 2  University of Illinois Urbana-Champaign            5.0

# %% [markdown]
# To compare the STD of review ratings of UIUC to other universities, I grouped by 'campus' and specified that I wanted the STD 'review rating' for each campus. UIUC, PSU, and BYU had STD's all around 1.7. Considering the review ratings only go from 1-5, an STD of 1.7 suggests that there is a large range of reviews and likely many 1/5 reviews.

# %%
std_review_by_university = df_merged.groupby('campus')['review_rating'].std().reset_index()
std_review_by_university
# Out:
#                                     campus  review_rating
# 0                Bringham Young University       1.707484
# 1               Penn State University Park       1.722988
# 2  University of Illinois Urbana-Champaign       1.722339

# %% [markdown]
# Based on my STD, I was curious and decided to check out the distribution of reviews from all universities. In the next few cells, I will then specify based on university.

# %%
# 1. Overall distribution of review ratings
plot = df_merged['review_rating'].value_counts().sort_index().plot(kind='bar', title='Distribution of Review Ratings Combined From BYU, UIUC, and PSU!')

# %%
merg_byu = df_merged[df_merged['campus'] == 'Bringham Young University']
merg_psu = df_merged[df_merged['campus'] == 'Penn State University Park']
merg_uiuc = df_merged[df_merged['campus'] == 'University of Illinois Urbana-Champaign']
plot1 = merg_byu['review_rating'].value_counts().sort_index().plot(kind='bar', title='Distribution of Review Ratings BYU')

# %%
plot2 = merg_psu['review_rating'].value_counts().sort_index().plot(kind='bar', title='Distribution of Review Ratings PSU')

# %%
plot3 = merg_uiuc['review_rating'].value_counts().sort_index().plot(kind='bar', title='Distribution of Review Ratings UIUC')

# %% [markdown]
# I wanted to find the top 10 highest-rated apartments out of all 10 Universities

# %%
top_rated_places = df_merged.groupby('name')['review_rating'].mean().nlargest(10).reset_index()
top_rated_places
# Out:
#                                             name  review_rating
# 0                                     PSU Houses       5.000000
# 1                                   the co.space       4.977778
# 2                            Blue Course Commons       4.865000
# 3                             Haus State College       4.813559
# 4  Toftrees Apartments - Turtle Creek Apartments       4.777778
# 5                                     The Canyon       4.740000
# 6                           Park Hill Apartments       4.718391
# 7               Hub on Campus Champaign - Daniel       4.695000
# 8                        Monaco Court Apartments       4.590909
# 9                                 ICON Apartment       4.578947

# %% [markdown]
# After seeing the top 10 apartments out of all universities, I got curious and decided to get the top 10 apartments from each university and find the top 10 averages from each university. To do this, I created a definition that stratified each university. Then with my new definitions, I grouped by the apartment and calculated the mean to find the top 10 apartments for each respective university.

# %%
places1 = df_merged[df_merged['campus'] == 'University of Illinois Urbana-Champaign']
places2 = df_merged[df_merged['campus'] == 'Penn State University Park']
places3 = df_merged[df_merged['campus'] == 'Bringham Young University']

# %%
top_rated_places_uiuc = places1.groupby('name')['review_rating'].mean().nlargest(10).reset_index()
top_rated_places_uiuc
# Out:
#                                name  review_rating
# 0  Hub on Campus Champaign - Daniel       4.695000
# 1                    ICON Apartment       4.578947
# 2                    MHM Properties       4.470588
# 3     Stone Ridge Square Apartments       4.461538
# 4        Element on Main Apartments       4.423729
# 5               Parkside Apartments       4.368421
# 6                       901 Western       4.262295
# 7     Community Property Management       4.250000
# 8                          212 East       4.245000
# 9     Royse + Brinkmeyer Apartments       4.138298

# %%
top_rated_places_uiuc.mean().reset_index()
# Out:
# <ipython-input-135-351ce34ce7f8>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   top_rated_places_uiuc.mean().reset_index()
#            index         0
# 0  review_rating  4.389382

# %%
top_rated_places_psu = places2.groupby('name')['review_rating'].mean().nlargest(10).reset_index()
top_rated_places_psu
# Out:
#                                             name  review_rating
# 0                                     PSU Houses       5.000000
# 1                                   the co.space       4.977778
# 2                            Blue Course Commons       4.865000
# 3                             Haus State College       4.813559
# 4  Toftrees Apartments - Turtle Creek Apartments       4.777778
# 5                                     The Canyon       4.740000
# 6                           Park Hill Apartments       4.718391
# 7                      Calder Commons Apartments       4.477273
# 8                   The Retreat at State College       4.378378
# 9                       Property Management, Inc       4.341772

# %%
top_rated_places_psu.mean().reset_index()
# Out:
# <ipython-input-136-4479e4de637d>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   top_rated_places_psu.mean().reset_index()
#            index         0
# 0  review_rating  4.708993

# %%
top_rated_places_byu = places3.groupby('name')['review_rating'].mean().nlargest(10).reset_index()
top_rated_places_byu
# Out:
#                        name  review_rating
# 0   Monaco Court Apartments       4.590909
# 1               Wyview Park       4.382609
# 2  200 City View Apartments       4.165289
# 3   Campus Plaza Apartments       4.127273
# 4                 The Isles       4.076923
# 5    400 Element Apartments       4.057692
# 6              Windsor Park       4.028571
# 7           Alta Apartments       3.854545
# 8     The Colony Apartments       3.800000
# 9      Sparks II Apartments       3.794872

# %%
top_rated_places_byu.mean().reset_index()
# Out:
# <ipython-input-137-aa5f74e4f790>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   top_rated_places_byu.mean().reset_index()
#            index         0
# 0  review_rating  4.087868

# %% [markdown]
# In my final project, I embarked on a comprehensive exploration of a database, seeking to extract meaningful insights and patterns within the data. My first insight was when I found that review ratings changed based on the time of day and year. After January the average review ratings for all universities in the database decreased until they reached their lowest average rating around August. This could be because most leases start and end in August. So what may be happening is as people's leases go on, they notice more and more issues with their apartments, prompting them to write worse reviews. I also found that earlier in the day around, 6 AM to 10 AM had worse reviews than any other time of day. This could be prompted by people being generally in a worse mood early in the morning, affecting their review score.
#
#
# Shockingly, I found that UIUC had the highest average apartment score out of all three universities. This was quite surprising since I rarely hear people being positive when talking about their apartment. I also found that the number of reviews for the three universities skyrocketed from 2012 to 2023. While BYU’s average review score remained about the same in that time stretch, UIUC’s and PSU’s apartment scores increased through that stretch. Through analyzing the data, I learned many new insights about UIUC’s apartments and their review scores. I’m more grateful now knowing that UIUC apartments fare pretty well against other schools.
