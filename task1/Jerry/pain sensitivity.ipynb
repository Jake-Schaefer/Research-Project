# %%
import os
import mygene
import io
import re
import pandas as pd
import gzip
import numpy as np
from typing import Optional, List, Tuple, Union, Any
import json
from sparse_lmm import VariableSelection
from sklearn.linear_model import Lasso, LogisticRegression
from sklearn.metrics import accuracy_score, mean_squared_error
from typing import Callable, Optional, List, Tuple, Union, Any
from statsmodels.stats.multitest import multipletests

def get_relevant_filepaths(cohort_dir):
    """Find the file paths of a SOFT file and a matrix file from the given data directory of a cohort.
    If there are multiple SOFT files or matrix files, simply choose the first one. May be replaced by better
    strategies later.
    """
    files = os.listdir(cohort_dir)
    soft_files = [f for f in files if 'soft' in f.lower()]
    matrix_files = [f for f in files if 'matrix' in f.lower()]
    assert len(soft_files) > 0 and len(matrix_files) > 0
    soft_file_path = os.path.join(cohort_dir, soft_files[0])
    matrix_file_path = os.path.join(cohort_dir, matrix_files[0])

    return soft_file_path, matrix_file_path

def line_generator(source, source_type):
    """Generator that yields lines from a file or a string.

    Parameters:
    - source: File path or string content.
    - source_type: 'file' or 'string'.
    """
    if source_type == 'file':
        with gzip.open(source, 'rt') as f:
            for line in f:
                yield line.strip()
    elif source_type == 'string':
        for line in source.split('\n'):
            yield line.strip()
    else:
        raise ValueError("source_type must be 'file' or 'string'")

def filter_content_by_prefix(
    source: str,
    prefixes_a: List[str],
    prefixes_b: Optional[List[str]] = None,
    unselect: bool = False,
    source_type: str = 'file',
    return_df_a: bool = True,
    return_df_b: bool = True
) -> Tuple[Union[str, pd.DataFrame], Optional[Union[str, pd.DataFrame]]]:
    """
    Filters rows from a file or a list of strings based on specified prefixes.

    Parameters:
    - source (str): File path or string content to filter.
    - prefixes_a (List[str]): Primary list of prefixes to filter by.
    - prefixes_b (Optional[List[str]]): Optional secondary list of prefixes to filter by.
    - unselect (bool): If True, selects rows that do not start with the specified prefixes.
    - source_type (str): 'file' if source is a file path, 'string' if source is a string of text.
    - return_df_a (bool): If True, returns filtered content for prefixes_a as a pandas DataFrame.
    - return_df_b (bool): If True, and if prefixes_b is provided, returns filtered content for prefixes_b as a pandas DataFrame.

    Returns:
    - Tuple: A tuple where the first element is the filtered content for prefixes_a, and the second element is the filtered content for prefixes_b.
    """
    filtered_lines_a = []
    filtered_lines_b = []
    prefix_set_a = set(prefixes_a)
    if prefixes_b is not None:
        prefix_set_b = set(prefixes_b)

    # Use generator to get lines
    for line in line_generator(source, source_type):
        matched_a = any(line.startswith(prefix) for prefix in prefix_set_a)
        if matched_a != unselect:
            filtered_lines_a.append(line)
        if prefixes_b is not None:
            matched_b = any(line.startswith(prefix) for prefix in prefix_set_b)
            if matched_b != unselect:
                filtered_lines_b.append(line)

    filtered_content_a = '\n'.join(filtered_lines_a)
    if return_df_a:
        filtered_content_a = pd.read_csv(io.StringIO(filtered_content_a), delimiter='\t', low_memory=False, on_bad_lines='skip')
    filtered_content_b = None
    if filtered_lines_b:
        filtered_content_b = '\n'.join(filtered_lines_b)
        if return_df_b:
            filtered_content_b = pd.read_csv(io.StringIO(filtered_content_b), delimiter='\t', low_memory=False, on_bad_lines='skip')

    return filtered_content_a, filtered_content_b

def get_background_and_clinical_data(file_path,
                                     prefixes_a=['!Series_title', '!Series_summary', '!Series_overall_design'],
                                     prefixes_b=['!Sample_geo_accession', '!Sample_characteristics_ch1']):
    """Extract from a matrix file the background information about the dataset, and sample characteristics data"""
    background_info, clinical_data = filter_content_by_prefix(file_path, prefixes_a, prefixes_b, unselect=False,
                                                              source_type='file',
                                                              return_df_a=False, return_df_b=True)
    return background_info, clinical_data

def get_unique_values_by_row(dataframe, max_len=30):
    """
    Organize the unique values in each row of the given dataframe, to get a dictionary
    :param dataframe:
    :param max_len:
    :return:
    """
    if '!Sample_geo_accession' in dataframe.columns:
        dataframe = dataframe.drop(columns=['!Sample_geo_accession'])
    unique_values_dict = {}
    for index, row in dataframe.iterrows():
        unique_values = list(row.unique())[:max_len]
        unique_values_dict[index] = unique_values
    return unique_values_dict

def check_rows_and_columns(dataframe, display=False):
    """
    Get the lists of row names and column names of a dataset, and optionally observe them.
    :param dataframe:
    :param display:
    :return:
    """
    dataframe_rows = dataframe.index.tolist()
    if display:
        print(f"The dataset has {len(dataframe_rows)} rows, such as {dataframe_rows[:20]}")
    dataframe_cols = dataframe.columns.tolist()
    if display:
        print(f"\nThe dataset has {len(dataframe_cols)} columns, such as {dataframe_cols[:20]}")
    return dataframe_rows, dataframe_cols

def preview_df(df, n=5):
    return df.head(n).to_dict(orient='list')

def xena_convert_trait(row_index: str):
    """
    Convert the trait information from Sample IDs to labels depending on the last two digits.
    Tumor types range from 01 - 09, normal types from 10 - 19.
    :param row_index: the index value of a row
    :return: the converted value
    """
    last_two_digits = int(row_index[-2:])

    if 1 <= last_two_digits <= 9:
        return 1
    elif 10 <= last_two_digits <= 19:
        return 0
    else:
        return -1


def xena_convert_gender(cell: str):
    """Convert the cell content about gender to a binary value
    """
    if isinstance(cell, str):
        cell = cell.lower()

    if cell == "female":
        return 0
    elif cell == "male":
        return 1
    else:
        return None


def xena_convert_age(cell: str):
    """Convert the cell content about age to a numerical value using regular expression
    """
    match = re.search(r'\d+', str(cell))
    if match:
        return int(match.group())
    else:
        return None

def xena_select_clinical_features(clinical_df, trait, age_col=None, gender_col=None):
    feature_list = []
    trait_data = clinical_df.index.to_series().apply(xena_convert_trait).rename(trait)
    feature_list.append(trait_data)
    if age_col:
        age_data = clinical_df[age_col].apply(xena_convert_age).rename("Age")
        feature_list.append(age_data)
    if gender_col:
        gender_data = clinical_df[gender_col].apply(xena_convert_gender).rename("Gender")
        feature_list.append(gender_data)
    selected_clinical_df = pd.concat(feature_list, axis=1)
    return selected_clinical_df

def normalize_gene_symbols(gene_symbols, batch_size=1000):
    """Normalize human gene symbols in batches using the 'mygenes' library"""
    mg = mygene.MyGeneInfo()
    normalized_genes = {}

    # Process in batches
    for i in range(0, len(gene_symbols), batch_size):
        batch = gene_symbols[i:i + batch_size]
        results = mg.querymany(batch, scopes='symbol', fields='symbol', species='human')

        # Update the normalized_genes dictionary with results from this batch
        for gene in results:
            normalized_genes[gene['query']] = gene.get('symbol', None)

    # Return the normalized symbols in the same order as the input
    return [normalized_genes.get(symbol) for symbol in gene_symbols]

def normalize_gene_symbols_in_index(gene_df):
    """Normalize the human gene symbols at the index of a dataframe, and replace the index with its normalized version.
    Remove the rows where the index failed to be normalized."""
    normalized_gene_list = normalize_gene_symbols(gene_df.index.tolist())
    assert len(normalized_gene_list) == len(gene_df.index)
    gene_df.index = normalized_gene_list
    gene_df = gene_df[gene_df.index.notnull()]
    return gene_df

def judge_binary_variable_biased(dataframe, col_name, min_proportion=0.1, min_num=5):
    """
    Check if the distribution of a binary variable in the dataset is too biased to be usable for analysis
    :param dataframe:
    :param col_name:
    :param min_proportion:
    :param min_num:
    :return:
    """
    label_counter = dataframe[col_name].value_counts()
    total_samples = len(dataframe)
    rare_label_num = label_counter.min()
    rare_label = label_counter.idxmin()
    rare_label_proportion = rare_label_num / total_samples

    print(
        f"For the feature \'{col_name}\', the least common label is '{rare_label}' with {rare_label_num} occurrences. This represents {rare_label_proportion:.2%} of the dataset.")

    biased = (len(label_counter) < 2) or ((rare_label_proportion < min_proportion) and (rare_label_num < min_num))
    return bool(biased)

def judge_continuous_variable_biased(dataframe, col_name):
    """Check if the distribution of a continuous variable in the dataset is too biased to be usable for analysis.
    As a starting point, we consider it biased if all values are the same. For the next step, maybe ask GPT to judge
    based on quartile statistics combined with its common sense knowledge about this feature.
    """
    quartiles = dataframe[col_name].quantile([0.25, 0.5, 0.75])
    min_value = dataframe[col_name].min()
    max_value = dataframe[col_name].max()

    # Printing quartile information
    print(f"Quartiles for '{col_name}':")
    print(f"  25%: {quartiles[0.25]}")
    print(f"  50% (Median): {quartiles[0.5]}")
    print(f"  75%: {quartiles[0.75]}")
    print(f"Min: {min_value}")
    print(f"Max: {max_value}")

    biased = min_value == max_value

    return bool(biased)

def judge_and_remove_biased_features(df, trait, trait_type):
    assert trait_type in ["binary", "continuous"], f"The trait must be either a binary or a continuous variable!"
    if trait_type == "binary":
        trait_biased = judge_binary_variable_biased(df, trait)
    else:
        trait_biased = judge_continuous_variable_biased(df, trait)
    if trait_biased:
        print(f"The distribution of the feature \'{trait}\' in this dataset is severely biased.\n")
    else:
        print(f"The distribution of the feature \'{trait}\' in this dataset is fine.\n")
    if "Age" in df.columns:
        age_biased = judge_continuous_variable_biased(df, 'Age')
        if age_biased:
            print(f"The distribution of the feature \'Age\' in this dataset is severely biased.\n")
            df = df.drop(columns='Age')
        else:
            print(f"The distribution of the feature \'Age\' in this dataset is fine.\n")
    if "Gender" in df.columns:
        gender_biased = judge_binary_variable_biased(df, 'Gender')
        if gender_biased:
            print(f"The distribution of the feature \'Gender\' in this dataset is severely biased.\n")
            df = df.drop(columns='Gender')
        else:
            print(f"The distribution of the feature \'Gender\' in this dataset is fine.\n")

    return trait_biased, df

def save_cohort_info(cohort: str, info_path: str, is_available: bool, is_biased: Optional[bool] = None,
                     df: Optional[pd.DataFrame] = None, note: str = '') -> None:
    """
    Add or update information about the usability and quality of a dataset for statistical analysis.

    Parameters:
    cohort (str): A unique identifier for the dataset.
    info_path (str): File path to the JSON file where records are stored.
    is_available (bool): Indicates whether both the genetic data and trait data are available in the dataset, and can be
     preprocessed into a dataframe.
    is_biased (bool, optional): Indicates whether the dataset is too biased to be usable.
        Required if `is_available` is True.
    df (pandas.DataFrame, optional): The preprocessed dataset. Required if `is_available` is True.
    note (str, optional): Additional notes about the dataset.

    Returns:
    None: The function does not return a value but updates or creates a record in the specified JSON file.
    """
    if is_available:
        assert (df is not None) and (is_biased is not None), "'df' and 'is_biased' should be provided if this cohort " \
                                                             "is relevant."
    is_usable = is_available and (not is_biased)
    new_record = {"is_usable": is_usable,
                  "is_available": is_available,
                  "is_biased": is_biased if is_available else None,
                  "has_age": "Age" in df.columns if is_available else None,
                  "has_gender": "Gender" in df.columns if is_available else None,
                  "sample_size": len(df) if is_available else None,
                  "note": note}

    if not os.path.exists(info_path):
        with open(info_path, 'w') as file:
            json.dump({}, file)
        print(f"A new JSON file was created at: {info_path}")

    with open(info_path, "r") as file:
        records = json.load(file)
    records[cohort] = new_record

    temp_path = info_path + ".tmp"
    try:
        with open(temp_path, 'w') as file:
            json.dump(records, file)
        os.replace(temp_path, info_path)

    except Exception as e:
        print(f"An error occurred: {e}")
        if os.path.exists(temp_path):
            os.remove(temp_path)
        raise

def get_feature_data(clinical_df, row_id, feature, convert_fn):
    """select the row corresponding to a feature in the sample characteristics dataframe, and convert the feature into
    a binary or continuous variable"""
    clinical_df = clinical_df.iloc[row_id:row_id + 1].drop(columns=['!Sample_geo_accession'], errors='ignore')
    clinical_df.index = [feature]
    clinical_df = clinical_df.applymap(convert_fn)

    return clinical_df

def geo_select_clinical_features(clinical_df: pd.DataFrame, trait: str, trait_row: int,
                                 convert_trait: Callable,
                                 age_row: Optional[int] = None,
                                 convert_age: Optional[Callable] = None,
                                 gender_row: Optional[int] = None,
                                 convert_gender: Optional[Callable] = None) -> pd.DataFrame:
    """
    Extracts and processes specific clinical features from a DataFrame representing
    sample characteristics in the GEO database series.

    Parameters:
    - clinical_df (pd.DataFrame): DataFrame containing clinical data.
    - trait (str): The trait of interest.
    - trait_row (int): Row identifier for the trait in the DataFrame.
    - convert_trait (Callable): Function to convert trait data into a desired format.
    - age_row (int, optional): Row identifier for age data. Default is None.
    - convert_age (Callable, optional): Function to convert age data. Default is None.
    - gender_row (int, optional): Row identifier for gender data. Default is None.
    - convert_gender (Callable, optional): Function to convert gender data. Default is None.

    Returns:
    pd.DataFrame: A DataFrame containing the selected and processed clinical features.
    """
    feature_list = []

    trait_data = get_feature_data(clinical_df, trait_row, trait, convert_trait)
    feature_list.append(trait_data)
    if age_row is not None:
        age_data = get_feature_data(clinical_df, age_row, 'Age', convert_age)
        feature_list.append(age_data)
    if gender_row is not None:
        gender_data = get_feature_data(clinical_df, gender_row, 'Gender', convert_gender)
        feature_list.append(gender_data)

    selected_clinical_df = pd.concat(feature_list, axis=0)
    return selected_clinical_df

def get_genetic_data(file_path):
    """Read the gene expression data into a dataframe, and adjust its format"""
    genetic_data = pd.read_csv(file_path, compression='gzip', skiprows=52, comment='!', delimiter='\t')
    genetic_data = genetic_data.dropna()
    genetic_data = genetic_data.rename(columns={'ID_REF': 'ID'}).astype({'ID': 'str'})
    genetic_data.set_index('ID', inplace=True)

    return genetic_data

def get_gene_annotation(file_path, prefixes=['^', '!', '#']):
    """Extract from a SOFT file the gene annotation data"""
    gene_metadata = filter_content_by_prefix(file_path, prefixes_a=prefixes, unselect=True, source_type='file',
                                             return_df_a=True)
    return gene_metadata[0]

def get_gene_mapping(annotation, prob_col, gene_col):
    """Process the gene annotation to get the mapping between gene names and gene probes.
    """
    mapping_data = annotation.loc[:, [prob_col, gene_col]]
    mapping_data = mapping_data.dropna()
    mapping_data = mapping_data.rename(columns={gene_col: 'Gene'}).astype({'ID': 'str'})

    return mapping_data

def apply_gene_mapping(expression_df, mapping_df):
    """
    Converts measured data about gene probes into gene expression data.
    Handles the potential many-to-many relationship between probes and genes.

    Parameters:
    expression_df (DataFrame): A DataFrame with gene expression data, indexed by 'ID'.
    mapping_df (DataFrame): A DataFrame mapping 'ID' to 'Gene', with 'ID' as a column.

    Returns:
    DataFrame: A DataFrame with mean gene expression values, indexed by 'Gene'.
    """

    # Define a regex pattern for splitting gene names
    split_pattern = r';|\|+|/{2,}|,|\[|\]|\(|\)'

    # Split the 'Gene' column in 'mapping_df' using the regex pattern
    mapping_df['Gene'] = mapping_df['Gene'].str.split(split_pattern)
    mapping_df = mapping_df.explode('Gene')

    # Set 'ID' as the index of 'mapping_df' for merging
    mapping_df.set_index('ID', inplace=True)

    # Merge 'mapping_df' with 'expression_df' by their indices
    merged_df = mapping_df.join(expression_df)

    # Group by 'Gene' and calculate the mean expression values
    gene_expression_df = merged_df.groupby('Gene').mean().dropna()

    return gene_expression_df

def geo_merge_clinical_genetic_data(clinical_df, genetic_df):
    """
    Merge the clinical features and gene expression features from two dataframes into one dataframe
    """
    if 'ID' in genetic_df.columns:
        genetic_df = genetic_df.rename(columns={'ID': 'Gene'})
    if 'Gene' in genetic_df.columns:
        genetic_df = genetic_df.set_index('Gene')
    merged_data = pd.concat([clinical_df, genetic_df], axis=0).T.dropna()
    return merged_data

def read_json_to_dataframe(json_file: str) -> pd.DataFrame:
    """
    Reads a JSON file and converts it into a pandas DataFrame.

    Args:
    json_file (str): The path to the JSON file containing the data.

    Returns:
    DataFrame: A pandas DataFrame with the JSON data.
    """
    with open(json_file, 'r') as file:
        data = json.load(file)
    return pd.DataFrame.from_dict(data, orient='index').reset_index().rename(columns={'index': 'cohort_id'})

def filter_and_rank_cohorts(json_file: str, condition: Union[str, None] = None) -> Tuple[
    Union[str, None], pd.DataFrame]:
    """
    Reads a JSON file, filters cohorts based on usability and an optional condition, then ranks them by sample size.

    Args:
    json_file (str): The path to the JSON file containing the data.
    condition (str, optional): An additional condition for filtering. If None, only 'is_usable' is considered.

    Returns:
    Tuple: A tuple containing the best cohort ID (str or None if no suitable cohort is found) and
           the filtered and ranked DataFrame.
    """
    # Read the JSON file into a DataFrame
    df = read_json_to_dataframe(json_file)

    if condition:
        filtered_df = df[(df['is_usable'] == True) & (df[condition] == True)]
    else:
        filtered_df = df[df['is_usable'] == True]

    ranked_df = filtered_df.sort_values(by='sample_size', ascending=False)
    best_cohort_id = ranked_df.iloc[0]['cohort_id'] if not ranked_df.empty else None

    return best_cohort_id, ranked_df

def detect_batch_effect(X):
    """
    Detect potential batch effects in a dataset using eigenvalues of XX^T.

    Args:
    X (numpy.ndarray): A feature matrix with shape (n_samples, n_features).

    Returns:
    bool: True if a potential batch effect is detected, False otherwise.
    """
    n_samples = X.shape[0]

    # Computing XX^T
    XXt = np.dot(X, X.T)

    # Compute the eigenvalues of XX^T
    eigen_values = np.linalg.eigvalsh(XXt)  # Using eigvalsh since XX^T is symmetric
    eigen_values = sorted(eigen_values, reverse=True)

    # Check for large gaps in the eigenvalues
    for i in range(len(eigen_values) - 1):
        gap = eigen_values[i] - eigen_values[i + 1]
        if gap > 1 / n_samples:  # You may need to adjust this threshold
            return True

    return False

def normalize_data(X_train, X_test=None):
    """Compute the mean and standard deviation statistics of the training data, use them to normalize the training data,
    and optionally the test data"""
    mean = np.mean(X_train, axis=0)
    std = np.std(X_train, axis=0)

    # Handling columns with std = 0
    std_no_zero = np.where(std == 0, 1, std)

    # Normalize X_train
    X_train_normalized = (X_train - mean) / std_no_zero
    # Set normalized values to 0 where std was 0
    X_train_normalized[:, std == 0] = 0

    if X_test is not None:
        X_test_normalized = (X_test - mean) / std_no_zero
        X_test_normalized[:, std == 0] = 0
    else:
        X_test_normalized = None

    return X_train_normalized, X_test_normalized


class ResidualizationRegressor:
    def __init__(self, regression_model_constructor, params=None):
        if params is None:
            params = {}
        self.regression_model = regression_model_constructor(**params)
        self.beta_Z = None  # Coefficients for regression of Y on Z
        self.beta_X = None  # Coefficients for regression of residual on X
        self.neg_log_p_values = None  # Negative logarithm of p-values
        self.p_values = None  # Actual p-values

    def _reshape_data(self, data):
        """
        Reshape the data to ensure it's in the correct format (2D array).

        :param data: The input data (can be 1D or 2D array).
        :return: Reshaped 2D array.
        """
        if data.ndim == 1:
            return data.reshape(-1, 1)
        return data

    def _reshape_output(self, data):
        """
        Reshape the output data to ensure it's in the correct format (1D array).

        :param data: The output data (can be 1D or 2D array).
        :return: Reshaped 1D array.
        """
        if data.ndim == 2 and data.shape[1] == 1:
            return data.ravel()
        return data

    def fit(self, X, Y, Z):
        X = self._reshape_data(X)
        Y = self._reshape_data(Y)
        Z = self._reshape_data(Z)

        # Step 1: Linear regression of Y on Z
        Z_ones = np.column_stack((np.ones(Z.shape[0]), Z))
        self.beta_Z = np.linalg.pinv(Z_ones.T @ Z_ones) @ Z_ones.T @ Y
        Y_hat = Z_ones @ self.beta_Z
        e_Y = Y - Y_hat  # Residual of Y

        # Step 2: Regress the residual on X using the included regression model
        self.regression_model.fit(X, e_Y)

        # Obtain coefficients from the regression model
        if hasattr(self.regression_model, 'coef_'):
            self.beta_X = self.regression_model.coef_
        elif hasattr(self.regression_model, 'getBeta'):
            beta_output = self.regression_model.getBeta()
            self.beta_X = self._reshape_output(beta_output)

        # Obtain negative logarithm of p-values, if available
        if hasattr(self.regression_model, 'getNegLogP'):
            neg_log_p_output = self.regression_model.getNegLogP()
            if neg_log_p_output is not None:
                self.neg_log_p_values = self._reshape_output(neg_log_p_output)
                self.p_values = np.exp(-self.neg_log_p_values)
                # Concatenate the p-values of Z and X. The p-values of Z were not computed, mark with NaN.
                p_values_Z = np.full(Z.shape[1], np.nan)
                self.p_values = np.concatenate((p_values_Z, self.p_values))

    def predict(self, X, Z):
        X = self._reshape_data(X)
        Z = self._reshape_data(Z)

        Z_ones = np.column_stack((np.ones(Z.shape[0]), Z))
        ZX = np.column_stack((Z, X))
        combined_beta = np.concatenate((self.beta_Z[1:].ravel(), self.beta_X.ravel()))
        return ZX @ combined_beta + self.beta_Z[0]

    def get_coefficients(self):
        return np.concatenate((self.beta_Z[1:].ravel(), self.beta_X.ravel()))

    def get_p_values(self):
        return self.p_values

    def predict(self, X, Z):
        X = self._reshape_data(X)
        Z = self._reshape_data(Z)

        Z_ones = np.column_stack((np.ones(Z.shape[0]), Z))
        ZX = np.column_stack((Z, X))
        combined_beta = np.concatenate((self.beta_Z[1:].ravel(), self.beta_X.ravel()))
        return ZX @ combined_beta + self.beta_Z[0]

    def get_coefficients(self):
        return np.concatenate((self.beta_Z[1:].ravel(), self.beta_X.ravel()))

    def get_p_values(self):
        return self.p_values


def cross_validation(X, Y, Z, model_constructor, model_params, k=5, target_type='binary'):
    assert target_type in ['binary', 'continuous'], "The target type must be chosen from 'binary' or 'continuous'"
    indices = np.arange(X.shape[0])
    np.random.shuffle(indices)

    fold_size = len(X) // k
    performances = []

    for i in range(k):
        # Split data into train and test based on the current fold
        test_indices = indices[i * fold_size: (i + 1) * fold_size]
        train_indices = np.setdiff1d(indices, test_indices)

        X_train, X_test = X[train_indices], X[test_indices]
        Y_train, Y_test = Y[train_indices], Y[test_indices]
        Z_train, Z_test = Z[train_indices], Z[test_indices]

        normalized_X_train, normalized_X_test = normalize_data(X_train, X_test)
        normalized_Z_train, normalized_Z_test = normalize_data(Z_train, Z_test)

        # model = model_constructor(**model_params)
        model = ResidualizationRegressor(model_constructor, model_params)
        model.fit(normalized_X_train, Y_train, normalized_Z_train)
        predictions = model.predict(normalized_X_test, normalized_Z_test)

        if target_type == 'binary':
            predictions = (predictions > 0.5).astype(int)
            Y_test = (Y_test > 0.5).astype(int)
            performance = accuracy_score(Y_test, predictions)
        elif target_type == 'continuous':
            performance = mean_squared_error(Y_test, predictions)

        performances.append(performance)

    cv_mean = np.mean(performances)
    cv_std = np.std(performances)

    if target_type == 'binary':
        print(f'The cross-validation accuracy is {(cv_mean * 100):.2f}% ± {(cv_std * 100):.2f}%')
    else:
        print(f'The cross-validation MSE is {(cv_mean * 100):.2f}% ± {(cv_std * 100):.2f}%')

    return cv_mean, cv_std

def interpret_result(model: Any, feature_names: List[str], trait: str, condition: str,
                     threshold: float = 0.05, save_output: bool = True,
                     output_dir: str = './output', model_id: int = 1) -> None:
    """This function interprets and reports the result of a trained linear regression model, where the regressor
    consists of one variable about condition and multiple variables about genetic factors.
    The function extracts coefficients and p-values from the model, and identifies the significant genes based on
    p-values or non-zero coefficients, depending on the availability of p-values.

    Parameters:
    model (Any): The trained regression Model.
    feature_names (List[str]): A list of feature names corresponding to the model's coefficients.
    trait (str): The target trait of interest.
    condition (str): The specific condition to examine within the model.
    threshold (float): Significance level for p-value correction. Defaults to 0.05.
    save_output (bool): Flag to determine whether to save the output to a file. Defaults to True.
    output_dir (str): Directory path where output files are saved. Defaults to './output'.
    model_id (int): The index of the model, 1 or 2.

    Returns:
    None: This function does not return anything but prints and optionally saves the output.
    """
    coefficients = model.get_coefficients().reshape(-1).tolist()
    p_values = model.get_p_values()
    if p_values is None:
        regression_df = pd.DataFrame({
            'Variable': feature_names,
            'Coefficient': coefficients
        })
    else:
        regression_df = pd.DataFrame({
            'Variable': feature_names,
            'Coefficient': coefficients,
            'p_value': p_values.reshape(-1).tolist()
        })

    condition_effect = regression_df[regression_df['Variable'] == condition].iloc[0]

    print(f"Effect of the condition on the target variable:")
    print(f"Variable: {condition}")
    print(f"Coefficient: {condition_effect['Coefficient']:.4f}")
    gene_regression_df = regression_df[regression_df['Variable'] != condition]
    if p_values is None:
        gene_regression_df['Absolute Coefficient'] = gene_regression_df['Coefficient'].abs()
        significant_genes = gene_regression_df[gene_regression_df['Coefficient'] != 0]
        significant_genes_sorted = significant_genes.sort_values(by='Absolute Coefficient', ascending=False)
        print(
            f"Found {len(significant_genes_sorted)} genes with non-zero coefficients associated with the trait '{trait}' "
            f"conditional on the factor '{condition}'. These genes are identified as significant based on the regression model.")
    else:
        # Apply the Benjamini-Hochberg correction, to get the corrected p-values
        corrected_p_values = multipletests(gene_regression_df['p_value'], alpha=threshold, method='fdr_bh')[1]
        gene_regression_df.loc[:, 'corrected_p_value'] = corrected_p_values
        significant_genes = gene_regression_df.loc[gene_regression_df['corrected_p_value'] < threshold]
        significant_genes_sorted = significant_genes.sort_values('corrected_p_value')
        print(
            f"Found {len(significant_genes_sorted)} significant genes associated with the trait '{trait}' conditional on "
            f"the factor '{condition}', with corrected p-value < {threshold}:")

    print(significant_genes_sorted.to_string(index=False))

    # Optionally, save this to a CSV file
    if save_output:
        significant_genes_sorted.to_csv(
            os.path.join(output_dir, f'significant_genes_condition_{condition}_{model_id}.csv'), index=False)

# %%
# Set your preferred name
USER = "Jinglei"
# Set the data and output directories
DATA_ROOT = '/Users/jane/UIUC/Research/Data'
OUTPUT_ROOT = '/Users/jane/UIUC/Research/Output'
TRAIT = 'pain sensitivity'

OUTPUT_DIR = os.path.join(OUTPUT_ROOT, USER, '-'.join(TRAIT.split()))
JSON_PATH = os.path.join(OUTPUT_DIR, "cohort_info.json")
if not os.path.exists(OUTPUT_DIR):
    os.makedirs(OUTPUT_DIR, exist_ok=True)

# Gene symbol normalization may take 1-2 minutes. You may set it to False for debugging.
NORMALIZE_GENE = True

# %% [markdown]
# 2. Data preprocessing and selection
#
# The GEO dataset

# %%
dataset = 'GEO'
trait_subdir = "Pain-Sensitivity"

trait_path = os.path.join(DATA_ROOT, dataset, trait_subdir)
os.listdir(trait_path)
# Out:
# ['GSE53128', 'GSE53130']

# %%
cohort = accession_num = "GSE53128"
cohort_dir = os.path.join(trait_path, accession_num)
soft_file, matrix_file = get_relevant_filepaths(cohort_dir)
soft_file, matrix_file
# Out:
# ('/Users/jane/UIUC/Research/Data/GEO/Pain-Sensitivity/GSE53128/GSE53128_family.soft.gz',
#  '/Users/jane/UIUC/Research/Data/GEO/Pain-Sensitivity/GSE53128/GSE53128_series_matrix.txt.gz')

# %%
cohort = accession_num = "GSE53130"
cohort_dir = os.path.join(trait_path, accession_num)
soft_file, matrix_file = get_relevant_filepaths(cohort_dir)
soft_file, matrix_file
# Out:
# ('/Users/jane/UIUC/Research/Data/GEO/Pain-Sensitivity/GSE53130/GSE53130_family.soft.gz',
#  '/Users/jane/UIUC/Research/Data/GEO/Pain-Sensitivity/GSE53130/GSE53130-GPL13534_series_matrix.txt.gz')

# %%
background_prefixes = ['!Series_title', '!Series_summary', '!Series_overall_design']
clinical_prefixes = ['!Sample_geo_accession', '!Sample_characteristics_ch1']

background_info, clinical_data = get_background_and_clinical_data(matrix_file, background_prefixes, clinical_prefixes)
print(background_info)
# Out:
# !Series_title	"Differential Methylation Of The  TRPA1 Promoter In Pain Sensitivity"
# !Series_summary	"This SuperSeries is composed of the SubSeries listed below."
# !Series_overall_design	"Refer to individual Series"

# %%
clinical_data.head()
# Out:
#          !Sample_geo_accession                               GSM1282779  \
# 0  !Sample_characteristics_ch1  individual: Family 2 monozygotic twin 1
# 1  !Sample_characteristics_ch1                           gender: Female
# 2  !Sample_characteristics_ch1                   pain temperature: 42.8
# 3  !Sample_characteristics_ch1                            age: 54.55168
# 4  !Sample_characteristics_ch1                       medip-seq id: 6160
#
#                                 GSM1282780  \
# 0  individual: Family 2 monozygotic twin 2
# 1                           gender: Female
# 2                   pain temperature: 47.6
# 3                            age: 54.55168
# 4                      medip-seq id: 13563
#
#                                 GSM1282781  \
# 0  individual: Family 3 monozygotic twin 1
# 1                           gender: Female
# 2                   pain temperature: 45.5
# 3                            age: 47.27721
# 4                       medip-seq id: 7752
#
#                                 GSM1282782  \
# 0  individual: Family 3 monozygotic twin 2
# 1                           gender: Female
# 2                   pain temperature: 49.5
# 3                            age: 47.27721
# 4                       medip-seq id: 1293
#
#                                 GSM1282783  \
# 0  individual: Family 4 monozygotic twin 1
# 1                           gender: Female
# 2                   pain temperature: 49.8
# 3                            age: 65.47296
# 4                      medip-seq id: 13812
#
#                                 GSM1282784  \
# 0  individual: Family 4 monozygotic twin 2
# 1                           gender: Female
# 2                     pain temperature: 46
# 3                            age: 65.47296
# 4                     medip-seq id: 110504
#
#                                 GSM1282785  \
# 0  individual: Family 5 monozygotic twin 1
# 1                           gender: Female
# 2                   pain temperature: 45.2
# 3                            age: 69.29774
# 4                     medip-seq id: 220824
#
#                                 GSM1282786  \
# 0  individual: Family 5 monozygotic twin 2
# 1                           gender: Female
# 2                   pain temperature: 48.4
# 3                            age: 69.29774
# 4                     medip-seq id: 147224
#
#                                 GSM1282787  ...  \
# 0  individual: Family 6 monozygotic twin 1  ...
# 1                           gender: Female  ...
# 2                   pain temperature: 43.8  ...
# 3                            age: 54.71321  ...
# 4                     medip-seq id: 150096  ...
#
#                                  GSM1282812  \
# 0  individual: Family 20 monozygotic twin 2
# 1                            gender: Female
# 2                      pain temperature: 50
# 3                             age: 61.91376
# 4                      medip-seq id: 877393
#
#                                  GSM1282813  \
# 0  individual: Family 21 monozygotic twin 1
# 1                            gender: Female
# 2                    pain temperature: 48.1
# 3                             age: 54.85558
# 4                       medip-seq id: 79872
#
#                                  GSM1282814  \
# 0  individual: Family 21 monozygotic twin 2
# 1                            gender: Female
# 2                    pain temperature: 43.4
# 3                             age: 54.85558
# 4                      medip-seq id: 559111
#
#                                  GSM1282815  \
# 0  individual: Family 22 monozygotic twin 1
# 1                            gender: Female
# 2                    pain temperature: 45.9
# 3                             age: 60.06297
# 4                      medip-seq id: 483852
#
#                                  GSM1282816  \
# 0  individual: Family 22 monozygotic twin 2
# 1                            gender: Female
# 2                      pain temperature: 50
# 3                             age: 60.06297
# 4                      medip-seq id: 403215
#
#                                  GSM1282817  \
# 0  individual: Family 23 monozygotic twin 1
# 1                            gender: Female
# 2                    pain temperature: 38.6
# 3                             age: 63.60575
# 4                      medip-seq id: 712976
#
#                                  GSM1282818  \
# 0  individual: Family 23 monozygotic twin 2
# 1                            gender: Female
# 2                    pain temperature: 46.5
# 3                             age: 63.60575
# 4                      medip-seq id: 445615
#
#                                  GSM1282819  \
# 0  individual: Family 24 monozygotic twin 1
# 1                            gender: Female
# 2                    pain temperature: 46.9
# 3                             age: 76.49555
# 4                      medip-seq id: 283836
#
#                                  GSM1282820  \
# 0  individual: Family 24 monozygotic twin 2
# 1                            gender: Female
# 2                      pain temperature: 42
# 3                             age: 76.49829
# 4                     medip-seq id: 1229969
#
#                                  GSM1282821
# 0  individual: Family 25 monozygotic twin 2
# 1                            gender: Female
# 2                      pain temperature: 50
# 3                             age: 60.01917
# 4                      medip-seq id: 477815
#
# [5 rows x 44 columns]

# %%
clinical_data_unique = get_unique_values_by_row(clinical_data)
clinical_data_unique
# Out:
# {0: ['individual: Family 2 monozygotic twin 1',
#   'individual: Family 2 monozygotic twin 2',
#   'individual: Family 3 monozygotic twin 1',
#   'individual: Family 3 monozygotic twin 2',
#   'individual: Family 4 monozygotic twin 1',
#   'individual: Family 4 monozygotic twin 2',
#   'individual: Family 5 monozygotic twin 1',
#   'individual: Family 5 monozygotic twin 2',
#   'individual: Family 6 monozygotic twin 1',
#   'individual: Family 6 monozygotic twin 2',
#   'individual: Family 7 monozygotic twin 1',
#   'individual: Family 7 monozygotic twin 2',
#   'individual: Family 8 monozygotic twin 2',
#   'individual: Family 9 monozygotic twin 1',
#   'individual: Family 9 monozygotic twin 2',
#   'individual: Family 11 monozygotic twin 1',
#   'individual: Family 11 monozygotic twin 2',
#   'individual: Family 12 monozygotic twin 1',
#   'individual: Family 12 monozygotic twin 2',
#   'individual: Family 13 monozygotic twin 1',
#   'individual: Family 13 monozygotic twin 2',
#   'individual: Family 14 monozygotic twin 1',
#   'individual: Family 14 monozygotic twin 2',
#   'individual: Family 15 monozygotic twin 1',
#   'individual: Family 15 monozygotic twin 2',
#   'individual: Family 16 monozygotic twin 1',
#   'individual: Family 17 monozygotic twin 1',
#   'individual: Family 17 monozygotic twin 2',
#   'individual: Family 18 monozygotic twin 1',
#   'individual: Family 18 monozygotic twin 2'],
#  1: ['gender: Female'],
#  2: ['pain temperature: 42.8',
#   'pain temperature: 47.6',
#   'pain temperature: 45.5',
#   'pain temperature: 49.5',
#   'pain temperature: 49.8',
#   'pain temperature: 46',
#   'pain temperature: 45.2',
#   'pain temperature: 48.4',
#   'pain temperature: 43.8',
#   'pain temperature: 46.8',
#   'pain temperature: 45',
#   'pain temperature: 48.7',
#   'pain temperature: 47.1',
#   'pain temperature: 44.6',
#   'pain temperature: 50',
#   'pain temperature: 46.9',
#   'pain temperature: 48.3',
#   'pain temperature: 44.8',
#   'pain temperature: 47.9',
#   'pain temperature: 47.7',
#   'pain temperature: 47',
#   'pain temperature: 47.4',
#   'pain temperature: 48.2',
#   'pain temperature: 45.1',
#   'pain temperature: 47.5',
#   'pain temperature: 49.9',
#   'pain temperature: 46.6',
#   'pain temperature: 48.1',
#   'pain temperature: 43.4',
#   'pain temperature: 45.9'],
#  3: ['age: 54.55168',
#   'age: 47.27721',
#   'age: 65.47296',
#   'age: 69.29774',
#   'age: 54.71321',
#   'age: 62.75428',
#   'age: 59.43327',
#   'age: 63.83573',
#   'age: 65.52499',
#   'age: 67.08282',
#   'age: 56.77208',
#   'age: 66.78713',
#   'age: 75.09651',
#   'age: 69.88091',
#   'age: 59.08008',
#   'age: 59.28268',
#   'age: 58.58727',
#   'age: 61.91102',
#   'age: 61.91376',
#   'age: 54.85558',
#   'age: 60.06297',
#   'age: 63.60575',
#   'age: 76.49555',
#   'age: 76.49829',
#   'age: 60.01917'],
#  4: ['medip-seq id: 6160',
#   'medip-seq id: 13563',
#   'medip-seq id: 7752',
#   'medip-seq id: 1293',
#   'medip-seq id: 13812',
#   'medip-seq id: 110504',
#   'medip-seq id: 220824',
#   'medip-seq id: 147224',
#   'medip-seq id: 150096',
#   'medip-seq id: 93815',
#   'medip-seq id: 182718',
#   'medip-seq id: 101515',
#   'medip-seq id: 293839',
#   'medip-seq id: 285498',
#   'medip-seq id: 63446',
#   'medip-seq id: 650936',
#   'medip-seq id: 450657',
#   'medip-seq id: 200728',
#   'medip-seq id: 602196',
#   'medip-seq id: 374374',
#   'medip-seq id: 160449',
#   'medip-seq id: 588020',
#   'medip-seq id: 176409',
#   'medip-seq id: 470736',
#   'medip-seq id: 588430',
#   'medip-seq id: 356052',
#   'medip-seq id: 766282',
#   'medip-seq id: 487641',
#   'medip-seq id: 844344',
#   'medip-seq id: 281452'],
#  5: ['450k chip: 6042316131',
#   '450k chip: 6042316145',
#   '450k chip: 6057825005',
#   '450k chip: 6057825006',
#   '450k chip: 6055432102',
#   '450k chip: 6055432099',
#   '450k chip: 6055432120',
#   '450k chip: 6055432140',
#   '450k chip: 6055432089',
#   '450k chip: 6042316074',
#   '450k chip: 6055432155',
#   '450k chip: 6042308068',
#   '450k chip: 6042316146',
#   '450k chip: 6057825033',
#   '450k chip: 6042308075',
#   '450k chip: 6057825025',
#   '450k chip: 6055432144',
#   '450k chip: 6055432092'],
#  6: ['order on 450k chip: R03C02',
#   'order on 450k chip: R05C01',
#   'order on 450k chip: R06C02',
#   'order on 450k chip: R03C01',
#   'order on 450k chip: R05C02',
#   'order on 450k chip: R02C01',
#   'order on 450k chip: R02C02',
#   'order on 450k chip: R04C02',
#   'order on 450k chip: R04C01',
#   'order on 450k chip: R06C01',
#   'order on 450k chip: R01C01']}

# %%
f'''As a biomedical research team, we are selecting datasets to study the association between the human trait \'{TRAIT}\' and genetic factors, optionally considering the influence of age and gender. After searching the GEO database and parsing the matrix file of a series, we obtained background information and sample characteristics data. We will provide textual information about the dataset background, and a Python dictionary storing a list of unique values for each field of the sample characteristics data. Please carefully review the provided information and answer the following questions about this dataset:
1. Does this dataset contain gene expression data? (Note: Pure miRNA data is not suitable.)
2. For each of the traits \'{TRAIT}\', 'age', and 'gender', please address these points:
   (1) Is there human data available for this trait?
   (2) If so, identify the key in the sample characteristics dictionary where unique values of this trait is recorded. The key is an integer. The trait information might be explicitly recorded, or can be inferred from the field with some biomedical knowledge or understanding about the data collection process.
   (3) Choose an appropriate data type (either 'continuous' or 'binary') for each trait. Write a Python function to convert any given value of the trait to this data type. The function should handle inference about the trait value and convert unknown values to None.
   Name the functions 'convert_trait', 'convert_age', and 'convert_gender', respectively.

Background information about the dataset:
{background_info}

Sample characteristics dictionary (from "!Sample_characteristics_ch1", converted to a Python dictionary that stores the unique values for each field):
{clinical_data_unique}
'''
# Out:
# 'As a biomedical research team, we are selecting datasets to study the association between the human trait \'pain sensitivity\' and genetic factors, optionally considering the influence of age and gender. After searching the GEO database and parsing the matrix file of a series, we obtained background information and sample characteristics data. We will provide textual information about the dataset background, and a Python dictionary storing a list of unique values for each field of the sample characteristics data. Please carefully review the provided information and answer the following questions about this dataset:\n1. Does this dataset contain gene expression data? (Note: Pure miRNA data is not suitable.)\n2. For each of the traits \'pain sensitivity\', \'age\', and \'gender\', please address these points:\n   (1) Is there human data available for this trait?\n   (2) If so, identify the key in the sample characteristics dictionary where unique values of this trait is recorded. The key is an integer. The trait information might be explicitly recorded, or can be inferred from the field with some biomedical knowledge or understanding about the data collection process.\n   (3) Choose an appropriate data type (either \'continuous\' or \'binary\') for each trait. Write a Python function to convert any given value of the trait to this data type. The function should handle inference about the trait value and convert unknown values to None.\n   Name the functions \'convert_trait\', \'convert_age\', and \'convert_gender\', respectively.\n\nBackground information about the dataset:\n!Series_title\t"Differential Methylation Of The  TRPA1 Promoter In Pain Sensitivity"\n!Series_summary\t"This SuperSeries is composed of the SubSeries listed below."\n!Series_overall_design\t"Refer to individual Series"\n\nSample characteristics dictionary (from "!Sample_characteristics_ch1", converted to a Python dictionary that stores the unique values for each field):\n{0: [\'individual: Family 2 monozygotic twin 1\', \'individual: Family 2 monozygotic twin 2\', \'individual: Family 3 monozygotic twin 1\', \'individual: Family 3 monozygotic twin 2\', \'individual: Family 4 monozygotic twin 1\', \'individual: Family 4 monozygotic twin 2\', \'individual: Family 5 monozygotic twin 1\', \'individual: Family 5 monozygotic twin 2\', \'individual: Family 6 monozygotic twin 1\', \'individual: Family 6 monozygotic twin 2\', \'individual: Family 7 monozygotic twin 1\', \'individual: Family 7 monozygotic twin 2\', \'individual: Family 8 monozygotic twin 2\', \'individual: Family 9 monozygotic twin 1\', \'individual: Family 9 monozygotic twin 2\', \'individual: Family 11 monozygotic twin 1\', \'individual: Family 11 monozygotic twin 2\', \'individual: Family 12 monozygotic twin 1\', \'individual: Family 12 monozygotic twin 2\', \'individual: Family 13 monozygotic twin 1\', \'individual: Family 13 monozygotic twin 2\', \'individual: Family 14 monozygotic twin 1\', \'individual: Family 14 monozygotic twin 2\', \'individual: Family 15 monozygotic twin 1\', \'individual: Family 15 monozygotic twin 2\', \'individual: Family 16 monozygotic twin 1\', \'individual: Family 17 monozygotic twin 1\', \'individual: Family 17 monozygotic twin 2\', \'individual: Family 18 monozygotic twin 1\', \'individual: Family 18 monozygotic twin 2\'], 1: [\'gender: Female\'], 2: [\'pain temperature: 42.8\', \'pain temperature: 47.6\', \'pain temperature: 45.5\', \'pain temperature: 49.5\', \'pain temperature: 49.8\', \'pain temperature: 46\', \'pain temperature: 45.2\', \'pain temperature: 48.4\', \'pain temperature: 43.8\', \'pain temperature: 46.8\', \'pain temperature: 45\', \'pain temperature: 48.7\', \'pain temperature: 47.1\', \'pain temperature: 44.6\', \'pain temperature: 50\', \'pain temperature: 46.9\', \'pain temperature: 48.3\', \'pain temperature: 44.8\', \'pain temperature: 47.9\', \'pain temperature: 47.7\', \'pain temperature: 47\', \'pain temperature: 47.4\', \'pain temperatur ...

# %%
is_gene_availabe = True
trait_row = 6
age_row = None
gender_row = 1

trait_type = 'binary'

# %%
is_available = is_gene_availabe and (trait_row is not None)
if not is_available:
    save_cohort_info(cohort, JSON_PATH, is_available)
    print("This cohort is not usable. Please skip the following steps and jump to the next accession number.")

# %%
# Verify and use the functions generated by GPT

def convert_trait(disease_string):
    """
    Convert disease string to a binary value representing low grade glioma and glioblastoma.
    Presence of low grade glioma and glioblastoma is represented as 1, absence as 0.
    Unknown or non-breast cancer histologies are converted to None.
    """
    cancer_histologies = ['r03c02', 'r05c01', 'r06c02','r03c01','r05c02','r02c01','r02c02','r04c02','r04c01','r06c01','r01c01']
    disease = disease_string.split(': ')[1].lower()
    if disease in cancer_histologies:
        return 1
    elif disease == 'unknown':
        return None
    else:
        return 0


def convert_age(age_string):
    """
    Convert age string to a continuous numerical value.
    Unknown values are converted to None.
    """
    if age_string.lower() == 'n.a.':
        return None
    try:
        # Extract age as an integer from the string
        age = int(age_string.split(': ')[1])
        return age
    except (ValueError, IndexError):
        # In case of any format error or unexpected string structure
        return None


# It sometimes maps 'female' to 0, and sometimes 1. Does it matter?
def convert_gender(gender_string):
    """
    Convert gender string to a binary value.
    'female' is represented as 1, 'male' as 0.
    Unknown values are converted to None.
    """
    if gender_string.lower() == 'gender: female':
        return 1
    elif gender_string.lower() == 'gender: male':
        return 0
    else:
        return None

# %%
selected_clinical_data = geo_select_clinical_features(clinical_data, TRAIT, trait_row, convert_trait, age_row=age_row,
                                                      convert_age=convert_age, gender_row=gender_row,
                                                      convert_gender=convert_gender)
selected_clinical_data.head()
# Out:
#                   GSM1282779  GSM1282780  GSM1282781  GSM1282782  GSM1282783  \
# pain sensitivity           1           1           1           1           1
# Gender                     1           1           1           1           1
#
#                   GSM1282784  GSM1282785  GSM1282786  GSM1282787  GSM1282788  \
# pain sensitivity           1           1           1           1           1
# Gender                     1           1           1           1           1
#
#                   ...  GSM1282812  GSM1282813  GSM1282814  GSM1282815  \
# pain sensitivity  ...           1           1           1           1
# Gender            ...           1           1           1           1
#
#                   GSM1282816  GSM1282817  GSM1282818  GSM1282819  GSM1282820  \
# pain sensitivity           1           1           1           1           1
# Gender                     1           1           1           1           1
#
#                   GSM1282821
# pain sensitivity           1
# Gender                     1
#
# [2 rows x 43 columns]

# %%
genetic_data = get_genetic_data(matrix_file)
genetic_data.head()
# Out:
#             GSM1282779  GSM1282780  GSM1282781  GSM1282782  GSM1282783  \
# ID
# cg00000029    0.533466    0.564146    0.549167    0.476987    0.406114
# cg00000108    0.922119    0.927693    0.937400    0.926955    0.954690
# cg00000109    0.865672    0.886020    0.862970    0.862737    0.876784
# cg00000165    0.181671    0.192395    0.186722    0.201887    0.215909
# cg00000236    0.729652    0.736926    0.765399    0.701918    0.737116
#
#             GSM1282784  GSM1282785  GSM1282786  GSM1282787  GSM1282788  ...  \
# ID                                                                      ...
# cg00000029    0.501069    0.549132    0.453998    0.441995    0.393680  ...
# cg00000108    0.948251    0.954381    0.959909    0.969577    0.947952  ...
# cg00000109    0.860930    0.894794    0.912737    0.911882    0.865924  ...
# cg00000165    0.182055    0.260559    0.243524    0.165632    0.144720  ...
# cg00000236    0.742708    0.790671    0.729157    0.644795    0.657083  ...
#
#             GSM1282812  GSM1282813  GSM1282814  GSM1282815  GSM1282816  \
# ID
# cg00000029    0.536809    0.464373    0.458733    0.508002    0.451573
# cg00000108    0.958121    0.914752    0.924501    0.943567    0.938889
# cg00000109    0.894590    0.834240    0.854293    0.904484    0.866167
# cg00000165    0.178240    0.170626    0.206671    0.166971    0.170375
# cg00000236    0.709794    0.724387    0.709070    0.733809    0.678203
#
#             GSM1282817  GSM1282818  GSM1282819  GSM1282820  GSM1282821
# ID
# cg00000029    0.446210    0.492105    0.433152    0.378790    0.522758
# cg00000108    0.963426    0.963751    0.947648    0.941801    0.923208
# cg00000109    0.858240    0.890501    0.887723    0.885118    0.823715
# cg00000165    0.169675    0.223803    0.180183    0.175323    0.255204
# cg00000236    0.688692    0.700868    0.743881    0.712342    0.696886
#
# [5 rows x 43 columns]

# %%
gene_row_ids = genetic_data.index[:20].tolist()
gene_row_ids
# Out:
# ['cg00000029',
#  'cg00000108',
#  'cg00000109',
#  'cg00000165',
#  'cg00000236',
#  'cg00000289',
#  'cg00000292',
#  'cg00000321',
#  'cg00000363',
#  'cg00000622',
#  'cg00000658',
#  'cg00000714',
#  'cg00000721',
#  'cg00000734',
#  'cg00000807',
#  'cg00000884',
#  'cg00000905',
#  'cg00000924',
#  'cg00000948',
#  'cg00000957']

# %%
f'''
Below are the row headers of a gene expression dataset in GEO. Based on your biomedical knowledge, are they human gene symbols, or are they some other identifiers that need to be mapped to gene symbols? Your answer should be concluded by starting a new line and strictly following this format:
requires_gene_mapping = (True or False)

Row headers:
{gene_row_ids}
'''
# Out:
# "\nBelow are the row headers of a gene expression dataset in GEO. Based on your biomedical knowledge, are they human gene symbols, or are they some other identifiers that need to be mapped to gene symbols? Your answer should be concluded by starting a new line and strictly following this format:\nrequires_gene_mapping = (True or False)\n\nRow headers:\n['cg00000029', 'cg00000108', 'cg00000109', 'cg00000165', 'cg00000236', 'cg00000289', 'cg00000292', 'cg00000321', 'cg00000363', 'cg00000622', 'cg00000658', 'cg00000714', 'cg00000721', 'cg00000734', 'cg00000807', 'cg00000884', 'cg00000905', 'cg00000924', 'cg00000948', 'cg00000957']\n"

# %%
requires_gene_mapping = False

# %%
if requires_gene_mapping:
    gene_annotation = get_gene_annotation(soft_file)
    gene_annotation_summary = preview_df(gene_annotation)
    print(gene_annotation_summary)

# %%
if requires_gene_mapping:
    print(f'''
    As a biomedical research team, we are analyzing a gene expression dataset, and find that its row headers are some identifiers related to genes:
    {gene_row_ids}
    To get the mapping from those identifiers to actual gene symbols, we extracted the gene annotation data from a series in the GEO database, and saved it to a Python dictionary. Please read the dictionary, and decide which key stores the identifiers, and which key stores the gene symbols. Please strictly follow this format in your answer:
    identifier_key = 'key_name1'
    gene_symbol_key = 'key_name2'

    Gene annotation dictionary:
    {gene_annotation_summary}
    ''')

# %%
if requires_gene_mapping:
    identifier_key = 'ID'
    gene_symbol_key = 'UCSC_RefGene_Name'
    gene_mapping = get_gene_mapping(gene_annotation, identifier_key, gene_symbol_key)
    genetic_data = apply_gene_mapping(genetic_data, gene_mapping)

# %%
if NORMALIZE_GENE:
    genetic_data = normalize_gene_symbols_in_index(genetic_data)
# Out:
# 1000 input query terms found no hit:	['cg00000029', 'cg00000108', 'cg00000109', 'cg00000165', 'cg00000236', 'cg00000289', 'cg00000292', '
# 1000 input query terms found no hit:	['cg00042837', 'cg00042874', 'cg00042882', 'cg00042914', 'cg00043004', 'cg00043005', 'cg00043043', '
# 1000 input query terms found no hit:	['cg00091302', 'cg00091349', 'cg00091483', 'cg00091552', 'cg00091569', 'cg00091589', 'cg00091596', '
# 1000 input query terms found no hit:	['cg00142759', 'cg00142815', 'cg00142834', 'cg00142925', 'cg00142933', 'cg00143045', 'cg00143220', '
# 1000 input query terms found no hit:	['cg00193859', 'cg00193902', 'cg00193947', 'cg00193959', 'cg00193963', 'cg00194044', 'cg00194109', '
# 1000 input query terms found no hit:	['cg00248521', 'cg00248574', 'cg00248638', 'cg00248713', 'cg00248776', 'cg00248795', 'cg00248805', '
# 1000 input query terms found no hit:	['cg00302983', 'cg00303026', 'cg00303108', 'cg00303111', 'cg00303183', 'cg00303210', 'cg00303223', '
# 1000 input query terms found no hit:	['cg00351838', 'cg00351930', 'cg00352005', 'cg00352027', 'cg00352031', 'cg00352043', 'cg00352106', '
# 1000 input query terms found no hit:	['cg00401796', 'cg00401797', 'cg00401844', 'cg00401880', 'cg00401939', 'cg00401972', 'cg00402068', '
# 1000 input query terms found no hit:	['cg00454409', 'cg00454447', 'cg00454517', 'cg00454577', 'cg00454592', 'cg00454650', 'cg00454696', '
# 1000 input query terms found no hit:	['cg00500507', 'cg00500564', 'cg00500602', 'cg00500626', 'cg00500681', 'cg00500705', 'cg00500729', '
# 1000 input query terms found no hit:	['cg00551153', 'cg00551313', 'cg00551378', 'cg00551387', 'cg00551398', 'cg00551487', 'cg00551589', '
# 1000 input query terms found no hit:	['cg00597931', 'cg00598009', 'cg00598021', 'cg00598125', 'cg00598143', 'cg00598204', 'cg00598235', '
# 1000 input query terms found no hit:	['cg00653387', 'cg00653455', 'cg00653460', 'cg00653565', 'cg00653609', 'cg00653615', 'cg00653700', '
# 1000 input query terms found no hit:	['cg00704369', 'cg00704554', 'cg00704626', 'cg00704633', 'cg00704652', 'cg00704664', 'cg00704734', '
# 1000 input query terms found no hit:	['cg00755423', 'cg00755448', 'cg00755470', 'cg00755505', 'cg00755546', 'cg00755561', 'cg00755572', '
# 1000 input query terms found no hit:	['cg00806311', 'cg00806319', 'cg00806367', 'cg00806454', 'cg00806461', 'cg00806481', 'cg00806490', '
# 1000 input query terms found no hit:	['cg00858417', 'cg00858483', 'cg00858599', 'cg00858738', 'cg00858760', 'cg00858840', 'cg00858855', '
# 1000 input query terms found no hit:	['cg00909976', 'cg00909993', 'cg00910015', 'cg00910029', 'cg00910052', 'cg00910067', 'cg00910103', '
# 1000 input query terms found no hit:	['cg00959883', 'cg00959922', 'cg00960017', 'cg00960050', 'cg00960138', 'cg00960147', 'cg00960186', '
# 1000 input query terms found no hit:	['cg01008310', 'cg01008361', 'cg01008365', 'cg01008405', 'cg01008415', 'cg01008433', 'cg01008495', '
# 1000 input query terms found no hit:	['cg01057268', 'cg01057287', 'cg01057527', 'cg01057552', 'cg01057573', 'cg01057599', 'cg01057635', '
# 1000 input query terms found no hit:	['cg01106036', 'cg01106038', 'cg01106114', 'cg01106145', 'cg01106248', 'cg01106303', 'cg01106338', '
# 1000 input query terms found no hit:	['cg01158257', 'cg01158277', 'cg01158375', 'cg01158415', 'cg01158447', 'cg01158469', 'cg01158527', '
# 1000 input query terms found no hit:	['cg01211165', 'cg01211283', 'cg01211349', 'cg01211396', 'cg01211424', 'cg01211627', 'cg01211763', '
# 1000 input query terms found no hit:	['cg01267522', 'cg01267532', 'cg01267797', 'cg01267899', 'cg01267908', 'cg01267941', 'cg01268021', '
# 1000 input query terms found no hit:	['cg01320507', 'cg01320540', 'cg01320573', 'cg01320579', 'cg01320614', 'cg01320648', 'cg01320698', '
# 1000 input query terms found no hit:	['cg01377644', 'cg01377696', 'cg01377807', 'cg01377911', 'cg01377916', 'cg01377936', 'cg01378062', '
# 1000 input query terms found no hit:	['cg01427630', 'cg01427750', 'cg01427769', 'cg01427815', 'cg01427848', 'cg01427849', 'cg01427869', '
# 1000 input query terms found no hit:	['cg01480205', 'cg01480384', 'cg01480393', 'cg01480550', 'cg01480708', 'cg01480771', 'cg01481116', '
# 1000 input query terms found no hit:	['cg01537486', 'cg01537494', 'cg01537571', 'cg01537645', 'cg01537665', 'cg01537687', 'cg01537713', '
# 1000 input query terms found no hit:	['cg01588581', 'cg01588592', 'cg01588725', 'cg01588748', 'cg01588776', 'cg01588826', 'cg01588901', '
# 1000 input query terms found no hit:	['cg01643690', 'cg01643712', 'cg01643856', 'cg01643927', 'cg01643997', 'cg01644092', 'cg01644112', '
# 1000 input query terms found no hit:	['cg01707361', 'cg01707391', 'cg01707559', 'cg01707656', 'cg01707795', 'cg01707818', 'cg01707820', '
# 1000 input query terms found no hit:	['cg01762091', 'cg01762263', 'cg01762264', 'cg01762315', 'cg01762581', 'cg01762626', 'cg01762738', '
# 1000 input query terms found no hit:	['cg01809170', 'cg01809214', 'cg01809217', 'cg01809281', 'cg01809371', 'cg01809377', 'cg01809408', '
# 1000 input query terms found no hit:	['cg01862034', 'cg01862160', 'cg01862172', 'cg01862180', 'cg01862266', 'cg01862311', 'cg01862363', '
# 1000 input query terms found no hit:	['cg01915642', 'cg01915791', 'cg01915804', 'cg01915822', 'cg01915885', 'cg01915895', 'cg01915951', '
# 1000 input query terms found no hit:	['cg01964562', 'cg01964683', 'cg01964685', 'cg01964720', 'cg01964765', 'cg01964795', 'cg01964850', '
# 1000 input query terms found no hit:	['cg02017200', 'cg02017208', 'cg02017257', 'cg02017282', 'cg02017323', 'cg02017347', 'cg02017348', '
# 1000 input query terms found no hit:	['cg02067712', 'cg02067722', 'cg02067788', 'cg02067946', 'cg02067983', 'cg02067994', 'cg02068015', '
# 1000 input query terms found no hit:	['cg02119091', 'cg02119134', 'cg02119152', 'cg02119220', 'cg02119229', 'cg02119348', 'cg02119494', '
# 1000 input query terms found no hit:	['cg02173977', 'cg02174006', 'cg02174092', 'cg02174203', 'cg02174225', 'cg02174232', 'cg02174252', '
# 1000 input query terms found no hit:	['cg02235641', 'cg02235659', 'cg02235663', 'cg02235741', 'cg02235760', 'cg02235843', 'cg02235848', '
# 1000 input query terms found no hit:	['cg02287362', 'cg02287371', 'cg02287436', 'cg02287573', 'cg02287606', 'cg02287630', 'cg02287685', '
# 1000 input query terms found no hit:	['cg02337836', 'cg02337873', 'cg02337897', 'cg02337898', 'cg02337960', 'cg02338142', 'cg02338146', '
# 1000 input query terms found no hit:	['cg02389084', 'cg02389091', 'cg02389180', 'cg02389195', 'cg02389228', 'cg02389252', 'cg02389264', '
# 1000 input query terms found no hit:	['cg02449978', 'cg02450004', 'cg02450064', 'cg02450124', 'cg02450164', 'cg02450267', 'cg02450563', '
# 1000 input query terms found no hit:	['cg02500075', 'cg02500152', 'cg02500201', 'cg02500231', 'cg02500264', 'cg02500300', 'cg02500392', '
# 1000 input query terms found no hit:	['cg02555215', 'cg02555243', 'cg02555274', 'cg02555393', 'cg02555579', 'cg02555585', 'cg02555727', '
# 1000 input query terms found no hit:	['cg02606403', 'cg02606423', 'cg02606480', 'cg02606505', 'cg02606566', 'cg02606575', 'cg02606596', '
# 1000 input query terms found no hit:	['cg02655906', 'cg02655972', 'cg02656049', 'cg02656060', 'cg02656089', 'cg02656169', 'cg02656341', '
# 1000 input query terms found no hit:	['cg02711460', 'cg02711472', 'cg02711476', 'cg02711479', 'cg02711510', 'cg02711527', 'cg02711579', '
# 1000 input query terms found no hit:	['cg02763032', 'cg02763146', 'cg02763183', 'cg02763234', 'cg02763290', 'cg02763409', 'cg02763536', '
# 1000 input query terms found no hit:	['cg02820514', 'cg02820566', 'cg02820613', 'cg02820646', 'cg02820717', 'cg02820748', 'cg02820759', '
# 1000 input query terms found no hit:	['cg02875120', 'cg02875130', 'cg02875185', 'cg02875240', 'cg02875253', 'cg02875297', 'cg02875404', '
# 1000 input query terms found no hit:	['cg02923224', 'cg02923264', 'cg02923300', 'cg02923302', 'cg02923340', 'cg02923393', 'cg02923485', '
# 1000 input query terms found no hit:	['cg02973379', 'cg02973416', 'cg02973441', 'cg02973469', 'cg02973644', 'cg02973680', 'cg02973693', '
# 1000 input query terms found no hit:	['cg03026939', 'cg03027013', 'cg03027037', 'cg03027179', 'cg03027227', 'cg03027239', 'cg03027241', '
# 1000 input query terms found no hit:	['cg03078400', 'cg03078486', 'cg03078488', 'cg03078520', 'cg03078551', 'cg03078586', 'cg03078593', '
# 1000 input query terms found no hit:	['cg03139057', 'cg03139204', 'cg03139228', 'cg03139255', 'cg03139377', 'cg03139388', 'cg03139423', '
# 1000 input query terms found no hit:	['cg03194064', 'cg03194122', 'cg03194151', 'cg03194226', 'cg03194311', 'cg03194383', 'cg03194442', '
# 1000 input query terms found no hit:	['cg03251068', 'cg03251079', 'cg03251111', 'cg03251249', 'cg03251287', 'cg03251349', 'cg03251356', '
# 1000 input query terms found no hit:	['cg03308881', 'cg03308985', 'cg03308986', 'cg03309050', 'cg03309176', 'cg03309180', 'cg03309232', '
# 1000 input query terms found no hit:	['cg03358887', 'cg03358982', 'cg03359043', 'cg03359095', 'cg03359183', 'cg03359285', 'cg03359362', '
# 1000 input query terms found no hit:	['cg03416888', 'cg03417055', 'cg03417110', 'cg03417156', 'cg03417182', 'cg03417191', 'cg03417233', '
# 1000 input query terms found no hit:	['cg03469118', 'cg03469122', 'cg03469129', 'cg03469202', 'cg03469233', 'cg03469456', 'cg03469461', '
# 1000 input query terms found no hit:	['cg03525424', 'cg03525433', 'cg03525467', 'cg03525583', 'cg03525644', 'cg03525728', 'cg03525818', '
# 1000 input query terms found no hit:	['cg03576411', 'cg03576419', 'cg03576422', 'cg03576425', 'cg03576467', 'cg03576469', 'cg03576480', '
# 1000 input query terms found no hit:	['cg03629107', 'cg03629141', 'cg03629151', 'cg03629318', 'cg03629351', 'cg03629458', 'cg03629497', '
# 1000 input query terms found no hit:	['cg03686392', 'cg03686395', 'cg03686402', 'cg03686455', 'cg03686522', 'cg03686593', 'cg03686645', '
# 1000 input query terms found no hit:	['cg03738025', 'cg03738116', 'cg03738134', 'cg03738168', 'cg03738208', 'cg03738247', 'cg03738253', '
# 1000 input query terms found no hit:	['cg03793937', 'cg03793951', 'cg03794213', 'cg03794214', 'cg03794218', 'cg03794219', 'cg03794288', '
# 1000 input query terms found no hit:	['cg03854071', 'cg03854077', 'cg03854098', 'cg03854198', 'cg03854238', 'cg03854262', 'cg03854322', '
# 1000 input query terms found no hit:	['cg03910337', 'cg03910363', 'cg03910375', 'cg03910557', 'cg03910582', 'cg03910652', 'cg03910767', '
# 1000 input query terms found no hit:	['cg03967266', 'cg03967293', 'cg03967327', 'cg03967329', 'cg03967337', 'cg03967346', 'cg03967448', '
# 1000 input query terms found no hit:	['cg04020735', 'cg04020764', 'cg04020816', 'cg04020908', 'cg04020944', 'cg04020984', 'cg04020999', '
# 1000 input query terms found no hit:	['cg04079538', 'cg04079760', 'cg04079779', 'cg04079883', 'cg04080005', 'cg04080022', 'cg04080041', '
# 1000 input query terms found no hit:	['cg04131468', 'cg04131494', 'cg04131524', 'cg04131583', 'cg04131610', 'cg04131638', 'cg04131734', '
# 1000 input query terms found no hit:	['cg04184232', 'cg04184273', 'cg04184278', 'cg04184316', 'cg04184427', 'cg04184432', 'cg04184623', '
# 1000 input query terms found no hit:	['cg04237075', 'cg04237127', 'cg04237288', 'cg04237338', 'cg04237429', 'cg04237436', 'cg04237482', '
# 1000 input query terms found no hit:	['cg04289585', 'cg04289624', 'cg04289820', 'cg04289880', 'cg04289891', 'cg04289959', 'cg04289992', '
# 1000 input query terms found no hit:	['cg04344792', 'cg04344875', 'cg04344917', 'cg04344923', 'cg04344997', 'cg04345034', 'cg04345102', '
# 1000 input query terms found no hit:	['cg04400533', 'cg04400540', 'cg04400587', 'cg04400620', 'cg04400631', 'cg04400653', 'cg04400841', '
# 1000 input query terms found no hit:	['cg04458869', 'cg04458919', 'cg04458920', 'cg04458969', 'cg04458972', 'cg04458985', 'cg04459013', '
# 1000 input query terms found no hit:	['cg04515533', 'cg04515534', 'cg04515567', 'cg04515572', 'cg04515583', 'cg04515608', 'cg04515667', '
# 1000 input query terms found no hit:	['cg04570604', 'cg04570624', 'cg04570669', 'cg04570715', 'cg04570735', 'cg04570827', 'cg04570910', '
# 1000 input query terms found no hit:	['cg04627266', 'cg04627496', 'cg04627530', 'cg04627702', 'cg04627849', 'cg04627863', 'cg04627891', '
# 1000 input query terms found no hit:	['cg04687241', 'cg04687310', 'cg04687337', 'cg04687371', 'cg04687409', 'cg04687437', 'cg04687439', '
# 1000 input query terms found no hit:	['cg04745408', 'cg04745491', 'cg04745662', 'cg04745673', 'cg04745698', 'cg04745771', 'cg04745805', '
# 1000 input query terms found no hit:	['cg04800715', 'cg04800749', 'cg04800788', 'cg04800816', 'cg04801003', 'cg04801098', 'cg04801133', '
# 1000 input query terms found no hit:	['cg04856285', 'cg04856292', 'cg04856396', 'cg04856409', 'cg04856590', 'cg04856605', 'cg04856629', '
# 1000 input query terms found no hit:	['cg04907456', 'cg04907505', 'cg04907571', 'cg04907595', 'cg04907664', 'cg04907738', 'cg04907849', '
# 1000 input query terms found no hit:	['cg04963089', 'cg04963153', 'cg04963177', 'cg04963199', 'cg04963424', 'cg04963480', 'cg04963514', '
# 1000 input query terms found no hit:	['cg05019168', 'cg05019173', 'cg05019180', 'cg05019221', 'cg05019307', 'cg05019311', 'cg05019381', '
# 1000 input query terms found no hit:	['cg05072470', 'cg05072473', 'cg05072492', 'cg05072547', 'cg05072552', 'cg05072559', 'cg05072774', '
# 1000 input query terms found no hit:	['cg05134918', 'cg05134926', 'cg05134987', 'cg05135015', 'cg05135033', 'cg05135107', 'cg05135156', '
# 1000 input query terms found no hit:	['cg05189242', 'cg05189253', 'cg05189281', 'cg05189517', 'cg05189570', 'cg05189667', 'cg05189730', '
# 1000 input query terms found no hit:	['cg05243338', 'cg05243389', 'cg05243438', 'cg05243560', 'cg05243629', 'cg05243641', 'cg05243700', '
# 1000 input query terms found no hit:	['cg05300316', 'cg05300378', 'cg05300440', 'cg05300538', 'cg05300577', 'cg05300697', 'cg05300717', '
# 1000 input query terms found no hit:	['cg05354180', 'cg05354195', 'cg05354330', 'cg05354432', 'cg05354479', 'cg05354556', 'cg05354831', '
# 1000 input query terms found no hit:	['cg05404227', 'cg05404233', 'cg05404236', 'cg05404309', 'cg05404459', 'cg05404715', 'cg05404787', '
# 1000 input query terms found no hit:	['cg05472841', 'cg05472854', 'cg05472934', 'cg05472974', 'cg05472998', 'cg05473018', 'cg05473175', '
# 1000 input query terms found no hit:	['cg05528623', 'cg05528782', 'cg05528899', 'cg05528916', 'cg05528918', 'cg05528931', 'cg05528975', '
# 1000 input query terms found no hit:	['cg05591605', 'cg05591701', 'cg05591716', 'cg05591728', 'cg05591741', 'cg05591758', 'cg05591769', '
# 1000 input query terms found no hit:	['cg05650260', 'cg05650397', 'cg05650453', 'cg05650559', 'cg05650565', 'cg05650568', 'cg05650604', '
# 1000 input query terms found no hit:	['cg05710561', 'cg05710562', 'cg05710651', 'cg05710676', 'cg05710730', 'cg05710753', 'cg05710982', '
# 1000 input query terms found no hit:	['cg05773958', 'cg05774001', 'cg05774141', 'cg05774166', 'cg05774231', 'cg05774290', 'cg05774324', '
# 1000 input query terms found no hit:	['cg05832925', 'cg05833067', 'cg05833104', 'cg05833158', 'cg05833251', 'cg05833318', 'cg05833518', '
# 1000 input query terms found no hit:	['cg05889186', 'cg05889198', 'cg05889222', 'cg05889234', 'cg05889266', 'cg05889294', 'cg05889321', '
# 1000 input query terms found no hit:	['cg05941212', 'cg05941247', 'cg05941292', 'cg05941299', 'cg05941375', 'cg05941376', 'cg05941540', '
# 1000 input query terms found no hit:	['cg05992628', 'cg05992726', 'cg05992786', 'cg05992829', 'cg05992904', 'cg05992977', 'cg05992990', '
# 1000 input query terms found no hit:	['cg06055249', 'cg06055266', 'cg06055392', 'cg06055478', 'cg06055551', 'cg06055561', 'cg06055562', '
# 1000 input query terms found no hit:	['cg06114456', 'cg06114471', 'cg06114556', 'cg06114605', 'cg06114765', 'cg06114987', 'cg06115018', '
# 1000 input query terms found no hit:	['cg06178308', 'cg06178309', 'cg06178310', 'cg06178315', 'cg06178322', 'cg06178383', 'cg06178492', '
# 1000 input query terms found no hit:	['cg06236140', 'cg06236206', 'cg06236279', 'cg06236312', 'cg06236559', 'cg06236573', 'cg06236748', '
# 1000 input query terms found no hit:	['cg06302566', 'cg06302690', 'cg06302803', 'cg06302806', 'cg06302818', 'cg06302857', 'cg06302877', '
# 1000 input query terms found no hit:	['cg06369056', 'cg06369076', 'cg06369108', 'cg06369118', 'cg06369155', 'cg06369248', 'cg06369261', '
# 1000 input query terms found no hit:	['cg06430102', 'cg06430220', 'cg06430309', 'cg06430387', 'cg06430424', 'cg06430479', 'cg06430509', '
# 1000 input query terms found no hit:	['cg06490988', 'cg06491101', 'cg06491116', 'cg06491137', 'cg06491139', 'cg06491147', 'cg06491244', '
# 1000 input query terms found no hit:	['cg06545490', 'cg06545648', 'cg06545693', 'cg06545742', 'cg06545761', 'cg06545762', 'cg06545804', '
# 1000 input query terms found no hit:	['cg06608374', 'cg06608376', 'cg06608378', 'cg06608399', 'cg06608414', 'cg06608599', 'cg06608945', '
# 1000 input query terms found no hit:	['cg06655560', 'cg06655570', 'cg06655623', 'cg06655665', 'cg06655771', 'cg06655796', 'cg06655810', '
# 1000 input query terms found no hit:	['cg06713830', 'cg06713968', 'cg06713999', 'cg06714021', 'cg06714086', 'cg06714088', 'cg06714180', '
# 1000 input query terms found no hit:	['cg06766817', 'cg06766857', 'cg06766860', 'cg06766960', 'cg06767025', 'cg06767059', 'cg06767136', '
# 1000 input query terms found no hit:	['cg06817269', 'cg06817312', 'cg06817368', 'cg06817454', 'cg06817455', 'cg06817490', 'cg06817516', '
# 1000 input query terms found no hit:	['cg06866655', 'cg06866657', 'cg06866686', 'cg06866756', 'cg06866814', 'cg06866839', 'cg06866938', '
# 1000 input query terms found no hit:	['cg06916446', 'cg06916463', 'cg06916514', 'cg06916552', 'cg06916574', 'cg06916591', 'cg06916620', '
# 1000 input query terms found no hit:	['cg06970960', 'cg06971005', 'cg06971029', 'cg06971044', 'cg06971092', 'cg06971096', 'cg06971129', '
# 1000 input query terms found no hit:	['cg07025343', 'cg07025432', 'cg07025471', 'cg07025478', 'cg07025505', 'cg07025548', 'cg07025583', '
# 1000 input query terms found no hit:	['cg07080007', 'cg07080019', 'cg07080031', 'cg07080049', 'cg07080050', 'cg07080067', 'cg07080177', '
# 1000 input query terms found no hit:	['cg07133434', 'cg07133445', 'cg07133479', 'cg07133629', 'cg07133692', 'cg07133729', 'cg07133741', '
# 1000 input query terms found no hit:	['cg07179825', 'cg07179872', 'cg07179924', 'cg07179925', 'cg07179981', 'cg07180125', 'cg07180182', '
# 1000 input query terms found no hit:	['cg07234439', 'cg07234508', 'cg07234569', 'cg07234639', 'cg07234865', 'cg07234876', 'cg07234880', '
# 1000 input query terms found no hit:	['cg07296268', 'cg07296387', 'cg07296447', 'cg07296565', 'cg07296597', 'cg07296661', 'cg07296665', '
# 1000 input query terms found no hit:	['cg07354556', 'cg07354565', 'cg07354581', 'cg07354583', 'cg07354666', 'cg07354679', 'cg07354728', '
# 1000 input query terms found no hit:	['cg07417284', 'cg07417348', 'cg07417666', 'cg07417683', 'cg07417708', 'cg07417733', 'cg07417745', '
# 1000 input query terms found no hit:	['cg07474269', 'cg07474271', 'cg07474296', 'cg07474312', 'cg07474324', 'cg07474356', 'cg07474441', '
# 1000 input query terms found no hit:	['cg07530681', 'cg07530759', 'cg07530925', 'cg07530947', 'cg07530960', 'cg07531020', 'cg07531037', '
# 1000 input query terms found no hit:	['cg07584200', 'cg07584208', 'cg07584237', 'cg07584320', 'cg07584494', 'cg07584558', 'cg07584563', '
# 1000 input query terms found no hit:	['cg07639900', 'cg07639959', 'cg07639963', 'cg07639982', 'cg07640083', 'cg07640117', 'cg07640336', '
# 1000 input query terms found no hit:	['cg07701909', 'cg07701911', 'cg07702100', 'cg07702216', 'cg07702235', 'cg07702236', 'cg07702240', '
# 1000 input query terms found no hit:	['cg07758404', 'cg07758428', 'cg07758528', 'cg07758529', 'cg07758574', 'cg07758667', 'cg07758738', '
# 1000 input query terms found no hit:	['cg07816786', 'cg07816809', 'cg07816873', 'cg07817024', 'cg07817055', 'cg07817097', 'cg07817208', '
# 1000 input query terms found no hit:	['cg07878486', 'cg07878514', 'cg07878537', 'cg07878625', 'cg07878800', 'cg07878857', 'cg07878951', '
# 1000 input query terms found no hit:	['cg07933493', 'cg07933542', 'cg07933552', 'cg07933563', 'cg07933656', 'cg07933682', 'cg07933720', '
# 1000 input query terms found no hit:	['cg07992840', 'cg07992918', 'cg07993003', 'cg07993036', 'cg07993112', 'cg07993178', 'cg07993350', '
# 1000 input query terms found no hit:	['cg08056903', 'cg08056957', 'cg08056990', 'cg08057037', 'cg08057038', 'cg08057040', 'cg08057062', '
# 1000 input query terms found no hit:	['cg08112356', 'cg08112448', 'cg08112479', 'cg08112616', 'cg08112724', 'cg08112737', 'cg08112740', '
# 1000 input query terms found no hit:	['cg08165221', 'cg08165261', 'cg08165291', 'cg08165339', 'cg08165340', 'cg08165361', 'cg08165462', '
# 1000 input query terms found no hit:	['cg08222555', 'cg08222609', 'cg08222610', 'cg08222618', 'cg08222662', 'cg08222798', 'cg08222800', '
# 1000 input query terms found no hit:	['cg08277306', 'cg08277314', 'cg08277369', 'cg08277382', 'cg08277486', 'cg08277548', 'cg08277679', '
# 1000 input query terms found no hit:	['cg08334432', 'cg08334575', 'cg08334726', 'cg08334780', 'cg08334899', 'cg08334962', 'cg08334984', '
# 1000 input query terms found no hit:	['cg08398691', 'cg08398805', 'cg08398855', 'cg08399230', 'cg08399308', 'cg08399404', 'cg08399444', '
# 1000 input query terms found no hit:	['cg08461451', 'cg08461457', 'cg08461546', 'cg08461576', 'cg08461586', 'cg08461617', 'cg08461672', '
# 1000 input query terms found no hit:	['cg08520148', 'cg08520191', 'cg08520200', 'cg08520228', 'cg08520383', 'cg08520408', 'cg08520423', '
# 1000 input query terms found no hit:	['cg08578212', 'cg08578216', 'cg08578245', 'cg08578317', 'cg08578320', 'cg08578323', 'cg08578393', '
# 1000 input query terms found no hit:	['cg08638960', 'cg08638999', 'cg08639121', 'cg08639244', 'cg08639279', 'cg08639283', 'cg08639339', '
# 1000 input query terms found no hit:	['cg08699196', 'cg08699206', 'cg08699270', 'cg08699355', 'cg08699381', 'cg08699435', 'cg08699489', '
# 1000 input query terms found no hit:	['cg08759745', 'cg08759770', 'cg08759899', 'cg08759957', 'cg08759960', 'cg08760073', 'cg08760128', '
# 1000 input query terms found no hit:	['cg08823554', 'cg08823577', 'cg08823767', 'cg08823837', 'cg08823894', 'cg08823898', 'cg08823908', '
# 1000 input query terms found no hit:	['cg08877269', 'cg08877293', 'cg08877322', 'cg08877357', 'cg08877374', 'cg08877404', 'cg08877463', '
# 1000 input query terms found no hit:	['cg08937562', 'cg08937573', 'cg08937612', 'cg08937613', 'cg08937639', 'cg08937674', 'cg08937729', '
# 1000 input query terms found no hit:	['cg09001953', 'cg09001989', 'cg09002049', 'cg09002092', 'cg09002231', 'cg09002351', 'cg09002358', '
# 1000 input query terms found no hit:	['cg09067818', 'cg09067967', 'cg09067976', 'cg09067990', 'cg09068004', 'cg09068031', 'cg09068086', '
# 1000 input query terms found no hit:	['cg09133953', 'cg09133979', 'cg09134003', 'cg09134012', 'cg09134154', 'cg09134165', 'cg09134179', '
# 1000 input query terms found no hit:	['cg09192412', 'cg09192572', 'cg09192711', 'cg09192732', 'cg09192801', 'cg09192898', 'cg09192940', '
# 1000 input query terms found no hit:	['cg09256781', 'cg09256832', 'cg09256862', 'cg09256880', 'cg09256930', 'cg09256941', 'cg09256964', '
# 1000 input query terms found no hit:	['cg09316607', 'cg09316688', 'cg09316703', 'cg09316713', 'cg09316772', 'cg09316954', 'cg09317036', '
# 1000 input query terms found no hit:	['cg09374857', 'cg09374916', 'cg09374949', 'cg09375033', 'cg09375034', 'cg09375063', 'cg09375065', '
# 1000 input query terms found no hit:	['cg09437885', 'cg09437994', 'cg09438069', 'cg09438075', 'cg09438085', 'cg09438113', 'cg09438147', '
# 1000 input query terms found no hit:	['cg09500002', 'cg09500171', 'cg09500196', 'cg09500200', 'cg09500207', 'cg09500317', 'cg09500328', '
# 1000 input query terms found no hit:	['cg09558502', 'cg09558547', 'cg09558619', 'cg09558850', 'cg09558872', 'cg09558961', 'cg09558982', '
# 1000 input query terms found no hit:	['cg09622330', 'cg09622420', 'cg09622432', 'cg09622447', 'cg09622504', 'cg09622514', 'cg09622557', '
# 1000 input query terms found no hit:	['cg09685104', 'cg09685182', 'cg09685250', 'cg09685351', 'cg09685472', 'cg09685500', 'cg09685505', '
# 1000 input query terms found no hit:	['cg09754550', 'cg09754671', 'cg09754828', 'cg09754842', 'cg09754845', 'cg09754868', 'cg09754882', '
# 1000 input query terms found no hit:	['cg09817427', 'cg09817503', 'cg09817599', 'cg09817641', 'cg09817985', 'cg09817993', 'cg09818055', '
# 1000 input query terms found no hit:	['cg09872491', 'cg09872523', 'cg09872616', 'cg09872737', 'cg09872760', 'cg09872774', 'cg09872841', '
# 1000 input query terms found no hit:	['cg09936581', 'cg09936609', 'cg09936645', 'cg09936663', 'cg09936762', 'cg09936799', 'cg09936824', '
# 1000 input query terms found no hit:	['cg10003048', 'cg10003231', 'cg10003262', 'cg10003267', 'cg10003284', 'cg10003443', 'cg10003549', '
# 1000 input query terms found no hit:	['cg10066151', 'cg10066186', 'cg10066188', 'cg10066189', 'cg10066231', 'cg10066305', 'cg10066332', '
# 1000 input query terms found no hit:	['cg10121865', 'cg10122050', 'cg10122079', 'cg10122103', 'cg10122187', 'cg10122230', 'cg10122252', '
# 1000 input query terms found no hit:	['cg10178228', 'cg10178261', 'cg10178263', 'cg10178498', 'cg10178621', 'cg10178628', 'cg10178795', '
# 1000 input query terms found no hit:	['cg10236247', 'cg10236261', 'cg10236414', 'cg10236417', 'cg10236452', 'cg10236503', 'cg10236528', '
# 1000 input query terms found no hit:	['cg10301212', 'cg10301236', 'cg10301254', 'cg10301258', 'cg10301338', 'cg10301401', 'cg10301657', '
# 1000 input query terms found no hit:	['cg10363003', 'cg10363005', 'cg10363018', 'cg10363118', 'cg10363202', 'cg10363246', 'cg10363284', '
# 1000 input query terms found no hit:	['cg10429747', 'cg10429922', 'cg10430011', 'cg10430021', 'cg10430077', 'cg10430123', 'cg10430126', '
# 1000 input query terms found no hit:	['cg10492836', 'cg10492935', 'cg10492953', 'cg10492999', 'cg10493018', 'cg10493055', 'cg10493075', '
# 1000 input query terms found no hit:	['cg10543450', 'cg10543500', 'cg10543501', 'cg10543503', 'cg10543582', 'cg10543634', 'cg10543784', '
# 1000 input query terms found no hit:	['cg10605246', 'cg10605442', 'cg10605511', 'cg10605520', 'cg10605681', 'cg10605694', 'cg10605724', '
# 1000 input query terms found no hit:	['cg10668781', 'cg10668926', 'cg10668933', 'cg10668980', 'cg10669058', 'cg10669129', 'cg10669219', '
# 1000 input query terms found no hit:	['cg10738025', 'cg10738026', 'cg10738041', 'cg10738119', 'cg10738239', 'cg10738358', 'cg10738479', '
# 1000 input query terms found no hit:	['cg10803577', 'cg10803714', 'cg10803722', 'cg10803767', 'cg10803816', 'cg10803829', 'cg10803871', '
# 1000 input query terms found no hit:	['cg10865436', 'cg10865444', 'cg10865498', 'cg10865849', 'cg10865856', 'cg10865887', 'cg10865936', '
# 1000 input query terms found no hit:	['cg10936564', 'cg10936763', 'cg10936841', 'cg10936879', 'cg10936964', 'cg10936995', 'cg10936999', '
# 1000 input query terms found no hit:	['cg10994858', 'cg10994870', 'cg10994914', 'cg10994944', 'cg10995081', 'cg10995082', 'cg10995297', '
# 1000 input query terms found no hit:	['cg11064524', 'cg11064537', 'cg11064558', 'cg11064678', 'cg11064738', 'cg11064744', 'cg11064797', '
# 1000 input query terms found no hit:	['cg11130692', 'cg11130780', 'cg11130955', 'cg11131117', 'cg11131384', 'cg11131508', 'cg11131532', '
# 1000 input query terms found no hit:	['cg11194925', 'cg11194994', 'cg11195002', 'cg11195034', 'cg11195059', 'cg11195065', 'cg11195082', '
# 1000 input query terms found no hit:	['cg11251367', 'cg11251378', 'cg11251399', 'cg11251470', 'cg11251498', 'cg11251499', 'cg11251554', '
# 1000 input query terms found no hit:	['cg11318576', 'cg11318690', 'cg11318895', 'cg11318906', 'cg11319028', 'cg11319211', 'cg11319265', '
# 1000 input query terms found no hit:	['cg11382976', 'cg11382979', 'cg11382993', 'cg11383001', 'cg11383134', 'cg11383148', 'cg11383165', '
# 1000 input query terms found no hit:	['cg11446345', 'cg11446398', 'cg11446507', 'cg11446543', 'cg11446617', 'cg11446651', 'cg11446693', '
# 1000 input query terms found no hit:	['cg11523538', 'cg11523661', 'cg11523685', 'cg11523712', 'cg11523799', 'cg11523905', 'cg11523960', '
# 1000 input query terms found no hit:	['cg11588857', 'cg11588889', 'cg11588903', 'cg11588906', 'cg11588932', 'cg11588975', 'cg11589062', '
# 1000 input query terms found no hit:	['cg11653789', 'cg11653858', 'cg11653864', 'cg11653912', 'cg11653944', 'cg11653966', 'cg11654006', '
# 1000 input query terms found no hit:	['cg11716640', 'cg11716681', 'cg11716795', 'cg11716884', 'cg11717054', 'cg11717150', 'cg11717189', '
# 1000 input query terms found no hit:	['cg11779808', 'cg11779900', 'cg11779941', 'cg11779973', 'cg11780005', 'cg11780042', 'cg11780053', '
# 1000 input query terms found no hit:	['cg11834066', 'cg11834140', 'cg11834170', 'cg11834440', 'cg11834473', 'cg11834527', 'cg11834635', '
# 1000 input query terms found no hit:	['cg11891393', 'cg11891395', 'cg11891431', 'cg11891504', 'cg11891522', 'cg11891579', 'cg11891591', '
# 1000 input query terms found no hit:	['cg11956545', 'cg11956748', 'cg11956761', 'cg11956804', 'cg11956813', 'cg11956866', 'cg11956908', '
# 1000 input query terms found no hit:	['cg12025690', 'cg12025821', 'cg12025832', 'cg12025938', 'cg12025941', 'cg12025996', 'cg12026015', '
# 1000 input query terms found no hit:	['cg12080391', 'cg12080431', 'cg12080452', 'cg12080492', 'cg12080503', 'cg12080566', 'cg12080675', '
# 1000 input query terms found no hit:	['cg12143651', 'cg12143717', 'cg12143767', 'cg12143784', 'cg12143789', 'cg12144084', 'cg12144100', '
# 1000 input query terms found no hit:	['cg12206648', 'cg12206846', 'cg12207022', 'cg12207033', 'cg12207153', 'cg12207248', 'cg12207367', '
# 1000 input query terms found no hit:	['cg12277310', 'cg12277336', 'cg12277366', 'cg12277416', 'cg12277495', 'cg12277524', 'cg12277532', '
# 1000 input query terms found no hit:	['cg12353636', 'cg12353670', 'cg12353688', 'cg12353788', 'cg12353802', 'cg12353927', 'cg12354014', '
# 1000 input query terms found no hit:	['cg12423902', 'cg12423935', 'cg12424088', 'cg12424230', 'cg12424293', 'cg12424329', 'cg12424345', '
# 1000 input query terms found no hit:	['cg12486486', 'cg12486493', 'cg12486498', 'cg12486510', 'cg12486521', 'cg12486533', 'cg12486558', '
# 1000 input query terms found no hit:	['cg12552771', 'cg12552820', 'cg12552835', 'cg12552889', 'cg12552944', 'cg12553181', 'cg12553198', '
# 1000 input query terms found no hit:	['cg12614090', 'cg12614105', 'cg12614113', 'cg12614148', 'cg12614178', 'cg12614213', 'cg12614244', '
# 1000 input query terms found no hit:	['cg12677163', 'cg12677267', 'cg12677330', 'cg12677436', 'cg12677723', 'cg12677759', 'cg12677853', '
# 1000 input query terms found no hit:	['cg12749246', 'cg12749280', 'cg12749531', 'cg12749559', 'cg12749636', 'cg12749787', 'cg12749890', '
# 1000 input query terms found no hit:	['cg12819197', 'cg12819393', 'cg12819417', 'cg12819431', 'cg12819537', 'cg12819548', 'cg12819676', '
# 1000 input query terms found no hit:	['cg12894325', 'cg12894336', 'cg12894371', 'cg12894449', 'cg12894478', 'cg12894524', 'cg12894629', '
# 1000 input query terms found no hit:	['cg12965338', 'cg12965344', 'cg12965421', 'cg12965426', 'cg12965464', 'cg12965512', 'cg12965553', '
# 1000 input query terms found no hit:	['cg13037895', 'cg13037952', 'cg13037971', 'cg13038025', 'cg13038030', 'cg13038108', 'cg13038216', '
# 1000 input query terms found no hit:	['cg13105730', 'cg13105766', 'cg13105872', 'cg13105904', 'cg13105945', 'cg13106156', 'cg13106215', '
# 1000 input query terms found no hit:	['cg13178597', 'cg13178709', 'cg13178766', 'cg13178798', 'cg13178873', 'cg13178910', 'cg13178935', '
# 1000 input query terms found no hit:	['cg13243779', 'cg13244000', 'cg13244110', 'cg13244211', 'cg13244241', 'cg13244260', 'cg13244293', '
# 1000 input query terms found no hit:	['cg13311509', 'cg13311549', 'cg13311607', 'cg13311655', 'cg13311758', 'cg13311803', 'cg13311805', '
# 1000 input query terms found no hit:	['cg13371951', 'cg13371976', 'cg13372003', 'cg13372055', 'cg13372231', 'cg13372293', 'cg13372314', '
# 1000 input query terms found no hit:	['cg13425888', 'cg13425938', 'cg13425960', 'cg13425998', 'cg13426079', 'cg13426096', 'cg13426098', '
# 1000 input query terms found no hit:	['cg13471996', 'cg13472000', 'cg13472192', 'cg13472341', 'cg13472359', 'cg13472369', 'cg13472406', '
# 1000 input query terms found no hit:	['cg13523072', 'cg13523125', 'cg13523132', 'cg13523144', 'cg13523217', 'cg13523232', 'cg13523236', '
# 1000 input query terms found no hit:	['cg13572260', 'cg13572289', 'cg13572309', 'cg13572369', 'cg13572511', 'cg13572539', 'cg13572545', '
# 1000 input query terms found no hit:	['cg13621679', 'cg13621701', 'cg13621836', 'cg13621882', 'cg13621925', 'cg13622028', 'cg13622068', '
# 1000 input query terms found no hit:	['cg13675835', 'cg13675837', 'cg13675849', 'cg13675859', 'cg13675871', 'cg13675957', 'cg13675958', '
# 1000 input query terms found no hit:	['cg13725172', 'cg13725272', 'cg13725495', 'cg13725516', 'cg13725579', 'cg13725590', 'cg13725599', '
# 1000 input query terms found no hit:	['cg13782932', 'cg13782937', 'cg13782957', 'cg13783152', 'cg13783167', 'cg13783177', 'cg13783191', '
# 1000 input query terms found no hit:	['cg13834670', 'cg13834811', 'cg13834844', 'cg13834851', 'cg13834896', 'cg13834913', 'cg13835053', '
# 1000 input query terms found no hit:	['cg13891181', 'cg13891189', 'cg13891220', 'cg13891250', 'cg13891539', 'cg13891576', 'cg13891659', '
# 1000 input query terms found no hit:	['cg13938035', 'cg13938098', 'cg13938187', 'cg13938218', 'cg13938257', 'cg13938349', 'cg13938361', '
# 1000 input query terms found no hit:	['cg13991019', 'cg13991029', 'cg13991233', 'cg13991568', 'cg13991609', 'cg13991631', 'cg13991635', '
# 1000 input query terms found no hit:	['cg14039343', 'cg14039347', 'cg14039368', 'cg14039463', 'cg14039479', 'cg14039622', 'cg14039649', '
# 1000 input query terms found no hit:	['cg14091954', 'cg14091978', 'cg14092010', 'cg14092045', 'cg14092208', 'cg14092276', 'cg14092337', '
# 1000 input query terms found no hit:	['cg14148944', 'cg14148981', 'cg14148995', 'cg14149107', 'cg14149172', 'cg14149304', 'cg14149337', '
# 1000 input query terms found no hit:	['cg14197892', 'cg14197907', 'cg14197923', 'cg14198101', 'cg14198172', 'cg14198221', 'cg14198223', '
# 1000 input query terms found no hit:	['cg14245347', 'cg14245356', 'cg14245421', 'cg14245471', 'cg14245501', 'cg14245548', 'cg14245791', '
# 1000 input query terms found no hit:	['cg14296274', 'cg14296326', 'cg14296331', 'cg14296394', 'cg14296446', 'cg14296488', 'cg14296561', '
# 1000 input query terms found no hit:	['cg14349977', 'cg14350002', 'cg14350114', 'cg14350120', 'cg14350158', 'cg14350179', 'cg14350197', '
# 1000 input query terms found no hit:	['cg14408467', 'cg14408505', 'cg14408590', 'cg14408738', 'cg14408823', 'cg14408831', 'cg14408927', '
# 1000 input query terms found no hit:	['cg14462557', 'cg14462566', 'cg14462626', 'cg14462645', 'cg14462670', 'cg14462686', 'cg14462750', '
# 1000 input query terms found no hit:	['cg14515614', 'cg14515634', 'cg14515779', 'cg14515791', 'cg14515801', 'cg14515803', 'cg14515811', '
# 1000 input query terms found no hit:	['cg14562851', 'cg14562871', 'cg14562915', 'cg14562990', 'cg14563115', 'cg14563165', 'cg14563196', '
# 1000 input query terms found no hit:	['cg14614975', 'cg14615010', 'cg14615128', 'cg14615152', 'cg14615192', 'cg14615195', 'cg14615266', '
# 1000 input query terms found no hit:	['cg14670266', 'cg14670303', 'cg14670310', 'cg14670315', 'cg14670380', 'cg14670435', 'cg14670629', '
# 1000 input query terms found no hit:	['cg14737877', 'cg14737905', 'cg14737977', 'cg14737994', 'cg14738170', 'cg14738273', 'cg14738290', '
# 1000 input query terms found no hit:	['cg14798653', 'cg14798745', 'cg14798754', 'cg14798760', 'cg14798919', 'cg14799008', 'cg14799129', '
# 1000 input query terms found no hit:	['cg14862722', 'cg14862787', 'cg14862791', 'cg14862806', 'cg14862864', 'cg14862950', 'cg14863019', '
# 1000 input query terms found no hit:	['cg14930674', 'cg14930690', 'cg14930706', 'cg14930737', 'cg14930754', 'cg14930838', 'cg14930864', '
# 1000 input query terms found no hit:	['cg14995181', 'cg14995202', 'cg14995214', 'cg14995235', 'cg14995274', 'cg14995416', 'cg14995475', '
# 1000 input query terms found no hit:	['cg15058894', 'cg15058901', 'cg15058956', 'cg15059065', 'cg15059162', 'cg15059176', 'cg15059225', '
# 1000 input query terms found no hit:	['cg15120855', 'cg15120925', 'cg15120942', 'cg15121053', 'cg15121240', 'cg15121267', 'cg15121276', '
# 1000 input query terms found no hit:	['cg15186616', 'cg15186638', 'cg15186648', 'cg15186685', 'cg15186869', 'cg15186910', 'cg15186969', '
# 1000 input query terms found no hit:	['cg15258696', 'cg15258722', 'cg15258754', 'cg15258936', 'cg15258980', 'cg15258981', 'cg15259031', '
# 1000 input query terms found no hit:	['cg15339164', 'cg15339180', 'cg15339231', 'cg15339249', 'cg15339435', 'cg15339605', 'cg15339616', '
# 1000 input query terms found no hit:	['cg15407900', 'cg15407965', 'cg15408020', 'cg15408073', 'cg15408080', 'cg15408180', 'cg15408237', '
# 1000 input query terms found no hit:	['cg15472210', 'cg15472251', 'cg15472282', 'cg15472403', 'cg15472485', 'cg15472574', 'cg15472658', '
# 1000 input query terms found no hit:	['cg15547703', 'cg15547734', 'cg15547825', 'cg15547959', 'cg15548046', 'cg15548101', 'cg15548198', '
# 1000 input query terms found no hit:	['cg15609035', 'cg15609069', 'cg15609237', 'cg15609273', 'cg15609308', 'cg15609321', 'cg15609373', '
# 1000 input query terms found no hit:	['cg15671996', 'cg15672022', 'cg15672044', 'cg15672065', 'cg15672072', 'cg15672234', 'cg15672304', '
# 1000 input query terms found no hit:	['cg15730931', 'cg15731001', 'cg15731038', 'cg15731053', 'cg15731056', 'cg15731108', 'cg15731152', '
# 1000 input query terms found no hit:	['cg15806569', 'cg15806588', 'cg15806723', 'cg15806780', 'cg15806857', 'cg15806880', 'cg15807035', '
# 1000 input query terms found no hit:	['cg15868287', 'cg15868367', 'cg15868400', 'cg15868421', 'cg15868425', 'cg15868426', 'cg15868692', '
# 1000 input query terms found no hit:	['cg15934100', 'cg15934104', 'cg15934191', 'cg15934248', 'cg15934368', 'cg15934415', 'cg15934607', '
# 1000 input query terms found no hit:	['cg16000393', 'cg16000406', 'cg16000463', 'cg16000504', 'cg16000520', 'cg16000544', 'cg16000599', '
# 1000 input query terms found no hit:	['cg16063162', 'cg16063272', 'cg16063308', 'cg16063312', 'cg16063416', 'cg16063474', 'cg16063519', '
# 1000 input query terms found no hit:	['cg16132351', 'cg16132469', 'cg16132520', 'cg16132546', 'cg16132555', 'cg16132709', 'cg16132851', '
# 1000 input query terms found no hit:	['cg16197636', 'cg16197643', 'cg16197653', 'cg16197684', 'cg16197717', 'cg16197772', 'cg16197857', '
# 1000 input query terms found no hit:	['cg16259229', 'cg16259268', 'cg16259317', 'cg16259330', 'cg16259355', 'cg16259362', 'cg16259464', '
# 1000 input query terms found no hit:	['cg16318994', 'cg16319080', 'cg16319085', 'cg16319129', 'cg16319136', 'cg16319142', 'cg16319192', '
# 1000 input query terms found no hit:	['cg16377790', 'cg16377819', 'cg16377836', 'cg16377872', 'cg16377880', 'cg16377881', 'cg16377923', '
# 1000 input query terms found no hit:	['cg16434547', 'cg16434657', 'cg16434674', 'cg16434681', 'cg16434764', 'cg16434897', 'cg16434940', '
# 1000 input query terms found no hit:	['cg16501701', 'cg16501779', 'cg16501892', 'cg16502049', 'cg16502355', 'cg16502437', 'cg16502522', '
# 1000 input query terms found no hit:	['cg16557111', 'cg16557178', 'cg16557204', 'cg16557308', 'cg16557355', 'cg16557370', 'cg16557526', '
# 1000 input query terms found no hit:	['cg16612742', 'cg16612806', 'cg16612876', 'cg16612926', 'cg16612995', 'cg16612998', 'cg16613012', '
# 1000 input query terms found no hit:	['cg16668931', 'cg16669339', 'cg16669395', 'cg16669455', 'cg16669485', 'cg16669491', 'cg16669541', '
# 1000 input query terms found no hit:	['cg16724811', 'cg16725050', 'cg16725094', 'cg16725097', 'cg16725191', 'cg16725225', 'cg16725234', '
# 1000 input query terms found no hit:	['cg16790560', 'cg16790676', 'cg16790682', 'cg16790794', 'cg16790827', 'cg16790844', 'cg16790847', '
# 1000 input query terms found no hit:	['cg16864700', 'cg16864803', 'cg16864819', 'cg16864825', 'cg16864867', 'cg16864938', 'cg16864999', '
# 1000 input query terms found no hit:	['cg16931825', 'cg16931969', 'cg16931980', 'cg16932017', 'cg16932094', 'cg16932098', 'cg16932285', '
# 1000 input query terms found no hit:	['cg17010118', 'cg17010394', 'cg17010522', 'cg17010657', 'cg17010769', 'cg17010827', 'cg17010835', '
# 1000 input query terms found no hit:	['cg17077180', 'cg17077288', 'cg17077516', 'cg17077566', 'cg17077639', 'cg17077641', 'cg17077669', '
# 1000 input query terms found no hit:	['cg17142743', 'cg17142816', 'cg17142870', 'cg17142898', 'cg17142931', 'cg17142950', 'cg17143168', '
# 1000 input query terms found no hit:	['cg17205832', 'cg17205928', 'cg17205988', 'cg17206029', 'cg17206034', 'cg17206150', 'cg17206393', '
# 1000 input query terms found no hit:	['cg17278057', 'cg17278062', 'cg17278072', 'cg17278249', 'cg17278295', 'cg17278355', 'cg17278401', '
# 1000 input query terms found no hit:	['cg17337791', 'cg17337807', 'cg17337874', 'cg17337917', 'cg17338133', 'cg17338146', 'cg17338208', '
# 1000 input query terms found no hit:	['cg17403881', 'cg17403899', 'cg17403974', 'cg17404000', 'cg17404081', 'cg17404186', 'cg17404289', '
# 1000 input query terms found no hit:	['cg17469276', 'cg17469321', 'cg17469356', 'cg17469359', 'cg17469361', 'cg17469434', 'cg17469471', '
# 1000 input query terms found no hit:	['cg17528967', 'cg17529041', 'cg17529058', 'cg17529152', 'cg17529235', 'cg17529386', 'cg17529435', '
# 1000 input query terms found no hit:	['cg17605084', 'cg17605107', 'cg17605235', 'cg17605476', 'cg17605604', 'cg17605814', 'cg17605847', '
# 1000 input query terms found no hit:	['cg17686973', 'cg17687040', 'cg17687282', 'cg17687285', 'cg17687367', 'cg17687442', 'cg17687451', '
# 1000 input query terms found no hit:	['cg17761265', 'cg17761410', 'cg17761419', 'cg17761538', 'cg17761554', 'cg17761743', 'cg17761772', '
# 1000 input query terms found no hit:	['cg17829533', 'cg17829673', 'cg17829746', 'cg17829810', 'cg17829816', 'cg17829914', 'cg17829936', '
# 1000 input query terms found no hit:	['cg17890940', 'cg17890959', 'cg17890983', 'cg17890984', 'cg17891011', 'cg17891088', 'cg17891123', '
# 1000 input query terms found no hit:	['cg17961535', 'cg17961556', 'cg17961725', 'cg17961835', 'cg17961892', 'cg17961932', 'cg17961943', '
# 1000 input query terms found no hit:	['cg18026225', 'cg18026227', 'cg18026235', 'cg18026244', 'cg18026264', 'cg18026359', 'cg18026416', '
# 1000 input query terms found no hit:	['cg18089238', 'cg18089324', 'cg18089335', 'cg18089380', 'cg18089397', 'cg18089426', 'cg18089519', '
# 1000 input query terms found no hit:	['cg18145026', 'cg18145047', 'cg18145080', 'cg18145088', 'cg18145090', 'cg18145105', 'cg18145189', '
# 1000 input query terms found no hit:	['cg18205517', 'cg18205636', 'cg18205668', 'cg18205770', 'cg18205787', 'cg18205933', 'cg18205949', '
# 1000 input query terms found no hit:	['cg18271789', 'cg18271897', 'cg18271913', 'cg18271914', 'cg18271964', 'cg18271969', 'cg18272089', '
# 1000 input query terms found no hit:	['cg18338288', 'cg18338293', 'cg18338296', 'cg18338311', 'cg18338319', 'cg18338391', 'cg18338460', '
# 1000 input query terms found no hit:	['cg18406197', 'cg18406232', 'cg18406255', 'cg18406285', 'cg18406314', 'cg18406492', 'cg18406531', '
# 1000 input query terms found no hit:	['cg18466674', 'cg18466859', 'cg18466911', 'cg18466965', 'cg18467041', 'cg18467083', 'cg18467110', '
# 1000 input query terms found no hit:	['cg18531405', 'cg18531635', 'cg18531690', 'cg18531720', 'cg18531779', 'cg18531869', 'cg18531916', '
# 1000 input query terms found no hit:	['cg18596794', 'cg18596939', 'cg18596947', 'cg18596952', 'cg18597031', 'cg18597188', 'cg18597220', '
# 1000 input query terms found no hit:	['cg18670767', 'cg18670846', 'cg18671037', 'cg18671057', 'cg18671115', 'cg18671199', 'cg18671318', '
# 1000 input query terms found no hit:	['cg18739800', 'cg18739808', 'cg18739821', 'cg18739865', 'cg18739932', 'cg18739944', 'cg18739950', '
# 1000 input query terms found no hit:	['cg18802021', 'cg18802022', 'cg18802048', 'cg18802138', 'cg18802268', 'cg18802332', 'cg18802368', '
# 1000 input query terms found no hit:	['cg18867923', 'cg18867950', 'cg18867970', 'cg18868017', 'cg18868146', 'cg18868178', 'cg18868357', '
# 1000 input query terms found no hit:	['cg18940113', 'cg18940258', 'cg18940439', 'cg18940588', 'cg18940674', 'cg18940723', 'cg18940763', '
# 1000 input query terms found no hit:	['cg19011752', 'cg19011805', 'cg19011826', 'cg19011844', 'cg19011911', 'cg19012258', 'cg19012475', '
# 1000 input query terms found no hit:	['cg19086540', 'cg19086570', 'cg19086599', 'cg19086603', 'cg19086858', 'cg19086905', 'cg19087028', '
# 1000 input query terms found no hit:	['cg19161333', 'cg19161424', 'cg19161559', 'cg19161859', 'cg19162075', 'cg19162106', 'cg19162158', '
# 1000 input query terms found no hit:	['cg19240052', 'cg19240090', 'cg19240110', 'cg19240117', 'cg19240178', 'cg19240213', 'cg19240233', '
# 1000 input query terms found no hit:	['cg19306847', 'cg19306864', 'cg19306866', 'cg19306948', 'cg19306958', 'cg19306970', 'cg19306990', '
# 1000 input query terms found no hit:	['cg19378624', 'cg19378631', 'cg19378640', 'cg19378729', 'cg19378892', 'cg19379102', 'cg19379103', '
# 1000 input query terms found no hit:	['cg19445734', 'cg19445758', 'cg19445996', 'cg19446018', 'cg19446077', 'cg19446165', 'cg19446264', '
# 1000 input query terms found no hit:	['cg19512268', 'cg19512473', 'cg19512521', 'cg19512582', 'cg19512604', 'cg19512730', 'cg19512736', '
# 1000 input query terms found no hit:	['cg19579080', 'cg19579160', 'cg19579167', 'cg19579176', 'cg19579183', 'cg19579216', 'cg19579217', '
# 1000 input query terms found no hit:	['cg19639831', 'cg19639845', 'cg19639873', 'cg19639898', 'cg19639967', 'cg19640007', 'cg19640029', '
# 1000 input query terms found no hit:	['cg19706515', 'cg19706516', 'cg19706534', 'cg19706682', 'cg19706817', 'cg19706900', 'cg19707004', '
# 1000 input query terms found no hit:	['cg19761060', 'cg19761149', 'cg19761211', 'cg19761245', 'cg19761258', 'cg19761262', 'cg19761271', '
# 1000 input query terms found no hit:	['cg19821527', 'cg19821536', 'cg19821582', 'cg19821589', 'cg19821612', 'cg19821682', 'cg19821713', '
# 1000 input query terms found no hit:	['cg19883017', 'cg19883066', 'cg19883293', 'cg19883384', 'cg19883472', 'cg19883689', 'cg19883748', '
# 1000 input query terms found no hit:	['cg19945078', 'cg19945092', 'cg19945202', 'cg19945263', 'cg19945464', 'cg19945535', 'cg19945554', '
# 1000 input query terms found no hit:	['cg20013920', 'cg20013942', 'cg20013963', 'cg20014049', 'cg20014063', 'cg20014094', 'cg20014207', '
# 1000 input query terms found no hit:	['cg20085268', 'cg20085411', 'cg20085561', 'cg20085588', 'cg20085812', 'cg20085953', 'cg20085985', '
# 1000 input query terms found no hit:	['cg20154865', 'cg20154938', 'cg20154947', 'cg20155035', 'cg20155064', 'cg20155196', 'cg20155440', '
# 1000 input query terms found no hit:	['cg20233582', 'cg20233727', 'cg20234007', 'cg20234060', 'cg20234121', 'cg20234170', 'cg20234205', '
# 1000 input query terms found no hit:	['cg20301993', 'cg20301998', 'cg20302069', 'cg20302082', 'cg20302133', 'cg20302139', 'cg20302165', '
# 1000 input query terms found no hit:	['cg20373416', 'cg20373432', 'cg20373544', 'cg20373634', 'cg20373635', 'cg20373747', 'cg20373761', '
# 1000 input query terms found no hit:	['cg20444218', 'cg20444256', 'cg20444320', 'cg20444341', 'cg20444370', 'cg20444381', 'cg20444525', '
# 1000 input query terms found no hit:	['cg20515672', 'cg20515679', 'cg20515787', 'cg20515846', 'cg20515900', 'cg20516032', 'cg20516074', '
# 1000 input query terms found no hit:	['cg20587188', 'cg20587236', 'cg20587332', 'cg20587336', 'cg20587394', 'cg20587409', 'cg20587464', '
# 1000 input query terms found no hit:	['cg20659485', 'cg20659584', 'cg20659657', 'cg20659663', 'cg20659736', 'cg20659752', 'cg20659757', '
# 1000 input query terms found no hit:	['cg20713092', 'cg20713102', 'cg20713130', 'cg20713174', 'cg20713234', 'cg20713299', 'cg20713333', '
# 1000 input query terms found no hit:	['cg20784259', 'cg20784263', 'cg20784295', 'cg20784314', 'cg20784391', 'cg20784531', 'cg20784591', '
# 1000 input query terms found no hit:	['cg20860726', 'cg20860806', 'cg20861091', 'cg20861237', 'cg20861250', 'cg20861314', 'cg20861422', '
# 1000 input query terms found no hit:	['cg20941699', 'cg20941737', 'cg20941739', 'cg20941758', 'cg20941820', 'cg20941823', 'cg20941843', '
# 1000 input query terms found no hit:	['cg21004633', 'cg21004684', 'cg21004899', 'cg21004924', 'cg21004982', 'cg21005054', 'cg21005154', '
# 1000 input query terms found no hit:	['cg21078247', 'cg21078322', 'cg21078330', 'cg21078414', 'cg21078654', 'cg21078963', 'cg21078966', '
# 1000 input query terms found no hit:	['cg21147203', 'cg21147310', 'cg21147364', 'cg21147422', 'cg21147433', 'cg21147626', 'cg21147648', '
# 1000 input query terms found no hit:	['cg21201884', 'cg21201924', 'cg21201934', 'cg21201971', 'cg21202136', 'cg21202178', 'cg21202204', '
# 1000 input query terms found no hit:	['cg21257293', 'cg21257581', 'cg21257635', 'cg21257675', 'cg21257892', 'cg21257950', 'cg21258057', '
# 1000 input query terms found no hit:	['cg21342636', 'cg21342728', 'cg21342994', 'cg21343189', 'cg21343191', 'cg21343223', 'cg21343363', '
# 1000 input query terms found no hit:	['cg21429087', 'cg21429105', 'cg21429107', 'cg21429173', 'cg21429394', 'cg21429408', 'cg21429409', '
# 1000 input query terms found no hit:	['cg21498503', 'cg21498547', 'cg21498620', 'cg21498772', 'cg21498785', 'cg21498950', 'cg21499006', '
# 1000 input query terms found no hit:	['cg21561315', 'cg21561470', 'cg21561492', 'cg21561537', 'cg21561596', 'cg21561672', 'cg21561712', '
# 1000 input query terms found no hit:	['cg21625570', 'cg21625737', 'cg21625817', 'cg21625829', 'cg21625858', 'cg21625881', 'cg21626086', '
# 1000 input query terms found no hit:	['cg21701585', 'cg21701856', 'cg21702011', 'cg21702128', 'cg21702188', 'cg21702431', 'cg21702497', '
# 1000 input query terms found no hit:	['cg21780717', 'cg21780796', 'cg21780812', 'cg21780842', 'cg21780859', 'cg21780952', 'cg21781009', '
# 1000 input query terms found no hit:	['cg21851395', 'cg21851530', 'cg21851534', 'cg21851553', 'cg21851632', 'cg21851672', 'cg21851693', '
# 1000 input query terms found no hit:	['cg21917349', 'cg21917351', 'cg21917448', 'cg21917512', 'cg21917524', 'cg21917532', 'cg21917550', '
# 1000 input query terms found no hit:	['cg21997766', 'cg21997857', 'cg21997986', 'cg21998184', 'cg21998208', 'cg21998325', 'cg21998339', '
# 1000 input query terms found no hit:	['cg22068211', 'cg22068371', 'cg22068395', 'cg22068400', 'cg22068464', 'cg22068473', 'cg22068529', '
# 1000 input query terms found no hit:	['cg22142858', 'cg22142913', 'cg22142922', 'cg22142968', 'cg22143064', 'cg22143209', 'cg22143274', '
# 1000 input query terms found no hit:	['cg22215739', 'cg22215783', 'cg22215784', 'cg22215815', 'cg22215836', 'cg22215942', 'cg22216015', '
# 1000 input query terms found no hit:	['cg22288657', 'cg22288690', 'cg22288737', 'cg22288798', 'cg22288927', 'cg22288982', 'cg22289115', '
# 1000 input query terms found no hit:	['cg22366819', 'cg22366885', 'cg22366897', 'cg22366909', 'cg22366933', 'cg22366938', 'cg22366943', '
# 1000 input query terms found no hit:	['cg22444730', 'cg22444983', 'cg22445167', 'cg22445256', 'cg22445346', 'cg22445447', 'cg22445712', '
# 1000 input query terms found no hit:	['cg22512973', 'cg22513099', 'cg22513237', 'cg22513328', 'cg22513356', 'cg22513396', 'cg22513455', '
# 1000 input query terms found no hit:	['cg22587509', 'cg22587514', 'cg22587600', 'cg22587602', 'cg22587675', 'cg22587703', 'cg22587751', '
# 1000 input query terms found no hit:	['cg22659564', 'cg22659681', 'cg22659770', 'cg22659852', 'cg22659922', 'cg22659953', 'cg22660033', '
# 1000 input query terms found no hit:	['cg22719314', 'cg22719334', 'cg22719559', 'cg22719586', 'cg22719623', 'cg22719655', 'cg22719658', '
# 1000 input query terms found no hit:	['cg22793832', 'cg22793860', 'cg22793871', 'cg22793897', 'cg22794078', 'cg22794127', 'cg22794214', '
# 1000 input query terms found no hit:	['cg22853601', 'cg22853607', 'cg22853641', 'cg22853713', 'cg22853797', 'cg22853813', 'cg22853855', '
# 1000 input query terms found no hit:	['cg22916593', 'cg22916646', 'cg22916672', 'cg22916722', 'cg22916756', 'cg22917082', 'cg22917147', '
# 1000 input query terms found no hit:	['cg22981104', 'cg22981125', 'cg22981153', 'cg22981158', 'cg22981175', 'cg22981198', 'cg22981296', '
# 1000 input query terms found no hit:	['cg23043968', 'cg23044005', 'cg23044017', 'cg23044053', 'cg23044068', 'cg23044079', 'cg23044087', '
# 1000 input query terms found no hit:	['cg23101551', 'cg23101564', 'cg23101632', 'cg23101649', 'cg23101675', 'cg23101680', 'cg23101686', '
# 1000 input query terms found no hit:	['cg23175428', 'cg23175533', 'cg23175573', 'cg23175583', 'cg23175599', 'cg23175907', 'cg23175918', '
# 1000 input query terms found no hit:	['cg23234847', 'cg23234860', 'cg23234999', 'cg23235004', 'cg23235067', 'cg23235135', 'cg23235141', '
# 1000 input query terms found no hit:	['cg23291158', 'cg23291161', 'cg23291200', 'cg23291271', 'cg23291280', 'cg23291301', 'cg23291305', '
# 1000 input query terms found no hit:	['cg23359363', 'cg23359385', 'cg23359394', 'cg23359401', 'cg23359665', 'cg23359706', 'cg23359714', '
# 1000 input query terms found no hit:	['cg23428738', 'cg23428905', 'cg23428922', 'cg23428985', 'cg23429036', 'cg23429042', 'cg23429047', '
# 1000 input query terms found no hit:	['cg23497857', 'cg23498106', 'cg23498221', 'cg23498254', 'cg23498273', 'cg23498394', 'cg23498494', '
# 1000 input query terms found no hit:	['cg23565428', 'cg23565561', 'cg23565563', 'cg23565607', 'cg23565663', 'cg23565749', 'cg23565757', '
# 1000 input query terms found no hit:	['cg23634322', 'cg23634348', 'cg23634395', 'cg23634401', 'cg23634413', 'cg23634417', 'cg23634451', '
# 1000 input query terms found no hit:	['cg23689428', 'cg23689429', 'cg23689441', 'cg23689457', 'cg23689517', 'cg23689579', 'cg23689615', '
# 1000 input query terms found no hit:	['cg23758305', 'cg23758309', 'cg23758354', 'cg23758485', 'cg23758597', 'cg23758687', 'cg23758703', '
# 1000 input query terms found no hit:	['cg23839074', 'cg23839113', 'cg23839136', 'cg23839159', 'cg23839180', 'cg23839479', 'cg23839556', '
# 1000 input query terms found no hit:	['cg23907108', 'cg23907260', 'cg23907586', 'cg23907837', 'cg23907852', 'cg23907860', 'cg23907926', '
# 1000 input query terms found no hit:	['cg23969423', 'cg23969506', 'cg23969508', 'cg23969515', 'cg23969559', 'cg23969669', 'cg23969884', '
# 1000 input query terms found no hit:	['cg24028120', 'cg24028122', 'cg24028141', 'cg24028161', 'cg24028202', 'cg24028218', 'cg24028260', '
# 1000 input query terms found no hit:	['cg24089887', 'cg24089932', 'cg24089935', 'cg24089936', 'cg24090019', 'cg24090068', 'cg24090192', '
# 1000 input query terms found no hit:	['cg24149904', 'cg24149930', 'cg24150012', 'cg24150032', 'cg24150051', 'cg24150153', 'cg24150157', '
# 1000 input query terms found no hit:	['cg24216893', 'cg24216908', 'cg24216966', 'cg24216990', 'cg24217003', 'cg24217005', 'cg24217159', '
# 1000 input query terms found no hit:	['cg24301139', 'cg24301192', 'cg24301247', 'cg24301250', 'cg24301288', 'cg24301290', 'cg24301350', '
# 1000 input query terms found no hit:	['cg24362824', 'cg24362829', 'cg24362923', 'cg24362960', 'cg24363020', 'cg24363146', 'cg24363160', '
# 1000 input query terms found no hit:	['cg24429533', 'cg24429613', 'cg24429622', 'cg24429708', 'cg24429727', 'cg24429831', 'cg24429836', '
# 1000 input query terms found no hit:	['cg24494556', 'cg24494577', 'cg24494587', 'cg24494617', 'cg24494643', 'cg24494707', 'cg24494791', '
# 1000 input query terms found no hit:	['cg24553862', 'cg24554054', 'cg24554059', 'cg24554061', 'cg24554147', 'cg24554151', 'cg24554319', '
# 1000 input query terms found no hit:	['cg24624901', 'cg24625034', 'cg24625084', 'cg24625115', 'cg24625128', 'cg24625136', 'cg24625240', '
# 1000 input query terms found no hit:	['cg24687358', 'cg24687395', 'cg24687432', 'cg24687529', 'cg24687543', 'cg24687639', 'cg24687652', '
# 1000 input query terms found no hit:	['cg24742912', 'cg24743052', 'cg24743122', 'cg24743155', 'cg24743156', 'cg24743200', 'cg24743229', '
# 1000 input query terms found no hit:	['cg24810473', 'cg24810594', 'cg24810637', 'cg24810646', 'cg24810836', 'cg24810917', 'cg24811125', '
# 1000 input query terms found no hit:	['cg24873410', 'cg24873414', 'cg24873464', 'cg24873508', 'cg24873562', 'cg24873592', 'cg24873593', '
# 1000 input query terms found no hit:	['cg24935976', 'cg24936032', 'cg24936095', 'cg24936179', 'cg24936204', 'cg24936273', 'cg24936299', '
# 1000 input query terms found no hit:	['cg25006823', 'cg25006829', 'cg25006998', 'cg25007165', 'cg25007250', 'cg25007283', 'cg25007351', '
# 1000 input query terms found no hit:	['cg25072733', 'cg25072766', 'cg25072880', 'cg25072895', 'cg25072945', 'cg25072949', 'cg25072962', '
# 1000 input query terms found no hit:	['cg25139471', 'cg25139493', 'cg25139596', 'cg25139619', 'cg25139636', 'cg25139641', 'cg25139649', '
# 1000 input query terms found no hit:	['cg25209842', 'cg25209938', 'cg25209983', 'cg25210023', 'cg25210134', 'cg25210378', 'cg25210451', '
# 1000 input query terms found no hit:	['cg25284841', 'cg25285041', 'cg25285053', 'cg25285090', 'cg25285186', 'cg25285236', 'cg25285237', '
# 1000 input query terms found no hit:	['cg25351353', 'cg25351461', 'cg25351550', 'cg25351565', 'cg25351572', 'cg25351588', 'cg25351599', '
# 1000 input query terms found no hit:	['cg25413342', 'cg25413347', 'cg25413414', 'cg25413575', 'cg25413720', 'cg25413748', 'cg25413757', '
# 1000 input query terms found no hit:	['cg25481253', 'cg25481384', 'cg25481454', 'cg25481474', 'cg25481491', 'cg25481630', 'cg25481635', '
# 1000 input query terms found no hit:	['cg25554455', 'cg25554496', 'cg25554557', 'cg25554685', 'cg25554740', 'cg25554744', 'cg25554751', '
# 1000 input query terms found no hit:	['cg25616607', 'cg25616762', 'cg25616771', 'cg25616777', 'cg25616829', 'cg25616869', 'cg25616918', '
# 1000 input query terms found no hit:	['cg25688164', 'cg25688483', 'cg25688523', 'cg25688568', 'cg25688583', 'cg25688584', 'cg25688633', '
# 1000 input query terms found no hit:	['cg25755107', 'cg25755191', 'cg25755261', 'cg25755283', 'cg25755428', 'cg25755500', 'cg25755573', '
# 1000 input query terms found no hit:	['cg25826546', 'cg25826576', 'cg25826596', 'cg25826644', 'cg25826698', 'cg25826721', 'cg25826740', '
# 1000 input query terms found no hit:	['cg25909811', 'cg25909854', 'cg25909885', 'cg25910083', 'cg25910261', 'cg25910314', 'cg25910432', '
# 1000 input query terms found no hit:	['cg25973293', 'cg25973354', 'cg25973369', 'cg25973374', 'cg25973445', 'cg25973534', 'cg25973580', '
# 1000 input query terms found no hit:	['cg26038589', 'cg26038596', 'cg26038649', 'cg26038697', 'cg26038700', 'cg26038708', 'cg26038749', '
# 1000 input query terms found no hit:	['cg26105310', 'cg26105341', 'cg26105495', 'cg26105558', 'cg26105649', 'cg26105658', 'cg26105660', '
# 1000 input query terms found no hit:	['cg26161528', 'cg26161643', 'cg26161708', 'cg26161725', 'cg26161747', 'cg26161780', 'cg26161795', '
# 1000 input query terms found no hit:	['cg26226546', 'cg26226555', 'cg26226566', 'cg26226576', 'cg26226608', 'cg26226650', 'cg26226702', '
# 1000 input query terms found no hit:	['cg26284388', 'cg26284390', 'cg26284483', 'cg26284540', 'cg26284544', 'cg26284638', 'cg26284685', '
# 1000 input query terms found no hit:	['cg26343883', 'cg26343889', 'cg26343910', 'cg26343958', 'cg26344024', 'cg26344026', 'cg26344087', '
# 1000 input query terms found no hit:	['cg26403416', 'cg26403494', 'cg26403559', 'cg26403580', 'cg26403608', 'cg26403748', 'cg26403777', '
# 1000 input query terms found no hit:	['cg26468414', 'cg26468430', 'cg26468478', 'cg26468693', 'cg26468696', 'cg26468833', 'cg26468878', '
# 1000 input query terms found no hit:	['cg26529877', 'cg26529911', 'cg26529963', 'cg26530020', 'cg26530045', 'cg26530061', 'cg26530063', '
# 1000 input query terms found no hit:	['cg26588076', 'cg26588194', 'cg26588398', 'cg26588612', 'cg26588685', 'cg26588688', 'cg26588699', '
# 1000 input query terms found no hit:	['cg26656022', 'cg26656113', 'cg26656135', 'cg26656163', 'cg26656175', 'cg26656202', 'cg26656208', '
# 1000 input query terms found no hit:	['cg26710738', 'cg26710819', 'cg26710858', 'cg26710891', 'cg26710926', 'cg26710963', 'cg26710983', '
# 1000 input query terms found no hit:	['cg26782361', 'cg26782451', 'cg26782539', 'cg26782787', 'cg26782824', 'cg26782825', 'cg26782833', '
# 1000 input query terms found no hit:	['cg26835419', 'cg26835440', 'cg26835506', 'cg26835520', 'cg26835568', 'cg26835675', 'cg26835683', '
# 1000 input query terms found no hit:	['cg26892843', 'cg26893124', 'cg26893134', 'cg26893197', 'cg26893231', 'cg26893451', 'cg26893600', '
# 1000 input query terms found no hit:	['cg26953153', 'cg26953232', 'cg26953234', 'cg26953293', 'cg26953326', 'cg26953403', 'cg26953435', '
# 1000 input query terms found no hit:	['cg27016020', 'cg27016051', 'cg27016106', 'cg27016107', 'cg27016114', 'cg27016262', 'cg27016272', '
# 1000 input query terms found no hit:	['cg27076777', 'cg27076781', 'cg27076799', 'cg27077033', 'cg27077050', 'cg27077070', 'cg27077106', '
# 1000 input query terms found no hit:	['cg27139491', 'cg27139805', 'cg27139836', 'cg27139841', 'cg27139851', 'cg27139933', 'cg27139941', '
# 1000 input query terms found no hit:	['cg27205301', 'cg27205487', 'cg27205559', 'cg27205667', 'cg27205687', 'cg27205688', 'cg27205791', '
# 1000 input query terms found no hit:	['cg27273675', 'cg27273866', 'cg27273886', 'cg27273946', 'cg27274028', 'cg27274072', 'cg27274135', '
# 1000 input query terms found no hit:	['cg27328236', 'cg27328245', 'cg27328408', 'cg27328431', 'cg27328469', 'cg27328673', 'cg27328797', '
# 1000 input query terms found no hit:	['cg27393726', 'cg27393730', 'cg27393769', 'cg27393925', 'cg27393982', 'cg27394015', 'cg27394038', '
# 1000 input query terms found no hit:	['cg27461213', 'cg27461254', 'cg27461259', 'cg27461422', 'cg27461468', 'cg27461542', 'cg27461733', '
# 1000 input query terms found no hit:	['cg27525731', 'cg27525876', 'cg27525902', 'cg27526038', 'cg27526098', 'cg27526149', 'cg27526317', '
# 1000 input query terms found no hit:	['cg27583604', 'cg27583655', 'cg27583671', 'cg27583690', 'cg27583740', 'cg27583815', 'cg27583853', '
# 1000 input query terms found no hit:	['cg27649037', 'cg27649073', 'cg27649089', 'cg27649094', 'cg27649194', 'cg27649239', 'cg27649253', '
# 1000 input query terms found no hit:	['ch.12.9379220R', 'ch.12.96843545R', 'ch.12.973812R', 'ch.13.100003653F', 'ch.13.100269732F', 'ch.1
# 1000 input query terms found no hit:	['ch.3.1012570R', 'ch.3.1012680R', 'ch.3.1021608R', 'ch.3.1040445R', 'ch.3.1042115R', 'ch.3.1042801R
# 222 input query terms found no hit:	['ch.9.2042397F', 'ch.9.2043201R', 'ch.9.2049598F', 'ch.9.2051689R', 'ch.9.21059582R', 'ch.9.2172872

# %%
merged_data = geo_merge_clinical_genetic_data(selected_clinical_data, genetic_data)
# The preprocessing runs through, which means is_available should be True
is_available = True

# %%
print(f"The merged dataset contains {len(merged_data)} samples.")
# Out:
# The merged dataset contains 43 samples.

# %%
is_trait_biased, merged_data = judge_and_remove_biased_features(merged_data, TRAIT, trait_type=trait_type)
is_trait_biased
# Out:
# For the feature 'pain sensitivity', the least common label is '1.0' with 43 occurrences. This represents 100.00% of the dataset.
# The distribution of the feature 'pain sensitivity' in this dataset is severely biased.
#
# For the feature 'Gender', the least common label is '1.0' with 43 occurrences. This represents 100.00% of the dataset.
# The distribution of the feature 'Gender' in this dataset is severely biased.
# True

# %%
if is_available:
    save_cohort_info(cohort, JSON_PATH, is_available, is_trait_biased, merged_data, note='')
else:
    save_cohort_info(cohort, JSON_PATH, is_available)

# %%
merged_data.head()
if not is_trait_biased:
    merged_data.to_csv(os.path.join(OUTPUT_DIR, cohort + '.csv'), index=False)

# %%
# Check the information of usable cohorts
best_cohort, ranked_df = filter_and_rank_cohorts(JSON_PATH)
ranked_df
# Out:
# Empty DataFrame
# Columns: [cohort_id, is_usable, is_available, is_biased, has_age, has_gender, sample_size, note]
# Index: []

# %%
# If both age and gender have available cohorts, select 'age' as the condition.
condition = 'Age'
filter_column = 'has_' + condition.lower()

condition_best_cohort, condition_ranked_df = filter_and_rank_cohorts(JSON_PATH, filter_column)
condition_best_cohort

# %%
condition_ranked_df.head()
# Out:
# Empty DataFrame
# Columns: [cohort_id, is_usable, is_available, is_biased, has_age, has_gender, sample_size, note]
# Index: []
