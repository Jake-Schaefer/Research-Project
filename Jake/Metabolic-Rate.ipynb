# %%
import os
import mygene
import io
import re
import pandas as pd
import gzip
import numpy as np
from typing import Optional, List, Tuple, Union, Any
import json
from sparse_lmm import VariableSelection
from sklearn.linear_model import Lasso, LogisticRegression
from sklearn.metrics import accuracy_score, mean_squared_error
from typing import Callable, Optional, List, Tuple, Union, Any
from statsmodels.stats.multitest import multipletests

def get_relevant_filepaths(cohort_dir):
    """Find the file paths of a SOFT file and a matrix file from the given data directory of a cohort.
    If there are multiple SOFT files or matrix files, simply choose the first one. May be replaced by better
    strategies later.
    """
    files = os.listdir(cohort_dir)
    soft_files = [f for f in files if 'soft' in f.lower()]
    matrix_files = [f for f in files if 'matrix' in f.lower()]
    assert len(soft_files) > 0 and len(matrix_files) > 0
    soft_file_path = os.path.join(cohort_dir, soft_files[0])
    matrix_file_path = os.path.join(cohort_dir, matrix_files[0])

    return soft_file_path, matrix_file_path

def line_generator(source, source_type):
    """Generator that yields lines from a file or a string.

    Parameters:
    - source: File path or string content.
    - source_type: 'file' or 'string'.
    """
    if source_type == 'file':
        with gzip.open(source, 'rt') as f:
            for line in f:
                yield line.strip()
    elif source_type == 'string':
        for line in source.split('\n'):
            yield line.strip()
    else:
        raise ValueError("source_type must be 'file' or 'string'")

def filter_content_by_prefix(
    source: str,
    prefixes_a: List[str],
    prefixes_b: Optional[List[str]] = None,
    unselect: bool = False,
    source_type: str = 'file',
    return_df_a: bool = True,
    return_df_b: bool = True
) -> Tuple[Union[str, pd.DataFrame], Optional[Union[str, pd.DataFrame]]]:
    """
    Filters rows from a file or a list of strings based on specified prefixes.

    Parameters:
    - source (str): File path or string content to filter.
    - prefixes_a (List[str]): Primary list of prefixes to filter by.
    - prefixes_b (Optional[List[str]]): Optional secondary list of prefixes to filter by.
    - unselect (bool): If True, selects rows that do not start with the specified prefixes.
    - source_type (str): 'file' if source is a file path, 'string' if source is a string of text.
    - return_df_a (bool): If True, returns filtered content for prefixes_a as a pandas DataFrame.
    - return_df_b (bool): If True, and if prefixes_b is provided, returns filtered content for prefixes_b as a pandas DataFrame.

    Returns:
    - Tuple: A tuple where the first element is the filtered content for prefixes_a, and the second element is the filtered content for prefixes_b.
    """
    filtered_lines_a = []
    filtered_lines_b = []
    prefix_set_a = set(prefixes_a)
    if prefixes_b is not None:
        prefix_set_b = set(prefixes_b)

    # Use generator to get lines
    for line in line_generator(source, source_type):
        matched_a = any(line.startswith(prefix) for prefix in prefix_set_a)
        if matched_a != unselect:
            filtered_lines_a.append(line)
        if prefixes_b is not None:
            matched_b = any(line.startswith(prefix) for prefix in prefix_set_b)
            if matched_b != unselect:
                filtered_lines_b.append(line)

    filtered_content_a = '\n'.join(filtered_lines_a)
    if return_df_a:
        filtered_content_a = pd.read_csv(io.StringIO(filtered_content_a), delimiter='\t', low_memory=False, on_bad_lines='skip')
    filtered_content_b = None
    if filtered_lines_b:
        filtered_content_b = '\n'.join(filtered_lines_b)
        if return_df_b:
            filtered_content_b = pd.read_csv(io.StringIO(filtered_content_b), delimiter='\t', low_memory=False, on_bad_lines='skip')

    return filtered_content_a, filtered_content_b

def get_background_and_clinical_data(file_path,
                                     prefixes_a=['!Series_title', '!Series_summary', '!Series_overall_design'],
                                     prefixes_b=['!Sample_geo_accession', '!Sample_characteristics_ch1']):
    """Extract from a matrix file the background information about the dataset, and sample characteristics data"""
    background_info, clinical_data = filter_content_by_prefix(file_path, prefixes_a, prefixes_b, unselect=False,
                                                              source_type='file',
                                                              return_df_a=False, return_df_b=True)
    return background_info, clinical_data

def get_unique_values_by_row(dataframe, max_len=30):
    """
    Organize the unique values in each row of the given dataframe, to get a dictionary
    :param dataframe:
    :param max_len:
    :return:
    """
    if '!Sample_geo_accession' in dataframe.columns:
        dataframe = dataframe.drop(columns=['!Sample_geo_accession'])
    unique_values_dict = {}
    for index, row in dataframe.iterrows():
        unique_values = list(row.unique())[:max_len]
        unique_values_dict[index] = unique_values
    return unique_values_dict

def check_rows_and_columns(dataframe, display=False):
    """
    Get the lists of row names and column names of a dataset, and optionally observe them.
    :param dataframe:
    :param display:
    :return:
    """
    dataframe_rows = dataframe.index.tolist()
    if display:
        print(f"The dataset has {len(dataframe_rows)} rows, such as {dataframe_rows[:20]}")
    dataframe_cols = dataframe.columns.tolist()
    if display:
        print(f"\nThe dataset has {len(dataframe_cols)} columns, such as {dataframe_cols[:20]}")
    return dataframe_rows, dataframe_cols

def preview_df(df, n=5):
    return df.head(n).to_dict(orient='list')

def xena_convert_trait(row_index: str):
    """
    Convert the trait information from Sample IDs to labels depending on the last two digits.
    Tumor types range from 01 - 09, normal types from 10 - 19.
    :param row_index: the index value of a row
    :return: the converted value
    """
    last_two_digits = int(row_index[-2:])

    if 1 <= last_two_digits <= 9:
        return 1
    elif 10 <= last_two_digits <= 19:
        return 0
    else:
        return -1


def xena_convert_gender(cell: str):
    """Convert the cell content about gender to a binary value
    """
    if isinstance(cell, str):
        cell = cell.lower()

    if cell == "female":
        return 0
    elif cell == "male":
        return 1
    else:
        return None


def xena_convert_age(cell: str):
    """Convert the cell content about age to a numerical value using regular expression
    """
    match = re.search(r'\d+', str(cell))
    if match:
        return int(match.group())
    else:
        return None

def xena_select_clinical_features(clinical_df, trait, age_col=None, gender_col=None):
    feature_list = []
    trait_data = clinical_df.index.to_series().apply(xena_convert_trait).rename(trait)
    feature_list.append(trait_data)
    if age_col:
        age_data = clinical_df[age_col].apply(xena_convert_age).rename("Age")
        feature_list.append(age_data)
    if gender_col:
        gender_data = clinical_df[gender_col].apply(xena_convert_gender).rename("Gender")
        feature_list.append(gender_data)
    selected_clinical_df = pd.concat(feature_list, axis=1)
    return selected_clinical_df

def normalize_gene_symbols(gene_symbols, batch_size=1000):
    """Normalize human gene symbols in batches using the 'mygenes' library"""
    mg = mygene.MyGeneInfo()
    normalized_genes = {}

    # Process in batches
    for i in range(0, len(gene_symbols), batch_size):
        batch = gene_symbols[i:i + batch_size]
        results = mg.querymany(batch, scopes='symbol', fields='symbol', species='human')

        # Update the normalized_genes dictionary with results from this batch
        for gene in results:
            normalized_genes[gene['query']] = gene.get('symbol', None)

    # Return the normalized symbols in the same order as the input
    return [normalized_genes.get(symbol) for symbol in gene_symbols]

def normalize_gene_symbols_in_index(gene_df):
    """Normalize the human gene symbols at the index of a dataframe, and replace the index with its normalized version.
    Remove the rows where the index failed to be normalized."""
    normalized_gene_list = normalize_gene_symbols(gene_df.index.tolist())
    assert len(normalized_gene_list) == len(gene_df.index)
    gene_df.index = normalized_gene_list
    gene_df = gene_df[gene_df.index.notnull()]
    return gene_df

def judge_binary_variable_biased(dataframe, col_name, min_proportion=0.1, min_num=5):
    """
    Check if the distribution of a binary variable in the dataset is too biased to be usable for analysis
    :param dataframe:
    :param col_name:
    :param min_proportion:
    :param min_num:
    :return:
    """
    label_counter = dataframe[col_name].value_counts()
    total_samples = len(dataframe)
    rare_label_num = label_counter.min()
    rare_label = label_counter.idxmin()
    rare_label_proportion = rare_label_num / total_samples

    print(
        f"For the feature \'{col_name}\', the least common label is '{rare_label}' with {rare_label_num} occurrences. This represents {rare_label_proportion:.2%} of the dataset.")

    biased = (len(label_counter) < 2) or ((rare_label_proportion < min_proportion) and (rare_label_num < min_num))
    return bool(biased)

def judge_continuous_variable_biased(dataframe, col_name):
    """Check if the distribution of a continuous variable in the dataset is too biased to be usable for analysis.
    As a starting point, we consider it biased if all values are the same. For the next step, maybe ask GPT to judge
    based on quartile statistics combined with its common sense knowledge about this feature.
    """
    quartiles = dataframe[col_name].quantile([0.25, 0.5, 0.75])
    min_value = dataframe[col_name].min()
    max_value = dataframe[col_name].max()

    # Printing quartile information
    print(f"Quartiles for '{col_name}':")
    print(f"  25%: {quartiles[0.25]}")
    print(f"  50% (Median): {quartiles[0.5]}")
    print(f"  75%: {quartiles[0.75]}")
    print(f"Min: {min_value}")
    print(f"Max: {max_value}")

    biased = min_value == max_value

    return bool(biased)

def judge_and_remove_biased_features(df, trait, trait_type):
    assert trait_type in ["binary", "continuous"], f"The trait must be either a binary or a continuous variable!"
    if trait_type == "binary":
        trait_biased = judge_binary_variable_biased(df, trait)
    else:
        trait_biased = judge_continuous_variable_biased(df, trait)
    if trait_biased:
        print(f"The distribution of the feature \'{trait}\' in this dataset is severely biased.\n")
    else:
        print(f"The distribution of the feature \'{trait}\' in this dataset is fine.\n")
    if "Age" in df.columns:
        age_biased = judge_continuous_variable_biased(df, 'Age')
        if age_biased:
            print(f"The distribution of the feature \'Age\' in this dataset is severely biased.\n")
            df = df.drop(columns='Age')
        else:
            print(f"The distribution of the feature \'Age\' in this dataset is fine.\n")
    if "Gender" in df.columns:
        gender_biased = judge_binary_variable_biased(df, 'Gender')
        if gender_biased:
            print(f"The distribution of the feature \'Gender\' in this dataset is severely biased.\n")
            df = df.drop(columns='Gender')
        else:
            print(f"The distribution of the feature \'Gender\' in this dataset is fine.\n")

    return trait_biased, df

def save_cohort_info(cohort: str, info_path: str, is_available: bool, is_biased: Optional[bool] = None,
                     df: Optional[pd.DataFrame] = None, note: str = '') -> None:
    """
    Add or update information about the usability and quality of a dataset for statistical analysis.

    Parameters:
    cohort (str): A unique identifier for the dataset.
    info_path (str): File path to the JSON file where records are stored.
    is_available (bool): Indicates whether both the genetic data and trait data are available in the dataset, and can be
     preprocessed into a dataframe.
    is_biased (bool, optional): Indicates whether the dataset is too biased to be usable.
        Required if `is_available` is True.
    df (pandas.DataFrame, optional): The preprocessed dataset. Required if `is_available` is True.
    note (str, optional): Additional notes about the dataset.

    Returns:
    None: The function does not return a value but updates or creates a record in the specified JSON file.
    """
    if is_available:
        assert (df is not None) and (is_biased is not None), "'df' and 'is_biased' should be provided if this cohort " \
                                                             "is relevant."
    is_usable = is_available and (not is_biased)
    new_record = {"is_usable": is_usable,
                  "is_available": is_available,
                  "is_biased": is_biased if is_available else None,
                  "has_age": "Age" in df.columns if is_available else None,
                  "has_gender": "Gender" in df.columns if is_available else None,
                  "sample_size": len(df) if is_available else None,
                  "note": note}

    if not os.path.exists(info_path):
        with open(info_path, 'w') as file:
            json.dump({}, file)
        print(f"A new JSON file was created at: {info_path}")

    with open(info_path, "r") as file:
        records = json.load(file)
    records[cohort] = new_record

    temp_path = info_path + ".tmp"
    try:
        with open(temp_path, 'w') as file:
            json.dump(records, file)
        os.replace(temp_path, info_path)

    except Exception as e:
        print(f"An error occurred: {e}")
        if os.path.exists(temp_path):
            os.remove(temp_path)
        raise

def get_feature_data(clinical_df, row_id, feature, convert_fn):
    """select the row corresponding to a feature in the sample characteristics dataframe, and convert the feature into
    a binary or continuous variable"""
    clinical_df = clinical_df.iloc[row_id:row_id + 1].drop(columns=['!Sample_geo_accession'], errors='ignore')
    clinical_df.index = [feature]
    clinical_df = clinical_df.applymap(convert_fn)

    return clinical_df

def geo_select_clinical_features(clinical_df: pd.DataFrame, trait: str, trait_row: int,
                                 convert_trait: Callable,
                                 age_row: Optional[int] = None,
                                 convert_age: Optional[Callable] = None,
                                 gender_row: Optional[int] = None,
                                 convert_gender: Optional[Callable] = None) -> pd.DataFrame:
    """
    Extracts and processes specific clinical features from a DataFrame representing
    sample characteristics in the GEO database series.

    Parameters:
    - clinical_df (pd.DataFrame): DataFrame containing clinical data.
    - trait (str): The trait of interest.
    - trait_row (int): Row identifier for the trait in the DataFrame.
    - convert_trait (Callable): Function to convert trait data into a desired format.
    - age_row (int, optional): Row identifier for age data. Default is None.
    - convert_age (Callable, optional): Function to convert age data. Default is None.
    - gender_row (int, optional): Row identifier for gender data. Default is None.
    - convert_gender (Callable, optional): Function to convert gender data. Default is None.

    Returns:
    pd.DataFrame: A DataFrame containing the selected and processed clinical features.
    """
    feature_list = []

    trait_data = get_feature_data(clinical_df, trait_row, trait, convert_trait)
    feature_list.append(trait_data)
    if age_row is not None:
        age_data = get_feature_data(clinical_df, age_row, 'Age', convert_age)
        feature_list.append(age_data)
    if gender_row is not None:
        gender_data = get_feature_data(clinical_df, gender_row, 'Gender', convert_gender)
        feature_list.append(gender_data)

    selected_clinical_df = pd.concat(feature_list, axis=0)
    return selected_clinical_df

def get_genetic_data(file_path):
    """Read the gene expression data into a dataframe, and adjust its format"""
    genetic_data = pd.read_csv(file_path, compression='gzip', skiprows=52, comment='!', delimiter='\t')
    genetic_data = genetic_data.dropna()
    genetic_data = genetic_data.rename(columns={'ID_REF': 'ID'}).astype({'ID': 'str'})
    genetic_data.set_index('ID', inplace=True)

    return genetic_data

def get_gene_annotation(file_path, prefixes=['^', '!', '#']):
    """Extract from a SOFT file the gene annotation data"""
    gene_metadata = filter_content_by_prefix(file_path, prefixes_a=prefixes, unselect=True, source_type='file',
                                             return_df_a=True)
    return gene_metadata[0]

def get_gene_mapping(annotation, prob_col, gene_col):
    """Process the gene annotation to get the mapping between gene names and gene probes.
    """
    mapping_data = annotation.loc[:, [prob_col, gene_col]]
    mapping_data = mapping_data.dropna()
    mapping_data = mapping_data.rename(columns={gene_col: 'Gene'}).astype({'ID': 'str'})

    return mapping_data

def apply_gene_mapping(expression_df, mapping_df):
    """
    Converts measured data about gene probes into gene expression data.
    Handles the potential many-to-many relationship between probes and genes.

    Parameters:
    expression_df (DataFrame): A DataFrame with gene expression data, indexed by 'ID'.
    mapping_df (DataFrame): A DataFrame mapping 'ID' to 'Gene', with 'ID' as a column.

    Returns:
    DataFrame: A DataFrame with mean gene expression values, indexed by 'Gene'.
    """

    # Define a regex pattern for splitting gene names
    split_pattern = r';|\|+|/{2,}|,|\[|\]|\(|\)'

    # Split the 'Gene' column in 'mapping_df' using the regex pattern
    mapping_df['Gene'] = mapping_df['Gene'].str.split(split_pattern)
    mapping_df = mapping_df.explode('Gene')

    # Set 'ID' as the index of 'mapping_df' for merging
    mapping_df.set_index('ID', inplace=True)

    # Merge 'mapping_df' with 'expression_df' by their indices
    merged_df = mapping_df.join(expression_df)

    # Group by 'Gene' and calculate the mean expression values
    gene_expression_df = merged_df.groupby('Gene').mean().dropna()

    return gene_expression_df

def geo_merge_clinical_genetic_data(clinical_df, genetic_df):
    """
    Merge the clinical features and gene expression features from two dataframes into one dataframe
    """
    if 'ID' in genetic_df.columns:
        genetic_df = genetic_df.rename(columns={'ID': 'Gene'})
    if 'Gene' in genetic_df.columns:
        genetic_df = genetic_df.set_index('Gene')
    merged_data = pd.concat([clinical_df, genetic_df], axis=0).T.dropna()
    return merged_data

def read_json_to_dataframe(json_file: str) -> pd.DataFrame:
    """
    Reads a JSON file and converts it into a pandas DataFrame.

    Args:
    json_file (str): The path to the JSON file containing the data.

    Returns:
    DataFrame: A pandas DataFrame with the JSON data.
    """
    with open(json_file, 'r') as file:
        data = json.load(file)
    return pd.DataFrame.from_dict(data, orient='index').reset_index().rename(columns={'index': 'cohort_id'})

def filter_and_rank_cohorts(json_file: str, condition: Union[str, None] = None) -> Tuple[
    Union[str, None], pd.DataFrame]:
    """
    Reads a JSON file, filters cohorts based on usability and an optional condition, then ranks them by sample size.

    Args:
    json_file (str): The path to the JSON file containing the data.
    condition (str, optional): An additional condition for filtering. If None, only 'is_usable' is considered.

    Returns:
    Tuple: A tuple containing the best cohort ID (str or None if no suitable cohort is found) and
           the filtered and ranked DataFrame.
    """
    # Read the JSON file into a DataFrame
    df = read_json_to_dataframe(json_file)

    if condition:
        filtered_df = df[(df['is_usable'] == True) & (df[condition] == True)]
    else:
        filtered_df = df[df['is_usable'] == True]

    ranked_df = filtered_df.sort_values(by='sample_size', ascending=False)
    best_cohort_id = ranked_df.iloc[0]['cohort_id'] if not ranked_df.empty else None

    return best_cohort_id, ranked_df

def detect_batch_effect(X):
    """
    Detect potential batch effects in a dataset using eigenvalues of XX^T.

    Args:
    X (numpy.ndarray): A feature matrix with shape (n_samples, n_features).

    Returns:
    bool: True if a potential batch effect is detected, False otherwise.
    """
    n_samples = X.shape[0]

    # Computing XX^T
    XXt = np.dot(X, X.T)

    # Compute the eigenvalues of XX^T
    eigen_values = np.linalg.eigvalsh(XXt)  # Using eigvalsh since XX^T is symmetric
    eigen_values = sorted(eigen_values, reverse=True)

    # Check for large gaps in the eigenvalues
    for i in range(len(eigen_values) - 1):
        gap = eigen_values[i] - eigen_values[i + 1]
        if gap > 1 / n_samples:  # You may need to adjust this threshold
            return True

    return False

def normalize_data(X_train, X_test=None):
    """Compute the mean and standard deviation statistics of the training data, use them to normalize the training data,
    and optionally the test data"""
    mean = np.mean(X_train, axis=0)
    std = np.std(X_train, axis=0)

    # Handling columns with std = 0
    std_no_zero = np.where(std == 0, 1, std)

    # Normalize X_train
    X_train_normalized = (X_train - mean) / std_no_zero
    # Set normalized values to 0 where std was 0
    X_train_normalized[:, std == 0] = 0

    if X_test is not None:
        X_test_normalized = (X_test - mean) / std_no_zero
        X_test_normalized[:, std == 0] = 0
    else:
        X_test_normalized = None

    return X_train_normalized, X_test_normalized


class ResidualizationRegressor:
    def __init__(self, regression_model_constructor, params=None):
        if params is None:
            params = {}
        self.regression_model = regression_model_constructor(**params)
        self.beta_Z = None  # Coefficients for regression of Y on Z
        self.beta_X = None  # Coefficients for regression of residual on X
        self.neg_log_p_values = None  # Negative logarithm of p-values
        self.p_values = None  # Actual p-values

    def _reshape_data(self, data):
        """
        Reshape the data to ensure it's in the correct format (2D array).

        :param data: The input data (can be 1D or 2D array).
        :return: Reshaped 2D array.
        """
        if data.ndim == 1:
            return data.reshape(-1, 1)
        return data

    def _reshape_output(self, data):
        """
        Reshape the output data to ensure it's in the correct format (1D array).

        :param data: The output data (can be 1D or 2D array).
        :return: Reshaped 1D array.
        """
        if data.ndim == 2 and data.shape[1] == 1:
            return data.ravel()
        return data

    def fit(self, X, Y, Z):
        X = self._reshape_data(X)
        Y = self._reshape_data(Y)
        Z = self._reshape_data(Z)

        # Step 1: Linear regression of Y on Z
        Z_ones = np.column_stack((np.ones(Z.shape[0]), Z))
        self.beta_Z = np.linalg.pinv(Z_ones.T @ Z_ones) @ Z_ones.T @ Y
        Y_hat = Z_ones @ self.beta_Z
        e_Y = Y - Y_hat  # Residual of Y

        # Step 2: Regress the residual on X using the included regression model
        self.regression_model.fit(X, e_Y)

        # Obtain coefficients from the regression model
        if hasattr(self.regression_model, 'coef_'):
            self.beta_X = self.regression_model.coef_
        elif hasattr(self.regression_model, 'getBeta'):
            beta_output = self.regression_model.getBeta()
            self.beta_X = self._reshape_output(beta_output)

        # Obtain negative logarithm of p-values, if available
        if hasattr(self.regression_model, 'getNegLogP'):
            neg_log_p_output = self.regression_model.getNegLogP()
            if neg_log_p_output is not None:
                self.neg_log_p_values = self._reshape_output(neg_log_p_output)
                self.p_values = np.exp(-self.neg_log_p_values)
                # Concatenate the p-values of Z and X. The p-values of Z were not computed, mark with NaN.
                p_values_Z = np.full(Z.shape[1], np.nan)
                self.p_values = np.concatenate((p_values_Z, self.p_values))

    def predict(self, X, Z):
        X = self._reshape_data(X)
        Z = self._reshape_data(Z)

        Z_ones = np.column_stack((np.ones(Z.shape[0]), Z))
        ZX = np.column_stack((Z, X))
        combined_beta = np.concatenate((self.beta_Z[1:].ravel(), self.beta_X.ravel()))
        return ZX @ combined_beta + self.beta_Z[0]

    def get_coefficients(self):
        return np.concatenate((self.beta_Z[1:].ravel(), self.beta_X.ravel()))

    def get_p_values(self):
        return self.p_values

    def predict(self, X, Z):
        X = self._reshape_data(X)
        Z = self._reshape_data(Z)

        Z_ones = np.column_stack((np.ones(Z.shape[0]), Z))
        ZX = np.column_stack((Z, X))
        combined_beta = np.concatenate((self.beta_Z[1:].ravel(), self.beta_X.ravel()))
        return ZX @ combined_beta + self.beta_Z[0]

    def get_coefficients(self):
        return np.concatenate((self.beta_Z[1:].ravel(), self.beta_X.ravel()))

    def get_p_values(self):
        return self.p_values


def cross_validation(X, Y, Z, model_constructor, model_params, k=5, target_type='binary'):
    assert target_type in ['binary', 'continuous'], "The target type must be chosen from 'binary' or 'continuous'"
    indices = np.arange(X.shape[0])
    np.random.shuffle(indices)

    fold_size = len(X) // k
    performances = []

    for i in range(k):
        # Split data into train and test based on the current fold
        test_indices = indices[i * fold_size: (i + 1) * fold_size]
        train_indices = np.setdiff1d(indices, test_indices)

        X_train, X_test = X[train_indices], X[test_indices]
        Y_train, Y_test = Y[train_indices], Y[test_indices]
        Z_train, Z_test = Z[train_indices], Z[test_indices]

        normalized_X_train, normalized_X_test = normalize_data(X_train, X_test)
        normalized_Z_train, normalized_Z_test = normalize_data(Z_train, Z_test)

        # model = model_constructor(**model_params)
        model = ResidualizationRegressor(model_constructor, model_params)
        model.fit(normalized_X_train, Y_train, normalized_Z_train)
        predictions = model.predict(normalized_X_test, normalized_Z_test)

        if target_type == 'binary':
            predictions = (predictions > 0.5).astype(int)
            Y_test = (Y_test > 0.5).astype(int)
            performance = accuracy_score(Y_test, predictions)
        elif target_type == 'continuous':
            performance = mean_squared_error(Y_test, predictions)

        performances.append(performance)

    cv_mean = np.mean(performances)
    cv_std = np.std(performances)

    if target_type == 'binary':
        print(f'The cross-validation accuracy is {(cv_mean * 100):.2f}% ± {(cv_std * 100):.2f}%')
    else:
        print(f'The cross-validation MSE is {(cv_mean * 100):.2f}% ± {(cv_std * 100):.2f}%')

    return cv_mean, cv_std

def interpret_result(model: Any, feature_names: List[str], trait: str, condition: str,
                     threshold: float = 0.05, save_output: bool = True,
                     output_dir: str = './output', model_id: int = 1) -> None:
    """This function interprets and reports the result of a trained linear regression model, where the regressor
    consists of one variable about condition and multiple variables about genetic factors.
    The function extracts coefficients and p-values from the model, and identifies the significant genes based on
    p-values or non-zero coefficients, depending on the availability of p-values.

    Parameters:
    model (Any): The trained regression Model.
    feature_names (List[str]): A list of feature names corresponding to the model's coefficients.
    trait (str): The target trait of interest.
    condition (str): The specific condition to examine within the model.
    threshold (float): Significance level for p-value correction. Defaults to 0.05.
    save_output (bool): Flag to determine whether to save the output to a file. Defaults to True.
    output_dir (str): Directory path where output files are saved. Defaults to './output'.
    model_id (int): The index of the model, 1 or 2.

    Returns:
    None: This function does not return anything but prints and optionally saves the output.
    """
    coefficients = model.get_coefficients().reshape(-1).tolist()
    p_values = model.get_p_values()
    if p_values is None:
        regression_df = pd.DataFrame({
            'Variable': feature_names,
            'Coefficient': coefficients
        })
    else:
        regression_df = pd.DataFrame({
            'Variable': feature_names,
            'Coefficient': coefficients,
            'p_value': p_values.reshape(-1).tolist()
        })

    condition_effect = regression_df[regression_df['Variable'] == condition].iloc[0]

    print(f"Effect of the condition on the target variable:")
    print(f"Variable: {condition}")
    print(f"Coefficient: {condition_effect['Coefficient']:.4f}")
    gene_regression_df = regression_df[regression_df['Variable'] != condition]
    if p_values is None:
        gene_regression_df['Absolute Coefficient'] = gene_regression_df['Coefficient'].abs()
        significant_genes = gene_regression_df[gene_regression_df['Coefficient'] != 0]
        significant_genes_sorted = significant_genes.sort_values(by='Absolute Coefficient', ascending=False)
        print(
            f"Found {len(significant_genes_sorted)} genes with non-zero coefficients associated with the trait '{trait}' "
            f"conditional on the factor '{condition}'. These genes are identified as significant based on the regression model.")
    else:
        # Apply the Benjamini-Hochberg correction, to get the corrected p-values
        corrected_p_values = multipletests(gene_regression_df['p_value'], alpha=threshold, method='fdr_bh')[1]
        gene_regression_df.loc[:, 'corrected_p_value'] = corrected_p_values
        significant_genes = gene_regression_df.loc[gene_regression_df['corrected_p_value'] < threshold]
        significant_genes_sorted = significant_genes.sort_values('corrected_p_value')
        print(
            f"Found {len(significant_genes_sorted)} significant genes associated with the trait '{trait}' conditional on "
            f"the factor '{condition}', with corrected p-value < {threshold}:")

    print(significant_genes_sorted.to_string(index=False))

    # Optionally, save this to a CSV file
    if save_output:
        significant_genes_sorted.to_csv(
            os.path.join(output_dir, f'significant_genes_condition_{condition}_{model_id}.csv'), index=False)

# %%
# Set your preferred name
USER = "Jake"
# Set the data and output directories
DATA_ROOT = '/Users/jacob/Documents'
OUTPUT_ROOT = '/Users/jacob/Documents/Output'
TRAIT = 'Metabolic-Rate'

OUTPUT_DIR = os.path.join(OUTPUT_ROOT, USER, '-'.join(TRAIT.split()))
JSON_PATH = os.path.join(OUTPUT_DIR, "cohort_info.json")
if not os.path.exists(OUTPUT_DIR):
    os.makedirs(OUTPUT_DIR, exist_ok=True)

# Gene symbol normalization may take 1-2 minutes. You may set it to False for debugging.
NORMALIZE_GENE = True

# %% [markdown]
# 2. Data preprocessing and selection
#
# The GEO dataset

# %%
dataset = 'GEO'
trait_subdir = "Metabolic-Rate"

trait_path = os.path.join(DATA_ROOT, dataset, trait_subdir)
os.listdir(trait_path)
# Out:
# ['GSE101492',
#  'GSE102177',
#  'GSE106800',
#  'GSE122279',
#  'GSE141479',
#  'GSE151683',
#  'GSE83414',
#  'GSE89231']

# %%
cohort = accession_num = "GSE151683"
cohort_dir = os.path.join(trait_path, accession_num)
soft_file, matrix_file = get_relevant_filepaths(cohort_dir)
soft_file, matrix_file
# Out:
# ('/Users/jacob/Documents\\GEO\\Metabolic-Rate\\GSE151683\\GSE151683_family.soft.gz',
#  '/Users/jacob/Documents\\GEO\\Metabolic-Rate\\GSE151683\\GSE151683_series_matrix.txt.gz')

# %%
cohort = accession_num = "GSE89231"
cohort_dir = os.path.join(trait_path, accession_num)
soft_file, matrix_file = get_relevant_filepaths(cohort_dir)
soft_file, matrix_file
# Out:
# ('/Users/jacob/Documents\\GEO\\Metabolic-Rate\\GSE89231\\GSE89231_family.soft.gz',
#  '/Users/jacob/Documents\\GEO\\Metabolic-Rate\\GSE89231\\GSE89231_series_matrix.txt.gz')

# %%
cohort = accession_num = "GSE101492"
cohort_dir = os.path.join(trait_path, accession_num)
soft_file, matrix_file = get_relevant_filepaths(cohort_dir)
soft_file, matrix_file
# Out:
# ('/Users/jacob/Documents\\GEO\\Metabolic-Rate\\GSE101492\\GSE101492_family.soft.gz',
#  '/Users/jacob/Documents\\GEO\\Metabolic-Rate\\GSE101492\\GSE101492_series_matrix.txt.gz')

# %%
cohort = accession_num = "GSE106800"
cohort_dir = os.path.join(trait_path, accession_num)
soft_file, matrix_file = get_relevant_filepaths(cohort_dir)
soft_file, matrix_file
# Out:
# ('/Users/jacob/Documents\\GEO\\Metabolic-Rate\\GSE106800\\GSE106800_family.soft.gz',
#  '/Users/jacob/Documents\\GEO\\Metabolic-Rate\\GSE106800\\GSE106800_series_matrix.txt.gz')

# %%
cohort = accession_num = "GSE83414"
cohort_dir = os.path.join(trait_path, accession_num)
soft_file, matrix_file = get_relevant_filepaths(cohort_dir)
soft_file, matrix_file
# Out:
# ('/Users/jacob/Documents\\GEO\\Metabolic-Rate\\GSE83414\\GSE83414_family.soft.gz',
#  '/Users/jacob/Documents\\GEO\\Metabolic-Rate\\GSE83414\\GSE83414_series_matrix.txt.gz')

# %%
cohort = accession_num = "GSE102177"
cohort_dir = os.path.join(trait_path, accession_num)
soft_file, matrix_file = get_relevant_filepaths(cohort_dir)
soft_file, matrix_file
# Out:
# ('/Users/jacob/Documents\\GEO\\Metabolic-Rate\\GSE102177\\GSE102177_family.soft.gz',
#  '/Users/jacob/Documents\\GEO\\Metabolic-Rate\\GSE102177\\GSE102177_series_matrix.txt.gz')

# %%
cohort = accession_num = "GSE141479"
cohort_dir = os.path.join(trait_path, accession_num)
soft_file, matrix_file = get_relevant_filepaths(cohort_dir)
soft_file, matrix_file
# Out:
# ('/Users/jacob/Documents\\GEO\\Metabolic-Rate\\GSE141479\\GSE141479_family.soft.gz',
#  '/Users/jacob/Documents\\GEO\\Metabolic-Rate\\GSE141479\\GSE141479_series_matrix.txt.gz')

# %%
cohort = accession_num = "GSE122279"
cohort_dir = os.path.join(trait_path, accession_num)
soft_file, matrix_file = get_relevant_filepaths(cohort_dir)
soft_file, matrix_file
# Out:
# ('/Users/jacob/Documents\\GEO\\Metabolic-Rate\\GSE122279\\GSE122279_family.soft.gz',
#  '/Users/jacob/Documents\\GEO\\Metabolic-Rate\\GSE122279\\GSE122279_series_matrix.txt.gz')

# %%
background_prefixes = ['!Series_title', '!Series_summary', '!Series_overall_design']
clinical_prefixes = ['!Sample_geo_accession', '!Sample_characteristics_ch1']

background_info, clinical_data = get_background_and_clinical_data(matrix_file, background_prefixes, clinical_prefixes)
print(background_info)
# Out:
# !Series_title	"High-throughput mediation analysis of human proteome and metabolome identifies mediators of post-bariatric surgical diabetes control"
# !Series_summary	"To improve the power of mediation in high-throughput studies, here we introduce High-throughput mediation analysis (Hitman), which accounts for direction of mediation and applies empirical Bayesian linear modeling. We apply Hitman in a retrospective, exploratory analysis of the SLIMM-T2D clinical trial in which participants with type 2 diabetes were randomized to Roux-en-Y gastric bypass (RYGB) or nonsurgical diabetes/weight management, and fasting plasma proteome and metabolome were assayed up to 3 years. RYGB caused greater improvement in HbA1c, which was mediated by growth hormone receptor (GHR). GHRâ€™s mediation is more significant than clinical mediators, including BMI. GHR decreases at 3 months postoperatively alongside increased insulin-like growth factor binding proteins IGFBP1/BP2; plasma GH increased at 1 year. Experimental validation indicates (1) hepatic GHR expression decreases in post-bariatric rats; (2) GHR knockdown in primary hepatocytes decreases gluconeogenic gene expression and glucose production. Thus, RYGB may induce resistance to diabetogenic effects of GH signaling."
# !Series_overall_design	"Randomized controlled trial with n=19 assigned to RYGB or DWM, measured over time."
# !Series_overall_design	""
# !Series_overall_design	"Raw data were not provided by SomaLogic."

# %%
clinical_data.head()
# Out:
#          !Sample_geo_accession        GSM3463033        GSM3463034  \
# 0  !Sample_characteristics_ch1    tissue: plasma    tissue: plasma
# 1  !Sample_characteristics_ch1   acrostic: FENCE   acrostic: HUMOR
# 2  !Sample_characteristics_ch1       group: RYGB       group: RYGB
# 3  !Sample_characteristics_ch1  height (cm): 182  height (cm): 164
# 4  !Sample_characteristics_ch1            mo: 12            mo: 36
#
#          GSM3463035           GSM3463036          GSM3463037  \
# 0    tissue: plasma       tissue: plasma      tissue: plasma
# 1   acrostic: VIDEO      acrostic: RADIO     acrostic: ELBOW
# 2       group: RYGB           group: DWM          group: DWM
# 3  height (cm): 172  height (cm): 172.72  height (cm): 172.5
# 4             mo: 3               mo: 12              mo: 36
#
#            GSM3463038          GSM3463039        GSM3463040        GSM3463041  \
# 0      tissue: plasma      tissue: plasma    tissue: plasma    tissue: plasma
# 1     acrostic: HUMAN     acrostic: MAGIC   acrostic: DAISY   acrostic: VISTA
# 2          group: DWM         group: RYGB        group: DWM       group: RYGB
# 3  height (cm): 154.5  height (cm): 178.2  height (cm): 153  height (cm): 174
# 4               mo: 0              mo: 24             mo: 0             mo: 0
#
#    ...          GSM3463182          GSM3463183          GSM3463184  \
# 0  ...      tissue: plasma      tissue: plasma      tissue: plasma
# 1  ...     acrostic: LAKES     acrostic: SCOPE     acrostic: INTRO
# 2  ...         group: RYGB         group: RYGB          group: DWM
# 3  ...  height (cm): 155.5  height (cm): 190.5  height (cm): 154.1
# 4  ...              mo: 12              mo: 12               mo: 0
#
#          GSM3463185        GSM3463186          GSM3463187          GSM3463188  \
# 0    tissue: plasma    tissue: plasma      tissue: plasma      tissue: plasma
# 1   acrostic: VISTA   acrostic: QUART     acrostic: HUMAN     acrostic: POETS
# 2       group: RYGB       group: RYGB          group: DWM          group: DWM
# 3  height (cm): 174  height (cm): 173  height (cm): 154.5  height (cm): 161.5
# 4            mo: 24            mo: 12              mo: 24               mo: 0
#
#          GSM3463189        GSM3463190          GSM3463191
# 0    tissue: plasma    tissue: plasma      tissue: plasma
# 1   acrostic: REMIX   acrostic: VISTA     acrostic: POETS
# 2       group: RYGB       group: RYGB          group: DWM
# 3  height (cm): 162  height (cm): 174  height (cm): 161.5
# 4             mo: 0             mo: 3              mo: 24
#
# [5 rows x 160 columns]

# %%
clinical_data_unique = get_unique_values_by_row(clinical_data)
clinical_data_unique
# Out:
# {0: ['tissue: plasma'],
#  1: ['acrostic: FENCE',
#   'acrostic: HUMOR',
#   'acrostic: VIDEO',
#   'acrostic: RADIO',
#   'acrostic: ELBOW',
#   'acrostic: HUMAN',
#   'acrostic: MAGIC',
#   'acrostic: DAISY',
#   'acrostic: VISTA',
#   'acrostic: ORBIT',
#   'acrostic: RODEO',
#   'acrostic: NURSE',
#   'acrostic: RELIC',
#   'acrostic: EAGLE',
#   'acrostic: VENUE',
#   'acrostic: PATCH',
#   'acrostic: FLAGS',
#   'acrostic: POETS',
#   'acrostic: LILAC',
#   'acrostic: JUROR',
#   'acrostic: IVORY',
#   'acrostic: LASSO',
#   'acrostic: FOGGY',
#   'acrostic: REMIX',
#   'acrostic: IMAGE',
#   'acrostic: WALTZ',
#   'acrostic: FILMS',
#   'acrostic: TOPAZ',
#   'acrostic: INTRO',
#   'acrostic: KAYAK'],
#  2: ['group: RYGB', 'group: DWM'],
#  3: ['height (cm): 182',
#   'height (cm): 164',
#   'height (cm): 172',
#   'height (cm): 172.72',
#   'height (cm): 172.5',
#   'height (cm): 154.5',
#   'height (cm): 178.2',
#   'height (cm): 153',
#   'height (cm): 174',
#   'height (cm): 177',
#   'height (cm): 180',
#   'height (cm): 159.5',
#   'height (cm): 183',
#   'height (cm): 170',
#   'height (cm): 178',
#   'height (cm): 155.6',
#   'height (cm): 167.5',
#   'height (cm): 161.5',
#   'height (cm): 176',
#   'height (cm): 156.5',
#   'height (cm): 185.42',
#   'height (cm): 162',
#   'height (cm): 155',
#   'height (cm): 166.5',
#   'height (cm): 155.2',
#   'height (cm): 169',
#   'height (cm): 154.1',
#   'height (cm): 167',
#   'height (cm): 190.5',
#   'height (cm): 173'],
#  4: ['mo: 12', 'mo: 36', 'mo: 3', 'mo: 0', 'mo: 24'],
#  5: ['albumin/creatinine ratio: 0',
#   'albumin/creatinine ratio: 4',
#   'dbp (mmhg): 77.5',
#   'albumin/creatinine ratio: 8',
#   'albumin/creatinine ratio: 7',
#   'albumin/creatinine ratio: 114',
#   'dbp (mmhg): 76.5',
#   'albumin/creatinine ratio: 9',
#   'albumin/creatinine ratio: 2',
#   'albumin/creatinine ratio: 50',
#   'dbp (mmhg): 81',
#   'albumin/creatinine ratio: 178',
#   'albumin/creatinine ratio: 51',
#   'albumin/creatinine ratio: 6',
#   'dbp (mmhg): 71',
#   'dbp (mmhg): 80.5',
#   'dbp (mmhg): 73.5',
#   'albumin/creatinine ratio: 14',
#   'dbp (mmhg): 78',
#   'albumin/creatinine ratio: 5',
#   'dbp (mmhg): 67.5',
#   'dbp (mmhg): 82.66666',
#   'albumin/creatinine ratio: 12',
#   'albumin/creatinine ratio: 104',
#   'albumin/creatinine ratio: 63',
#   'dbp (mmhg): 80',
#   'dbp (mmhg): 71.66666',
#   'dbp (mmhg): 77.66666',
#   'albumin/creatinine ratio: 3',
#   'dbp (mmhg): 66.33334'],
#  6: ['dbp (mmhg): 70',
#   'dbp (mmhg): 87.5',
#   'sbp (mmhg): 122.5',
#   'dbp (mmhg): 78.5',
#   'dbp (mmhg): 86.33334',
#   'dbp (mmhg): 66',
#   'dbp (mmhg): 69',
#   'dbp (mmhg): 82',
#   'dbp (mmhg): 84',
#   'dbp (mmhg): 75.5',
#   'dbp (mmhg): 83.5',
#   'dbp (mmhg): 88.5',
#   'dbp (mmhg): 79.5',
#   'dbp (mmhg): 75',
#   'dbp (mmhg): 68.5',
#   'dbp (mmhg): 83',
#   'dbp (mmhg): 65',
#   'dbp (mmhg): 80.66666',
#   'dbp (mmhg): 59',
#   'dbp (mmhg): 62',
#   'sbp (mmhg): 142.5',
#   'sbp (mmhg): 127.5',
#   'sbp (mmhg): 114',
#   'dbp (mmhg): 77.33334',
#   'dbp (mmhg): 59.5',
#   'sbp (mmhg): 118',
#   'dbp (mmhg): 89.5',
#   'sbp (mmhg): 97',
#   'sbp (mmhg): 140.3333',
#   'dbp (mmhg): 79.33333'],
#  7: ['sbp (mmhg): 111',
#   'sbp (mmhg): 118.5',
#   'waist (cm): 110.5',
#   'sbp (mmhg): 130',
#   'sbp (mmhg): 126',
#   'sbp (mmhg): 99.5',
#   'sbp (mmhg): 105',
#   'sbp (mmhg): 127',
#   'sbp (mmhg): 113.5',
#   'sbp (mmhg): 152.5',
#   'waist (cm): 130.5',
#   'sbp (mmhg): 117',
#   'sbp (mmhg): 140',
#   'sbp (mmhg): 116',
#   'sbp (mmhg): 110',
#   'sbp (mmhg): 128.5',
#   'sbp (mmhg): 144',
#   'waist (cm): 92',
#   'sbp (mmhg): 106.5',
#   'sbp (mmhg): 140.6667',
#   'sbp (mmhg): 119',
#   'sbp (mmhg): 114.5',
#   'sbp (mmhg): 118',
#   'sbp (mmhg): 121',
#   'sbp (mmhg): 119.6667',
#   'waist (cm): 120.1',
#   'waist (cm): 118',
#   'sbp (mmhg): 143',
#   'waist (cm): 113.5',
#   'sbp (mmhg): 148'],
#  8: ['serum creatinine (mg/dl): 0.64',
#   'serum creatinine (mg/dl): 1.22',
#   'weight (kg): 109.6818',
#   'serum creatinine (mg/dl): 0.65',
#   'serum creatinine (mg/dl): 1.06',
#   'serum creatinine (mg/dl): 0.68',
#   'serum creatinine (mg/dl): 0.86',
#   'serum creatinine (mg/dl): 0.54',
#   'serum creatinine (mg/dl): 0.82',
#   'weight (kg): 119.1818',
#   'serum creatinine (mg/dl): 0.57',
#   'serum creatinine (mg/dl): 0.85',
#   'serum creatinine (mg/dl): 0.75',
#   'serum creatinine (mg/dl): 0.93',
#   'serum creatinine (mg/dl): 0.56',
#   'serum creatinine (mg/dl): 0.77',
#   'weight (kg): 76.18182',
#   'serum creatinine (mg/dl): 0.97',
#   'serum creatinine (mg/dl): 0.81',
#   'serum creatinine (mg/dl): 0.73',
#   'serum creatinine (mg/dl): 0.52',
#   'weight (kg): 112.9545',
#   'weight (kg): 123.2273',
#   'serum creatinine (mg/dl): 0.66',
#   'weight (kg): 108.1591',
#   'serum creatinine (mg/dl): 0.55',
#   'weight (kg): 78.72727',
#   'serum creatinine (mg/dl): 0.71',
#   'weight (kg): 84.68182',
#   'weight (kg): 108.9545'],
#  9: ['waist (cm): 90.5',
#   'waist (cm): 96.85',
#   'bmi: 37.0747025419145',
#   'waist (cm): 103.8',
#   'waist (cm): 103.1',
#   'waist (cm): 115.2',
#   'waist (cm): 91.6',
#   'waist (cm): 95.8',
#   'waist (cm): 110',
#   'waist (cm): 135.2',
#   'bmi: 36.7845061728395',
#   'waist (cm): 125.2',
#   'waist (cm): 101.5',
#   'waist (cm): 99.5',
#   'waist (cm): 120',
#   'waist (cm): 97.5',
#   'waist (cm): 117',
#   'bmi: 27.1532439296057',
#   'waist (cm): 97.9',
#   'waist (cm): 100',
#   'waist (cm): 96.9',
#   'waist (cm): 84.2',
#   'waist (cm): 117.9',
#   'waist (cm): 98.75',
#   'waist (cm): 93',
#   'bmi: 39.0846020761246',
#   'bmi: 35.8421274170377',
#   'bmi: 32.2969034608379',
#   'waist (cm): 73.5',
#   'waist (cm): 87'],
#  10: ['weight (kg): 92.84091',
#   'weight (kg): 67.86364',
#   'basal metabolic rate: 7453',
#   'weight (kg): 103.7273',
#   'weight (kg): 97.4091',
#   'weight (kg): 87.31818',
#   'weight (kg): 89.45454',
#   'weight (kg): 75',
#   'weight (kg): 112.4091',
#   'weight (kg): 131.3182',
#   'basal metabolic rate: 9408',
#   'weight (kg): 105.5',
#   'weight (kg): 95.54546',
#   'weight (kg): 71.63637',
#   'weight (kg): 106.7273',
#   'weight (kg): 86.13636',
#   'weight (kg): 100.7273',
#   'basal metabolic rate: 5945',
#   'weight (kg): 80.40909',
#   'weight (kg): 96.38637',
#   'weight (kg): 92.18182',
#   'weight (kg): 72.52273',
#   'weight (kg): 91.31818',
#   'weight (kg): 83.81818',
#   'weight (kg): 85.90909',
#   'basal metabolic rate: 8559',
#   'basal metabolic rate: 9617',
#   'weight (kg): 76.81818',
#   'basal metabolic rate: 8902',
#   'weight (kg): 47'],
#  11: ['bmi: 28.0282906653786',
#   'bmi: 25.2318709101725',
#   'body fat (%): 49.2',
#   'bmi: 34.770250120085',
#   'bmi: 32.735677378702',
#   'bmi: 36.5803374493355',
#   'bmi: 28.1700091071584',
#   'bmi: 32.0389593745995',
#   'bmi: 37.1281212841855',
#   'bmi: 41.9158607041399',
#   'body fat (%): 38.1',
#   'bmi: 41.4697182614165',
#   'bmi: 28.530401027203',
#   'bmi: 26.6345813503867',
#   'bmi: 36.9298615916955',
#   'bmi: 27.1860749905315',
#   'bmi: 41.6033217464859',
#   'body fat (%): 39.3',
#   'bmi: 30.8290465738194',
#   'bmi: 28.7815013885156',
#   'bmi: 29.0288531908435',
#   'bmi: 23.4125548811983',
#   'bmi: 37.2845206136635',
#   'bmi: 26.4544186340109',
#   'bmi: 29.7263287197232',
#   'body fat (%): 41.8',
#   'body fat (%): 33.2',
#   'bmi: 29.2707590306356',
#   'body fat (%): 35.4',
#   'bmi: 19.5629552549428'],
#  12: ['basal metabolic rate: 7760',
#   'basal metabolic rate: 5465',
#   'fat mass (lb): 116.6',
#   'basal metabolic rate: 7162',
#   'basal metabolic rate: 7847',
#   'basal metabolic rate: 6299',
#   'basal metabolic rate: 7556',
#   'basal metabolic rate: 5881',
#   'basal metabolic rate: 7830',
#   'basal metabolic rate: 9797',
#   'fat mass (lb): 98.2',
#   'basal metabolic rate: 7130',
#   'basal metabolic rate: 8075',
#   'basal metabolic rate: 5680',
#   'basal metabolic rate: 8572',
#   'basal metabolic rate: 7104',
#   'basal metabolic rate: 7174',
#   'fat mass (lb): 64.2',
#   'basal metabolic rate: 5975',
#   'basal metabolic rate: 8198',
#   'basal metabolic rate: 7671',
#   'basal metabolic rate: 5731',
#   'basal metabolic rate: 6399',
#   'basal metabolic rate: 6911',
#   'basal metabolic rate: 6329',
#   'fat mass (lb): 102.2',
#   'fat mass (lb): 88.8',
#   'basal metabolic rate: 5890',
#   'fat mass (lb): 82.6',
#   'basal metabolic rate: 4428'],
#  13: ['body fat (%): 18.7',
#   'body fat (%): 35.8',
#   'fat free mass (lb): 120.4',
#   'body fat (%): 43.9',
#   'body fat (%): 27',
#   'body fat (%): 46.5',
#   'body fat (%): 18.6',
#   'body fat (%): 38.5',
#   'body fat (%): 46.6',
#   'body fat (%): 43.8',
#   'fat free mass (lb): 159.6',
#   'body fat (%): 51.5',
#   'body fat (%): 32.2',
#   'body fat (%): 35.6',
#   'body fat (%): 39.6',
#   'body fat (%): 29.4',
#   'body fat (%): 48.4',
#   'fat free mass (lb): 99.2',
#   'body fat (%): 43.3',
#   'body fat (%): 25.1',
#   'body fat (%): 34.1',
#   'body fat (%): 45.4',
#   'body fat (%): 27.2',
#   'body fat (%): 42.4',
#   'fat free mass (lb): 142.2',
#   'fat free mass (lb): 178.8',
#   'body fat (%): 41.2',
#   'fat free mass (lb): 151',
#   'body fat (%): 23.3',
#   'body fat (%): 32.8'],
#  14: ['fat mass (lb): 37.4',
#   'fat mass (lb): 52.01',
#   '6 min walk test distance (m): 335.5',
#   'fat mass (lb): 98.2',
#   'fat mass (lb): 56.6',
#   'fat mass (lb): 87.6',
#   'fat mass (lb): 35.8',
#   'fat mass (lb): 61.8',
#   'fat mass (lb): 113.2',
#   'fat mass (lb): 124.2',
#   '6 min walk test distance (m): 432.93',
#   'fat mass (lb): 115.21',
#   'fat mass (lb): 66.4',
#   'fat mass (lb): 54.6',
#   'fat mass (lb): 92.2',
#   'fat mass (lb): 108.2',
#   '6 min walk test distance (m): 488.2',
#   'fat mass (lb): 75',
#   'fat mass (lb): 52.2',
#   'fat mass (lb): 37.01',
#   'fat mass (lb): 53',
#   'fat mass (lb): 89.8',
#   'fat mass (lb): 49',
#   'fat mass (lb): 78.8',
#   '6 min walk test distance (m): 443.8',
#   '6 min walk test distance (m): 469',
#   'fat mass (lb): 67.8',
#   '6 min walk test distance (m): 458.37',
#   'fat mass (lb): 23.01',
#   'fat mass (lb): 55.6'],
#  15: ['fat free mass (lb): 162.4',
#   'fat free mass (lb): 93.01',
#   '6 min walk test heart rate (beats/min): 99',
#   'fat free mass (lb): 125.6',
#   'fat free mass (lb): 153.2',
#   'fat free mass (lb): 100.81',
#   'fat free mass (lb): 157',
#   'fat free mass (lb): 98.6',
#   'fat free mass (lb): 129.8',
#   'fat free mass (lb): 159.2',
#   '6 min walk test heart rate (beats/min): 102',
#   'fat free mass (lb): 108.41',
#   'fat free mass (lb): 139.8',
#   'fat free mass (lb): 98.8',
#   'fat free mass (lb): 140.6',
#   'fat free mass (lb): 130.8',
#   'fat free mass (lb): 115.2',
#   '6 min walk test heart rate (beats/min): 100',
#   'fat free mass (lb): 98',
#   'fat free mass (lb): 155.8',
#   'fat free mass (lb): 161.4',
#   'fat free mass (lb): 102.2',
#   'fat free mass (lb): 107.8',
#   'fat free mass (lb): 131',
#   'fat free mass (lb): 107',
#   '6 min walk test heart rate (beats/min): 92',
#   'fat free mass (lb): 96.8',
#   '6 min walk test heart rate (beats/min): 86',
#   'fat free mass (lb): 76.01',
#   'fat free mass (lb): 114'],
#  16: ['6 min walk test distance (m): 416.55',
#   '6 min walk test distance (m): 444.28',
#   'hba1c: 7.7',
#   '6 min walk test distance (m): 406.4',
#   '6 min walk test distance (m): 560.3',
#   '6 min walk test distance (m): 363.55',
#   '6 min walk test distance (m): 531.89',
#   '6 min walk test distance (m): 427',
#   '6 min walk test distance (m): 454.7',
#   '6 min walk test distance (m): 498.6',
#   'hba1c: 6.7',
#   '6 min walk test distance (m): 421.71',
#   '6 min walk test distance (m): 621.09',
#   '6 min walk test distance (m): 535.2',
#   '6 min walk test distance (m): 521.2',
#   '6 min walk test distance (m): 517.99',
#   '6 min walk test distance (m): 446.5',
#   'hba1c: 6.2',
#   '6 min walk test distance (m): 546.9',
#   '6 min walk test distance (m): 550.8',
#   '6 min walk test distance (m): 488.64',
#   '6 min walk test distance (m): 528.16',
#   '6 min walk test distance (m): 443.7',
#   '6 min walk test distance (m): 607.59',
#   '6 min walk test distance (m): 606.39',
#   'hba1c: 9.4',
#   'hba1c: 6.9',
#   'hba1c: 6.4',
#   '6 min walk test distance (m): 404.71',
#   '6 min walk test distance (m): 399.2'],
#  17: ['6 min walk test heart rate (beats/min): 113',
#   '6 min walk test heart rate (beats/min): 102',
#   'alt (iu/l): 23',
#   '6 min walk test heart rate (beats/min): 122',
#   '6 min walk test heart rate (beats/min): 95',
#   '6 min walk test heart rate (beats/min): 92',
#   '6 min walk test heart rate (beats/min): 108',
#   '6 min walk test heart rate (beats/min): 110',
#   '6 min walk test heart rate (beats/min): 120',
#   'alt (iu/l): 45',
#   '6 min walk test heart rate (beats/min): 155',
#   '6 min walk test heart rate (beats/min): 101',
#   '6 min walk test heart rate (beats/min): 107',
#   '6 min walk test heart rate (beats/min): 82',
#   '6 min walk test heart rate (beats/min): 145',
#   'alt (iu/l): 6',
#   '6 min walk test heart rate (beats/min): 87',
#   '6 min walk test heart rate (beats/min): 79',
#   '6 min walk test heart rate (beats/min): 78',
#   '6 min walk test heart rate (beats/min): 83',
#   '6 min walk test heart rate (beats/min): 115',
#   'alt (iu/l): 25',
#   'alt (iu/l): 32',
#   'alt (iu/l): 8',
#   'alt (iu/l): 13',
#   '6 min walk test heart rate (beats/min): 91',
#   '6 min walk test heart rate (beats/min): 85',
#   'alt (iu/l): 24',
#   '6 min walk test heart rate (beats/min): 100',
#   'alt (iu/l): 30'],
#  18: ['hba1c: 6.1',
#   'ast (iu/l): 21',
#   'hba1c: 6.4',
#   'hba1c: 9.6',
#   'hba1c: 7.8',
#   'hba1c: 6.9',
#   'hba1c: 7.7',
#   'hba1c: 9.4',
#   'ast (iu/l): 34',
#   'hba1c: 9.2',
#   'hba1c: 6',
#   'hba1c: 10.2',
#   'hba1c: 6.6',
#   'hba1c: 9.1',
#   'ast (iu/l): 19',
#   'hba1c: 7.2',
#   'hba1c: 5.7',
#   'hba1c: 7.3',
#   'hba1c: 5.8',
#   'hba1c: 6.3',
#   'hba1c: 6.8',
#   'hba1c: 7.9',
#   'ast (iu/l): 27',
#   'ast (iu/l): 59',
#   'ast (iu/l): 14',
#   'ast (iu/l): 18',
#   'hba1c: 5.9',
#   'ast (iu/l): 16',
#   'ast (iu/l): 13',
#   'hba1c: 13.3'],
#  19: ['alt (iu/l): 15',
#   'alt (iu/l): 11',
#   'hematocrit (%): 34.3',
#   'alt (iu/l): 17',
#   'alt (iu/l): 16',
#   'alt (iu/l): 42',
#   'alt (iu/l): 21',
#   'alt (iu/l): 25',
#   'alt (iu/l): 79',
#   'alt (iu/l): 54',
#   'hematocrit (%): 41.8',
#   'alt (iu/l): 51',
#   'alt (iu/l): 13',
#   'alt (iu/l): 26',
#   'alt (iu/l): 34',
#   'hematocrit (%): 30.9',
#   'alt (iu/l): 18',
#   'alt (iu/l): 9',
#   'fasting plasma glucose (mg/dl): 216',
#   'hematocrit (%): 38.3',
#   'hematocrit (%): 32.7',
#   'alt (iu/l): 12',
#   'alt (iu/l): 22',
#   'hematocrit (%): 39.9',
#   'alt (iu/l): 33',
#   'hematocrit (%): 39.2',
#   'hematocrit (%): 37.4',
#   'alt (iu/l): 27',
#   'alt (iu/l): 8',
#   'alt (iu/l): 28'],
#  20: ['ast (iu/l): 17',
#   'ast (iu/l): 15',
#   'white blood count (10^6 / ml): 6.3',
#   'ast (iu/l): 19',
#   'ast (iu/l): 35',
#   'ast (iu/l): 88',
#   'ast (iu/l): 33',
#   'white blood count (10^6 / ml): 4.2',
#   'ast (iu/l): 71',
#   'ast (iu/l): 16',
#   'ast (iu/l): 22',
#   'hematocrit (%): 32.5',
#   'white blood count (10^6 / ml): 4.3',
#   'hematocrit (%): 37.6',
#   'ast (iu/l): 20',
#   'ast (iu/l): 21',
#   'ast (iu/l): 11',
#   'total cholesterol (mg/dl): 139',
#   'white blood count (10^6 / ml): 3.8',
#   'white blood count (10^6 / ml): 6.4',
#   'white blood count (10^6 / ml): 5.2',
#   'ast (iu/l): 26',
#   'ast (iu/l): 24',
#   'white blood count (10^6 / ml): 6.5',
#   'white blood count (10^6 / ml): 9.9',
#   'ast (iu/l): 31',
#   'ast (iu/l): 13',
#   'ast (iu/l): 34',
#   'ast (iu/l): 23',
#   'white blood count (10^6 / ml): 3.4'],
#  21: ['hematocrit (%): 39.8',
#   'hematocrit (%): 33.7',
#   'fasting plasma glucose (mg/dl): 99',
#   'hematocrit (%): 36.5',
#   'hematocrit (%): 44.9',
#   'hematocrit (%): 40.8',
#   'hematocrit (%): 34.5',
#   'hematocrit (%): 37.2',
#   'hematocrit (%): 38.8',
#   'hematocrit (%): 43.1',
#   'fasting plasma glucose (mg/dl): 141',
#   'hematocrit (%): 41.4',
#   'hematocrit (%): 37.1',
#   'hematocrit (%): 34.6',
#   'hematocrit (%): 41.3',
#   'hematocrit (%): 38.9',
#   'white blood count (10^6 / ml): 6.3',
#   'fasting plasma glucose (mg/dl): 94',
#   'hematocrit (%): 42.2',
#   'white blood count (10^6 / ml): 5.5',
#   'hematocrit (%): 32.9',
#   'hematocrit (%): 37.8',
#   'hematocrit (%): 38.6',
#   'hematocrit (%): 32.2',
#   'hematocrit (%): 40.4',
#   'ldl cholesterol (mg/dl): 62',
#   'fasting plasma glucose (mg/dl): 84',
#   'fasting plasma glucose (mg/dl): 92',
#   'fasting plasma glucose (mg/dl): 91',
#   'fasting plasma glucose (mg/dl): 137'],
#  22: ['white blood count (10^6 / ml): 5.6',
#   'white blood count (10^6 / ml): 6.8',
#   'total cholesterol (mg/dl): 134',
#   'white blood count (10^6 / ml): 5.5',
#   'white blood count (10^6 / ml): 5',
#   'white blood count (10^6 / ml): 7.5',
#   'white blood count (10^6 / ml): 3.9',
#   'white blood count (10^6 / ml): 3.4',
#   'white blood count (10^6 / ml): 3.6',
#   'white blood count (10^6 / ml): 6.9',
#   'total cholesterol (mg/dl): 95',
#   'white blood count (10^6 / ml): 11.3',
#   'white blood count (10^6 / ml): 7.8',
#   'white blood count (10^6 / ml): 6.4',
#   'fasting plasma glucose (mg/dl): 154',
#   'total cholesterol (mg/dl): 171',
#   'fasting plasma glucose (mg/dl): 97',
#   'white blood count (10^6 / ml): 4.1',
#   'white blood count (10^6 / ml): 4.3',
#   'white blood count (10^6 / ml): 10',
#   'hdl cholesterol (mg/dl): 50',
#   'total cholesterol (mg/dl): 162',
#   'total cholesterol (mg/dl): 141',
#   'total cholesterol (mg/dl): 113',
#   'white blood count (10^6 / ml): 7.3',
#   'white blood count (10^6 / ml): 5.7',
#   'total cholesterol (mg/dl): 110',
#   'white blood count (10^6 / ml): 8.4',
#   'total cholesterol (mg/dl): 236',
#   'white blood count (10^6 / ml): 8.1'],
#  23: ['fasting plasma glucose (mg/dl): 96',
#   'fasting plasma glucose (mg/dl): 86',
#   'ldl cholesterol (mg/dl): 91',
#   'fasting plasma glucose (mg/dl): 130',
#   'fasting plasma glucose (mg/dl): 103',
#   'fasting plasma glucose (mg/dl): 137',
#   'fasting plasma glucose (mg/dl): 128',
#   'fasting plasma glucose (mg/dl): 157',
#   'fasting plasma glucose (mg/dl): 171',
#   'fasting plasma glucose (mg/dl): 202',
#   'ldl cholesterol (mg/dl): 52',
#   'fasting plasma glucose (mg/dl): 144',
#   'fasting plasma glucose (mg/dl): 102',
#   'fasting plasma glucose (mg/dl): 91',
#   'fasting plasma glucose (mg/dl): 231',
#   'fasting plasma glucose (mg/dl): 78',
#   'total cholesterol (mg/dl): 213',
#   'ldl cholesterol (mg/dl): 115',
#   'fasting plasma glucose (mg/dl): 131',
#   'total cholesterol (mg/dl): 174',
#   'fasting plasma glucose (mg/dl): 132',
#   'fasting plasma glucose (mg/dl): 89',
#   'fasting plasma glucose (mg/dl): 170',
#   'triglycerides (mg/dl): 134',
#   'ldl cholesterol (mg/dl): 103',
#   'ldl cholesterol (mg/dl): 62',
#   'ldl cholesterol (mg/dl): 48',
#   'fasting plasma glucose (mg/dl): 101',
#   'fasting plasma glucose (mg/dl): 65',
#   'ldl cholesterol (mg/dl): 56'],
#  24: ['total cholesterol (mg/dl): 136',
#   'total cholesterol (mg/dl): 172',
#   'hdl cholesterol (mg/dl): 33',
#   'total cholesterol (mg/dl): 113',
#   'total cholesterol (mg/dl): 196',
#   'total cholesterol (mg/dl): 166',
#   'total cholesterol (mg/dl): 176',
#   'total cholesterol (mg/dl): 198',
#   'hdl cholesterol (mg/dl): 24',
#   'total cholesterol (mg/dl): 189',
#   'total cholesterol (mg/dl): 134',
#   'total cholesterol (mg/dl): 167',
#   'total cholesterol (mg/dl): 102',
#   'ldl cholesterol (mg/dl): 126',
#   'hdl cholesterol (mg/dl): 36',
#   'total cholesterol (mg/dl): 260',
#   'ldl cholesterol (mg/dl): 110',
#   'total cholesterol (mg/dl): 121',
#   'total cholesterol (mg/dl): 173',
#   'total cholesterol (mg/dl): 300',
#   'total cholesterol (mg/dl): 150',
#   'mttg0: meal tolerance test glucose time 0 min (mg/dl): 216',
#   'hdl cholesterol (mg/dl): 44',
#   'hdl cholesterol (mg/dl): 60',
#   'hdl cholesterol (mg/dl): 40',
#   'total cholesterol (mg/dl): 160',
#   'hdl cholesterol (mg/dl): 38',
#   'hdl cholesterol (mg/dl): 51',
#   'total cholesterol (mg/dl): 293',
#   'total cholesterol (mg/dl): 194'],
#  25: ['ldl cholesterol (mg/dl): 88',
#   'ldl cholesterol (mg/dl): 94',
#   'triglycerides (mg/dl): 50',
#   'ldl cholesterol (mg/dl): 69',
#   'ldl cholesterol (mg/dl): 56',
#   'ldl cholesterol (mg/dl): 110',
#   'ldl cholesterol (mg/dl): 103',
#   'ldl cholesterol (mg/dl): 117',
#   'ldl cholesterol (mg/dl): 128',
#   'ldl cholesterol (mg/dl): 84',
#   'triglycerides (mg/dl): 94',
#   'ldl cholesterol (mg/dl): 115',
#   'ldl cholesterol (mg/dl): 72',
#   'ldl cholesterol (mg/dl): 93',
#   'ldl cholesterol (mg/dl): 76',
#   'ldl cholesterol (mg/dl): 41',
#   'hdl cholesterol (mg/dl): 51',
#   'triglycerides (mg/dl): 100',
#   'ldl cholesterol (mg/dl): 186',
#   'hdl cholesterol (mg/dl): 45',
#   'ldl cholesterol (mg/dl): 59',
#   'ldl cholesterol (mg/dl): 216',
#   'ldl cholesterol (mg/dl): 67',
#   'ldl cholesterol (mg/dl): 73',
#   'mttg15: meal tolerance test glucose time 15 min (mg/dl): 235',
#   'triglycerides (mg/dl): 74',
#   'triglycerides (mg/dl): 96',
#   'triglycerides (mg/dl): 127',
#   'ldl cholesterol (mg/dl): 90',
#   'triglycerides (mg/dl): 80'],
#  26: ['hdl cholesterol (mg/dl): 27',
#   'hdl cholesterol (mg/dl): 52',
#   'mttg0: meal tolerance test glucose time 0 min (mg/dl): 99',
#   'hdl cholesterol (mg/dl): 54',
#   'hdl cholesterol (mg/dl): 25',
#   'hdl cholesterol (mg/dl): 34',
#   'hdl cholesterol (mg/dl): 47',
#   'hdl cholesterol (mg/dl): 45',
#   'hdl cholesterol (mg/dl): 48',
#   'hdl cholesterol (mg/dl): 39',
#   'mttg0: meal tolerance test glucose time 0 min (mg/dl): 141',
#   'hdl cholesterol (mg/dl): 43',
#   'hdl cholesterol (mg/dl): 33',
#   'hdl cholesterol (mg/dl): 49',
#   'triglycerides (mg/dl): 179',
#   'mttg0: meal tolerance test glucose time 0 min (mg/dl): 94',
#   'hdl cholesterol (mg/dl): 58',
#   'triglycerides (mg/dl): 93',
#   'hdl cholesterol (mg/dl): 50',
#   'hdl cholesterol (mg/dl): 67',
#   'hdl cholesterol (mg/dl): 40',
#   'hdl cholesterol (mg/dl): 57',
#   'mttg30: meal tolerance test glucose time 30 min (mg/dl): 271',
#   'mttg0: meal tolerance test glucose time 0 min (mg/dl): 84',
#   'dmcure: FPG < 126 and HbA1c < 6.5 (0 = no; 1 = yes; 9 = missing): 1',
#   'mttg0: meal tolerance test glucose time 0 min (mg/dl): 91',
#   'hdl cholesterol (mg/dl): 59',
#   'mttg0: meal tolerance test glucose time 0 min (mg/dl): 137',
#   'mttg0: meal tolerance test glucose time 0 min (mg/dl): 97',
#   'mttg0: meal tolerance test glucose time 0 min (mg/dl): 171'],
#  27: ['triglycerides (mg/dl): 103',
#   'triglycerides (mg/dl): 131',
#   'mttg15: meal tolerance test glucose time 15 min (mg/dl): 151',
#   'triglycerides (mg/dl): 66',
#   'triglycerides (mg/dl): 159',
#   'triglycerides (mg/dl): 261',
#   'triglycerides (mg/dl): 81',
#   'triglycerides (mg/dl): 70',
#   'triglycerides (mg/dl): 111',
#   'triglycerides (mg/dl): 245',
#   'mttg15: meal tolerance test glucose time 15 min (mg/dl): 161',
#   'triglycerides (mg/dl): 202',
#   'triglycerides (mg/dl): 95',
#   'triglycerides (mg/dl): 145',
#   'triglycerides (mg/dl): 288',
#   'triglycerides (mg/dl): 59',
#   'mttg0: meal tolerance test glucose time 0 min (mg/dl): 154',
#   'mttg15: meal tolerance test glucose time 15 min (mg/dl): 167',
#   'mttg0: meal tolerance test glucose time 0 min (mg/dl): 97',
#   'triglycerides (mg/dl): 89',
#   'triglycerides (mg/dl): 220',
#   'triglycerides (mg/dl): 87',
#   'triglycerides (mg/dl): 100',
#   'mttg60: meal tolerance test glucose time 60 min (mg/dl): 289',
#   'mttg15: meal tolerance test glucose time 15 min (mg/dl): 98',
#   nan,
#   'mttg15: meal tolerance test glucose time 15 min (mg/dl): 180',
#   'triglycerides (mg/dl): 125',
#   'triglycerides (mg/dl): 37',
#   'mttg15: meal tolerance test glucose time 15 min (mg/dl): 143'],
#  28: ['mttg0: meal tolerance test glucose time 0 min (mg/dl): 96',
#   'dmcure: FPG < 126 and HbA1c < 6.5 (0 = no; 1 = yes; 9 = missing): 1',
#   'mttg30: meal tolerance test glucose time 30 min (mg/dl): 149',
#   'mttg0: meal tolerance test glucose time 0 min (mg/dl): 130',
#   'dmcure: FPG < 126 and HbA1c < 6.5 (0 = no; 1 = yes; 9 = missing): 0',
#   'mttg0: meal tolerance test glucose time 0 min (mg/dl): 137',
#   'mttg0: meal tolerance test glucose time 0 min (mg/dl): 157',
#   'mttg0: meal tolerance test glucose time 0 min (mg/dl): 171',
#   'mttg0: meal tolerance test glucose time 0 min (mg/dl): 202',
#   'mttg30: meal tolerance test glucose time 30 min (mg/dl): 185',
#   'mttg0: meal tolerance test glucose time 0 min (mg/dl): 144',
#   'mttg0: meal tolerance test glucose time 0 min (mg/dl): 91',
#   'mttg0: meal tolerance test glucose time 0 min (mg/dl): 231',
#   'mttg0: meal tolerance test glucose time 0 min (mg/dl): 78',
#   'mttg15: meal tolerance test glucose time 15 min (mg/dl): 140',
#   'mttg30: meal tolerance test glucose time 30 min (mg/dl): 181',
#   'mttg0: meal tolerance test glucose time 0 min (mg/dl): 131',
#   'mttg15: meal tolerance test glucose time 15 min (mg/dl): 189',
#   'mttg0: meal tolerance test glucose time 0 min (mg/dl): 89',
#   'mttg120: meal tolerance test glucose time 120 min (mg/dl): 259',
#   'mttg30: meal tolerance test glucose time 30 min (mg/dl): 121',
#   nan,
#   'mttg30: meal tolerance test glucose time 30 min (mg/dl): 186',
#   'mttg0: meal tolerance test glucose time 0 min (mg/dl): 65',
#   'mttg30: meal tolerance test glucose time 30 min (mg/dl): 199',
#   'mttg0: meal tolerance test glucose time 0 min (mg/dl): 60',
#   'mttg30: meal tolerance test glucose time 30 min (mg/dl): 133',
#   'mttg30: meal tolerance test glucose time 30 min (mg/dl): 213',
#   'mttg0: meal tolerance test glucose time 0 min (mg/dl): 222',
#   'mttg0: meal tolerance test glucose time 0 min (mg/dl): 297'],
#  29: ['mttg15: meal tolerance test glucose time 15 min (mg/dl): 181',
#   nan,
#   'mttg60: meal tolerance test glucose time 60 min (mg/dl): 135',
#   'mttg15: meal tolerance test glucose time 15 min (mg/dl): 159',
#   'mttg15: meal tolerance test glucose time 15 min (mg/dl): 162',
#   'mttg15: meal tolerance test glucose time 15 min (mg/dl): 198',
#   'mttg15: meal tolerance test glucose time 15 min (mg/dl): 192',
#   'mttg15: meal tolerance test glucose time 15 min (mg/dl): 203',
#   'mttg60: meal tolerance test glucose time 60 min (mg/dl): 212',
#   'mttg15: meal tolerance test glucose time 15 min (mg/dl): 160',
#   'mttg15: meal tolerance test glucose time 15 min (mg/dl): 216',
#   'mttg15: meal tolerance test glucose time 15 min (mg/dl): 264',
#   'mttg15: meal tolerance test glucose time 15 min (mg/dl): 171',
#   'mttg30: meal tolerance test glucose time 30 min (mg/dl): 183',
#   'mttg60: meal tolerance test glucose time 60 min (mg/dl): 175',
#   'mttg15: meal tolerance test glucose time 15 min (mg/dl): 134',
#   'mttg30: meal tolerance test glucose time 30 min (mg/dl): 164',
#   'mttg15: meal tolerance test glucose time 15 min (mg/dl): 85',
#   'mttins0: meal tolerance test insulin time 0 min (mcU/ml): 9.61800003051758',
#   'mttg60: meal tolerance test glucose time 60 min (mg/dl): 129',
#   'mttg60: meal tolerance test glucose time 60 min (mg/dl): 128',
#   'mttg15: meal tolerance test glucose time 15 min (mg/dl): 133',
#   'mttg60: meal tolerance test glucose time 60 min (mg/dl): 250',
#   'mttg15: meal tolerance test glucose time 15 min (mg/dl): 95',
#   'mttg60: meal tolerance test glucose time 60 min (mg/dl): 176',
#   'mttg60: meal tolerance test glucose time 60 min (mg/dl): 216',
#   'mttg15: meal tolerance test glucose time 15 min (mg/dl): 230',
#   'mttg15: meal tolerance test glucose time 15 min (mg/dl): 314',
#   'mttg15: meal tolerance test glucose time 15 min (mg/dl): 90',
#   'mttg15: meal tolerance test glucose time 15 min (mg/dl): 196'],
#  30: ['mttg30: meal tolerance test glucose time 30 min (mg/dl): 186',
#   nan,
#   'mttg120: meal tolerance test glucose time 120 min (mg/dl): 117',
#   'mttg30: meal tolerance test glucose time 30 min (mg/dl): 194',
#   'mttg30: meal tolerance test glucose time 30 min (mg/dl): 172',
#   'mttg30: meal tolerance test glucose time 30 min (mg/dl): 229',
#   'mttg30: meal tolerance test glucose time 30 min (mg/dl): 222',
#   'mttg30: meal tolerance test glucose time 30 min (mg/dl): 243',
#   'mttg120: meal tolerance test glucose time 120 min (mg/dl): 213',
#   'mttg30: meal tolerance test glucose time 30 min (mg/dl): 165',
#   'mttg30: meal tolerance test glucose time 30 min (mg/dl): 263',
#   'mttg30: meal tolerance test glucose time 30 min (mg/dl): 271',
#   'mttg30: meal tolerance test glucose time 30 min (mg/dl): 197',
#   'mttg60: meal tolerance test glucose time 60 min (mg/dl): 193',
#   'mttg120: meal tolerance test glucose time 120 min (mg/dl): 88',
#   'mttg30: meal tolerance test glucose time 30 min (mg/dl): 167',
#   'mttg60: meal tolerance test glucose time 60 min (mg/dl): 132',
#   'mttg30: meal tolerance test glucose time 30 min (mg/dl): 102',
#   'mttins15: meal tolerance test insulin time 15 min (mcU/ml): 11.7320003509521',
#   'mttg120: meal tolerance test glucose time 120 min (mg/dl): 119',
#   'mttg120: meal tolerance test glucose time 120 min (mg/dl): 92',
#   'mttg30: meal tolerance test glucose time 30 min (mg/dl): 129',
#   'mttg120: meal tolerance test glucose time 120 min (mg/dl): 250',
#   'mttg30: meal tolerance test glucose time 30 min (mg/dl): 122',
#   'mttg120: meal tolerance test glucose time 120 min (mg/dl): 144',
#   'mttg120: meal tolerance test glucose time 120 min (mg/dl): 239',
#   'mttg30: meal tolerance test glucose time 30 min (mg/dl): 261',
#   'mttg30: meal tolerance test glucose time 30 min (mg/dl): 345',
#   'mttg30: meal tolerance test glucose time 30 min (mg/dl): 109',
#   'mttg30: meal tolerance test glucose time 30 min (mg/dl): 227'],
#  31: ['mttg60: meal tolerance test glucose time 60 min (mg/dl): 162',
#   nan,
#   'mttins0: meal tolerance test insulin time 0 min (mcU/ml): 3.41599988937378',
#   'mttg60: meal tolerance test glucose time 60 min (mg/dl): 192',
#   'mttg60: meal tolerance test glucose time 60 min (mg/dl): 215',
#   'mttg60: meal tolerance test glucose time 60 min (mg/dl): 254',
#   'mttg60: meal tolerance test glucose time 60 min (mg/dl): 257',
#   'mttg60: meal tolerance test glucose time 60 min (mg/dl): 268',
#   'mttins0: meal tolerance test insulin time 0 min (mcU/ml): 3.15000009536743',
#   'mttg60: meal tolerance test glucose time 60 min (mg/dl): 186',
#   'mttg60: meal tolerance test glucose time 60 min (mg/dl): 299',
#   'mttg60: meal tolerance test glucose time 60 min (mg/dl): 181',
#   'mttg120: meal tolerance test glucose time 120 min (mg/dl): 190',
#   'mttins0: meal tolerance test insulin time 0 min (mcU/ml): 6.46400022506714',
#   'mttg60: meal tolerance test glucose time 60 min (mg/dl): 228',
#   'mttg120: meal tolerance test glucose time 120 min (mg/dl): 103',
#   'mttg60: meal tolerance test glucose time 60 min (mg/dl): 160',
#   'mttins30: meal tolerance test insulin time 30 min (mcU/ml): 24.5310001373291',
#   'mttins0: meal tolerance test insulin time 0 min (mcU/ml): 11.3229999542236',
#   'mttins0: meal tolerance test insulin time 0 min (mcU/ml): 3.63199996948242',
#   'mttg60: meal tolerance test glucose time 60 min (mg/dl): 110',
#   'mttins0: meal tolerance test insulin time 0 min (mcU/ml): 3.78500008583069',
#   'mttg60: meal tolerance test glucose time 60 min (mg/dl): 135',
#   'mttins0: meal tolerance test insulin time 0 min (mcU/ml): 10.8620004653931',
#   'mttg60: meal tolerance test glucose time 60 min (mg/dl): 284',
#   'mttg60: meal tolerance test glucose time 60 min (mg/dl): 370',
#   'mttg60: meal tolerance test glucose time 60 min (mg/dl): 129',
#   'mttg60: meal tolerance test glucose time 60 min (mg/dl): 245',
#   'mttg60: meal tolerance test glucose time 60 min (mg/dl): 178',
#   'mttins0: meal tolerance test insulin time 0 min (mcU/ml): 12.5080003738403'],
#  32: ['mttg120: meal tolerance test glucose time 120 min (mg/dl): 120',
#   nan,
#   'mttins15: meal tolerance test insulin time 15 min (mcU/ml): 41.367000579834',
#   'mttg120: meal tolerance test glucose time 120 min (mg/dl): 180',
#   'mttg120: meal tolerance test glucose time 120 min (mg/dl): 191',
#   'mttg120: meal tolerance test glucose time 120 min (mg/dl): 236',
#   'mttg120: meal tolerance test glucose time 120 min (mg/dl): 228',
#   'mttg120: meal tolerance test glucose time 120 min (mg/dl): 233',
#   'mttins15: meal tolerance test insulin time 15 min (mcU/ml): 17.4029998779297',
#   'mttg120: meal tolerance test glucose time 120 min (mg/dl): 172',
#   'mttg120: meal tolerance test glucose time 120 min (mg/dl): 129',
#   'mttg120: meal tolerance test glucose time 120 min (mg/dl): 309',
#   'mttg120: meal tolerance test glucose time 120 min (mg/dl): 144',
#   'mttins0: meal tolerance test insulin time 0 min (mcU/ml): 3.15000009536743',
#   'mttins15: meal tolerance test insulin time 15 min (mcU/ml): 84.0189971923828',
#   'mttg120: meal tolerance test glucose time 120 min (mg/dl): 199',
#   'mttins0: meal tolerance test insulin time 0 min (mcU/ml): 5.1560001373291',
#   'mttg120: meal tolerance test glucose time 120 min (mg/dl): 123',
#   'mttins60: meal tolerance test insulin time 60 min (mcU/ml): 20.4139995574951',
#   'mttins15: meal tolerance test insulin time 15 min (mcU/ml): 31.0330009460449',
#   'mttins15: meal tolerance test insulin time 15 min (mcU/ml): 33.3349990844727',
#   'mttg120: meal tolerance test glucose time 120 min (mg/dl): 75',
#   'mttins15: meal tolerance test insulin time 15 min (mcU/ml): 3.15000009536743',
#   'mttg120: meal tolerance test glucose time 120 min (mg/dl): 93',
#   'mttins15: meal tolerance test insulin time 15 min (mcU/ml): 20.6909999847412',
#   'mttg120: meal tolerance test glucose time 120 min (mg/dl): 317',
#   'mttg120: meal tolerance test glucose time 120 min (mg/dl): 351',
#   'mttg120: meal tolerance test glucose time 120 min (mg/dl): 155',
#   'mttg120: meal tolerance test glucose time 120 min (mg/dl): 214',
#   'mttg120: meal tolerance test glucose time 120 min (mg/dl): 156'],
#  33: ['mttins0: meal tolerance test insulin time 0 min (mcU/ml): 9.31900024414062',
#   nan,
#   'mttins30: meal tolerance test insulin time 30 min (mcU/ml): 12.1479997634888',
#   'mttins0: meal tolerance test insulin time 0 min (mcU/ml): 4.08199977874756',
#   'mttins0: meal tolerance test insulin time 0 min (mcU/ml): 11.4980001449585',
#   'mttins0: meal tolerance test insulin time 0 min (mcU/ml): 3.23699998855591',
#   'mttins0: meal tolerance test insulin time 0 min (mcU/ml): 6.73000001907349',
#   'mttins0: meal tolerance test insulin time 0 min (mcU/ml): 27.6660003662109',
#   'mttins30: meal tolerance test insulin time 30 min (mcU/ml): 11.7349996566772',
#   'mttins0: meal tolerance test insulin time 0 min (mcU/ml): 3.68700003623962',
#   'mttins0: meal tolerance test insulin time 0 min (mcU/ml): 5.76599979400635',
#   'mttins0: meal tolerance test insulin time 0 min (mcU/ml): 8.05099964141846',
#   'mttins15: meal tolerance test insulin time 15 min (mcU/ml): 7.94000005722046',
#   'mttins15: meal tolerance test insulin time 15 min (mcU/ml): 14.2180004119873',
#   'mttins30: meal tolerance test insulin time 30 min (mcU/ml): 132.613006591797',
#   'mttins0: meal tolerance test insulin time 0 min (mcU/ml): 6.99100017547607',
#   'mttins15: meal tolerance test insulin time 15 min (mcU/ml): 17.3689994812012',
#   'mttins0: meal tolerance test insulin time 0 min (mcU/ml): 21.2369995117188',
#   'mttins120: meal tolerance test insulin time 120 min (mcU/ml): 13.3870000839233',
#   'mttins30: meal tolerance test insulin time 30 min (mcU/ml): 50.5940017700195',
#   'mttins30: meal tolerance test insulin time 30 min (mcU/ml): 76.0230026245117',
#   'mttins0: meal tolerance test insulin time 0 min (mcU/ml): 3.15000009536743',
#   'mttins30: meal tolerance test insulin time 30 min (mcU/ml): 9.57100009918213',
#   'mttins30: meal tolerance test insulin time 30 min (mcU/ml): 43.8079986572266',
#   'mttins30: meal tolerance test insulin time 30 min (mcU/ml): 13.7919998168945',
#   'mttins0: meal tolerance test insulin time 0 min (mcU/ml): 6.59499979019165',
#   'mttins0: meal tolerance test insulin time 0 min (mcU/ml): 9.04500007629395',
#   'mttins0: meal tolerance test insulin time 0 min (mcU/ml): 16.7929992675781',
#   'mttins0: meal tolerance test insulin time 0 min (mcU/ml): 8.27600002288818',
#   'mttins30: meal tolerance test insulin time 30 min (mcU/ml): 47.5779991149902'],
#  34: ['mttins15: meal tolerance test insulin time 15 min (mcU/ml): 48.318000793457',
#   nan,
#   'mttins60: meal tolerance test insulin time 60 min (mcU/ml): 6.59499979019165',
#   'mttins15: meal tolerance test insulin time 15 min (mcU/ml): 7.56400012969971',
#   'mttins15: meal tolerance test insulin time 15 min (mcU/ml): 25.4790000915527',
#   'mttins15: meal tolerance test insulin time 15 min (mcU/ml): 15.1999998092651',
#   'mttins15: meal tolerance test insulin time 15 min (mcU/ml): 14.6770000457764',
#   'mttins15: meal tolerance test insulin time 15 min (mcU/ml): 48.8800010681152',
#   'mttins60: meal tolerance test insulin time 60 min (mcU/ml): 14.6409997940063',
#   'mttins15: meal tolerance test insulin time 15 min (mcU/ml): 22.238000869751',
#   'mttins15: meal tolerance test insulin time 15 min (mcU/ml): 62.9280014038086',
#   'mttins15: meal tolerance test insulin time 15 min (mcU/ml): 12.8819999694824',
#   'mttins30: meal tolerance test insulin time 30 min (mcU/ml): 6.73199987411499',
#   'mttins30: meal tolerance test insulin time 30 min (mcU/ml): 22.7269992828369',
#   'mttins60: meal tolerance test insulin time 60 min (mcU/ml): 175.110000610352',
#   'mttins15: meal tolerance test insulin time 15 min (mcU/ml): 9.02200031280518',
#   'mttins30: meal tolerance test insulin time 30 min (mcU/ml): 23.3969993591309',
#   'mttins15: meal tolerance test insulin time 15 min (mcU/ml): 3.24499988555908',
#   'homair: HOMA-IR (mM * mcU/ml): 5.12960004806519',
#   'mttins60: meal tolerance test insulin time 60 min (mcU/ml): 48.2019996643066',
#   'mttins60: meal tolerance test insulin time 60 min (mcU/ml): 31.2929992675781',
#   'mttins15: meal tolerance test insulin time 15 min (mcU/ml): 78.2470016479492',
#   'mttins60: meal tolerance test insulin time 60 min (mcU/ml): 4.33599996566772',
#   'mttins15: meal tolerance test insulin time 15 min (mcU/ml): 30.6060009002686',
#   'mttins60: meal tolerance test insulin time 60 min (mcU/ml): 28.2689990997314',
#   'mttins60: meal tolerance test insulin time 60 min (mcU/ml): 3.33400011062622',
#   'mttins15: meal tolerance test insulin time 15 min (mcU/ml): 15.9630002975464',
#   'mttins15: meal tolerance test insulin time 15 min (mcU/ml): 10.3290004730225',
#   'mttins15: meal tolerance test insulin time 15 min (mcU/ml): 6.46400022506714',
#   'mttins15: meal tolerance test insulin time 15 min (mcU/ml): 10.2180004119873'],
#  35: ['mttins30: meal tolerance test insulin time 30 min (mcU/ml): 41.2770004272461',
#   nan,
#   'mttins120: meal tolerance test insulin time 120 min (mcU/ml): 8.54199981689453',
#   'mttins30: meal tolerance test insulin time 30 min (mcU/ml): 13.7399997711182',
#   'mttins30: meal tolerance test insulin time 30 min (mcU/ml): 41.7820014953613',
#   'mttins30: meal tolerance test insulin time 30 min (mcU/ml): 27.75',
#   'mttins30: meal tolerance test insulin time 30 min (mcU/ml): 21.1620006561279',
#   'mttins30: meal tolerance test insulin time 30 min (mcU/ml): 71.390998840332',
#   'mttins120: meal tolerance test insulin time 120 min (mcU/ml): 29.0510005950928',
#   'mttins30: meal tolerance test insulin time 30 min (mcU/ml): 30.5470008850098',
#   'mttins30: meal tolerance test insulin time 30 min (mcU/ml): 64.5500030517578',
#   'mttins30: meal tolerance test insulin time 30 min (mcU/ml): 13.496000289917',
#   'mttins60: meal tolerance test insulin time 60 min (mcU/ml): 6.53000020980835',
#   'mttins60: meal tolerance test insulin time 60 min (mcU/ml): 18.8299999237061',
#   'mttins120: meal tolerance test insulin time 120 min (mcU/ml): 16.875',
#   'mttins30: meal tolerance test insulin time 30 min (mcU/ml): 19.2649993896484',
#   'mttins60: meal tolerance test insulin time 60 min (mcU/ml): 14.7650003433228',
#   'mttins30: meal tolerance test insulin time 30 min (mcU/ml): 47.5639991760254',
#   'homab: HOMA-B cell (%): 22.6305885314941',
#   'mttins120: meal tolerance test insulin time 120 min (mcU/ml): 40.734001159668',
#   'mttins120: meal tolerance test insulin time 120 min (mcU/ml): 3.15000009536743',
#   'mttins30: meal tolerance test insulin time 30 min (mcU/ml): 62.1980018615723',
#   'mttins120: meal tolerance test insulin time 120 min (mcU/ml): 11.1709995269775',
#   'mttins30: meal tolerance test insulin time 30 min (mcU/ml): 6.22800016403198',
#   'mttins120: meal tolerance test insulin time 120 min (mcU/ml): 30.3680000305176',
#   'mttins120: meal tolerance test insulin time 120 min (mcU/ml): 4.45499992370605',
#   'mttins30: meal tolerance test insulin time 30 min (mcU/ml): 16.2320003509521',
#   'mttins30: meal tolerance test insulin time 30 min (mcU/ml): 8.61400032043457',
#   'mttins30: meal tolerance test insulin time 30 min (mcU/ml): 13.7919998168945',
#   'mttins30: meal tolerance test insulin time 30 min (mcU/ml): 53.4900016784668'],
#  36: ['mttins60: meal tolerance test insulin time 60 min (mcU/ml): 21.2250003814697',
#   nan,
#   'homair: HOMA-IR (mM * mcU/ml): 0.835022211074829',
#   'mttins60: meal tolerance test insulin time 60 min (mcU/ml): 7.68699979782104',
#   'mttins60: meal tolerance test insulin time 60 min (mcU/ml): 47.5769996643066',
#   'mttins60: meal tolerance test insulin time 60 min (mcU/ml): 24.0820007324219',
#   'mttins60: meal tolerance test insulin time 60 min (mcU/ml): 28.1030006408691',
#   'mttins60: meal tolerance test insulin time 60 min (mcU/ml): 56.6139984130859',
#   'homair: HOMA-IR (mM * mcU/ml): 1.09666669368744',
#   'mttins60: meal tolerance test insulin time 60 min (mcU/ml): 13.8809995651245',
#   'mttins60: meal tolerance test insulin time 60 min (mcU/ml): 35.3450012207031',
#   'mttins60: meal tolerance test insulin time 60 min (mcU/ml): 16.1870002746582',
#   'mttins120: meal tolerance test insulin time 120 min (mcU/ml): 10.2069997787476',
#   'mttins120: meal tolerance test insulin time 120 min (mcU/ml): 16.2770004272461',
#   'homair: HOMA-IR (mM * mcU/ml): 1.50028645992279',
#   'mttins60: meal tolerance test insulin time 60 min (mcU/ml): 30.2490005493164',
#   'mttins120: meal tolerance test insulin time 120 min (mcU/ml): 4.72700023651123',
#   'mttins60: meal tolerance test insulin time 60 min (mcU/ml): 92.6660003662109',
#   'matsuda: Matsuda index: 3.19535684585571',
#   'homair: HOMA-IR (mM * mcU/ml): 2.34847402572632',
#   'homair: HOMA-IR (mM * mcU/ml): 0.816079020500183',
#   'mttins60: meal tolerance test insulin time 60 min (mcU/ml): 14.5459995269775',
#   'homair: HOMA-IR (mM * mcU/ml): 1.28035807609558',
#   'mttins60: meal tolerance test insulin time 60 min (mcU/ml): 23.6499996185303',
#   'homair: HOMA-IR (mM * mcU/ml): 2.60151624679565',
#   'homair: HOMA-IR (mM * mcU/ml): 1.33000004291534',
#   'mttins60: meal tolerance test insulin time 60 min (mcU/ml): 12.0089998245239',
#   'mttins60: meal tolerance test insulin time 60 min (mcU/ml): 8.10900020599365',
#   'mttins60: meal tolerance test insulin time 60 min (mcU/ml): 11.8859996795654',
#   'mttins60: meal tolerance test insulin time 60 min (mcU/ml): 35.4259986877441'],
#  37: ['mttins120: meal tolerance test insulin time 120 min (mcU/ml): 13.496000289917',
#   nan,
#   'homab: HOMA-B cell (%): 34.1599998474121',
#   'mttins120: meal tolerance test insulin time 120 min (mcU/ml): 10.0319995880127',
#   'mttins120: meal tolerance test insulin time 120 min (mcU/ml): 32.0909996032715',
#   'mttins120: meal tolerance test insulin time 120 min (mcU/ml): 14.4630002975464',
#   'mttins120: meal tolerance test insulin time 120 min (mcU/ml): 11.3039999008179',
#   'mttins120: meal tolerance test insulin time 120 min (mcU/ml): 44.7309989929199',
#   'homab: HOMA-B cell (%): 14.5384616851807',
#   'mttins120: meal tolerance test insulin time 120 min (mcU/ml): 17.4589996337891',
#   'mttins120: meal tolerance test insulin time 120 min (mcU/ml): 15.7270002365112',
#   'mttins120: meal tolerance test insulin time 120 min (mcU/ml): 16.2740001678467',
#   'dmcure: FPG < 126 and HbA1c < 6.5 (0 = no; 1 = yes; 9 = missing): 0',
#   'homair: HOMA-IR (mM * mcU/ml): 1.1977778673172',
#   'homab: HOMA-B cell (%): 75.0658111572266',
#   'mttins120: meal tolerance test insulin time 120 min (mcU/ml): 30.0100002288818',
#   'homair: HOMA-IR (mM * mcU/ml): 1.23489391803741',
#   'mttins120: meal tolerance test insulin time 120 min (mcU/ml): 119.591003417969',
#   'homab: HOMA-B cell (%): 194.10856628418',
#   'homab: HOMA-B cell (%): 46.6971435546875',
#   'mttins120: meal tolerance test insulin time 120 min (mcU/ml): 3.15000009536743',
#   'homab: HOMA-B cell (%): 18.4135131835938',
#   'mttins120: meal tolerance test insulin time 120 min (mcU/ml): 4.87799978256226',
#   'homab: HOMA-B cell (%): 115.009414672852',
#   'homab: HOMA-B cell (%): 10.5',
#   'mttins120: meal tolerance test insulin time 120 min (mcU/ml): 16.2320003509521',
#   'mttins120: meal tolerance test insulin time 120 min (mcU/ml): 13.5920000076294',
#   'mttins120: meal tolerance test insulin time 120 min (mcU/ml): 9.40900039672852',
#   'mttins120: meal tolerance test insulin time 120 min (mcU/ml): 8.08199977874756',
#   'mttins120: meal tolerance test insulin time 120 min (mcU/ml): 51.4129981994629'],
#  38: ['homair: HOMA-IR (mM * mcU/ml): 2.20894813537598',
#   nan,
#   'matsuda: Matsuda index: 13.4668579101562',
#   'homair: HOMA-IR (mM * mcU/ml): 1.31027150154114',
#   'homair: HOMA-IR (mM * mcU/ml): 3.88944697380066',
#   'homair: HOMA-IR (mM * mcU/ml): 1.25483703613281',
#   'homair: HOMA-IR (mM * mcU/ml): 2.84155559539795',
#   'homair: HOMA-IR (mM * mcU/ml): 13.7988443374634',
#   'matsuda: Matsuda index: 8.13479900360107',
#   'homair: HOMA-IR (mM * mcU/ml): 1.31093335151672',
#   'homair: HOMA-IR (mM * mcU/ml): 1.29557037353516',
#   'homair: HOMA-IR (mM * mcU/ml): 4.59205150604248',
#   'dg030: change in glucose from 0 to 30 min (mg/dl): 119',
#   'homab: HOMA-B cell (%): 12.4615392684937',
#   'matsuda: Matsuda index: 3.24077415466309',
#   'homair: HOMA-IR (mM * mcU/ml): 2.26128649711609',
#   'homab: HOMA-B cell (%): 54.5929412841797',
#   'homair: HOMA-IR (mM * mcU/ml): 4.6668963432312',
#   'instauc: insulin total area under curve (mcU/ml Â· 120 min): 2120.302',
#   'matsuda: Matsuda index: 4.58171033859253',
#   'matsuda: Matsuda index: 8.50903701782227',
#   'homair: HOMA-IR (mM * mcU/ml): 0.50555557012558',
#   'matsuda: Matsuda index: 11.3175477981567',
#   'homair: HOMA-IR (mM * mcU/ml): 0.466666668653488',
#   'matsuda: Matsuda index: 4.68468761444092',
#   'matsuda: Matsuda index: 12.5056667327881',
#   'homair: HOMA-IR (mM * mcU/ml): 3.6150369644165',
#   'homair: HOMA-IR (mM * mcU/ml): 6.63299989700317',
#   'homair: HOMA-IR (mM * mcU/ml): 0.622222244739532',
#   'homair: HOMA-IR (mM * mcU/ml): 7.50501918792725'],
#  39: ['homab: HOMA-B cell (%): 101.661819458008',
#   nan,
#   'dmcure: FPG < 126 and HbA1c < 6.5 (0 = no; 1 = yes; 9 = missing): 0',
#   'homab: HOMA-B cell (%): 21.9331340789795',
#   'homab: HOMA-B cell (%): 55.9362182617188',
#   'homab: HOMA-B cell (%): 12.3970212936401',
#   'homab: HOMA-B cell (%): 22.4333343505859',
#   'homab: HOMA-B cell (%): 71.6529541015625',
#   'homab: HOMA-B cell (%): 16.3866672515869',
#   'homab: HOMA-B cell (%): 74.1342849731445',
#   'homab: HOMA-B cell (%): 17.2521419525146',
#   'matsuda: Matsuda index: 8.09135723114014',
#   'dmcure: FPG < 126 and HbA1c < 6.5 (0 = no; 1 = yes; 9 = missing): 1',
#   'homab: HOMA-B cell (%): 37.0111770629883',
#   'matsuda: Matsuda index: 10.409628868103',
#   'homab: HOMA-B cell (%): 294.050750732422',
#   'insiauc: insulin incremental area under curve (mcU/ml Â· 120 min): 966.1425',
#   'matsuda: Matsuda index: 12.9237670898438',
#   'matsuda: Matsuda index: 17.5546474456787',
#   'homab: HOMA-B cell (%): 14.932074546814',
#   'homab: HOMA-B cell (%): 13.9153842926025',
#   'homab: HOMA-B cell (%): 66.7058868408203',
#   'homab: HOMA-B cell (%): 51.2328796386719',
#   'homab: HOMA-B cell (%): 80.5232467651367',
#   'homab: HOMA-B cell (%): 82.4123077392578',
#   'homab: HOMA-B cell (%): 34.4777946472168',
#   'homab: HOMA-B cell (%): 20.3611755371094',
#   'homab: HOMA-B cell (%): 24.6544780731201',
#   'homab: HOMA-B cell (%): 10.1714601516724',
#   'homab: HOMA-B cell (%): 189'],
#  40: ['dmcure: FPG < 126 and HbA1c < 6.5 (0 = no; 1 = yes; 9 = missing): 1',
#   nan,
#   'instauc: insulin total area under curve (mcU/ml Â· 120 min): 1472.49',
#   'matsuda: Matsuda index: 10.6457843780518',
#   'matsuda: Matsuda index: 2.98532462120056',
#   'matsuda: Matsuda index: 6.52343606948853',
#   'matsuda: Matsuda index: 4.39474296569824',
#   'matsuda: Matsuda index: 1.17334890365601',
#   'instauc: insulin total area under curve (mcU/ml Â· 120 min): 2079.083',
#   'matsuda: Matsuda index: 7.71849727630615',
#   'matsuda: Matsuda index: 5.1057300567627',
#   'matsuda: Matsuda index: 3.55615711212158',
#   'dmcure: FPG < 126 and HbA1c < 6.5 (0 = no; 1 = yes; 9 = missing): 0',
#   'instauc: insulin total area under curve (mcU/ml Â· 120 min): 12678.76',
#   'matsuda: Matsuda index: 4.87190675735474',
#   'matsuda: Matsuda index: 2.36086821556091',
#   'dins030: change in insulin from 0 to 30 min (mcU/ml): 14.913',
#   'instauc: insulin total area under curve (mcU/ml Â· 120 min): 5079.893',
#   'instauc: insulin total area under curve (mcU/ml Â· 120 min): 3740.468',
#   'instauc: insulin total area under curve (mcU/ml Â· 120 min): 821.235',
# ...
#   'matsuda: Matsuda index: 4.90383815765381'],
#  41: ['instauc: insulin total area under curve (mcU/ml Â· 120 min): 3083.4',
#   nan,
#   'insiauc: insulin incremental area under curve (mcU/ml Â· 120 min): 1062.57',
#   'dmcure: FPG < 126 and HbA1c < 6.5 (0 = no; 1 = yes; 9 = missing): 0',
#   'insiauc: insulin incremental area under curve (mcU/ml Â· 120 min): 1701.083',
#   'dmcure: FPG < 126 and HbA1c < 6.5 (0 = no; 1 = yes; 9 = missing): 1',
#   'instauc: insulin total area under curve (mcU/ml Â· 120 min): 2083.913',
#   'insiauc: insulin incremental area under curve (mcU/ml Â· 120 min): 11903.08',
#   'instauc: insulin total area under curve (mcU/ml Â· 120 min): 1631.873',
#   'dg030: change in glucose from 0 to 30 min (mg/dl): 55',
#   'insiauc: insulin incremental area under curve (mcU/ml Â· 120 min): 3721.133',
#   'insiauc: insulin incremental area under curve (mcU/ml Â· 120 min): 3304.627',
#   'instauc: insulin total area under curve (mcU/ml Â· 120 min): 3345.855',
#   'insiauc: insulin incremental area under curve (mcU/ml Â· 120 min): 367.035',
#   'instauc: insulin total area under curve (mcU/ml Â· 120 min): 1833.435',
#   'insiauc: insulin incremental area under curve (mcU/ml Â· 120 min): 2257.215',
#   'insiauc: insulin incremental area under curve (mcU/ml Â· 120 min): 286.875',
#   'insiauc: insulin incremental area under curve (mcU/ml Â· 120 min): 4097.73',
#   'insiauc: insulin incremental area under curve (mcU/ml Â· 120 min): 1579.71',
#   'insiauc: insulin incremental area under curve (mcU/ml Â· 120 min): 6554.002',
#   'insiauc: insulin incremental area under curve (mcU/ml Â· 120 min): -226.41',
#   'insiauc: insulin incremental area under curve (mcU/ml Â· 120 min): 780.975',
#   'insiauc: insulin incremental area under curve (mcU/ml Â· 120 min): 1173.083',
#   'instauc: insulin total area under curve (mcU/ml Â· 120 min): 1482.975',
#   'dins030: change in insulin from 0 to 30 min (mcU/ml): 24.721',
#   'insiauc: insulin incremental area under curve (mcU/ml Â· 120 min): -55.57501',
#   'insiauc: insulin incremental area under curve (mcU/ml Â· 120 min): 835.17',
#   'insiauc: insulin incremental area under curve (mcU/ml Â· 120 min): 3708.232',
#   'dins030: change in insulin from 0 to 30 min (mcU/ml): 36.086',
#   'instauc: insulin total area under curve (mcU/ml Â· 120 min): 2156.16'],
#  42: ['insiauc: insulin incremental area under curve (mcU/ml Â· 120 min): 1965.12',
#   nan,
#   'dins030: change in insulin from 0 to 30 min (mcU/ml): 8.732',
#   'instauc: insulin total area under curve (mcU/ml Â· 120 min): 1100.1',
#   'instauc: insulin total area under curve (mcU/ml Â· 120 min): 4512.21',
#   'instauc: insulin total area under curve (mcU/ml Â· 120 min): 2394.232',
#   'instauc: insulin total area under curve (mcU/ml Â· 120 min): 2350.53',
#   'instauc: insulin total area under curve (mcU/ml Â· 120 min): 6436.552',
#   'dins030: change in insulin from 0 to 30 min (mcU/ml): 8.584999',
#   'instauc: insulin total area under curve (mcU/ml Â· 120 min): 2196.945',
#   'instauc: insulin total area under curve (mcU/ml Â· 120 min): 4501.875',
#   'instauc: insulin total area under curve (mcU/ml Â· 120 min): 1773.907',
#   'insiauc: insulin incremental area under curve (mcU/ml Â· 120 min): 1705.912',
#   'dins030: change in insulin from 0 to 30 min (mcU/ml): 126.149',
#   'instauc: insulin total area under curve (mcU/ml Â· 120 min): 2882.73',
#   'insiauc: insulin incremental area under curve (mcU/ml Â· 120 min): 1013.152',
#   'instauc: insulin total area under curve (mcU/ml Â· 120 min): 9035.843',
#   'dinsg030: change in insulin from 0 to 30 min / change in glucose from 0 to 30 min (mcU/ml / mg/dl): 0.2711455',
#   'dins030: change in insulin from 0 to 30 min (mcU/ml): 39.271',
#   'dins030: change in insulin from 0 to 30 min (mcU/ml): 72.39101',
#   'insiauc: insulin incremental area under curve (mcU/ml Â· 120 min): 2967.855',
#   'dins030: change in insulin from 0 to 30 min (mcU/ml): 5.786',
#   'insiauc: insulin incremental area under curve (mcU/ml Â· 120 min): 1455.435',
#   'dins030: change in insulin from 0 to 30 min (mcU/ml): 32.946',
#   'dins030: change in insulin from 0 to 30 min (mcU/ml): 10.642',
#   'instauc: insulin total area under curve (mcU/ml Â· 120 min): 1681.493',
#   'instauc: insulin total area under curve (mcU/ml Â· 120 min): 1189.253',
#   'instauc: insulin total area under curve (mcU/ml Â· 120 min): 1248.045',
#   'instauc: insulin total area under curve (mcU/ml Â· 120 min): 3319.373',
#   'instauc: insulin total area under curve (mcU/ml Â· 120 min): 4634.115'],
#  43: ['dins030: change in insulin from 0 to 30 min (mcU/ml): 31.958',
#   nan,
#   'dg030: change in glucose from 0 to 30 min (mg/dl): 50',
#   'insiauc: insulin incremental area under curve (mcU/ml Â· 120 min): 610.26',
#   'insiauc: insulin incremental area under curve (mcU/ml Â· 120 min): 3132.45',
#   'insiauc: insulin incremental area under curve (mcU/ml Â· 120 min): 2005.792',
#   'insiauc: insulin incremental area under curve (mcU/ml Â· 120 min): 1542.93',
#   'insiauc: insulin incremental area under curve (mcU/ml Â· 120 min): 3116.632',
#   'dg030: change in glucose from 0 to 30 min (mg/dl): 44',
#   'insiauc: insulin incremental area under curve (mcU/ml Â· 120 min): 1754.505',
#   'insiauc: insulin incremental area under curve (mcU/ml Â· 120 min): 3809.955',
#   'insiauc: insulin incremental area under curve (mcU/ml Â· 120 min): 807.7875',
#   'dins030: change in insulin from 0 to 30 min (mcU/ml): 19.577',
#   'dg030: change in glucose from 0 to 30 min (mg/dl): 87',
#   'insiauc: insulin incremental area under curve (mcU/ml Â· 120 min): 2043.81',
#   'dins030: change in insulin from 0 to 30 min (mcU/ml): 18.241',
#   'insiauc: insulin incremental area under curve (mcU/ml Â· 120 min): 6487.403',
#   'odi: oral disposition index = dinsg030 / mttins0: 0.0281915',
#   'dg030: change in glucose from 0 to 30 min (mg/dl): 37',
#   'dg030: change in glucose from 0 to 30 min (mg/dl): 95',
#   'dins030: change in insulin from 0 to 30 min (mcU/ml): 59.048',
#   'dg030: change in glucose from 0 to 30 min (mg/dl): 62',
#   'dins030: change in insulin from 0 to 30 min (mcU/ml): 3.078',
#   'dg030: change in glucose from 0 to 30 min (mg/dl): 36',
#   'dg030: change in glucose from 0 to 30 min (mg/dl): 42',
#   'insiauc: insulin incremental area under curve (mcU/ml Â· 120 min): 890.0925',
#   'insiauc: insulin incremental area under curve (mcU/ml Â· 120 min): 103.8525',
#   'insiauc: insulin incremental area under curve (mcU/ml Â· 120 min): 870.045',
#   'insiauc: insulin incremental area under curve (mcU/ml Â· 120 min): 1304.213',
#   'insiauc: insulin incremental area under curve (mcU/ml Â· 120 min): 3640.995'],
#  44: ['dg030: change in glucose from 0 to 30 min (mg/dl): 90',
#   nan,
#   'dinsg030: change in insulin from 0 to 30 min / change in glucose from 0 to 30 min (mcU/ml / mg/dl): 0.17464',
#   'dins030: change in insulin from 0 to 30 min (mcU/ml): 9.658',
#   'dins030: change in insulin from 0 to 30 min (mcU/ml): 30.284',
#   'dins030: change in insulin from 0 to 30 min (mcU/ml): 24.513',
#   'dins030: change in insulin from 0 to 30 min (mcU/ml): 14.432',
#   'dins030: change in insulin from 0 to 30 min (mcU/ml): 43.725',
#   'dinsg030: change in insulin from 0 to 30 min / change in glucose from 0 to 30 min (mcU/ml / mg/dl): 0.1951136',
#   'dins030: change in insulin from 0 to 30 min (mcU/ml): 26.86',
#   'dins030: change in insulin from 0 to 30 min (mcU/ml): 58.784',
#   'dins030: change in insulin from 0 to 30 min (mcU/ml): 5.445001',
#   'dg030: change in glucose from 0 to 30 min (mg/dl): 29',
#   'dinsg030: change in insulin from 0 to 30 min / change in glucose from 0 to 30 min (mcU/ml / mg/dl): 1.449989',
#   'dins030: change in insulin from 0 to 30 min (mcU/ml): 12.274',
#   'dg030: change in glucose from 0 to 30 min (mg/dl): 67',
#   'dins030: change in insulin from 0 to 30 min (mcU/ml): 26.327',
#   'dinsg030: change in insulin from 0 to 30 min / change in glucose from 0 to 30 min (mcU/ml / mg/dl): 1.061378',
#   'dinsg030: change in insulin from 0 to 30 min / change in glucose from 0 to 30 min (mcU/ml / mg/dl): 0.7620106',
#   'dg030: change in glucose from 0 to 30 min (mg/dl): 64',
#   'dinsg030: change in insulin from 0 to 30 min / change in glucose from 0 to 30 min (mcU/ml / mg/dl): 0.0933226',
#   'dg030: change in glucose from 0 to 30 min (mg/dl): 62',
#   'dinsg030: change in insulin from 0 to 30 min / change in glucose from 0 to 30 min (mcU/ml / mg/dl): 0.9151666',
#   'dinsg030: change in insulin from 0 to 30 min / change in glucose from 0 to 30 min (mcU/ml / mg/dl): 0.253381',
#   'dins030: change in insulin from 0 to 30 min (mcU/ml): 9.637001',
#   'dins030: change in insulin from 0 to 30 min (mcU/ml): -0.4309998',
#   'dins030: change in insulin from 0 to 30 min (mcU/ml): 10.642',
#   'dins030: change in insulin from 0 to 30 min (mcU/ml): 36.697',
#   'dins030: change in insulin from 0 to 30 min (mcU/ml): 21.816',
#   'dinsg030: change in insulin from 0 to 30 min / change in glucose from 0 to 30 min (mcU/ml / mg/dl): 0.835'],
#  45: ['dinsg030: change in insulin from 0 to 30 min / change in glucose from 0 to 30 min (mcU/ml / mg/dl): 0.3550889',
#   nan,
#   'odi: oral disposition index = dinsg030 / mttins0: 0.0511241',
#   'dg030: change in glucose from 0 to 30 min (mg/dl): 64',
#   'dg030: change in glucose from 0 to 30 min (mg/dl): 35',
#   'dg030: change in glucose from 0 to 30 min (mg/dl): 72',
#   'dg030: change in glucose from 0 to 30 min (mg/dl): 51',
#   'dg030: change in glucose from 0 to 30 min (mg/dl): 41',
#   'odi: oral disposition index = dinsg030 / mttins0: 0.0619408',
#   'dg030: change in glucose from 0 to 30 min (mg/dl): 21',
#   'dg030: change in glucose from 0 to 30 min (mg/dl): 172',
#   'dg030: change in glucose from 0 to 30 min (mg/dl): 40',
#   'dinsg030: change in insulin from 0 to 30 min / change in glucose from 0 to 30 min (mcU/ml / mg/dl): 0.675069',
#   'odi: oral disposition index = dinsg030 / mttins0: 0.2243175',
#   'dg030: change in glucose from 0 to 30 min (mg/dl): 36',
#   'dinsg030: change in insulin from 0 to 30 min / change in glucose from 0 to 30 min (mcU/ml / mg/dl): 0.2722537',
#   'dg030: change in glucose from 0 to 30 min (mg/dl): 13',
#   'odi: oral disposition index = dinsg030 / mttins0: 0.0937365',
#   'odi: oral disposition index = dinsg030 / mttins0: 0.2098047',
#   'dinsg030: change in insulin from 0 to 30 min / change in glucose from 0 to 30 min (mcU/ml / mg/dl): 0.922625',
#   'odi: oral disposition index = dinsg030 / mttins0: 0.0246559',
#   'dinsg030: change in insulin from 0 to 30 min / change in glucose from 0 to 30 min (mcU/ml / mg/dl): 0.0496452',
#   'odi: oral disposition index = dinsg030 / mttins0: 0.084254',
#   'odi: oral disposition index = dinsg030 / mttins0: 0.0804384',
#   'dg030: change in glucose from 0 to 30 min (mg/dl): 39',
#   'dg030: change in glucose from 0 to 30 min (mg/dl): 48',
#   'dg030: change in glucose from 0 to 30 min (mg/dl): 29',
#   'dg030: change in glucose from 0 to 30 min (mg/dl): 46',
#   'dg030: change in glucose from 0 to 30 min (mg/dl): 33',
#   'odi: oral disposition index = dinsg030 / mttins0: 0.0667573'],
#  46: ['odi: oral disposition index = dinsg030 / mttins0: 0.0381038',
#   nan,
#   'dinsg030: change in insulin from 0 to 30 min / change in glucose from 0 to 30 min (mcU/ml / mg/dl): 0.1509062',
#   'dinsg030: change in insulin from 0 to 30 min / change in glucose from 0 to 30 min (mcU/ml / mg/dl): 0.8652571',
#   'dinsg030: change in insulin from 0 to 30 min / change in glucose from 0 to 30 min (mcU/ml / mg/dl): 0.3404583',
#   'dinsg030: change in insulin from 0 to 30 min / change in glucose from 0 to 30 min (mcU/ml / mg/dl): 0.2829804',
#   'dinsg030: change in insulin from 0 to 30 min / change in glucose from 0 to 30 min (mcU/ml / mg/dl): 1.066463',
#   'dinsg030: change in insulin from 0 to 30 min / change in glucose from 0 to 30 min (mcU/ml / mg/dl): 1.279048',
#   'dinsg030: change in insulin from 0 to 30 min / change in glucose from 0 to 30 min (mcU/ml / mg/dl): 0.3417675',
#   'dinsg030: change in insulin from 0 to 30 min / change in glucose from 0 to 30 min (mcU/ml / mg/dl): 0.136125',
#   'odi: oral disposition index = dinsg030 / mttins0: 0.2143076',
#   'dinsg030: change in insulin from 0 to 30 min / change in glucose from 0 to 30 min (mcU/ml / mg/dl): 0.3409444',
#   'odi: oral disposition index = dinsg030 / mttins0: 0.0528033',
#   'dinsg030: change in insulin from 0 to 30 min / change in glucose from 0 to 30 min (mcU/ml / mg/dl): 2.025154',
#   'odi: oral disposition index = dinsg030 / mttins0: 0.2928968',
#   'odi: oral disposition index = dinsg030 / mttins0: 0.0157604',
#   'dinsg030: change in insulin from 0 to 30 min / change in glucose from 0 to 30 min (mcU/ml / mg/dl): 0.2471026',
#   'dinsg030: change in insulin from 0 to 30 min / change in glucose from 0 to 30 min (mcU/ml / mg/dl): -0.0089792',
#   'dinsg030: change in insulin from 0 to 30 min / change in glucose from 0 to 30 min (mcU/ml / mg/dl): 0.3669655',
#   'dinsg030: change in insulin from 0 to 30 min / change in glucose from 0 to 30 min (mcU/ml / mg/dl): 0.7977609',
#   'dinsg030: change in insulin from 0 to 30 min / change in glucose from 0 to 30 min (mcU/ml / mg/dl): 0.6610909',
#   'dinsg030: change in insulin from 0 to 30 min / change in glucose from 0 to 30 min (mcU/ml / mg/dl): 0.8481531',
#   'dinsg030: change in insulin from 0 to 30 min / change in glucose from 0 to 30 min (mcU/ml / mg/dl): 0.4806667',
#   'dinsg030: change in insulin from 0 to 30 min / change in glucose from 0 to 30 min (mcU/ml / mg/dl): 0.2595686',
#   'dinsg030: change in insulin from 0 to 30 min / change in glucose from 0 to 30 min (mcU/ml / mg/dl): 0.0220164',
#   'dinsg030: change in insulin from 0 to 30 min / change in glucose from 0 to 30 min (mcU/ml / mg/dl): 2.084556',
#   'dinsg030: change in insulin from 0 to 30 min / change in glucose from 0 to 30 min (mcU/ml / mg/dl): 0.3272439',
#   'dinsg030: change in insulin from 0 to 30 min / change in glucose from 0 to 30 min (mcU/ml / mg/dl): 0.18865',
#   'dinsg030: change in insulin from 0 to 30 min / change in glucose from 0 to 30 min (mcU/ml / mg/dl): 0.5348333',
#   'dinsg030: change in insulin from 0 to 30 min / change in glucose from 0 to 30 min (mcU/ml / mg/dl): 0.4662967'],
#  47: [nan,
#   'odi: oral disposition index = dinsg030 / mttins0: 0.0369687',
#   'odi: oral disposition index = dinsg030 / mttins0: 0.0752528',
#   'odi: oral disposition index = dinsg030 / mttins0: 0.1051771',
#   'odi: oral disposition index = dinsg030 / mttins0: 0.0420476',
#   'odi: oral disposition index = dinsg030 / mttins0: 0.0385478',
#   'odi: oral disposition index = dinsg030 / mttins0: 0.3469074',
#   'odi: oral disposition index = dinsg030 / mttins0: 0.0592729',
#   'odi: oral disposition index = dinsg030 / mttins0: 0.0169078',
#   'odi: oral disposition index = dinsg030 / mttins0: 0.048769',
#   'odi: oral disposition index = dinsg030 / mttins0: 0.0953597',
#   'odi: oral disposition index = dinsg030 / mttins0: 0.0374682',
#   'odi: oral disposition index = dinsg030 / mttins0: -0.0009927',
#   'odi: oral disposition index = dinsg030 / mttins0: 0.116497',
#   'odi: oral disposition index = dinsg030 / mttins0: 0.0475056',
#   'odi: oral disposition index = dinsg030 / mttins0: 0.0798805',
#   'odi: oral disposition index = dinsg030 / mttins0: 0.1424988',
#   'odi: oral disposition index = dinsg030 / mttins0: 0.0395188',
#   'odi: oral disposition index = dinsg030 / mttins0: 0.0674905',
#   'odi: oral disposition index = dinsg030 / mttins0: 0.0019723',
#   'odi: oral disposition index = dinsg030 / mttins0: 0.3988054',
#   'odi: oral disposition index = dinsg030 / mttins0: 0.1038869',
#   'odi: oral disposition index = dinsg030 / mttins0: 0.0191562',
#   'odi: oral disposition index = dinsg030 / mttins0: 0.052797',
#   'odi: oral disposition index = dinsg030 / mttins0: 0.1480307',
#   'odi: oral disposition index = dinsg030 / mttins0: 0.0302851',
#   'odi: oral disposition index = dinsg030 / mttins0: 0.0178767',
#   'odi: oral disposition index = dinsg030 / mttins0: 0.2054335',
#   'odi: oral disposition index = dinsg030 / mttins0: 0.2397359',
#   'odi: oral disposition index = dinsg030 / mttins0: -0.0019763']}

# %%
f'''As a biomedical research team, we are selecting datasets to study the association between the human trait \'{TRAIT}\' and genetic factors, optionally considering the influence of age and gender. After searching the GEO database and parsing the matrix file of a series, we obtained background information and sample characteristics data. We will provide textual information about the dataset background, and a Python dictionary storing a list of unique values for each field of the sample characteristics data. Please carefully review the provided information and answer the following questions about this dataset:
1. Does this dataset contain gene expression data? (Note: Pure miRNA data is not suitable.)
2. For each of the traits \'{TRAIT}\', 'age', and 'gender', please address these points:
   (1) Is there human data available for this trait?
   (2) If so, identify the key in the sample characteristics dictionary where unique values of this trait is recorded. The key is an integer. The trait information might be explicitly recorded, or can be inferred from the field with some biomedical knowledge or understanding about the data collection process.
   (3) Choose an appropriate data type (either 'continuous' or 'binary') for each trait. Write a Python function to convert any given value of the trait to this data type. The function should handle inference about the trait value and convert unknown values to None.
   Name the functions 'convert_trait', 'convert_age', and 'convert_gender', respectively.

Background information about the dataset:
{background_info}

Sample characteristics dictionary (from "!Sample_characteristics_ch1", converted to a Python dictionary that stores the unique values for each field):
{clinical_data_unique}
'''
# Out:
# 'As a biomedical research team, we are selecting datasets to study the association between the human trait \'Metabolic-Rate\' and genetic factors, optionally considering the influence of age and gender. After searching the GEO database and parsing the matrix file of a series, we obtained background information and sample characteristics data. We will provide textual information about the dataset background, and a Python dictionary storing a list of unique values for each field of the sample characteristics data. Please carefully review the provided information and answer the following questions about this dataset:\n1. Does this dataset contain gene expression data? (Note: Pure miRNA data is not suitable.)\n2. For each of the traits \'Metabolic-Rate\', \'age\', and \'gender\', please address these points:\n   (1) Is there human data available for this trait?\n   (2) If so, identify the key in the sample characteristics dictionary where unique values of this trait is recorded. The key is an integer. The trait information might be explicitly recorded, or can be inferred from the field with some biomedical knowledge or understanding about the data collection process.\n   (3) Choose an appropriate data type (either \'continuous\' or \'binary\') for each trait. Write a Python function to convert any given value of the trait to this data type. The function should handle inference about the trait value and convert unknown values to None.\n   Name the functions \'convert_trait\', \'convert_age\', and \'convert_gender\', respectively.\n\nBackground information about the dataset:\n!Series_title\t"High-throughput mediation analysis of human proteome and metabolome identifies mediators of post-bariatric surgical diabetes control"\n!Series_summary\t"To improve the power of mediation in high-throughput studies, here we introduce High-throughput mediation analysis (Hitman), which accounts for direction of mediation and applies empirical Bayesian linear modeling. We apply Hitman in a retrospective, exploratory analysis of the SLIMM-T2D clinical trial in which participants with type 2 diabetes were randomized to Roux-en-Y gastric bypass (RYGB) or nonsurgical diabetes/weight management, and fasting plasma proteome and metabolome were assayed up to 3 years. RYGB caused greater improvement in HbA1c, which was mediated by growth hormone receptor (GHR). GHRâ€™s mediation is more significant than clinical mediators, including BMI. GHR decreases at 3 months postoperatively alongside increased insulin-like growth factor binding proteins IGFBP1/BP2; plasma GH increased at 1 year. Experimental validation indicates (1) hepatic GHR expression decreases in post-bariatric rats; (2) GHR knockdown in primary hepatocytes decreases gluconeogenic gene expression and glucose production. Thus, RYGB may induce resistance to diabetogenic effects of GH signaling."\n!Series_overall_design\t"Randomized controlled trial with n=19 assigned to RYGB or DWM, measured over time."\n!Series_overall_design\t""\n!Series_overall_design\t"Raw data were not provided by SomaLogic."\n\nSample characteristics dictionary (from "!Sample_characteristics_ch1", converted to a Python dictionary that stores the unique values for each field):\n{0: [\'tissue: plasma\'], 1: [\'acrostic: FENCE\', \'acrostic: HUMOR\', \'acrostic: VIDEO\', \'acrostic: RADIO\', \'acrostic: ELBOW\', \'acrostic: HUMAN\', \'acrostic: MAGIC\', \'acrostic: DAISY\', \'acrostic: VISTA\', \'acrostic: ORBIT\', \'acrostic: RODEO\', \'acrostic: NURSE\', \'acrostic: RELIC\', \'acrostic: EAGLE\', \'acrostic: VENUE\', \'acrostic: PATCH\', \'acrostic: FLAGS\', \'acrostic: POETS\', \'acrostic: LILAC\', \'acrostic: JUROR\', \'acrostic: IVORY\', \'acrostic: LASSO\', \'acrostic: FOGGY\', \'acrostic: REMIX\', \'acrostic: IMAGE\', \'acrostic: WALTZ\', \'acrostic: FILMS\', \'acrostic: TOPAZ\', \'acrostic: INTRO\', \'acrostic: KAYAK\'], 2: [\'group: RYGB\', \'group: DWM\'], 3: [\'height (cm): 182\', \'height (cm): 164\', \'height (cm): 17 ...

# %%
is_gene_availabe = True
trait_row = 2
age_row = None
gender_row = None

trait_type = 'binary'

# %%
is_available = is_gene_availabe and (trait_row is not None)
if not is_available:
    save_cohort_info(cohort, JSON_PATH, is_available)
    print("This cohort is not usable. Please skip the following steps and jump to the next accession number.")

# %%
# Verify and use the functions generated by GPT

def convert_trait(tissue_colum):
    """
    Convert histology string to a binary value represent Age_related Macular Degeration.
    Presence of Age_related Macular Degeration is represented as 1, absence as 0.
    Unknown or non-breast cancer histologies are converted to None.
    """
    Tissue = ['tissue: macular rpe-choroid', 'tissue: extramacular rpe-choroid', 'tissue: macular retina', 'tissue: extramacular Retina']
    tissue = tissue_colum.split(':')[1].lower()
    if tissue in Tissue:
        return 1
    elif tissue == 'unknown':
        return None
    else:
        return 0

def convert_age(age_string):
    """
    Convert age string to a continuous numerical value.
    Unknown values are converted to None.
    """
    if age_string.lower() == 'n.a.':
        return None
    try:
        # Extract age as an integer from the string
        age = int(age_string.split(': ')[1])
        return age
    except (ValueError, IndexError):
        # In case of any format error or unexpected string structure
        return None



# It sometimes maps 'female' to 0, and sometimes 1. Does it matter?
def convert_gender(gender_string):
    """
    Convert gender string to a binary value.
    'female' is represented as 1, 'male' as 0.
    Unknown values are converted to None.
    """
    if gender_string.lower() == 'gender: female':
        return 1
    elif gender_string.lower() == 'gender: male':
        return 0
    else:
        return None

# %%
selected_clinical_data = geo_select_clinical_features(clinical_data, TRAIT, trait_row, convert_trait, age_row=age_row,
                                                      convert_age=convert_age, gender_row=gender_row,
                                                      convert_gender=convert_gender)
selected_clinical_data.head()
# Out:
# C:\Users\jacob\AppData\Local\Temp\ipykernel_47240\4263505135.py:344: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   clinical_df = clinical_df.applymap(convert_fn)
#                 GSM3463033  GSM3463034  GSM3463035  GSM3463036  GSM3463037  \
# Metabolic-Rate           0           0           0           0           0
#
#                 GSM3463038  GSM3463039  GSM3463040  GSM3463041  GSM3463042  \
# Metabolic-Rate           0           0           0           0           0
#
#                 ...  GSM3463182  GSM3463183  GSM3463184  GSM3463185  \
# Metabolic-Rate  ...           0           0           0           0
#
#                 GSM3463186  GSM3463187  GSM3463188  GSM3463189  GSM3463190  \
# Metabolic-Rate           0           0           0           0           0
#
#                 GSM3463191
# Metabolic-Rate           0
#
# [1 rows x 159 columns]

# %%
genetic_data = get_genetic_data(matrix_file)
genetic_data.head()
# Out:
#           GSM3463033  GSM3463034  GSM3463035  GSM3463036  GSM3463037  \
# ID
# SL000002   13.353767   13.314073   13.037066   13.467071   13.743982
# SL000003   11.594838   11.498849   11.383002   11.049781   11.760886
# SL000004   11.517030   12.007378   11.179971   12.579693   10.563959
# SL000006   10.058262   10.914834   10.465464    9.876210    9.738937
# SL000007    9.404503    9.763544    9.640787    9.290710    9.262095
#
#           GSM3463038  GSM3463039  GSM3463040  GSM3463041  GSM3463042  ...  \
# ID                                                                    ...
# SL000002   13.283956   13.559986   13.393645   13.554769   13.384473  ...
# SL000003   11.194264   11.446721   11.294736   10.763212   11.248521  ...
# SL000004   11.567956    9.698531   11.462042   11.183945   11.506853  ...
# SL000006   10.502235    8.453682   10.454813   11.166351   10.608255  ...
# SL000007    9.611578    9.391888    9.625526    9.415319    9.605480  ...
#
#           GSM3463182  GSM3463183  GSM3463184  GSM3463185  GSM3463186  \
# ID
# SL000002   13.409497   13.451417   13.629573   13.523550   13.219138
# SL000003   11.334944   11.552525   11.246800   11.424376   11.652397
# SL000004    9.555548   11.171990   11.911017   11.922770   13.300967
# SL000006    9.484017    9.386078    9.847527    9.279146   11.203715
# SL000007    9.526108    9.492855    9.425216    9.221587   10.192786
#
#           GSM3463187  GSM3463188  GSM3463189  GSM3463190  GSM3463191
# ID
# SL000002   13.398129   13.171724   13.342797   13.582977   13.217231
# SL000003   11.515355   11.472285   10.993505   11.193094   11.613743
# SL000004   10.811937   12.535105   14.170582   10.949900   11.566054
# SL000006   10.643405   10.806308   11.071328   10.066224    9.410663
# SL000007    9.375691    9.622052    9.551708    9.072803    9.832415
#
# [5 rows x 159 columns]

# %%
gene_row_ids = genetic_data.index[:20].tolist()
gene_row_ids
# Out:
# ['SL000002',
#  'SL000003',
#  'SL000004',
#  'SL000006',
#  'SL000007',
#  'SL000009',
#  'SL000017',
#  'SL000019',
#  'SL000020',
#  'SL000021',
#  'SL000022',
#  'SL000024',
#  'SL000027',
#  'SL000038',
#  'SL000039',
#  'SL000045',
#  'SL000047',
#  'SL000048',
#  'SL000049',
#  'SL000051']

# %%
f'''
Below are the row headers of a gene expression dataset in GEO. Based on your biomedical knowledge, are they human gene symbols, or are they some other identifiers that need to be mapped to gene symbols? Your answer should be concluded by starting a new line and strictly following this format:
requires_gene_mapping = (True or False)

Row headers:
{gene_row_ids}
'''
# Out:
# "\nBelow are the row headers of a gene expression dataset in GEO. Based on your biomedical knowledge, are they human gene symbols, or are they some other identifiers that need to be mapped to gene symbols? Your answer should be concluded by starting a new line and strictly following this format:\nrequires_gene_mapping = (True or False)\n\nRow headers:\n['SL000002', 'SL000003', 'SL000004', 'SL000006', 'SL000007', 'SL000009', 'SL000017', 'SL000019', 'SL000020', 'SL000021', 'SL000022', 'SL000024', 'SL000027', 'SL000038', 'SL000039', 'SL000045', 'SL000047', 'SL000048', 'SL000049', 'SL000051']\n"

# %%
requires_gene_mapping = False

# %%
if requires_gene_mapping:
    gene_annotation = get_gene_annotation(soft_file)
    gene_annotation_summary = preview_df(gene_annotation)
    print(gene_annotation_summary)

# %%
if requires_gene_mapping:
    print(f'''
    As a biomedical research team, we are analyzing a gene expression dataset, and find that its row headers are some identifiers related to genes:
    {gene_row_ids}
    To get the mapping from those identifiers to actual gene symbols, we extracted the gene annotation data from a series in the GEO database, and saved it to a Python dictionary. Please read the dictionary, and decide which key stores the identifiers, and which key stores the gene symbols. Please strictly follow this format in your answer:
    identifier_key = 'key_name1'
    gene_symbol_key = 'key_name2'

    Gene annotation dictionary:
    {gene_annotation_summary}
    ''')

# %%
if requires_gene_mapping:
    identifier_key = 'ID'
    gene_symbol_key = 'UCSC_RefGene_Name'
    gene_mapping = get_gene_mapping(gene_annotation, identifier_key, gene_symbol_key)
    genetic_data = apply_gene_mapping(genetic_data, gene_mapping)

# %%
if NORMALIZE_GENE:
    genetic_data = normalize_gene_symbols_in_index(genetic_data)
# Out:
# 1000 input query terms found no hit:	['SL000002', 'SL000003', 'SL000004', 'SL000006', 'SL000007', 'SL000009', 'SL000017', 'SL000019', 'SL
# 129 input query terms found no hit:	['SL010617', 'SL010619', 'SL010830', 'SL010927', 'SL010928', 'SL010973', 'SL011049', 'SL011068', 'SL

# %%
merged_data = geo_merge_clinical_genetic_data(selected_clinical_data, genetic_data)
# The preprocessing runs through, which means is_available should be True
is_available = True

# %%
print(f"The merged dataset contains {len(merged_data)} samples.")
# Out:
# The merged dataset contains 159 samples.

# %%
is_trait_biased, merged_data = judge_and_remove_biased_features(merged_data, TRAIT, trait_type=trait_type)
is_trait_biased
# Out:
# For the feature 'Metabolic-Rate', the least common label is '0.0' with 159 occurrences. This represents 100.00% of the dataset.
# The distribution of the feature 'Metabolic-Rate' in this dataset is severely biased.
# True

# %%
if is_available:
    save_cohort_info(cohort, JSON_PATH, is_available, is_trait_biased, merged_data, note='')
else:
    save_cohort_info(cohort, JSON_PATH, is_available)
# Out:
# A new JSON file was created at: /Users/jacob/Documents/Output\Jake\Metabolic-Rate\cohort_info.json

# %%
merged_data.head()
if not is_trait_biased:
    merged_data.to_csv(os.path.join(OUTPUT_DIR, cohort + '.csv'), index=False)

# %%
# Check the information of usable cohorts
best_cohort, ranked_df = filter_and_rank_cohorts(JSON_PATH)
ranked_df
# Out:
# Empty DataFrame
# Columns: [cohort_id, is_usable, is_available, is_biased, has_age, has_gender, sample_size, note]
# Index: []

# %%
# If both age and gender have available cohorts, select 'age' as the condition.
condition = 'Age'
filter_column = 'has_' + condition.lower()

condition_best_cohort, condition_ranked_df = filter_and_rank_cohorts(JSON_PATH, filter_column)
condition_best_cohort

# %%
condition_ranked_df.head()
# Out:
# Empty DataFrame
# Columns: [cohort_id, is_usable, is_available, is_biased, has_age, has_gender, sample_size, note]
# Index: []
